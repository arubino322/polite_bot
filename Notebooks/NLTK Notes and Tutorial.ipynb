# %%
from matplotlib import pyplot as plt
import numpy as np

# %matplotlib inline

# %% [markdown]
# # Lesson 1 - Tokenizing words and sentences

# %% [markdown]
# NLTK Notes:
# - Tokenizing: word tokenizers and sentence tokenizers
#     - groups corpus by words and sentences
# - Lexicon and Corporas
#      - Lexicon: words and their meanings (like a dictionary)
#      - Corporas: body of text, e.g., medical journals, presidential speeches, English language

# %%
from nltk.tokenize import sent_tokenize, word_tokenize

# %%
example_text = """Hello Mr. Smith, how are you doing today? 
                    The weather is great and Python is awesome .The sky is pinkish blue. 
                    You should not eat cardboard"""

print(sent_tokenize(example_text))
# Out:
# ['Hello Mr. Smith, how are you doing today?', 'The weather is great and Python is awesome .The sky is pinkish blue.', 'You should not eat cardboard']

# %%
print(word_tokenize(example_text))
# Out:
# ['Hello', 'Mr.', 'Smith', ',', 'how', 'are', 'you', 'doing', 'today', '?', 'The', 'weather', 'is', 'great', 'and', 'Python', 'is', 'awesome', '.The', 'sky', 'is', 'pinkish', 'blue', '.', 'You', 'should', 'not', 'eat', 'cardboard']

# %% [markdown]
# # Lesson 2 - Stop words

# %%
from nltk.corpus import stopwords

# %%
example_sentence = "This is an example showing off stop word filtration"

stop_words = set(stopwords.words("english"))
print(stop_words)
# Out:
# set([u'all', u'just', u"don't", u'being', u'over', u'both', u'through', u'yourselves', u'its', u'before', u'o', u'don', u'hadn', u'herself', u'll', u'had', u'should', u'to', u'only', u'won', u'under', u'ours', u'has', u"should've", u"haven't", u'do', u'them', u'his', u'very', u"you've", u'they', u'not', u'during', u'now', u'him', u'nor', u"wasn't", u'd', u'did', u'didn', u'this', u'she', u'each', u'further', u"won't", u'where', u"mustn't", u"isn't", u'few', u'because', u"you'd", u'doing', u'some', u'hasn', u"hasn't", u'are', u'our', u'ourselves', u'out', u'what', u'for', u"needn't", u'below', u're', u'does', u"shouldn't", u'above', u'between', u'mustn', u't', u'be', u'we', u'who', u"mightn't", u"doesn't", u'were', u'here', u'shouldn', u'hers', u"aren't", u'by', u'on', u'about', u'couldn', u'of', u"wouldn't", u'against', u's', u'isn', u'or', u'own', u'into', u'yourself', u'down', u"hadn't", u'mightn', u"couldn't", u'wasn', u'your', u"you're", u'from', u'her', u'their', u'aren', u"it's", u'there', u'been', u'whom', u'too', u'wouldn', u'themselves', u'weren', u'was', u'until', u'more', u'himself', u'that', u"didn't", u'but', u"that'll", u'with', u'than', u'those', u'he', u'me', u'myself', u'ma', u"weren't", u'these', u'up', u'will', u'while', u'ain', u'can', u'theirs', u'my', u'and', u've', u'then', u'is', u'am', u'it', u'doesn', u'an', u'as', u'itself', u'at', u'have', u'in', u'any', u'if', u'again', u'no', u'when', u'same', u'how', u'other', u'which', u'you', u"shan't", u'shan', u'needn', u'haven', u'after', u'most', u'such', u'why', u'a', u'off', u'i', u'm', u'yours', u"you'll", u'so', u'y', u"she's", u'the', u'having', u'once'])

# %%
words = word_tokenize(example_sentence)
filtered_sentence = []
for w in words:
    if w not in stop_words:
        filtered_sentence.append(w)

filtered_sentence
# Out:
# ['This', 'example', 'showing', 'stop', 'word', 'filtration']

# %%
# We can do this with list comprehension also
filtered_sentence2 = [w for w in words if not w in stop_words]
filtered_sentence2
# Out:
# ['This', 'example', 'showing', 'stop', 'word', 'filtration']

# %% [markdown]
# # Lesson 3 - Stemming

# %% [markdown]
# - A form of preprocessing
# - Takes the stem of words (written, writing, wrote, write -> stem = writ)
# - We do it b/c there are different variations of words based on stems, but the meaning of the word is unchanged.

# %%
from nltk.stem import PorterStemmer
from nltk.tokenize import word_tokenize

ps = PorterStemmer()

example_words = ["python", "pythoner", "pythoning", "pythoned", "pythonly"]

for w in example_words:
    print(ps.stem(w))
# Out:
# python
# python
# python
# python
# pythonli

# %%
new_text = "It is very import to be pythonly while you are pythoning with python. All pythoners have pythoned poorly at least once."

words = word_tokenize(new_text)

for w in words:
    print(ps.stem(w))
# Out:
# It
# is
# veri
# import
# to
# be
# pythonli
# while
# you
# are
# python
# with
# python
# .
# all
# python
# have
# python
# poorli
# at
# least
# onc
# .

# %% [markdown]
# # Lesson 4 - Part of Speech Tagging

# %% [markdown]
# POS tag list:
#
# - CC	coordinating conjunction
# - CD	cardinal digit
# - DT	determiner
# - EX	existential there (like: "there is" ... think of it like "there exists")
# - FW	foreign word
# - IN	preposition/subordinating conjunction
# - JJ	adjective	'big'
# - JJR	adjective, comparative	'bigger'
# - JJS	adjective, superlative	'biggest'
# - LS	list marker	1)
# - MD	modal	could, will
# - NN	noun, singular 'desk'
# - NNS	noun plural	'desks'
# - NNP	proper noun, singular	'Harrison'
# - NNPS	proper noun, plural	'Americans'
# - PDT	predeterminer	'all the kids'
# - POS	possessive ending	parent's
# - PRP	personal pronoun	I, he, she
# - PRP\$	possessive pronoun	my, his, hers
# - RB	adverb	very, silently,
# - RBR	adverb, comparative	better
# - RBS	adverb, superlative	best
# - RP	particle	give up
# - TO	to	go 'to' the store.
# - UH	interjection	errrrrrrrm
# - VB	verb, base form	take
# - VBD	verb, past tense	took
# - VBG	verb, gerund/present participle	taking
# - VBN	verb, past participle	taken
# - VBP	verb, sing. present, non-3d	take
# - VBZ	verb, 3rd person sing. present	takes
# - WDT	wh-determiner	which
# - WP	wh-pronoun	who, what
# - WP\$	possessive wh-pronoun	whose
# - WRB	wh-abverb	where, when

# %%
import nltk
from nltk.corpus import state_union
from nltk.tokenize import PunktSentenceTokenizer # unsupervised ML tokenizer. sent_tokenizer works the same, but it is pretrained

train_text = state_union.raw("2005-GWBush.txt")
sample_text = state_union.raw("2006-GWBush.txt")

custom_sent_tokenizer = PunktSentenceTokenizer(train_text)

tokenized = custom_sent_tokenizer.tokenize(sample_text)

tokenized[:10]
# Out:
# [u"PRESIDENT GEORGE W. BUSH'S ADDRESS BEFORE A JOINT SESSION OF THE CONGRESS ON THE STATE OF THE UNION\n \nJanuary 31, 2006\n\nTHE PRESIDENT: Thank you all.",
#  u'Mr. Speaker, Vice President Cheney, members of Congress, members of the Supreme Court and diplomatic corps, distinguished guests, and fellow citizens: Today our nation lost a beloved, graceful, courageous woman who called America to its founding ideals and carried on a noble dream.',
#  u'Tonight we are comforted by the hope of a glad reunion with the husband who was taken so long ago, and we are grateful for the good life of Coretta Scott King.',
#  u'(Applause.)',
#  u'President George W. Bush reacts to applause during his State of the Union Address at the Capitol, Tuesday, Jan.',
#  u'31, 2006.',
#  u"White House photo by Eric DraperEvery time I'm invited to this rostrum, I'm humbled by the privilege, and mindful of the history we've seen together.",
#  u'We have gathered under this Capitol dome in moments of national mourning and national achievement.',
#  u'We have served America through one of the most consequential periods of our history -- and it has been my honor to serve with you.',
#  u'In a system of two parties, two chambers, and two elected branches, there will always be differences and debate.']

# %%
def process_content():
    try:
        for i in tokenized:
            words = nltk.word_tokenize(i)
            tagged = nltk.pos_tag(words)
            print(tagged)
    except Exception as e:
        print(str(e))
        
process_content()
# Out:
# [(u'PRESIDENT', 'NNP'), (u'GEORGE', 'NNP'), (u'W.', 'NNP'), (u'BUSH', 'NNP'), (u"'S", 'POS'), (u'ADDRESS', 'NNP'), (u'BEFORE', 'IN'), (u'A', 'NNP'), (u'JOINT', 'NNP'), (u'SESSION', 'NNP'), (u'OF', 'IN'), (u'THE', 'NNP'), (u'CONGRESS', 'NNP'), (u'ON', 'NNP'), (u'THE', 'NNP'), (u'STATE', 'NNP'), (u'OF', 'IN'), (u'THE', 'NNP'), (u'UNION', 'NNP'), (u'January', 'NNP'), (u'31', 'CD'), (u',', ','), (u'2006', 'CD'), (u'THE', 'NNP'), (u'PRESIDENT', 'NNP'), (u':', ':'), (u'Thank', 'NNP'), (u'you', 'PRP'), (u'all', 'DT'), (u'.', '.')]
# [(u'Mr.', 'NNP'), (u'Speaker', 'NNP'), (u',', ','), (u'Vice', 'NNP'), (u'President', 'NNP'), (u'Cheney', 'NNP'), (u',', ','), (u'members', 'NNS'), (u'of', 'IN'), (u'Congress', 'NNP'), (u',', ','), (u'members', 'NNS'), (u'of', 'IN'), (u'the', 'DT'), (u'Supreme', 'NNP'), (u'Court', 'NNP'), (u'and', 'CC'), (u'diplomatic', 'JJ'), (u'corps', 'NN'), (u',', ','), (u'distinguished', 'JJ'), (u'guests', 'NNS'), (u',', ','), (u'and', 'CC'), (u'fellow', 'JJ'), (u'citizens', 'NNS'), (u':', ':'), (u'Today', 'VB'), (u'our', 'PRP$'), (u'nation', 'NN'), (u'lost', 'VBD'), (u'a', 'DT'), (u'beloved', 'VBN'), (u',', ','), (u'graceful', 'JJ'), (u',', ','), (u'courageous', 'JJ'), (u'woman', 'NN'), (u'who', 'WP'), (u'called', 'VBD'), (u'America', 'NNP'), (u'to', 'TO'), (u'its', 'PRP$'), (u'founding', 'NN'), (u'ideals', 'NNS'), (u'and', 'CC'), (u'carried', 'VBD'), (u'on', 'IN'), (u'a', 'DT'), (u'noble', 'JJ'), (u'dream', 'NN'), (u'.', '.')]
# [(u'Tonight', 'NN'), (u'we', 'PRP'), (u'are', 'VBP'), (u'comforted', 'VBN'), (u'by', 'IN'), (u'the', 'DT'), (u'hope', 'NN'), (u'of', 'IN'), (u'a', 'DT'), (u'glad', 'JJ'), (u'reunion', 'NN'), (u'with', 'IN'), (u'the', 'DT'), (u'husband', 'NN'), (u'who', 'WP'), (u'was', 'VBD'), (u'taken', 'VBN'), (u'so', 'RB'), (u'long', 'RB'), (u'ago', 'RB'), (u',', ','), (u'and', 'CC'), (u'we', 'PRP'), (u'are', 'VBP'), (u'grateful', 'JJ'), (u'for', 'IN'), (u'the', 'DT'), (u'good', 'JJ'), (u'life', 'NN'), (u'of', 'IN'), (u'Coretta', 'NNP'), (u'Scott', 'NNP'), (u'King', 'NNP'), (u'.', '.')]
# [(u'(', '('), (u'Applause', 'NNP'), (u'.', '.'), (u')', ')')]
# [(u'President', 'NNP'), (u'George', 'NNP'), (u'W.', 'NNP'), (u'Bush', 'NNP'), (u'reacts', 'VBZ'), (u'to', 'TO'), (u'applause', 'VB'), (u'during', 'IN'), (u'his', 'PRP$'), (u'State', 'NNP'), (u'of', 'IN'), (u'the', 'DT'), (u'Union', 'NNP'), (u'Address', 'NNP'), (u'at', 'IN'), (u'the', 'DT'), (u'Capitol', 'NNP'), (u',', ','), (u'Tuesday', 'NNP'), (u',', ','), (u'Jan', 'NNP'), (u'.', '.')]
# [(u'31', 'CD'), (u',', ','), (u'2006', 'CD'), (u'.', '.')]
# [(u'White', 'NNP'), (u'House', 'NNP'), (u'photo', 'NN'), (u'by', 'IN'), (u'Eric', 'NNP'), (u'DraperEvery', 'NNP'), (u'time', 'NN'), (u'I', 'PRP'), (u"'m", 'VBP'), (u'invited', 'JJ'), (u'to', 'TO'), (u'this', 'DT'), (u'rostrum', 'NN'), (u',', ','), (u'I', 'PRP'), (u"'m", 'VBP'), (u'humbled', 'VBN'), (u'by', 'IN'), (u'the', 'DT'), (u'privilege', 'NN'), (u',', ','), (u'and', 'CC'), (u'mindful', 'NN'), (u'of', 'IN'), (u'the', 'DT'), (u'history', 'NN'), (u'we', 'PRP'), (u"'ve", 'VBP'), (u'seen', 'VBN'), (u'together', 'RB'), (u'.', '.')]
# [(u'We', 'PRP'), (u'have', 'VBP'), (u'gathered', 'VBN'), (u'under', 'IN'), (u'this', 'DT'), (u'Capitol', 'NNP'), (u'dome', 'NN'), (u'in', 'IN'), (u'moments', 'NNS'), (u'of', 'IN'), (u'national', 'JJ'), (u'mourning', 'NN'), (u'and', 'CC'), (u'national', 'JJ'), (u'achievement', 'NN'), (u'.', '.')]
# [(u'We', 'PRP'), (u'have', 'VBP'), (u'served', 'VBN'), (u'America', 'NNP'), (u'through', 'IN'), (u'one', 'CD'), (u'of', 'IN'), (u'the', 'DT'), (u'most', 'RBS'), (u'consequential', 'JJ'), (u'periods', 'NNS'), (u'of', 'IN'), (u'our', 'PRP$'), (u'history', 'NN'), (u'--', ':'), (u'and', 'CC'), (u'it', 'PRP'), (u'has', 'VBZ'), (u'been', 'VBN'), (u'my', 'PRP$'), (u'honor', 'NN'), (u'to', 'TO'), (u'serve', 'VB'), (u'with', 'IN'), (u'you', 'PRP'), (u'.', '.')]
# [(u'In', 'IN'), (u'a', 'DT'), (u'system', 'NN'), (u'of', 'IN'), (u'two', 'CD'), (u'parties', 'NNS'), (u',', ','), (u'two', 'CD'), (u'chambers', 'NNS'), (u',', ','), (u'and', 'CC'), (u'two', 'CD'), (u'elected', 'JJ'), (u'branches', 'NNS'), (u',', ','), (u'there', 'EX'), (u'will', 'MD'), (u'always', 'RB'), (u'be', 'VB'), (u'differences', 'NNS'), (u'and', 'CC'), (u'debate', 'NN'), (u'.', '.')]
# [(u'But', 'CC'), (u'even', 'RB'), (u'tough', 'JJ'), (u'debates', 'NNS'), (u'can', 'MD'), (u'be', 'VB'), (u'conducted', 'VBN'), (u'in', 'IN'), (u'a', 'DT'), (u'civil', 'JJ'), (u'tone', 'NN'), (u',', ','), (u'and', 'CC'), (u'our', 'PRP$'), (u'differences', 'NNS'), (u'can', 'MD'), (u'not', 'RB'), (u'be', 'VB'), (u'allowed', 'VBN'), (u'to', 'TO'), (u'harden', 'VB'), (u'into', 'IN'), (u'anger', 'NN'), (u'.', '.')]
# [(u'To', 'TO'), (u'confront', 'VB'), (u'the', 'DT'), (u'great', 'JJ'), (u'issues', 'NNS'), (u'before', 'IN'), (u'us', 'PRP'), (u',', ','), (u'we', 'PRP'), (u'must', 'MD'), (u'act', 'VB'), (u'in', 'IN'), (u'a', 'DT'), (u'spirit', 'NN'), (u'of', 'IN'), (u'goodwill', 'NN'), (u'and', 'CC'), (u'respect', 'NN'), (u'for', 'IN'), (u'one', 'CD'), (u'another', 'DT'), (u'--', ':'), (u'and', 'CC'), (u'I', 'PRP'), (u'will', 'MD'), (u'do', 'VB'), (u'my', 'PRP$'), (u'part', 'NN'), (u'.', '.')]
# [(u'Tonight', 'NNP'), (u'the', 'DT'), (u'state', 'NN'), (u'of', 'IN'), (u'our', 'PRP$'), (u'Union', 'NNP'), (u'is', 'VBZ'), (u'strong', 'JJ'), (u'--', ':'), (u'and', 'CC'), (u'together', 'RB'), (u'we', 'PRP'), (u'will', 'MD'), (u'make', 'VB'), (u'it', 'PRP'), (u'stronger', 'JJR'), (u'.', '.')]
# [(u'(', '('), (u'Applause', 'NNP'), (u'.', '.'), (u')', ')')]
# [(u'In', 'IN'), (u'this', 'DT'), (u'decisive', 'JJ'), (u'year', 'NN'), (u',', ','), (u'you', 'PRP'), (u'and', 'CC'), (u'I', 'PRP'), (u'will', 'MD'), (u'make', 'VB'), (u'choices', 'NNS'), (u'that', 'WDT'), (u'determine', 'VBP'), (u'both', 'DT'), (u'the', 'DT'), (u'future', 'NN'), (u'and', 'CC'), (u'the', 'DT'), (u'character', 'NN'), (u'of', 'IN'), (u'our', 'PRP$'), (u'country', 'NN'), (u'.', '.')]
# [(u'We', 'PRP'), (u'will', 'MD'), (u'choose', 'VB'), (u'to', 'TO'), (u'act', 'VB'), (u'confidently', 'RB'), (u'in', 'IN'), (u'pursuing', 'VBG'), (u'the', 'DT'), (u'enemies', 'NNS'), (u'of', 'IN'), (u'freedom', 'NN'), (u'--', ':'), (u'or', 'CC'), (u'retreat', 'NN'), (u'from', 'IN'), (u'our', 'PRP$'), (u'duties', 'NNS'), (u'in', 'IN'), (u'the', 'DT'), (u'hope', 'NN'), (u'of', 'IN'), (u'an', 'DT'), (u'easier', 'JJR'), (u'life', 'NN'), (u'.', '.')]
# [(u'We', 'PRP'), (u'will', 'MD'), (u'choose', 'VB'), (u'to', 'TO'), (u'build', 'VB'), (u'our', 'PRP$'), (u'prosperity', 'NN'), (u'by', 'IN'), (u'leading', 'VBG'), (u'the', 'DT'), (u'world', 'NN'), (u'economy', 'NN'), (u'--', ':'), (u'or', 'CC'), (u'shut', 'VB'), (u'ourselves', 'PRP'), (u'off', 'RP'), (u'from', 'IN'), (u'trade', 'NN'), (u'and', 'CC'), (u'opportunity', 'NN'), (u'.', '.')]
# [(u'In', 'IN'), (u'a', 'DT'), (u'complex', 'JJ'), (u'and', 'CC'), (u'challenging', 'JJ'), (u'time', 'NN'), (u',', ','), (u'the', 'DT'), (u'road', 'NN'), (u'of', 'IN'), (u'isolationism', 'NN'), (u'and', 'CC'), (u'protectionism', 'NN'), (u'may', 'MD'), (u'seem', 'VB'), (u'broad', 'JJ'), (u'and', 'CC'), (u'inviting', 'NN'), (u'--', ':'), (u'yet', 'CC'), (u'it', 'PRP'), (u'ends', 'VBZ'), (u'in', 'IN'), (u'danger', 'NN'), (u'and', 'CC'), (u'decline', 'NN'), (u'.', '.')]
# [(u'The', 'DT'), (u'only', 'JJ'), (u'way', 'NN'), (u'to', 'TO'), (u'protect', 'VB'), (u'our', 'PRP$'), (u'people', 'NNS'), (u',', ','), (u'the', 'DT'), (u'only', 'JJ'), (u'way', 'NN'), (u'to', 'TO'), (u'secure', 'VB'), (u'the', 'DT'), (u'peace', 'NN'), (u',', ','), (u'the', 'DT'), (u'only', 'JJ'), (u'way', 'NN'), (u'to', 'TO'), (u'control', 'VB'), (u'our', 'PRP$'), (u'destiny', 'NN'), (u'is', 'VBZ'), (u'by', 'IN'), (u'our', 'PRP$'), (u'leadership', 'NN'), (u'--', ':'), (u'so', 'IN'), (u'the', 'DT'), (u'United', 'NNP'), (u'States', 'NNPS'), (u'of', 'IN'), (u'America', 'NNP'), (u'will', 'MD'), (u'continue', 'VB'), (u'to', 'TO'), (u'lead', 'VB'), (u'.', '.')]
# [(u'(', '('), (u'Applause', 'NNP'), (u'.', '.'), (u')', ')')]
# [(u'Abroad', 'RB'), (u',', ','), (u'our', 'PRP$'), (u'nation', 'NN'), (u'is', 'VBZ'), (u'committed', 'VBN'), (u'to', 'TO'), (u'an', 'DT'), (u'historic', 'JJ'), (u',', ','), (u'long-term', 'JJ'), (u'goal', 'NN'), (u'--', ':'), (u'we', 'PRP'), (u'seek', 'VBP'), (u'the', 'DT'), (u'end', 'NN'), (u'of', 'IN'), (u'tyranny', 'NN'), (u'in', 'IN'), (u'our', 'PRP$'), (u'world', 'NN'), (u'.', '.')]
# [(u'Some', 'DT'), (u'dismiss', 'VBP'), (u'that', 'DT'), (u'goal', 'NN'), (u'as', 'IN'), (u'misguided', 'JJ'), (u'idealism', 'NN'), (u'.', '.')]
# [(u'In', 'IN'), (u'reality', 'NN'), (u',', ','), (u'the', 'DT'), (u'future', 'JJ'), (u'security', 'NN'), (u'of', 'IN'), (u'America', 'NNP'), (u'depends', 'VBZ'), (u'on', 'IN'), (u'it', 'PRP'), (u'.', '.')]
# [(u'On', 'IN'), (u'September', 'NNP'), (u'the', 'DT'), (u'11th', 'CD'), (u',', ','), (u'2001', 'CD'), (u',', ','), (u'we', 'PRP'), (u'found', 'VBD'), (u'that', 'IN'), (u'problems', 'NNS'), (u'originating', 'VBG'), (u'in', 'IN'), (u'a', 'DT'), (u'failed', 'JJ'), (u'and', 'CC'), (u'oppressive', 'JJ'), (u'state', 'NN'), (u'7,000', 'CD'), (u'miles', 'NNS'), (u'away', 'RB'), (u'could', 'MD'), (u'bring', 'VB'), (u'murder', 'NN'), (u'and', 'CC'), (u'destruction', 'NN'), (u'to', 'TO'), (u'our', 'PRP$'), (u'country', 'NN'), (u'.', '.')]
# [(u'Dictatorships', 'NNP'), (u'shelter', 'NN'), (u'terrorists', 'NNS'), (u',', ','), (u'and', 'CC'), (u'feed', 'VB'), (u'resentment', 'NN'), (u'and', 'CC'), (u'radicalism', 'NN'), (u',', ','), (u'and', 'CC'), (u'seek', 'JJ'), (u'weapons', 'NNS'), (u'of', 'IN'), (u'mass', 'NN'), (u'destruction', 'NN'), (u'.', '.')]
# [(u'Democracies', 'NNS'), (u'replace', 'VB'), (u'resentment', 'NN'), (u'with', 'IN'), (u'hope', 'NN'), (u',', ','), (u'respect', 'VB'), (u'the', 'DT'), (u'rights', 'NNS'), (u'of', 'IN'), (u'their', 'PRP$'), (u'citizens', 'NNS'), (u'and', 'CC'), (u'their', 'PRP$'), (u'neighbors', 'NNS'), (u',', ','), (u'and', 'CC'), (u'join', 'VB'), (u'the', 'DT'), (u'fight', 'NN'), (u'against', 'IN'), (u'terror', 'NN'), (u'.', '.')]
# [(u'Every', 'DT'), (u'step', 'NN'), (u'toward', 'IN'), (u'freedom', 'NN'), (u'in', 'IN'), (u'the', 'DT'), (u'world', 'NN'), (u'makes', 'VBZ'), (u'our', 'PRP$'), (u'country', 'NN'), (u'safer', 'NN'), (u'--', ':'), (u'so', 'IN'), (u'we', 'PRP'), (u'will', 'MD'), (u'act', 'VB'), (u'boldly', 'RB'), (u'in', 'IN'), (u'freedom', 'NN'), (u"'s", 'POS'), (u'cause', 'NN'), (u'.', '.')]
# [(u'(', '('), (u'Applause', 'NNP'), (u'.', '.'), (u')', ')')]
# [(u'Far', 'RB'), (u'from', 'IN'), (u'being', 'VBG'), (u'a', 'DT'), (u'hopeless', 'NN'), (u'dream', 'NN'), (u',', ','), (u'the', 'DT'), (u'advance', 'NN'), (u'of', 'IN'), (u'freedom', 'NN'), (u'is', 'VBZ'), (u'the', 'DT'), (u'great', 'JJ'), (u'story', 'NN'), (u'of', 'IN'), (u'our', 'PRP$'), (u'time', 'NN'), (u'.', '.')]
# [(u'In', 'IN'), (u'1945', 'CD'), (u',', ','), (u'there', 'EX'), (u'were', 'VBD'), (u'about', 'RB'), (u'two', 'CD'), (u'dozen', 'NN'), (u'lonely', 'RB'), (u'democracies', 'VBZ'), (u'in', 'IN'), (u'the', 'DT'), (u'world', 'NN'), (u'.', '.')]
# [(u'Today', 'NN'), (u',', ','), (u'there', 'EX'), (u'are', 'VBP'), (u'122', 'CD'), (u'.', '.')]
# [(u'And', 'CC'), (u'we', 'PRP'), (u"'re", 'VBP'), (u'writing', 'VBG'), (u'a', 'DT'), (u'new', 'JJ'), (u'chapter', 'NN'), (u'in', 'IN'), (u'the', 'DT'), (u'story', 'NN'), (u'of', 'IN'), (u'self-government', 'JJ'), (u'--', ':'), (u'with', 'IN'), (u'women', 'NNS'), (u'lining', 'VBG'), (u'up', 'RP'), (u'to', 'TO'), (u'vote', 'VB'), (u'in', 'IN'), (u'Afghanistan', 'NNP'), (u',', ','), (u'and', 'CC'), (u'millions', 'NNS'), (u'of', 'IN'), (u'Iraqis', 'NNP'), (u'marking', 'VBG'), (u'their', 'PRP$'), (u'liberty', 'NN'), (u'with', 'IN'), (u'purple', 'JJ'), (u'ink', 'NN'), (u',', ','), (u'and', 'CC'), (u'men', 'NNS'), (u'and', 'CC'), (u'women', 'NNS'), (u'from', 'IN'), (u'Lebanon', 'NNP'), (u'to', 'TO'), (u'Egypt', 'NNP'), (u'debating', 'VBG'), (u'the', 'DT'), (u'rights', 'NNS'), (u'of', 'IN'), (u'individuals', 'NNS'), (u'and', 'CC'), (u'the', 'DT'), (u'necessity', 'NN'), (u'of', 'IN'), (u'freedom', 'NN'), (u'.', '.')]
# [(u'At', 'IN'), (u'the', 'DT'), (u'start', 'NN'), (u'of', 'IN'), (u'2006', 'CD'), (u',', ','), (u'more', 'JJR'), (u'than', 'IN'), (u'half', 'PDT'), (u'the', 'DT'), (u'people', 'NNS'), (u'of', 'IN'), (u'our', 'PRP$'), (u'world', 'NN'), (u'live', 'VBP'), (u'in', 'IN'), (u'democratic', 'JJ'), (u'nations', 'NNS'), (u'.', '.')]
# [(u'And', 'CC'), (u'we', 'PRP'), (u'do', 'VBP'), (u'not', 'RB'), (u'forget', 'VB'), (u'the', 'DT'), (u'other', 'JJ'), (u'half', 'NN'), (u'--', ':'), (u'in', 'IN'), (u'places', 'NNS'), (u'like', 'IN'), (u'Syria', 'NNP'), (u'and', 'CC'), (u'Burma', 'NNP'), (u',', ','), (u'Zimbabwe', 'NNP'), (u',', ','), (u'North', 'NNP'), (u'Korea', 'NNP'), (u',', ','), (u'and', 'CC'), (u'Iran', 'NNP'), (u'--', ':'), (u'because', 'IN'), (u'the', 'DT'), (u'demands', 'NNS'), (u'of', 'IN'), (u'justice', 'NN'), (u',', ','), (u'and', 'CC'), (u'the', 'DT'), (u'peace', 'NN'), (u'of', 'IN'), (u'this', 'DT'), (u'world', 'NN'), (u',', ','), (u'require', 'VBP'), (u'their', 'PRP$'), (u'freedom', 'NN'), (u',', ','), (u'as', 'RB'), (u'well', 'RB'), (u'.', '.')]
# [(u'(', '('), (u'Applause', 'NNP'), (u'.', '.'), (u')', ')')]
# [(u'President', 'NNP'), (u'George', 'NNP'), (u'W.', 'NNP'), (u'Bush', 'NNP'), (u'delivers', 'VBZ'), (u'his', 'PRP$'), (u'State', 'NN'), (u'of', 'IN'), (u'the', 'DT'), (u'Union', 'NNP'), (u'Address', 'NNP'), (u'at', 'IN'), (u'the', 'DT'), (u'Capitol', 'NNP'), (u',', ','), (u'Tuesday', 'NNP'), (u',', ','), (u'Jan', 'NNP'), (u'.', '.')]
# [(u'31', 'CD'), (u',', ','), (u'2006', 'CD'), (u'.', '.')]
# [(u'White', 'NNP'), (u'House', 'NNP'), (u'photo', 'NN'), (u'by', 'IN'), (u'Eric', 'NNP'), (u'Draper', 'NNP'), (u'No', 'NNP'), (u'one', 'NN'), (u'can', 'MD'), (u'deny', 'VB'), (u'the', 'DT'), (u'success', 'NN'), (u'of', 'IN'), (u'freedom', 'NN'), (u',', ','), (u'but', 'CC'), (u'some', 'DT'), (u'men', 'NNS'), (u'rage', 'VB'), (u'and', 'CC'), (u'fight', 'VB'), (u'against', 'IN'), (u'it', 'PRP'), (u'.', '.')]
# [(u'And', 'CC'), (u'one', 'CD'), (u'of', 'IN'), (u'the', 'DT'), (u'main', 'JJ'), (u'sources', 'NNS'), (u'of', 'IN'), (u'reaction', 'NN'), (u'and', 'CC'), (u'opposition', 'NN'), (u'is', 'VBZ'), (u'radical', 'JJ'), (u'Islam', 'NNP'), (u'--', ':'), (u'the', 'DT'), (u'perversion', 'NN'), (u'by', 'IN'), (u'a', 'DT'), (u'few', 'JJ'), (u'of', 'IN'), (u'a', 'DT'), (u'noble', 'JJ'), (u'faith', 'NN'), (u'into', 'IN'), (u'an', 'DT'), (u'ideology', 'NN'), (u'of', 'IN'), (u'terror', 'NN'), (u'and', 'CC'), (u'death', 'NN'), (u'.', '.')]
# [(u'Terrorists', 'NNS'), (u'like', 'IN'), (u'bin', 'NN'), (u'Laden', 'NNP'), (u'are', 'VBP'), (u'serious', 'JJ'), (u'about', 'IN'), (u'mass', 'NN'), (u'murder', 'NN'), (u'--', ':'), (u'and', 'CC'), (u'all', 'DT'), (u'of', 'IN'), (u'us', 'PRP'), (u'must', 'MD'), (u'take', 'VB'), (u'their', 'PRP$'), (u'declared', 'JJ'), (u'intentions', 'NNS'), (u'seriously', 'RB'), (u'.', '.')]
# [(u'They', 'PRP'), (u'seek', 'VBP'), (u'to', 'TO'), (u'impose', 'VB'), (u'a', 'DT'), (u'heartless', 'NN'), (u'system', 'NN'), (u'of', 'IN'), (u'totalitarian', 'JJ'), (u'control', 'NN'), (u'throughout', 'IN'), (u'the', 'DT'), (u'Middle', 'NNP'), (u'East', 'NNP'), (u',', ','), (u'and', 'CC'), (u'arm', 'NN'), (u'themselves', 'PRP'), (u'with', 'IN'), (u'weapons', 'NNS'), (u'of', 'IN'), (u'mass', 'NN'), (u'murder', 'NN'), (u'.', '.')]
# [(u'Their', 'PRP$'), (u'aim', 'NN'), (u'is', 'VBZ'), (u'to', 'TO'), (u'seize', 'VB'), (u'power', 'NN'), (u'in', 'IN'), (u'Iraq', 'NNP'), (u',', ','), (u'and', 'CC'), (u'use', 'VB'), (u'it', 'PRP'), (u'as', 'IN'), (u'a', 'DT'), (u'safe', 'JJ'), (u'haven', 'NN'), (u'to', 'TO'), (u'launch', 'VB'), (u'attacks', 'NNS'), (u'against', 'IN'), (u'America', 'NNP'), (u'and', 'CC'), (u'the', 'DT'), (u'world', 'NN'), (u'.', '.')]
# [(u'Lacking', 'VBG'), (u'the', 'DT'), (u'military', 'JJ'), (u'strength', 'NN'), (u'to', 'TO'), (u'challenge', 'VB'), (u'us', 'PRP'), (u'directly', 'RB'), (u',', ','), (u'the', 'DT'), (u'terrorists', 'NNS'), (u'have', 'VBP'), (u'chosen', 'VBN'), (u'the', 'DT'), (u'weapon', 'NN'), (u'of', 'IN'), (u'fear', 'NN'), (u'.', '.')]
# [(u'When', 'WRB'), (u'they', 'PRP'), (u'murder', 'VBP'), (u'children', 'NNS'), (u'at', 'IN'), (u'a', 'DT'), (u'school', 'NN'), (u'in', 'IN'), (u'Beslan', 'NNP'), (u',', ','), (u'or', 'CC'), (u'blow', 'VB'), (u'up', 'RP'), (u'commuters', 'NNS'), (u'in', 'IN'), (u'London', 'NNP'), (u',', ','), (u'or', 'CC'), (u'behead', 'VB'), (u'a', 'DT'), (u'bound', 'NN'), (u'captive', 'NN'), (u',', ','), (u'the', 'DT'), (u'terrorists', 'NNS'), (u'hope', 'VBP'), (u'these', 'DT'), (u'horrors', 'NNS'), (u'will', 'MD'), (u'break', 'VB'), (u'our', 'PRP$'), (u'will', 'MD'), (u',', ','), (u'allowing', 'VBG'), (u'the', 'DT'), (u'violent', 'NN'), (u'to', 'TO'), (u'inherit', 'VB'), (u'the', 'DT'), (u'Earth', 'NNP'), (u'.', '.')]
# [(u'But', 'CC'), (u'they', 'PRP'), (u'have', 'VBP'), (u'miscalculated', 'VBN'), (u':', ':'), (u'We', 'PRP'), (u'love', 'VBP'), (u'our', 'PRP$'), (u'freedom', 'NN'), (u',', ','), (u'and', 'CC'), (u'we', 'PRP'), (u'will', 'MD'), (u'fight', 'VB'), (u'to', 'TO'), (u'keep', 'VB'), (u'it', 'PRP'), (u'.', '.')]
# [(u'(', '('), (u'Applause', 'NNP'), (u'.', '.'), (u')', ')')]
# [(u'In', 'IN'), (u'a', 'DT'), (u'time', 'NN'), (u'of', 'IN'), (u'testing', 'VBG'), (u',', ','), (u'we', 'PRP'), (u'can', 'MD'), (u'not', 'RB'), (u'find', 'VB'), (u'security', 'NN'), (u'by', 'IN'), (u'abandoning', 'VBG'), (u'our', 'PRP$'), (u'commitments', 'NNS'), (u'and', 'CC'), (u'retreating', 'VBG'), (u'within', 'IN'), (u'our', 'PRP$'), (u'borders', 'NNS'), (u'.', '.')]
# [(u'If', 'IN'), (u'we', 'PRP'), (u'were', 'VBD'), (u'to', 'TO'), (u'leave', 'VB'), (u'these', 'DT'), (u'vicious', 'JJ'), (u'attackers', 'NNS'), (u'alone', 'RB'), (u',', ','), (u'they', 'PRP'), (u'would', 'MD'), (u'not', 'RB'), (u'leave', 'VB'), (u'us', 'PRP'), (u'alone', 'RB'), (u'.', '.')]
# [(u'They', 'PRP'), (u'would', 'MD'), (u'simply', 'RB'), (u'move', 'VB'), (u'the', 'DT'), (u'battlefield', 'NN'), (u'to', 'TO'), (u'our', 'PRP$'), (u'own', 'JJ'), (u'shores', 'NNS'), (u'.', '.')]
# [(u'There', 'EX'), (u'is', 'VBZ'), (u'no', 'DT'), (u'peace', 'NN'), (u'in', 'IN'), (u'retreat', 'NN'), (u'.', '.')]
# [(u'And', 'CC'), (u'there', 'EX'), (u'is', 'VBZ'), (u'no', 'DT'), (u'honor', 'NN'), (u'in', 'IN'), (u'retreat', 'NN'), (u'.', '.')]
# [(u'By', 'IN'), (u'allowing', 'VBG'), (u'radical', 'JJ'), (u'Islam', 'NNP'), (u'to', 'TO'), (u'work', 'VB'), (u'its', 'PRP$'), (u'will', 'MD'), (u'--', ':'), (u'by', 'IN'), (u'leaving', 'VBG'), (u'an', 'DT'), (u'assaulted', 'JJ'), (u'world', 'NN'), (u'to', 'TO'), (u'fend', 'VB'), (u'for', 'IN'), (u'itself', 'PRP'), (u'--', ':'), (u'we', 'PRP'), (u'would', 'MD'), (u'signal', 'VB'), (u'to', 'TO'), (u'all', 'PDT'), (u'that', 'IN'), (u'we', 'PRP'), (u'no', 'DT'), (u'longer', 'RBR'), (u'believe', 'VBP'), (u'in', 'IN'), (u'our', 'PRP$'), (u'own', 'JJ'), (u'ideals', 'NNS'), (u',', ','), (u'or', 'CC'), (u'even', 'RB'), (u'in', 'IN'), (u'our', 'PRP$'), (u'own', 'JJ'), (u'courage', 'NN'), (u'.', '.')]
# [(u'But', 'CC'), (u'our', 'PRP$'), (u'enemies', 'NNS'), (u'and', 'CC'), (u'our', 'PRP$'), (u'friends', 'NNS'), (u'can', 'MD'), (u'be', 'VB'), (u'certain', 'JJ'), (u':', ':'), (u'The', 'DT'), (u'United', 'NNP'), (u'States', 'NNPS'), (u'will', 'MD'), (u'not', 'RB'), (u'retreat', 'VB'), (u'from', 'IN'), (u'the', 'DT'), (u'world', 'NN'), (u',', ','), (u'and', 'CC'), (u'we', 'PRP'), (u'will', 'MD'), (u'never', 'RB'), (u'surrender', 'VB'), (u'to', 'TO'), (u'evil', 'VB'), (u'.', '.')]
# [(u'(', '('), (u'Applause', 'NNP'), (u'.', '.'), (u')', ')')]
# [(u'America', 'NNP'), (u'rejects', 'VBZ'), (u'the', 'DT'), (u'false', 'JJ'), (u'comfort', 'NN'), (u'of', 'IN'), (u'isolationism', 'NN'), (u'.', '.')]
# [(u'We', 'PRP'), (u'are', 'VBP'), (u'the', 'DT'), (u'nation', 'NN'), (u'that', 'IN'), (u'saved', 'VBD'), (u'liberty', 'NN'), (u'in', 'IN'), (u'Europe', 'NNP'), (u',', ','), (u'and', 'CC'), (u'liberated', 'VBD'), (u'death', 'NN'), (u'camps', 'NNS'), (u',', ','), (u'and', 'CC'), (u'helped', 'VBD'), (u'raise', 'VB'), (u'up', 'RP'), (u'democracies', 'NNS'), (u',', ','), (u'and', 'CC'), (u'faced', 'VBD'), (u'down', 'IN'), (u'an', 'DT'), (u'evil', 'JJ'), (u'empire', 'NN'), (u'.', '.')]
# [(u'Once', 'RB'), (u'again', 'RB'), (u',', ','), (u'we', 'PRP'), (u'accept', 'VBP'), (u'the', 'DT'), (u'call', 'NN'), (u'of', 'IN'), (u'history', 'NN'), (u'to', 'TO'), (u'deliver', 'VB'), (u'the', 'DT'), (u'oppressed', 'VBN'), (u'and', 'CC'), (u'move', 'VB'), (u'this', 'DT'), (u'world', 'NN'), (u'toward', 'IN'), (u'peace', 'NN'), (u'.', '.')]
# [(u'We', 'PRP'), (u'remain', 'VBP'), (u'on', 'IN'), (u'the', 'DT'), (u'offensive', 'JJ'), (u'against', 'IN'), (u'terror', 'NN'), (u'networks', 'NNS'), (u'.', '.')]
# [(u'We', 'PRP'), (u'have', 'VBP'), (u'killed', 'VBN'), (u'or', 'CC'), (u'captured', 'VBN'), (u'many', 'JJ'), (u'of', 'IN'), (u'their', 'PRP$'), (u'leaders', 'NNS'), (u'--', ':'), (u'and', 'CC'), (u'for', 'IN'), (u'the', 'DT'), (u'others', 'NNS'), (u',', ','), (u'their', 'PRP$'), (u'day', 'NN'), (u'will', 'MD'), (u'come', 'VB'), (u'.', '.')]
# [(u'President', 'NNP'), (u'George', 'NNP'), (u'W.', 'NNP'), (u'Bush', 'NNP'), (u'greets', 'VBZ'), (u'members', 'NNS'), (u'of', 'IN'), (u'Congress', 'NNP'), (u'after', 'IN'), (u'his', 'PRP$'), (u'State', 'NN'), (u'of', 'IN'), (u'the', 'DT'), (u'Union', 'NNP'), (u'Address', 'NNP'), (u'at', 'IN'), (u'the', 'DT'), (u'Capitol', 'NNP'), (u',', ','), (u'Tuesday', 'NNP'), (u',', ','), (u'Jan', 'NNP'), (u'.', '.')]
# [(u'31', 'CD'), (u',', ','), (u'2006', 'CD'), (u'.', '.')]
# [(u'White', 'NNP'), (u'House', 'NNP'), (u'photo', 'NN'), (u'by', 'IN'), (u'Eric', 'NNP'), (u'Draper', 'NNP'), (u'We', 'PRP'), (u'remain', 'VBP'), (u'on', 'IN'), (u'the', 'DT'), (u'offensive', 'JJ'), (u'in', 'IN'), (u'Afghanistan', 'NNP'), (u',', ','), (u'where', 'WRB'), (u'a', 'DT'), (u'fine', 'JJ'), (u'President', 'NNP'), (u'and', 'CC'), (u'a', 'DT'), (u'National', 'NNP'), (u'Assembly', 'NNP'), (u'are', 'VBP'), (u'fighting', 'VBG'), (u'terror', 'NN'), (u'while', 'IN'), (u'building', 'VBG'), (u'the', 'DT'), (u'institutions', 'NNS'), (u'of', 'IN'), (u'a', 'DT'), (u'new', 'JJ'), (u'democracy', 'NN'), (u'.', '.')]
# [(u'We', 'PRP'), (u"'re", 'VBP'), (u'on', 'IN'), (u'the', 'DT'), (u'offensive', 'JJ'), (u'in', 'IN'), (u'Iraq', 'NNP'), (u',', ','), (u'with', 'IN'), (u'a', 'DT'), (u'clear', 'JJ'), (u'plan', 'NN'), (u'for', 'IN'), (u'victory', 'NN'), (u'.', '.')]
# [(u'First', 'RB'), (u',', ','), (u'we', 'PRP'), (u"'re", 'VBP'), (u'helping', 'VBG'), (u'Iraqis', 'NNP'), (u'build', 'VB'), (u'an', 'DT'), (u'inclusive', 'JJ'), (u'government', 'NN'), (u',', ','), (u'so', 'IN'), (u'that', 'DT'), (u'old', 'JJ'), (u'resentments', 'NNS'), (u'will', 'MD'), (u'be', 'VB'), (u'eased', 'VBN'), (u'and', 'CC'), (u'the', 'DT'), (u'insurgency', 'NN'), (u'will', 'MD'), (u'be', 'VB'), (u'marginalized', 'VBN'), (u'.', '.')]
# [(u'Second', 'JJ'), (u',', ','), (u'we', 'PRP'), (u"'re", 'VBP'), (u'continuing', 'VBG'), (u'reconstruction', 'NN'), (u'efforts', 'NNS'), (u',', ','), (u'and', 'CC'), (u'helping', 'VBG'), (u'the', 'DT'), (u'Iraqi', 'NNP'), (u'government', 'NN'), (u'to', 'TO'), (u'fight', 'VB'), (u'corruption', 'NN'), (u'and', 'CC'), (u'build', 'VB'), (u'a', 'DT'), (u'modern', 'JJ'), (u'economy', 'NN'), (u',', ','), (u'so', 'IN'), (u'all', 'DT'), (u'Iraqis', 'NNP'), (u'can', 'MD'), (u'experience', 'VB'), (u'the', 'DT'), (u'benefits', 'NNS'), (u'of', 'IN'), (u'freedom', 'NN'), (u'.', '.')]
# [(u'And', 'CC'), (u',', ','), (u'third', 'JJ'), (u',', ','), (u'we', 'PRP'), (u"'re", 'VBP'), (u'striking', 'VBG'), (u'terrorist', 'JJ'), (u'targets', 'NNS'), (u'while', 'IN'), (u'we', 'PRP'), (u'train', 'VBP'), (u'Iraqi', 'JJ'), (u'forces', 'NNS'), (u'that', 'WDT'), (u'are', 'VBP'), (u'increasingly', 'RB'), (u'capable', 'JJ'), (u'of', 'IN'), (u'defeating', 'VBG'), (u'the', 'DT'), (u'enemy', 'NN'), (u'.', '.')]
# [(u'Iraqis', 'NNP'), (u'are', 'VBP'), (u'showing', 'VBG'), (u'their', 'PRP$'), (u'courage', 'NN'), (u'every', 'DT'), (u'day', 'NN'), (u',', ','), (u'and', 'CC'), (u'we', 'PRP'), (u'are', 'VBP'), (u'proud', 'JJ'), (u'to', 'TO'), (u'be', 'VB'), (u'their', 'PRP$'), (u'allies', 'NNS'), (u'in', 'IN'), (u'the', 'DT'), (u'cause', 'NN'), (u'of', 'IN'), (u'freedom', 'NN'), (u'.', '.')]
# [(u'(', '('), (u'Applause', 'NNP'), (u'.', '.'), (u')', ')')]
# [(u'Our', 'PRP$'), (u'work', 'NN'), (u'in', 'IN'), (u'Iraq', 'NNP'), (u'is', 'VBZ'), (u'difficult', 'JJ'), (u'because', 'IN'), (u'our', 'PRP$'), (u'enemy', 'NN'), (u'is', 'VBZ'), (u'brutal', 'JJ'), (u'.', '.')]
# [(u'But', 'CC'), (u'that', 'DT'), (u'brutality', 'NN'), (u'has', 'VBZ'), (u'not', 'RB'), (u'stopped', 'VBN'), (u'the', 'DT'), (u'dramatic', 'JJ'), (u'progress', 'NN'), (u'of', 'IN'), (u'a', 'DT'), (u'new', 'JJ'), (u'democracy', 'NN'), (u'.', '.')]
# [(u'In', 'IN'), (u'less', 'JJR'), (u'than', 'IN'), (u'three', 'CD'), (u'years', 'NNS'), (u',', ','), (u'the', 'DT'), (u'nation', 'NN'), (u'has', 'VBZ'), (u'gone', 'VBN'), (u'from', 'IN'), (u'dictatorship', 'NN'), (u'to', 'TO'), (u'liberation', 'NN'), (u',', ','), (u'to', 'TO'), (u'sovereignty', 'VB'), (u',', ','), (u'to', 'TO'), (u'a', 'DT'), (u'constitution', 'NN'), (u',', ','), (u'to', 'TO'), (u'national', 'JJ'), (u'elections', 'NNS'), (u'.', '.')]
# [(u'At', 'IN'), (u'the', 'DT'), (u'same', 'JJ'), (u'time', 'NN'), (u',', ','), (u'our', 'PRP$'), (u'coalition', 'NN'), (u'has', 'VBZ'), (u'been', 'VBN'), (u'relentless', 'VBN'), (u'in', 'IN'), (u'shutting', 'VBG'), (u'off', 'RP'), (u'terrorist', 'JJ'), (u'infiltration', 'NN'), (u',', ','), (u'clearing', 'VBG'), (u'out', 'RP'), (u'insurgent', 'JJ'), (u'strongholds', 'NNS'), (u',', ','), (u'and', 'CC'), (u'turning', 'VBG'), (u'over', 'RP'), (u'territory', 'NN'), (u'to', 'TO'), (u'Iraqi', 'NNP'), (u'security', 'NN'), (u'forces', 'NNS'), (u'.', '.')]
# [(u'I', 'PRP'), (u'am', 'VBP'), (u'confident', 'JJ'), (u'in', 'IN'), (u'our', 'PRP$'), (u'plan', 'NN'), (u'for', 'IN'), (u'victory', 'NN'), (u';', ':'), (u'I', 'PRP'), (u'am', 'VBP'), (u'confident', 'JJ'), (u'in', 'IN'), (u'the', 'DT'), (u'will', 'MD'), (u'of', 'IN'), (u'the', 'DT'), (u'Iraqi', 'NNP'), (u'people', 'NNS'), (u';', ':'), (u'I', 'PRP'), (u'am', 'VBP'), (u'confident', 'JJ'), (u'in', 'IN'), (u'the', 'DT'), (u'skill', 'NN'), (u'and', 'CC'), (u'spirit', 'NN'), (u'of', 'IN'), (u'our', 'PRP$'), (u'military', 'JJ'), (u'.', '.')]
# [(u'Fellow', 'NNP'), (u'citizens', 'NNS'), (u',', ','), (u'we', 'PRP'), (u'are', 'VBP'), (u'in', 'IN'), (u'this', 'DT'), (u'fight', 'NN'), (u'to', 'TO'), (u'win', 'VB'), (u',', ','), (u'and', 'CC'), (u'we', 'PRP'), (u'are', 'VBP'), (u'winning', 'VBG'), (u'.', '.')]
# [(u'(', '('), (u'Applause', 'NNP'), (u'.', '.'), (u')', ')')]
# [(u'The', 'DT'), (u'road', 'NN'), (u'of', 'IN'), (u'victory', 'NN'), (u'is', 'VBZ'), (u'the', 'DT'), (u'road', 'NN'), (u'that', 'WDT'), (u'will', 'MD'), (u'take', 'VB'), (u'our', 'PRP$'), (u'troops', 'NNS'), (u'home', 'NN'), (u'.', '.')]
# [(u'As', 'IN'), (u'we', 'PRP'), (u'make', 'VBP'), (u'progress', 'NN'), (u'on', 'IN'), (u'the', 'DT'), (u'ground', 'NN'), (u',', ','), (u'and', 'CC'), (u'Iraqi', 'NNP'), (u'forces', 'NNS'), (u'increasingly', 'RB'), (u'take', 'VBP'), (u'the', 'DT'), (u'lead', 'NN'), (u',', ','), (u'we', 'PRP'), (u'should', 'MD'), (u'be', 'VB'), (u'able', 'JJ'), (u'to', 'TO'), (u'further', 'JJ'), (u'decrease', 'VB'), (u'our', 'PRP$'), (u'troop', 'NN'), (u'levels', 'NNS'), (u'--', ':'), (u'but', 'CC'), (u'those', 'DT'), (u'decisions', 'NNS'), (u'will', 'MD'), (u'be', 'VB'), (u'made', 'VBN'), (u'by', 'IN'), (u'our', 'PRP$'), (u'military', 'JJ'), (u'commanders', 'NNS'), (u',', ','), (u'not', 'RB'), (u'by', 'IN'), (u'politicians', 'NNS'), (u'in', 'IN'), (u'Washington', 'NNP'), (u',', ','), (u'D.C', 'NNP'), (u'.', '.')]
# [(u'(', '('), (u'Applause', 'NNP'), (u'.', '.'), (u')', ')')]
# [(u'Our', 'PRP$'), (u'coalition', 'NN'), (u'has', 'VBZ'), (u'learned', 'VBN'), (u'from', 'IN'), (u'our', 'PRP$'), (u'experience', 'NN'), (u'in', 'IN'), (u'Iraq', 'NNP'), (u'.', '.')]
# [(u'We', 'PRP'), (u"'ve", 'VBP'), (u'adjusted', 'VBN'), (u'our', 'PRP$'), (u'military', 'JJ'), (u'tactics', 'NNS'), (u'and', 'CC'), (u'changed', 'VBD'), (u'our', 'PRP$'), (u'approach', 'NN'), (u'to', 'TO'), (u'reconstruction', 'NN'), (u'.', '.')]
# [(u'Along', 'IN'), (u'the', 'DT'), (u'way', 'NN'), (u',', ','), (u'we', 'PRP'), (u'have', 'VBP'), (u'benefitted', 'VBN'), (u'from', 'IN'), (u'responsible', 'JJ'), (u'criticism', 'NN'), (u'and', 'CC'), (u'counsel', 'NN'), (u'offered', 'VBN'), (u'by', 'IN'), (u'members', 'NNS'), (u'of', 'IN'), (u'Congress', 'NNP'), (u'of', 'IN'), (u'both', 'DT'), (u'parties', 'NNS'), (u'.', '.')]
# [(u'In', 'IN'), (u'the', 'DT'), (u'coming', 'VBG'), (u'year', 'NN'), (u',', ','), (u'I', 'PRP'), (u'will', 'MD'), (u'continue', 'VB'), (u'to', 'TO'), (u'reach', 'VB'), (u'out', 'RP'), (u'and', 'CC'), (u'seek', 'VB'), (u'your', 'PRP$'), (u'good', 'JJ'), (u'advice', 'NN'), (u'.', '.')]
# [(u'Yet', 'RB'), (u',', ','), (u'there', 'EX'), (u'is', 'VBZ'), (u'a', 'DT'), (u'difference', 'NN'), (u'between', 'IN'), (u'responsible', 'JJ'), (u'criticism', 'NN'), (u'that', 'WDT'), (u'aims', 'VBZ'), (u'for', 'IN'), (u'success', 'NN'), (u',', ','), (u'and', 'CC'), (u'defeatism', 'NN'), (u'that', 'WDT'), (u'refuses', 'VBZ'), (u'to', 'TO'), (u'acknowledge', 'VB'), (u'anything', 'NN'), (u'but', 'CC'), (u'failure', 'NN'), (u'.', '.')]
# [(u'(', '('), (u'Applause', 'NNP'), (u'.', '.'), (u')', ')')]
# [(u'Hindsight', 'NNP'), (u'alone', 'RB'), (u'is', 'VBZ'), (u'not', 'RB'), (u'wisdom', 'JJ'), (u',', ','), (u'and', 'CC'), (u'second-guessing', 'NN'), (u'is', 'VBZ'), (u'not', 'RB'), (u'a', 'DT'), (u'strategy', 'NN'), (u'.', '.')]
# [(u'(', '('), (u'Applause', 'NNP'), (u'.', '.'), (u')', ')')]
# [(u'With', 'IN'), (u'so', 'RB'), (u'much', 'JJ'), (u'in', 'IN'), (u'the', 'DT'), (u'balance', 'NN'), (u',', ','), (u'those', 'DT'), (u'of', 'IN'), (u'us', 'PRP'), (u'in', 'IN'), (u'public', 'JJ'), (u'office', 'NN'), (u'have', 'VBP'), (u'a', 'DT'), (u'duty', 'NN'), (u'to', 'TO'), (u'speak', 'VB'), (u'with', 'IN'), (u'candor', 'NN'), (u'.', '.')]
# [(u'A', 'DT'), (u'sudden', 'JJ'), (u'withdrawal', 'NN'), (u'of', 'IN'), (u'our', 'PRP$'), (u'forces', 'NNS'), (u'from', 'IN'), (u'Iraq', 'NNP'), (u'would', 'MD'), (u'abandon', 'VB'), (u'our', 'PRP$'), (u'Iraqi', 'NNP'), (u'allies', 'NNS'), (u'to', 'TO'), (u'death', 'NN'), (u'and', 'CC'), (u'prison', 'NN'), (u',', ','), (u'would', 'MD'), (u'put', 'VB'), (u'men', 'NNS'), (u'like', 'IN'), (u'bin', 'NN'), (u'Laden', 'NNP'), (u'and', 'CC'), (u'Zarqawi', 'NNP'), (u'in', 'IN'), (u'charge', 'NN'), (u'of', 'IN'), (u'a', 'DT'), (u'strategic', 'JJ'), (u'country', 'NN'), (u',', ','), (u'and', 'CC'), (u'show', 'VBP'), (u'that', 'IN'), (u'a', 'DT'), (u'pledge', 'NN'), (u'from', 'IN'), (u'America', 'NNP'), (u'means', 'VBZ'), (u'little', 'JJ'), (u'.', '.')]
# [(u'Members', 'NNS'), (u'of', 'IN'), (u'Congress', 'NNP'), (u',', ','), (u'however', 'RB'), (u'we', 'PRP'), (u'feel', 'VBP'), (u'about', 'IN'), (u'the', 'DT'), (u'decisions', 'NNS'), (u'and', 'CC'), (u'debates', 'NNS'), (u'of', 'IN'), (u'the', 'DT'), (u'past', 'NN'), (u',', ','), (u'our', 'PRP$'), (u'nation', 'NN'), (u'has', 'VBZ'), (u'only', 'RB'), (u'one', 'CD'), (u'option', 'NN'), (u':', ':'), (u'We', 'PRP'), (u'must', 'MD'), (u'keep', 'VB'), (u'our', 'PRP$'), (u'word', 'NN'), (u',', ','), (u'defeat', 'VB'), (u'our', 'PRP$'), (u'enemies', 'NNS'), (u',', ','), (u'and', 'CC'), (u'stand', 'VBP'), (u'behind', 'IN'), (u'the', 'DT'), (u'American', 'JJ'), (u'military', 'NN'), (u'in', 'IN'), (u'this', 'DT'), (u'vital', 'JJ'), (u'mission', 'NN'), (u'.', '.')]
# [(u'(', '('), (u'Applause', 'NNP'), (u'.', '.'), (u')', ')')]
# [(u'Laura', 'NNP'), (u'Bush', 'NNP'), (u'is', 'VBZ'), (u'applauded', 'VBN'), (u'as', 'IN'), (u'she', 'PRP'), (u'is', 'VBZ'), (u'introduced', 'VBN'), (u'Tuesday', 'NNP'), (u'evening', 'NN'), (u',', ','), (u'Jan', 'NNP'), (u'.', '.')]
# [(u'31', 'CD'), (u',', ','), (u'2006', 'CD'), (u'during', 'IN'), (u'the', 'DT'), (u'State', 'NNP'), (u'of', 'IN'), (u'the', 'DT'), (u'Union', 'NNP'), (u'Address', 'NNP'), (u'at', 'IN'), (u'United', 'NNP'), (u'States', 'NNPS'), (u'Capitol', 'NNP'), (u'in', 'IN'), (u'Washington', 'NNP'), (u'.', '.')]
# [(u'White', 'NNP'), (u'House', 'NNP'), (u'photo', 'NN'), (u'by', 'IN'), (u'Eric', 'NNP'), (u'Draper', 'NNP'), (u'Our', 'PRP$'), (u'men', 'NNS'), (u'and', 'CC'), (u'women', 'NNS'), (u'in', 'IN'), (u'uniform', 'JJ'), (u'are', 'VBP'), (u'making', 'VBG'), (u'sacrifices', 'NNS'), (u'--', ':'), (u'and', 'CC'), (u'showing', 'VBG'), (u'a', 'DT'), (u'sense', 'NN'), (u'of', 'IN'), (u'duty', 'NN'), (u'stronger', 'JJR'), (u'than', 'IN'), (u'all', 'DT'), (u'fear', 'NN'), (u'.', '.')]
# [(u'They', 'PRP'), (u'know', 'VBP'), (u'what', 'WP'), (u'it', 'PRP'), (u"'s", 'VBZ'), (u'like', 'IN'), (u'to', 'TO'), (u'fight', 'VB'), (u'house', 'NN'), (u'to', 'TO'), (u'house', 'NN'), (u'in', 'IN'), (u'a', 'DT'), (u'maze', 'NN'), (u'of', 'IN'), (u'streets', 'NNS'), (u',', ','), (u'to', 'TO'), (u'wear', 'VB'), (u'heavy', 'JJ'), (u'gear', 'NN'), (u'in', 'IN'), (u'the', 'DT'), (u'desert', 'NN'), (u'heat', 'NN'), (u',', ','), (u'to', 'TO'), (u'see', 'VB'), (u'a', 'DT'), (u'comrade', 'NN'), (u'killed', 'VBN'), (u'by', 'IN'), (u'a', 'DT'), (u'roadside', 'NN'), (u'bomb', 'NN'), (u'.', '.')]
# [(u'And', 'CC'), (u'those', 'DT'), (u'who', 'WP'), (u'know', 'VBP'), (u'the', 'DT'), (u'costs', 'NNS'), (u'also', 'RB'), (u'know', 'VBP'), (u'the', 'DT'), (u'stakes', 'NNS'), (u'.', '.')]
# [(u'Marine', 'JJ'), (u'Staff', 'NNP'), (u'Sergeant', 'NNP'), (u'Dan', 'NNP'), (u'Clay', 'NNP'), (u'was', 'VBD'), (u'killed', 'VBN'), (u'last', 'JJ'), (u'month', 'NN'), (u'fighting', 'VBG'), (u'in', 'IN'), (u'Fallujah', 'NNP'), (u'.', '.')]
# [(u'He', 'PRP'), (u'left', 'VBD'), (u'behind', 'RP'), (u'a', 'DT'), (u'letter', 'NN'), (u'to', 'TO'), (u'his', 'PRP$'), (u'family', 'NN'), (u',', ','), (u'but', 'CC'), (u'his', 'PRP$'), (u'words', 'NNS'), (u'could', 'MD'), (u'just', 'RB'), (u'as', 'RB'), (u'well', 'RB'), (u'be', 'VB'), (u'addressed', 'VBN'), (u'to', 'TO'), (u'every', 'DT'), (u'American', 'NNP'), (u'.', '.')]
# [(u'Here', 'RB'), (u'is', 'VBZ'), (u'what', 'WP'), (u'Dan', 'NNP'), (u'wrote', 'VBD'), (u':', ':'), (u'``', '``'), (u'I', 'PRP'), (u'know', 'VBP'), (u'what', 'WP'), (u'honor', 'NN'), (u'is', 'VBZ'), (u'.', '.')]
# [(u'...', ':'), (u'It', 'PRP'), (u'has', 'VBZ'), (u'been', 'VBN'), (u'an', 'DT'), (u'honor', 'NN'), (u'to', 'TO'), (u'protect', 'VB'), (u'and', 'CC'), (u'serve', 'VB'), (u'all', 'DT'), (u'of', 'IN'), (u'you', 'PRP'), (u'.', '.')]
# [(u'I', 'PRP'), (u'faced', 'VBD'), (u'death', 'NN'), (u'with', 'IN'), (u'the', 'DT'), (u'secure', 'NN'), (u'knowledge', 'NN'), (u'that', 'IN'), (u'you', 'PRP'), (u'would', 'MD'), (u'not', 'RB'), (u'have', 'VB'), (u'to', 'TO'), (u'...', ':'), (u'.', '.')]
# [(u'Never', 'RB'), (u'falter', 'NN'), (u'!', '.')]
# [(u'Do', 'VBP'), (u"n't", 'RB'), (u'hesitate', 'VB'), (u'to', 'TO'), (u'honor', 'VB'), (u'and', 'CC'), (u'support', 'VB'), (u'those', 'DT'), (u'of', 'IN'), (u'us', 'PRP'), (u'who', 'WP'), (u'have', 'VBP'), (u'the', 'DT'), (u'honor', 'NN'), (u'of', 'IN'), (u'protecting', 'VBG'), (u'that', 'DT'), (u'which', 'WDT'), (u'is', 'VBZ'), (u'worth', 'JJ'), (u'protecting', 'VBG'), (u'.', '.'), (u"''", "''")]
# [(u'Staff', 'NNP'), (u'Sergeant', 'NNP'), (u'Dan', 'NNP'), (u'Clay', 'NNP'), (u"'s", 'POS'), (u'wife', 'NN'), (u',', ','), (u'Lisa', 'NNP'), (u',', ','), (u'and', 'CC'), (u'his', 'PRP$'), (u'mom', 'NN'), (u'and', 'CC'), (u'dad', 'NN'), (u',', ','), (u'Sara', 'NNP'), (u'Jo', 'NNP'), (u'and', 'CC'), (u'Bud', 'NNP'), (u',', ','), (u'are', 'VBP'), (u'with', 'IN'), (u'us', 'PRP'), (u'this', 'DT'), (u'evening', 'NN'), (u'.', '.')]
# [(u'Welcome', 'NNP'), (u'.', '.')]
# [(u'(', '('), (u'Applause', 'NNP'), (u'.', '.'), (u')', ')')]
# [(u'Our', 'PRP$'), (u'nation', 'NN'), (u'is', 'VBZ'), (u'grateful', 'JJ'), (u'to', 'TO'), (u'the', 'DT'), (u'fallen', 'VBN'), (u',', ','), (u'who', 'WP'), (u'live', 'VBP'), (u'in', 'IN'), (u'the', 'DT'), (u'memory', 'NN'), (u'of', 'IN'), (u'our', 'PRP$'), (u'country', 'NN'), (u'.', '.')]
# [(u'We', 'PRP'), (u"'re", 'VBP'), (u'grateful', 'JJ'), (u'to', 'TO'), (u'all', 'DT'), (u'who', 'WP'), (u'volunteer', 'VBP'), (u'to', 'TO'), (u'wear', 'VB'), (u'our', 'PRP$'), (u'nation', 'NN'), (u"'s", 'POS'), (u'uniform', 'NN'), (u'--', ':'), (u'and', 'CC'), (u'as', 'IN'), (u'we', 'PRP'), (u'honor', 'VBP'), (u'our', 'PRP$'), (u'brave', 'NN'), (u'troops', 'NNS'), (u',', ','), (u'let', 'VB'), (u'us', 'PRP'), (u'never', 'RB'), (u'forget', 'VBP'), (u'the', 'DT'), (u'sacrifices', 'NNS'), (u'of', 'IN'), (u'America', 'NNP'), (u"'s", 'POS'), (u'military', 'JJ'), (u'families', 'NNS'), (u'.', '.')]
# [(u'(', '('), (u'Applause', 'NNP'), (u'.', '.'), (u')', ')')]
# [(u'Our', 'PRP$'), (u'offensive', 'JJ'), (u'against', 'IN'), (u'terror', 'NN'), (u'involves', 'VBZ'), (u'more', 'JJR'), (u'than', 'IN'), (u'military', 'JJ'), (u'action', 'NN'), (u'.', '.')]
# [(u'Ultimately', 'RB'), (u',', ','), (u'the', 'DT'), (u'only', 'JJ'), (u'way', 'NN'), (u'to', 'TO'), (u'defeat', 'VB'), (u'the', 'DT'), (u'terrorists', 'NNS'), (u'is', 'VBZ'), (u'to', 'TO'), (u'defeat', 'VB'), (u'their', 'PRP$'), (u'dark', 'JJ'), (u'vision', 'NN'), (u'of', 'IN'), (u'hatred', 'VBN'), (u'and', 'CC'), (u'fear', 'VBN'), (u'by', 'IN'), (u'offering', 'VBG'), (u'the', 'DT'), (u'hopeful', 'JJ'), (u'alternative', 'NN'), (u'of', 'IN'), (u'political', 'JJ'), (u'freedom', 'NN'), (u'and', 'CC'), (u'peaceful', 'JJ'), (u'change', 'NN'), (u'.', '.')]
# [(u'So', 'IN'), (u'the', 'DT'), (u'United', 'NNP'), (u'States', 'NNPS'), (u'of', 'IN'), (u'America', 'NNP'), (u'supports', 'NNS'), (u'democratic', 'JJ'), (u'reform', 'NN'), (u'across', 'IN'), (u'the', 'DT'), (u'broader', 'JJR'), (u'Middle', 'NNP'), (u'East', 'NNP'), (u'.', '.')]
# [(u'Elections', 'NNS'), (u'are', 'VBP'), (u'vital', 'JJ'), (u',', ','), (u'but', 'CC'), (u'they', 'PRP'), (u'are', 'VBP'), (u'only', 'RB'), (u'the', 'DT'), (u'beginning', 'NN'), (u'.', '.')]
# [(u'Raising', 'VBG'), (u'up', 'RP'), (u'a', 'DT'), (u'democracy', 'NN'), (u'requires', 'VBZ'), (u'the', 'DT'), (u'rule', 'NN'), (u'of', 'IN'), (u'law', 'NN'), (u',', ','), (u'and', 'CC'), (u'protection', 'NN'), (u'of', 'IN'), (u'minorities', 'NNS'), (u',', ','), (u'and', 'CC'), (u'strong', 'JJ'), (u',', ','), (u'accountable', 'JJ'), (u'institutions', 'NNS'), (u'that', 'IN'), (u'last', 'JJ'), (u'longer', 'JJR'), (u'than', 'IN'), (u'a', 'DT'), (u'single', 'JJ'), (u'vote', 'NN'), (u'.', '.')]
# [(u'The', 'DT'), (u'great', 'JJ'), (u'people', 'NNS'), (u'of', 'IN'), (u'Egypt', 'NNP'), (u'have', 'VBP'), (u'voted', 'VBN'), (u'in', 'IN'), (u'a', 'DT'), (u'multi-party', 'JJ'), (u'presidential', 'JJ'), (u'election', 'NN'), (u'--', ':'), (u'and', 'CC'), (u'now', 'RB'), (u'their', 'PRP$'), (u'government', 'NN'), (u'should', 'MD'), (u'open', 'VB'), (u'paths', 'NNS'), (u'of', 'IN'), (u'peaceful', 'JJ'), (u'opposition', 'NN'), (u'that', 'WDT'), (u'will', 'MD'), (u'reduce', 'VB'), (u'the', 'DT'), (u'appeal', 'NN'), (u'of', 'IN'), (u'radicalism', 'NN'), (u'.', '.')]
# [(u'The', 'DT'), (u'Palestinian', 'JJ'), (u'people', 'NNS'), (u'have', 'VBP'), (u'voted', 'VBN'), (u'in', 'IN'), (u'elections', 'NNS'), (u'.', '.')]
# [(u'And', 'CC'), (u'now', 'RB'), (u'the', 'DT'), (u'leaders', 'NNS'), (u'of', 'IN'), (u'Hamas', 'NNP'), (u'must', 'MD'), (u'recognize', 'VB'), (u'Israel', 'NNP'), (u',', ','), (u'disarm', 'NN'), (u',', ','), (u'reject', 'JJ'), (u'terrorism', 'NN'), (u',', ','), (u'and', 'CC'), (u'work', 'NN'), (u'for', 'IN'), (u'lasting', 'VBG'), (u'peace', 'NN'), (u'.', '.')]
# [(u'(', '('), (u'Applause', 'NNP'), (u'.', '.'), (u')', ')')]
# [(u'Saudi', 'NNP'), (u'Arabia', 'NNP'), (u'has', 'VBZ'), (u'taken', 'VBN'), (u'the', 'DT'), (u'first', 'JJ'), (u'steps', 'NNS'), (u'of', 'IN'), (u'reform', 'NN'), (u'--', ':'), (u'now', 'RB'), (u'it', 'PRP'), (u'can', 'MD'), (u'offer', 'VB'), (u'its', 'PRP$'), (u'people', 'NNS'), (u'a', 'DT'), (u'better', 'JJR'), (u'future', 'NN'), (u'by', 'IN'), (u'pressing', 'VBG'), (u'forward', 'RB'), (u'with', 'IN'), (u'those', 'DT'), (u'efforts', 'NNS'), (u'.', '.')]
# [(u'Democracies', 'NNS'), (u'in', 'IN'), (u'the', 'DT'), (u'Middle', 'NNP'), (u'East', 'NNP'), (u'will', 'MD'), (u'not', 'RB'), (u'look', 'VB'), (u'like', 'IN'), (u'our', 'PRP$'), (u'own', 'JJ'), (u',', ','), (u'because', 'IN'), (u'they', 'PRP'), (u'will', 'MD'), (u'reflect', 'VB'), (u'the', 'DT'), (u'traditions', 'NNS'), (u'of', 'IN'), (u'their', 'PRP$'), (u'own', 'JJ'), (u'citizens', 'NNS'), (u'.', '.')]
# [(u'Yet', 'RB'), (u'liberty', 'NN'), (u'is', 'VBZ'), (u'the', 'DT'), (u'future', 'NN'), (u'of', 'IN'), (u'every', 'DT'), (u'nation', 'NN'), (u'in', 'IN'), (u'the', 'DT'), (u'Middle', 'NNP'), (u'East', 'NNP'), (u',', ','), (u'because', 'IN'), (u'liberty', 'NN'), (u'is', 'VBZ'), (u'the', 'DT'), (u'right', 'NN'), (u'and', 'CC'), (u'hope', 'NN'), (u'of', 'IN'), (u'all', 'DT'), (u'humanity', 'NN'), (u'.', '.')]
# [(u'(', '('), (u'Applause', 'NNP'), (u'.', '.'), (u')', ')')]
# [(u'President', 'NNP'), (u'George', 'NNP'), (u'W.', 'NNP'), (u'Bush', 'NNP'), (u'waves', 'VBZ'), (u'toward', 'IN'), (u'the', 'DT'), (u'upper', 'JJ'), (u'visitors', 'NNS'), (u'gallery', 'NN'), (u'of', 'IN'), (u'the', 'DT'), (u'House', 'NNP'), (u'Chamber', 'NNP'), (u'following', 'VBG'), (u'his', 'PRP$'), (u'State', 'NN'), (u'of', 'IN'), (u'the', 'DT'), (u'Union', 'NNP'), (u'remarks', 'NNS'), (u'Tuesday', 'NNP'), (u',', ','), (u'Jan', 'NNP'), (u'.', '.')]
# [(u'31', 'CD'), (u',', ','), (u'2006', 'CD'), (u'at', 'IN'), (u'the', 'DT'), (u'United', 'NNP'), (u'States', 'NNPS'), (u'Capitol', 'NNP'), (u'.', '.')]
# [(u'White', 'NNP'), (u'House', 'NNP'), (u'photo', 'NN'), (u'by', 'IN'), (u'Eric', 'NNP'), (u'Draper', 'NNP'), (u'The', 'DT'), (u'same', 'JJ'), (u'is', 'VBZ'), (u'true', 'JJ'), (u'of', 'IN'), (u'Iran', 'NNP'), (u',', ','), (u'a', 'DT'), (u'nation', 'NN'), (u'now', 'RB'), (u'held', 'VBN'), (u'hostage', 'NN'), (u'by', 'IN'), (u'a', 'DT'), (u'small', 'JJ'), (u'clerical', 'JJ'), (u'elite', 'NN'), (u'that', 'WDT'), (u'is', 'VBZ'), (u'isolating', 'VBG'), (u'and', 'CC'), (u'repressing', 'VBG'), (u'its', 'PRP$'), (u'people', 'NNS'), (u'.', '.')]
# [(u'The', 'DT'), (u'regime', 'NN'), (u'in', 'IN'), (u'that', 'DT'), (u'country', 'NN'), (u'sponsors', 'NNS'), (u'terrorists', 'NNS'), (u'in', 'IN'), (u'the', 'DT'), (u'Palestinian', 'JJ'), (u'territories', 'NNS'), (u'and', 'CC'), (u'in', 'IN'), (u'Lebanon', 'NNP'), (u'--', ':'), (u'and', 'CC'), (u'that', 'DT'), (u'must', 'MD'), (u'come', 'VB'), (u'to', 'TO'), (u'an', 'DT'), (u'end', 'NN'), (u'.', '.')]
# [(u'(', '('), (u'Applause', 'NNP'), (u'.', '.'), (u')', ')')]
# [(u'The', 'DT'), (u'Iranian', 'JJ'), (u'government', 'NN'), (u'is', 'VBZ'), (u'defying', 'VBG'), (u'the', 'DT'), (u'world', 'NN'), (u'with', 'IN'), (u'its', 'PRP$'), (u'nuclear', 'JJ'), (u'ambitions', 'NNS'), (u',', ','), (u'and', 'CC'), (u'the', 'DT'), (u'nations', 'NNS'), (u'of', 'IN'), (u'the', 'DT'), (u'world', 'NN'), (u'must', 'MD'), (u'not', 'RB'), (u'permit', 'VB'), (u'the', 'DT'), (u'Iranian', 'JJ'), (u'regime', 'NN'), (u'to', 'TO'), (u'gain', 'VB'), (u'nuclear', 'JJ'), (u'weapons', 'NNS'), (u'.', '.')]
# [(u'(', '('), (u'Applause', 'NNP'), (u'.', '.'), (u')', ')')]
# [(u'America', 'NNP'), (u'will', 'MD'), (u'continue', 'VB'), (u'to', 'TO'), (u'rally', 'VB'), (u'the', 'DT'), (u'world', 'NN'), (u'to', 'TO'), (u'confront', 'VB'), (u'these', 'DT'), (u'threats', 'NNS'), (u'.', '.')]
# [(u'Tonight', 'NNP'), (u',', ','), (u'let', 'VB'), (u'me', 'PRP'), (u'speak', 'VB'), (u'directly', 'RB'), (u'to', 'TO'), (u'the', 'DT'), (u'citizens', 'NNS'), (u'of', 'IN'), (u'Iran', 'NNP'), (u':', ':'), (u'America', 'NNP'), (u'respects', 'VBZ'), (u'you', 'PRP'), (u',', ','), (u'and', 'CC'), (u'we', 'PRP'), (u'respect', 'VBP'), (u'your', 'PRP$'), (u'country', 'NN'), (u'.', '.')]
# [(u'We', 'PRP'), (u'respect', 'VBP'), (u'your', 'PRP$'), (u'right', 'NN'), (u'to', 'TO'), (u'choose', 'VB'), (u'your', 'PRP$'), (u'own', 'JJ'), (u'future', 'NN'), (u'and', 'CC'), (u'win', 'VB'), (u'your', 'PRP$'), (u'own', 'JJ'), (u'freedom', 'NN'), (u'.', '.')]
# [(u'And', 'CC'), (u'our', 'PRP$'), (u'nation', 'NN'), (u'hopes', 'VBZ'), (u'one', 'CD'), (u'day', 'NN'), (u'to', 'TO'), (u'be', 'VB'), (u'the', 'DT'), (u'closest', 'JJS'), (u'of', 'IN'), (u'friends', 'NNS'), (u'with', 'IN'), (u'a', 'DT'), (u'free', 'JJ'), (u'and', 'CC'), (u'democratic', 'JJ'), (u'Iran', 'NNP'), (u'.', '.')]
# [(u'(', '('), (u'Applause', 'NNP'), (u'.', '.'), (u')', ')')]
# [(u'To', 'TO'), (u'overcome', 'VB'), (u'dangers', 'NNS'), (u'in', 'IN'), (u'our', 'PRP$'), (u'world', 'NN'), (u',', ','), (u'we', 'PRP'), (u'must', 'MD'), (u'also', 'RB'), (u'take', 'VB'), (u'the', 'DT'), (u'offensive', 'JJ'), (u'by', 'IN'), (u'encouraging', 'VBG'), (u'economic', 'JJ'), (u'progress', 'NN'), (u',', ','), (u'and', 'CC'), (u'fighting', 'VBG'), (u'disease', 'NN'), (u',', ','), (u'and', 'CC'), (u'spreading', 'VBG'), (u'hope', 'NN'), (u'in', 'IN'), (u'hopeless', 'JJ'), (u'lands', 'NNS'), (u'.', '.')]
# [(u'Isolationism', 'NNP'), (u'would', 'MD'), (u'not', 'RB'), (u'only', 'RB'), (u'tie', 'VB'), (u'our', 'PRP$'), (u'hands', 'NNS'), (u'in', 'IN'), (u'fighting', 'VBG'), (u'enemies', 'NNS'), (u',', ','), (u'it', 'PRP'), (u'would', 'MD'), (u'keep', 'VB'), (u'us', 'PRP'), (u'from', 'IN'), (u'helping', 'VBG'), (u'our', 'PRP$'), (u'friends', 'NNS'), (u'in', 'IN'), (u'desperate', 'JJ'), (u'need', 'NN'), (u'.', '.')]
# [(u'We', 'PRP'), (u'show', 'VBP'), (u'compassion', 'JJ'), (u'abroad', 'RB'), (u'because', 'IN'), (u'Americans', 'NNPS'), (u'believe', 'VBP'), (u'in', 'IN'), (u'the', 'DT'), (u'God-given', 'NNP'), (u'dignity', 'NN'), (u'and', 'CC'), (u'worth', 'NN'), (u'of', 'IN'), (u'a', 'DT'), (u'villager', 'NN'), (u'with', 'IN'), (u'HIV/AIDS', 'NNP'), (u',', ','), (u'or', 'CC'), (u'an', 'DT'), (u'infant', 'NN'), (u'with', 'IN'), (u'malaria', 'NNS'), (u',', ','), (u'or', 'CC'), (u'a', 'DT'), (u'refugee', 'JJ'), (u'fleeing', 'NN'), (u'genocide', 'NN'), (u',', ','), (u'or', 'CC'), (u'a', 'DT'), (u'young', 'JJ'), (u'girl', 'NN'), (u'sold', 'VBN'), (u'into', 'IN'), (u'slavery', 'NN'), (u'.', '.')]
# [(u'We', 'PRP'), (u'also', 'RB'), (u'show', 'VBP'), (u'compassion', 'NN'), (u'abroad', 'RB'), (u'because', 'IN'), (u'regions', 'NNS'), (u'overwhelmed', 'VBN'), (u'by', 'IN'), (u'poverty', 'NN'), (u',', ','), (u'corruption', 'NN'), (u',', ','), (u'and', 'CC'), (u'despair', 'NN'), (u'are', 'VBP'), (u'sources', 'NNS'), (u'of', 'IN'), (u'terrorism', 'NN'), (u',', ','), (u'and', 'CC'), (u'organized', 'VBD'), (u'crime', 'NN'), (u',', ','), (u'and', 'CC'), (u'human', 'JJ'), (u'trafficking', 'NN'), (u',', ','), (u'and', 'CC'), (u'the', 'DT'), (u'drug', 'NN'), (u'trade', 'NN'), (u'.', '.')]
# [(u'In', 'IN'), (u'recent', 'JJ'), (u'years', 'NNS'), (u',', ','), (u'you', 'PRP'), (u'and', 'CC'), (u'I', 'PRP'), (u'have', 'VBP'), (u'taken', 'VBN'), (u'unprecedented', 'JJ'), (u'action', 'NN'), (u'to', 'TO'), (u'fight', 'VB'), (u'AIDS', 'NNP'), (u'and', 'CC'), (u'malaria', 'NNS'), (u',', ','), (u'expand', 'VBP'), (u'the', 'DT'), (u'education', 'NN'), (u'of', 'IN'), (u'girls', 'NNS'), (u',', ','), (u'and', 'CC'), (u'reward', 'RB'), (u'developing', 'VBG'), (u'nations', 'NNS'), (u'that', 'WDT'), (u'are', 'VBP'), (u'moving', 'VBG'), (u'forward', 'RB'), (u'with', 'IN'), (u'economic', 'JJ'), (u'and', 'CC'), (u'political', 'JJ'), (u'reform', 'NN'), (u'.', '.')]
# [(u'For', 'IN'), (u'people', 'NNS'), (u'everywhere', 'RB'), (u',', ','), (u'the', 'DT'), (u'United', 'NNP'), (u'States', 'NNPS'), (u'is', 'VBZ'), (u'a', 'DT'), (u'partner', 'NN'), (u'for', 'IN'), (u'a', 'DT'), (u'better', 'JJR'), (u'life', 'NN'), (u'.', '.')]
# [(u'Short-changing', 'VBG'), (u'these', 'DT'), (u'efforts', 'NNS'), (u'would', 'MD'), (u'increase', 'VB'), (u'the', 'DT'), (u'suffering', 'NN'), (u'and', 'CC'), (u'chaos', 'NN'), (u'of', 'IN'), (u'our', 'PRP$'), (u'world', 'NN'), (u',', ','), (u'undercut', 'JJ'), (u'our', 'PRP$'), (u'long-term', 'JJ'), (u'security', 'NN'), (u',', ','), (u'and', 'CC'), (u'dull', 'VB'), (u'the', 'DT'), (u'conscience', 'NN'), (u'of', 'IN'), (u'our', 'PRP$'), (u'country', 'NN'), (u'.', '.')]
# [(u'I', 'PRP'), (u'urge', 'VBP'), (u'members', 'NNS'), (u'of', 'IN'), (u'Congress', 'NNP'), (u'to', 'TO'), (u'serve', 'VB'), (u'the', 'DT'), (u'interests', 'NNS'), (u'of', 'IN'), (u'America', 'NNP'), (u'by', 'IN'), (u'showing', 'VBG'), (u'the', 'DT'), (u'compassion', 'NN'), (u'of', 'IN'), (u'America', 'NNP'), (u'.', '.')]
# ...
# [(u'(', '('), (u'Applause', 'NNP'), (u'.', '.'), (u')', ')')]
# [(u'Today', 'NN'), (u'marks', 'VBZ'), (u'the', 'DT'), (u'official', 'JJ'), (u'retirement', 'NN'), (u'of', 'IN'), (u'a', 'DT'), (u'very', 'RB'), (u'special', 'JJ'), (u'American', 'NNP'), (u'.', '.')]
# [(u'For', 'IN'), (u'24', 'CD'), (u'years', 'NNS'), (u'of', 'IN'), (u'faithful', 'JJ'), (u'service', 'NN'), (u'to', 'TO'), (u'our', 'PRP$'), (u'nation', 'NN'), (u',', ','), (u'the', 'DT'), (u'United', 'NNP'), (u'States', 'NNPS'), (u'is', 'VBZ'), (u'grateful', 'JJ'), (u'to', 'TO'), (u'Justice', 'NNP'), (u'Sandra', 'NNP'), (u'Day', 'NNP'), (u"O'Connor", 'NNP'), (u'.', '.')]
# [(u'(', '('), (u'Applause', 'NNP'), (u'.', '.'), (u')', ')')]
# [(u'A', 'DT'), (u'hopeful', 'JJ'), (u'society', 'NN'), (u'has', 'VBZ'), (u'institutions', 'NNS'), (u'of', 'IN'), (u'science', 'NN'), (u'and', 'CC'), (u'medicine', 'NN'), (u'that', 'WDT'), (u'do', 'VBP'), (u'not', 'RB'), (u'cut', 'VB'), (u'ethical', 'JJ'), (u'corners', 'NNS'), (u',', ','), (u'and', 'CC'), (u'that', 'IN'), (u'recognize', 'VBP'), (u'the', 'DT'), (u'matchless', 'NN'), (u'value', 'NN'), (u'of', 'IN'), (u'every', 'DT'), (u'life', 'NN'), (u'.', '.')]
# [(u'Tonight', 'NNP'), (u'I', 'PRP'), (u'ask', 'VBP'), (u'you', 'PRP'), (u'to', 'TO'), (u'pass', 'VB'), (u'legislation', 'NN'), (u'to', 'TO'), (u'prohibit', 'VB'), (u'the', 'DT'), (u'most', 'RBS'), (u'egregious', 'JJ'), (u'abuses', 'NNS'), (u'of', 'IN'), (u'medical', 'JJ'), (u'research', 'NN'), (u':', ':'), (u'human', 'JJ'), (u'cloning', 'VBG'), (u'in', 'IN'), (u'all', 'DT'), (u'its', 'PRP$'), (u'forms', 'NNS'), (u',', ','), (u'creating', 'VBG'), (u'or', 'CC'), (u'implanting', 'VBG'), (u'embryos', 'NN'), (u'for', 'IN'), (u'experiments', 'NNS'), (u',', ','), (u'creating', 'VBG'), (u'human-animal', 'JJ'), (u'hybrids', 'NNS'), (u',', ','), (u'and', 'CC'), (u'buying', 'NN'), (u',', ','), (u'selling', 'NN'), (u',', ','), (u'or', 'CC'), (u'patenting', 'VBG'), (u'human', 'JJ'), (u'embryos', 'NN'), (u'.', '.')]
# [(u'Human', 'NNP'), (u'life', 'NN'), (u'is', 'VBZ'), (u'a', 'DT'), (u'gift', 'NN'), (u'from', 'IN'), (u'our', 'PRP$'), (u'Creator', 'NNP'), (u'--', ':'), (u'and', 'CC'), (u'that', 'IN'), (u'gift', 'NN'), (u'should', 'MD'), (u'never', 'RB'), (u'be', 'VB'), (u'discarded', 'VBN'), (u',', ','), (u'devalued', 'VBD'), (u'or', 'CC'), (u'put', 'VB'), (u'up', 'RP'), (u'for', 'IN'), (u'sale', 'NN'), (u'.', '.')]
# [(u'(', '('), (u'Applause', 'NNP'), (u'.', '.'), (u')', ')')]
# [(u'A', 'DT'), (u'hopeful', 'JJ'), (u'society', 'NN'), (u'expects', 'VBZ'), (u'elected', 'VBN'), (u'officials', 'NNS'), (u'to', 'TO'), (u'uphold', 'VB'), (u'the', 'DT'), (u'public', 'JJ'), (u'trust', 'NN'), (u'.', '.')]
# [(u'(', '('), (u'Applause', 'NNP'), (u'.', '.'), (u')', ')')]
# [(u'Honorable', 'JJ'), (u'people', 'NNS'), (u'in', 'IN'), (u'both', 'DT'), (u'parties', 'NNS'), (u'are', 'VBP'), (u'working', 'VBG'), (u'on', 'IN'), (u'reforms', 'NNS'), (u'to', 'TO'), (u'strengthen', 'VB'), (u'the', 'DT'), (u'ethical', 'JJ'), (u'standards', 'NNS'), (u'of', 'IN'), (u'Washington', 'NNP'), (u'--', ':'), (u'I', 'PRP'), (u'support', 'VBP'), (u'your', 'PRP$'), (u'efforts', 'NNS'), (u'.', '.')]
# [(u'Each', 'DT'), (u'of', 'IN'), (u'us', 'PRP'), (u'has', 'VBZ'), (u'made', 'VBN'), (u'a', 'DT'), (u'pledge', 'NN'), (u'to', 'TO'), (u'be', 'VB'), (u'worthy', 'JJ'), (u'of', 'IN'), (u'public', 'JJ'), (u'responsibility', 'NN'), (u'--', ':'), (u'and', 'CC'), (u'that', 'DT'), (u'is', 'VBZ'), (u'a', 'DT'), (u'pledge', 'NN'), (u'we', 'PRP'), (u'must', 'MD'), (u'never', 'RB'), (u'forget', 'VB'), (u',', ','), (u'never', 'RB'), (u'dismiss', 'NN'), (u',', ','), (u'and', 'CC'), (u'never', 'RB'), (u'betray', 'NN'), (u'.', '.')]
# [(u'(', '('), (u'Applause', 'NNP'), (u'.', '.'), (u')', ')')]
# [(u'As', 'IN'), (u'we', 'PRP'), (u'renew', 'VBP'), (u'the', 'DT'), (u'promise', 'NN'), (u'of', 'IN'), (u'our', 'PRP$'), (u'institutions', 'NNS'), (u',', ','), (u'let', 'VB'), (u'us', 'PRP'), (u'also', 'RB'), (u'show', 'VBP'), (u'the', 'DT'), (u'character', 'NN'), (u'of', 'IN'), (u'America', 'NNP'), (u'in', 'IN'), (u'our', 'PRP$'), (u'compassion', 'NN'), (u'and', 'CC'), (u'care', 'NN'), (u'for', 'IN'), (u'one', 'CD'), (u'another', 'DT'), (u'.', '.')]
# [(u'A', 'DT'), (u'hopeful', 'JJ'), (u'society', 'NN'), (u'gives', 'VBZ'), (u'special', 'JJ'), (u'attention', 'NN'), (u'to', 'TO'), (u'children', 'NNS'), (u'who', 'WP'), (u'lack', 'VBP'), (u'direction', 'NN'), (u'and', 'CC'), (u'love', 'NN'), (u'.', '.')]
# [(u'Through', 'IN'), (u'the', 'DT'), (u'Helping', 'NNP'), (u'America', 'NNP'), (u"'s", 'POS'), (u'Youth', 'NNP'), (u'Initiative', 'NNP'), (u',', ','), (u'we', 'PRP'), (u'are', 'VBP'), (u'encouraging', 'VBG'), (u'caring', 'VBG'), (u'adults', 'NNS'), (u'to', 'TO'), (u'get', 'VB'), (u'involved', 'VBN'), (u'in', 'IN'), (u'the', 'DT'), (u'life', 'NN'), (u'of', 'IN'), (u'a', 'DT'), (u'child', 'NN'), (u'--', ':'), (u'and', 'CC'), (u'this', 'DT'), (u'good', 'JJ'), (u'work', 'NN'), (u'is', 'VBZ'), (u'being', 'VBG'), (u'led', 'VBN'), (u'by', 'IN'), (u'our', 'PRP$'), (u'First', 'NNP'), (u'Lady', 'NNP'), (u',', ','), (u'Laura', 'NNP'), (u'Bush', 'NNP'), (u'.', '.')]
# [(u'(', '('), (u'Applause', 'NNP'), (u'.', '.'), (u')', ')')]
# [(u'This', 'DT'), (u'year', 'NN'), (u'we', 'PRP'), (u'will', 'MD'), (u'add', 'VB'), (u'resources', 'NNS'), (u'to', 'TO'), (u'encourage', 'VB'), (u'young', 'JJ'), (u'people', 'NNS'), (u'to', 'TO'), (u'stay', 'VB'), (u'in', 'IN'), (u'school', 'NN'), (u',', ','), (u'so', 'RB'), (u'more', 'JJR'), (u'of', 'IN'), (u'America', 'NNP'), (u"'s", 'POS'), (u'youth', 'NN'), (u'can', 'MD'), (u'raise', 'VB'), (u'their', 'PRP$'), (u'sights', 'NNS'), (u'and', 'CC'), (u'achieve', 'VBP'), (u'their', 'PRP$'), (u'dreams', 'NNS'), (u'.', '.')]
# [(u'A', 'DT'), (u'hopeful', 'JJ'), (u'society', 'NN'), (u'comes', 'VBZ'), (u'to', 'TO'), (u'the', 'DT'), (u'aid', 'NN'), (u'of', 'IN'), (u'fellow', 'JJ'), (u'citizens', 'NNS'), (u'in', 'IN'), (u'times', 'NNS'), (u'of', 'IN'), (u'suffering', 'NN'), (u'and', 'CC'), (u'emergency', 'NN'), (u'--', ':'), (u'and', 'CC'), (u'stays', 'NNS'), (u'at', 'IN'), (u'it', 'PRP'), (u'until', 'IN'), (u'they', 'PRP'), (u"'re", 'VBP'), (u'back', 'RB'), (u'on', 'IN'), (u'their', 'PRP$'), (u'feet', 'NNS'), (u'.', '.')]
# [(u'So', 'RB'), (u'far', 'RB'), (u'the', 'DT'), (u'federal', 'JJ'), (u'government', 'NN'), (u'has', 'VBZ'), (u'committed', 'VBN'), (u'$', '$'), (u'85', 'CD'), (u'billion', 'CD'), (u'to', 'TO'), (u'the', 'DT'), (u'people', 'NNS'), (u'of', 'IN'), (u'the', 'DT'), (u'Gulf', 'NNP'), (u'Coast', 'NNP'), (u'and', 'CC'), (u'New', 'NNP'), (u'Orleans', 'NNP'), (u'.', '.')]
# [(u'We', 'PRP'), (u"'re", 'VBP'), (u'removing', 'VBG'), (u'debris', 'NN'), (u'and', 'CC'), (u'repairing', 'NN'), (u'highways', 'NNS'), (u'and', 'CC'), (u'rebuilding', 'VBG'), (u'stronger', 'JJR'), (u'levees', 'NNS'), (u'.', '.')]
# [(u'We', 'PRP'), (u"'re", 'VBP'), (u'providing', 'VBG'), (u'business', 'NN'), (u'loans', 'NNS'), (u'and', 'CC'), (u'housing', 'NN'), (u'assistance', 'NN'), (u'.', '.')]
# [(u'Yet', 'RB'), (u'as', 'IN'), (u'we', 'PRP'), (u'meet', 'VBP'), (u'these', 'DT'), (u'immediate', 'JJ'), (u'needs', 'NNS'), (u',', ','), (u'we', 'PRP'), (u'must', 'MD'), (u'also', 'RB'), (u'address', 'VB'), (u'deeper', 'JJR'), (u'challenges', 'NNS'), (u'that', 'WDT'), (u'existed', 'VBD'), (u'before', 'IN'), (u'the', 'DT'), (u'storm', 'NN'), (u'arrived', 'VBD'), (u'.', '.')]
# [(u'In', 'IN'), (u'New', 'NNP'), (u'Orleans', 'NNP'), (u'and', 'CC'), (u'in', 'IN'), (u'other', 'JJ'), (u'places', 'NNS'), (u',', ','), (u'many', 'JJ'), (u'of', 'IN'), (u'our', 'PRP$'), (u'fellow', 'JJ'), (u'citizens', 'NNS'), (u'have', 'VBP'), (u'felt', 'VBN'), (u'excluded', 'VBN'), (u'from', 'IN'), (u'the', 'DT'), (u'promise', 'NN'), (u'of', 'IN'), (u'our', 'PRP$'), (u'country', 'NN'), (u'.', '.')]
# [(u'The', 'DT'), (u'answer', 'NN'), (u'is', 'VBZ'), (u'not', 'RB'), (u'only', 'RB'), (u'temporary', 'JJ'), (u'relief', 'NN'), (u',', ','), (u'but', 'CC'), (u'schools', 'NNS'), (u'that', 'WDT'), (u'teach', 'VBP'), (u'every', 'DT'), (u'child', 'NN'), (u',', ','), (u'and', 'CC'), (u'job', 'NN'), (u'skills', 'NNS'), (u'that', 'IN'), (u'bring', 'VBG'), (u'upward', 'JJ'), (u'mobility', 'NN'), (u',', ','), (u'and', 'CC'), (u'more', 'JJR'), (u'opportunities', 'NNS'), (u'to', 'TO'), (u'own', 'VB'), (u'a', 'DT'), (u'home', 'NN'), (u'and', 'CC'), (u'start', 'VB'), (u'a', 'DT'), (u'business', 'NN'), (u'.', '.')]
# [(u'As', 'IN'), (u'we', 'PRP'), (u'recover', 'VBP'), (u'from', 'IN'), (u'a', 'DT'), (u'disaster', 'NN'), (u',', ','), (u'let', 'VB'), (u'us', 'PRP'), (u'also', 'RB'), (u'work', 'NN'), (u'for', 'IN'), (u'the', 'DT'), (u'day', 'NN'), (u'when', 'WRB'), (u'all', 'DT'), (u'Americans', 'NNPS'), (u'are', 'VBP'), (u'protected', 'VBN'), (u'by', 'IN'), (u'justice', 'NN'), (u',', ','), (u'equal', 'JJ'), (u'in', 'IN'), (u'hope', 'NN'), (u',', ','), (u'and', 'CC'), (u'rich', 'JJ'), (u'in', 'IN'), (u'opportunity', 'NN'), (u'.', '.')]
# [(u'(', '('), (u'Applause', 'NNP'), (u'.', '.'), (u')', ')')]
# [(u'A', 'DT'), (u'hopeful', 'JJ'), (u'society', 'NN'), (u'acts', 'NNS'), (u'boldly', 'RB'), (u'to', 'TO'), (u'fight', 'VB'), (u'diseases', 'NNS'), (u'like', 'IN'), (u'HIV/AIDS', 'NNP'), (u',', ','), (u'which', 'WDT'), (u'can', 'MD'), (u'be', 'VB'), (u'prevented', 'VBN'), (u',', ','), (u'and', 'CC'), (u'treated', 'VBD'), (u',', ','), (u'and', 'CC'), (u'defeated', 'VBD'), (u'.', '.')]
# [(u'More', 'JJR'), (u'than', 'IN'), (u'a', 'DT'), (u'million', 'CD'), (u'Americans', 'NNPS'), (u'live', 'VBP'), (u'with', 'IN'), (u'HIV', 'NNP'), (u',', ','), (u'and', 'CC'), (u'half', 'NN'), (u'of', 'IN'), (u'all', 'DT'), (u'AIDS', 'NNP'), (u'cases', 'NNS'), (u'occur', 'VBP'), (u'among', 'IN'), (u'African', 'JJ'), (u'Americans', 'NNPS'), (u'.', '.')]
# [(u'I', 'PRP'), (u'ask', 'VBP'), (u'Congress', 'NNP'), (u'to', 'TO'), (u'reform', 'VB'), (u'and', 'CC'), (u'reauthorize', 'VB'), (u'the', 'DT'), (u'Ryan', 'NNP'), (u'White', 'NNP'), (u'Act', 'NNP'), (u',', ','), (u'and', 'CC'), (u'provide', 'VB'), (u'new', 'JJ'), (u'funding', 'NN'), (u'to', 'TO'), (u'states', 'NNS'), (u',', ','), (u'so', 'IN'), (u'we', 'PRP'), (u'end', 'VBP'), (u'the', 'DT'), (u'waiting', 'NN'), (u'lists', 'NNS'), (u'for', 'IN'), (u'AIDS', 'NNP'), (u'medicines', 'NNS'), (u'in', 'IN'), (u'America', 'NNP'), (u'.', '.')]
# [(u'(', '('), (u'Applause', 'NNP'), (u'.', '.'), (u')', ')')]
# [(u'We', 'PRP'), (u'will', 'MD'), (u'also', 'RB'), (u'lead', 'VB'), (u'a', 'DT'), (u'nationwide', 'JJ'), (u'effort', 'NN'), (u',', ','), (u'working', 'VBG'), (u'closely', 'RB'), (u'with', 'IN'), (u'African', 'JJ'), (u'American', 'JJ'), (u'churches', 'NNS'), (u'and', 'CC'), (u'faith-based', 'JJ'), (u'groups', 'NNS'), (u',', ','), (u'to', 'TO'), (u'deliver', 'VB'), (u'rapid', 'JJ'), (u'HIV', 'NNP'), (u'tests', 'NNS'), (u'to', 'TO'), (u'millions', 'NNS'), (u',', ','), (u'end', 'VBP'), (u'the', 'DT'), (u'stigma', 'NN'), (u'of', 'IN'), (u'AIDS', 'NNP'), (u',', ','), (u'and', 'CC'), (u'come', 'VB'), (u'closer', 'JJR'), (u'to', 'TO'), (u'the', 'DT'), (u'day', 'NN'), (u'when', 'WRB'), (u'there', 'EX'), (u'are', 'VBP'), (u'no', 'DT'), (u'new', 'JJ'), (u'infections', 'NNS'), (u'in', 'IN'), (u'America', 'NNP'), (u'.', '.')]
# [(u'(', '('), (u'Applause', 'NNP'), (u'.', '.'), (u')', ')')]
# [(u'Fellow', 'NNP'), (u'citizens', 'NNS'), (u',', ','), (u'we', 'PRP'), (u"'ve", 'VBP'), (u'been', 'VBN'), (u'called', 'VBN'), (u'to', 'TO'), (u'leadership', 'NN'), (u'in', 'IN'), (u'a', 'DT'), (u'period', 'NN'), (u'of', 'IN'), (u'consequence', 'NN'), (u'.', '.')]
# [(u'We', 'PRP'), (u"'ve", 'VBP'), (u'entered', 'VBN'), (u'a', 'DT'), (u'great', 'JJ'), (u'ideological', 'JJ'), (u'conflict', 'NN'), (u'we', 'PRP'), (u'did', 'VBD'), (u'nothing', 'NN'), (u'to', 'TO'), (u'invite', 'VB'), (u'.', '.')]
# [(u'We', 'PRP'), (u'see', 'VBP'), (u'great', 'JJ'), (u'changes', 'NNS'), (u'in', 'IN'), (u'science', 'NN'), (u'and', 'CC'), (u'commerce', 'NN'), (u'that', 'WDT'), (u'will', 'MD'), (u'influence', 'VB'), (u'all', 'DT'), (u'our', 'PRP$'), (u'lives', 'NNS'), (u'.', '.')]
# [(u'Sometimes', 'RB'), (u'it', 'PRP'), (u'can', 'MD'), (u'seem', 'VB'), (u'that', 'DT'), (u'history', 'NN'), (u'is', 'VBZ'), (u'turning', 'VBG'), (u'in', 'IN'), (u'a', 'DT'), (u'wide', 'JJ'), (u'arc', 'NN'), (u',', ','), (u'toward', 'IN'), (u'an', 'DT'), (u'unknown', 'JJ'), (u'shore', 'NN'), (u'.', '.')]
# [(u'Yet', 'CC'), (u'the', 'DT'), (u'destination', 'NN'), (u'of', 'IN'), (u'history', 'NN'), (u'is', 'VBZ'), (u'determined', 'VBN'), (u'by', 'IN'), (u'human', 'JJ'), (u'action', 'NN'), (u',', ','), (u'and', 'CC'), (u'every', 'DT'), (u'great', 'JJ'), (u'movement', 'NN'), (u'of', 'IN'), (u'history', 'NN'), (u'comes', 'VBZ'), (u'to', 'TO'), (u'a', 'DT'), (u'point', 'NN'), (u'of', 'IN'), (u'choosing', 'NN'), (u'.', '.')]
# [(u'Lincoln', 'NNP'), (u'could', 'MD'), (u'have', 'VB'), (u'accepted', 'VBN'), (u'peace', 'NN'), (u'at', 'IN'), (u'the', 'DT'), (u'cost', 'NN'), (u'of', 'IN'), (u'disunity', 'NN'), (u'and', 'CC'), (u'continued', 'JJ'), (u'slavery', 'NN'), (u'.', '.')]
# [(u'Martin', 'NNP'), (u'Luther', 'NNP'), (u'King', 'NNP'), (u'could', 'MD'), (u'have', 'VB'), (u'stopped', 'VBN'), (u'at', 'IN'), (u'Birmingham', 'NNP'), (u'or', 'CC'), (u'at', 'IN'), (u'Selma', 'NNP'), (u',', ','), (u'and', 'CC'), (u'achieved', 'VBD'), (u'only', 'RB'), (u'half', 'PDT'), (u'a', 'DT'), (u'victory', 'NN'), (u'over', 'IN'), (u'segregation', 'NN'), (u'.', '.')]
# [(u'The', 'DT'), (u'United', 'NNP'), (u'States', 'NNPS'), (u'could', 'MD'), (u'have', 'VB'), (u'accepted', 'VBN'), (u'the', 'DT'), (u'permanent', 'JJ'), (u'division', 'NN'), (u'of', 'IN'), (u'Europe', 'NNP'), (u',', ','), (u'and', 'CC'), (u'been', 'VBN'), (u'complicit', 'NNS'), (u'in', 'IN'), (u'the', 'DT'), (u'oppression', 'NN'), (u'of', 'IN'), (u'others', 'NNS'), (u'.', '.')]
# [(u'Today', 'NN'), (u',', ','), (u'having', 'VBG'), (u'come', 'VBN'), (u'far', 'RB'), (u'in', 'IN'), (u'our', 'PRP$'), (u'own', 'JJ'), (u'historical', 'JJ'), (u'journey', 'NN'), (u',', ','), (u'we', 'PRP'), (u'must', 'MD'), (u'decide', 'VB'), (u':', ':'), (u'Will', 'MD'), (u'we', 'PRP'), (u'turn', 'VB'), (u'back', 'RP'), (u',', ','), (u'or', 'CC'), (u'finish', 'VB'), (u'well', 'RB'), (u'?', '.')]
# [(u'Before', 'IN'), (u'history', 'NN'), (u'is', 'VBZ'), (u'written', 'VBN'), (u'down', 'RP'), (u'in', 'IN'), (u'books', 'NNS'), (u',', ','), (u'it', 'PRP'), (u'is', 'VBZ'), (u'written', 'VBN'), (u'in', 'IN'), (u'courage', 'NN'), (u'.', '.')]
# [(u'Like', 'IN'), (u'Americans', 'NNPS'), (u'before', 'IN'), (u'us', 'PRP'), (u',', ','), (u'we', 'PRP'), (u'will', 'MD'), (u'show', 'VB'), (u'that', 'DT'), (u'courage', 'NN'), (u'and', 'CC'), (u'we', 'PRP'), (u'will', 'MD'), (u'finish', 'VB'), (u'well', 'RB'), (u'.', '.')]
# [(u'We', 'PRP'), (u'will', 'MD'), (u'lead', 'VB'), (u'freedom', 'NN'), (u"'s", 'POS'), (u'advance', 'NN'), (u'.', '.')]
# [(u'We', 'PRP'), (u'will', 'MD'), (u'compete', 'VB'), (u'and', 'CC'), (u'excel', 'VB'), (u'in', 'IN'), (u'the', 'DT'), (u'global', 'JJ'), (u'economy', 'NN'), (u'.', '.')]
# [(u'We', 'PRP'), (u'will', 'MD'), (u'renew', 'VB'), (u'the', 'DT'), (u'defining', 'VBG'), (u'moral', 'JJ'), (u'commitments', 'NNS'), (u'of', 'IN'), (u'this', 'DT'), (u'land', 'NN'), (u'.', '.')]
# [(u'And', 'CC'), (u'so', 'RB'), (u'we', 'PRP'), (u'move', 'VBP'), (u'forward', 'RB'), (u'--', ':'), (u'optimistic', 'JJ'), (u'about', 'IN'), (u'our', 'PRP$'), (u'country', 'NN'), (u',', ','), (u'faithful', 'JJ'), (u'to', 'TO'), (u'its', 'PRP$'), (u'cause', 'NN'), (u',', ','), (u'and', 'CC'), (u'confident', 'NN'), (u'of', 'IN'), (u'the', 'DT'), (u'victories', 'NNS'), (u'to', 'TO'), (u'come', 'VB'), (u'.', '.')]
# [(u'May', 'NNP'), (u'God', 'NNP'), (u'bless', 'NN'), (u'America', 'NNP'), (u'.', '.')]
# [(u'(', '('), (u'Applause', 'NNP'), (u'.', '.'), (u')', ')')]

# %% [markdown]
# # Lesson 5 - Chunking

# %% [markdown]
# - Associating the groups of words/phrases that are tied to the respective noun in a sentence.
# - Chunking is combo of POS tags and regex.

# %%
def process_content():
    try:
        for i in tokenized:
            words = nltk.word_tokenize(i)
            tagged = nltk.pos_tag(words)
            
            chunk_gram = r"""Chunk: {<RB.?>*<VB.?>*<NNP>+<NN>?}""" # looking for this grouping of POS words
            # RB = adverb
            # VB = verb
            # NNP = proper noun
            # NN = noun
            
            chunk_parser = nltk.RegexpParser(chunk_gram)
            chunked = chunk_parser.parse(tagged)
            
            print(chunked)
            # chunked.draw()
            
    except Exception as e:
        print(str(e))
        
process_content()
# Out:
# (S
#   (Chunk PRESIDENT/NNP GEORGE/NNP W./NNP BUSH/NNP)
#   'S/POS
#   (Chunk ADDRESS/NNP)
#   BEFORE/IN
#   (Chunk A/NNP JOINT/NNP SESSION/NNP)
#   OF/IN
#   (Chunk THE/NNP CONGRESS/NNP ON/NNP THE/NNP STATE/NNP)
#   OF/IN
#   (Chunk THE/NNP UNION/NNP January/NNP)
#   31/CD
#   ,/,
#   2006/CD
#   (Chunk THE/NNP PRESIDENT/NNP)
#   :/:
#   (Chunk Thank/NNP)
#   you/PRP
#   all/DT
#   ./.)
# (S
#   (Chunk Mr./NNP Speaker/NNP)
#   ,/,
#   (Chunk Vice/NNP President/NNP Cheney/NNP)
#   ,/,
#   members/NNS
#   of/IN
#   (Chunk Congress/NNP)
#   ,/,
#   members/NNS
#   of/IN
#   the/DT
#   (Chunk Supreme/NNP Court/NNP)
#   and/CC
#   diplomatic/JJ
#   corps/NN
#   ,/,
#   distinguished/JJ
#   guests/NNS
#   ,/,
#   and/CC
#   fellow/JJ
#   citizens/NNS
#   :/:
#   Today/VB
#   our/PRP$
#   nation/NN
#   lost/VBD
#   a/DT
#   beloved/VBN
#   ,/,
#   graceful/JJ
#   ,/,
#   courageous/JJ
#   woman/NN
#   who/WP
#   (Chunk called/VBD America/NNP)
#   to/TO
#   its/PRP$
#   founding/NN
#   ideals/NNS
#   and/CC
#   carried/VBD
#   on/IN
#   a/DT
#   noble/JJ
#   dream/NN
#   ./.)
# (S
#   Tonight/NN
#   we/PRP
#   are/VBP
#   comforted/VBN
#   by/IN
#   the/DT
#   hope/NN
#   of/IN
#   a/DT
#   glad/JJ
#   reunion/NN
#   with/IN
#   the/DT
#   husband/NN
#   who/WP
#   was/VBD
#   taken/VBN
#   so/RB
#   long/RB
#   ago/RB
#   ,/,
#   and/CC
#   we/PRP
#   are/VBP
#   grateful/JJ
#   for/IN
#   the/DT
#   good/JJ
#   life/NN
#   of/IN
#   (Chunk Coretta/NNP Scott/NNP King/NNP)
#   ./.)
# (S (/( (Chunk Applause/NNP) ./. )/))
# (S
#   (Chunk President/NNP George/NNP W./NNP Bush/NNP)
#   reacts/VBZ
#   to/TO
#   applause/VB
#   during/IN
#   his/PRP$
#   (Chunk State/NNP)
#   of/IN
#   the/DT
#   (Chunk Union/NNP Address/NNP)
#   at/IN
#   the/DT
#   (Chunk Capitol/NNP)
#   ,/,
#   (Chunk Tuesday/NNP)
#   ,/,
#   (Chunk Jan/NNP)
#   ./.)
# (S 31/CD ,/, 2006/CD ./.)
# (S
#   (Chunk White/NNP House/NNP photo/NN)
#   by/IN
#   (Chunk Eric/NNP DraperEvery/NNP time/NN)
#   I/PRP
#   'm/VBP
#   invited/JJ
#   to/TO
#   this/DT
#   rostrum/NN
#   ,/,
#   I/PRP
#   'm/VBP
#   humbled/VBN
#   by/IN
#   the/DT
#   privilege/NN
#   ,/,
#   and/CC
#   mindful/NN
#   of/IN
#   the/DT
#   history/NN
#   we/PRP
#   've/VBP
#   seen/VBN
#   together/RB
#   ./.)
# (S
#   We/PRP
#   have/VBP
#   gathered/VBN
#   under/IN
#   this/DT
#   (Chunk Capitol/NNP dome/NN)
#   in/IN
#   moments/NNS
#   of/IN
#   national/JJ
#   mourning/NN
#   and/CC
#   national/JJ
#   achievement/NN
#   ./.)
# (S
#   We/PRP
#   (Chunk have/VBP served/VBN America/NNP)
#   through/IN
#   one/CD
#   of/IN
#   the/DT
#   most/RBS
#   consequential/JJ
#   periods/NNS
#   of/IN
#   our/PRP$
#   history/NN
#   --/:
#   and/CC
#   it/PRP
#   has/VBZ
#   been/VBN
#   my/PRP$
#   honor/NN
#   to/TO
#   serve/VB
#   with/IN
#   you/PRP
#   ./.)
# (S
#   In/IN
#   a/DT
#   system/NN
#   of/IN
#   two/CD
#   parties/NNS
#   ,/,
#   two/CD
#   chambers/NNS
#   ,/,
#   and/CC
#   two/CD
#   elected/JJ
#   branches/NNS
#   ,/,
#   there/EX
#   will/MD
#   always/RB
#   be/VB
#   differences/NNS
#   and/CC
#   debate/NN
#   ./.)
# (S
#   But/CC
#   even/RB
#   tough/JJ
#   debates/NNS
#   can/MD
#   be/VB
#   conducted/VBN
#   in/IN
#   a/DT
#   civil/JJ
#   tone/NN
#   ,/,
#   and/CC
#   our/PRP$
#   differences/NNS
#   can/MD
#   not/RB
#   be/VB
#   allowed/VBN
#   to/TO
#   harden/VB
#   into/IN
#   anger/NN
#   ./.)
# (S
#   To/TO
#   confront/VB
#   the/DT
#   great/JJ
#   issues/NNS
#   before/IN
#   us/PRP
#   ,/,
#   we/PRP
#   must/MD
#   act/VB
#   in/IN
#   a/DT
#   spirit/NN
#   of/IN
#   goodwill/NN
#   and/CC
#   respect/NN
#   for/IN
#   one/CD
#   another/DT
#   --/:
#   and/CC
#   I/PRP
#   will/MD
#   do/VB
#   my/PRP$
#   part/NN
#   ./.)
# (S
#   (Chunk Tonight/NNP)
#   the/DT
#   state/NN
#   of/IN
#   our/PRP$
#   (Chunk Union/NNP)
#   is/VBZ
#   strong/JJ
#   --/:
#   and/CC
#   together/RB
#   we/PRP
#   will/MD
#   make/VB
#   it/PRP
#   stronger/JJR
#   ./.)
# (S (/( (Chunk Applause/NNP) ./. )/))
# (S
#   In/IN
#   this/DT
#   decisive/JJ
#   year/NN
#   ,/,
#   you/PRP
#   and/CC
#   I/PRP
#   will/MD
#   make/VB
#   choices/NNS
#   that/WDT
#   determine/VBP
#   both/DT
#   the/DT
#   future/NN
#   and/CC
#   the/DT
#   character/NN
#   of/IN
#   our/PRP$
#   country/NN
#   ./.)
# (S
#   We/PRP
#   will/MD
#   choose/VB
#   to/TO
#   act/VB
#   confidently/RB
#   in/IN
#   pursuing/VBG
#   the/DT
#   enemies/NNS
#   of/IN
#   freedom/NN
#   --/:
#   or/CC
#   retreat/NN
#   from/IN
#   our/PRP$
#   duties/NNS
#   in/IN
#   the/DT
#   hope/NN
#   of/IN
#   an/DT
#   easier/JJR
#   life/NN
#   ./.)
# (S
#   We/PRP
#   will/MD
#   choose/VB
#   to/TO
#   build/VB
#   our/PRP$
#   prosperity/NN
#   by/IN
#   leading/VBG
#   the/DT
#   world/NN
#   economy/NN
#   --/:
#   or/CC
#   shut/VB
#   ourselves/PRP
#   off/RP
#   from/IN
#   trade/NN
#   and/CC
#   opportunity/NN
#   ./.)
# (S
#   In/IN
#   a/DT
#   complex/JJ
#   and/CC
#   challenging/JJ
#   time/NN
#   ,/,
#   the/DT
#   road/NN
#   of/IN
#   isolationism/NN
#   and/CC
#   protectionism/NN
#   may/MD
#   seem/VB
#   broad/JJ
#   and/CC
#   inviting/NN
#   --/:
#   yet/CC
#   it/PRP
#   ends/VBZ
#   in/IN
#   danger/NN
#   and/CC
#   decline/NN
#   ./.)
# (S
#   The/DT
#   only/JJ
#   way/NN
#   to/TO
#   protect/VB
#   our/PRP$
#   people/NNS
#   ,/,
#   the/DT
#   only/JJ
#   way/NN
#   to/TO
#   secure/VB
#   the/DT
#   peace/NN
#   ,/,
#   the/DT
#   only/JJ
#   way/NN
#   to/TO
#   control/VB
#   our/PRP$
#   destiny/NN
#   is/VBZ
#   by/IN
#   our/PRP$
#   leadership/NN
#   --/:
#   so/IN
#   the/DT
#   (Chunk United/NNP)
#   States/NNPS
#   of/IN
#   (Chunk America/NNP)
#   will/MD
#   continue/VB
#   to/TO
#   lead/VB
#   ./.)
# (S (/( (Chunk Applause/NNP) ./. )/))
# (S
#   Abroad/RB
#   ,/,
#   our/PRP$
#   nation/NN
#   is/VBZ
#   committed/VBN
#   to/TO
#   an/DT
#   historic/JJ
#   ,/,
#   long-term/JJ
#   goal/NN
#   --/:
#   we/PRP
#   seek/VBP
#   the/DT
#   end/NN
#   of/IN
#   tyranny/NN
#   in/IN
#   our/PRP$
#   world/NN
#   ./.)
# (S
#   Some/DT
#   dismiss/VBP
#   that/DT
#   goal/NN
#   as/IN
#   misguided/JJ
#   idealism/NN
#   ./.)
# (S
#   In/IN
#   reality/NN
#   ,/,
#   the/DT
#   future/JJ
#   security/NN
#   of/IN
#   (Chunk America/NNP)
#   depends/VBZ
#   on/IN
#   it/PRP
#   ./.)
# (S
#   On/IN
#   (Chunk September/NNP)
#   the/DT
#   11th/CD
#   ,/,
#   2001/CD
#   ,/,
#   we/PRP
#   found/VBD
#   that/IN
#   problems/NNS
#   originating/VBG
#   in/IN
#   a/DT
#   failed/JJ
#   and/CC
#   oppressive/JJ
#   state/NN
#   7,000/CD
#   miles/NNS
#   away/RB
#   could/MD
#   bring/VB
#   murder/NN
#   and/CC
#   destruction/NN
#   to/TO
#   our/PRP$
#   country/NN
#   ./.)
# (S
#   (Chunk Dictatorships/NNP shelter/NN)
#   terrorists/NNS
#   ,/,
#   and/CC
#   feed/VB
#   resentment/NN
#   and/CC
#   radicalism/NN
#   ,/,
#   and/CC
#   seek/JJ
#   weapons/NNS
#   of/IN
#   mass/NN
#   destruction/NN
#   ./.)
# (S
#   Democracies/NNS
#   replace/VB
#   resentment/NN
#   with/IN
#   hope/NN
#   ,/,
#   respect/VB
#   the/DT
#   rights/NNS
#   of/IN
#   their/PRP$
#   citizens/NNS
#   and/CC
#   their/PRP$
#   neighbors/NNS
#   ,/,
#   and/CC
#   join/VB
#   the/DT
#   fight/NN
#   against/IN
#   terror/NN
#   ./.)
# (S
#   Every/DT
#   step/NN
#   toward/IN
#   freedom/NN
#   in/IN
#   the/DT
#   world/NN
#   makes/VBZ
#   our/PRP$
#   country/NN
#   safer/NN
#   --/:
#   so/IN
#   we/PRP
#   will/MD
#   act/VB
#   boldly/RB
#   in/IN
#   freedom/NN
#   's/POS
#   cause/NN
#   ./.)
# (S (/( (Chunk Applause/NNP) ./. )/))
# (S
#   Far/RB
#   from/IN
#   being/VBG
#   a/DT
#   hopeless/NN
#   dream/NN
#   ,/,
#   the/DT
#   advance/NN
#   of/IN
#   freedom/NN
#   is/VBZ
#   the/DT
#   great/JJ
#   story/NN
#   of/IN
#   our/PRP$
#   time/NN
#   ./.)
# (S
#   In/IN
#   1945/CD
#   ,/,
#   there/EX
#   were/VBD
#   about/RB
#   two/CD
#   dozen/NN
#   lonely/RB
#   democracies/VBZ
#   in/IN
#   the/DT
#   world/NN
#   ./.)
# (S Today/NN ,/, there/EX are/VBP 122/CD ./.)
# (S
#   And/CC
#   we/PRP
#   're/VBP
#   writing/VBG
#   a/DT
#   new/JJ
#   chapter/NN
#   in/IN
#   the/DT
#   story/NN
#   of/IN
#   self-government/JJ
#   --/:
#   with/IN
#   women/NNS
#   lining/VBG
#   up/RP
#   to/TO
#   vote/VB
#   in/IN
#   (Chunk Afghanistan/NNP)
#   ,/,
#   and/CC
#   millions/NNS
#   of/IN
#   (Chunk Iraqis/NNP)
#   marking/VBG
#   their/PRP$
#   liberty/NN
#   with/IN
#   purple/JJ
#   ink/NN
#   ,/,
#   and/CC
#   men/NNS
#   and/CC
#   women/NNS
#   from/IN
#   (Chunk Lebanon/NNP)
#   to/TO
#   (Chunk Egypt/NNP)
#   debating/VBG
#   the/DT
#   rights/NNS
#   of/IN
#   individuals/NNS
#   and/CC
#   the/DT
#   necessity/NN
#   of/IN
#   freedom/NN
#   ./.)
# (S
#   At/IN
#   the/DT
#   start/NN
#   of/IN
#   2006/CD
#   ,/,
#   more/JJR
#   than/IN
#   half/PDT
#   the/DT
#   people/NNS
#   of/IN
#   our/PRP$
#   world/NN
#   live/VBP
#   in/IN
#   democratic/JJ
#   nations/NNS
#   ./.)
# (S
#   And/CC
#   we/PRP
#   do/VBP
#   not/RB
#   forget/VB
#   the/DT
#   other/JJ
#   half/NN
#   --/:
#   in/IN
#   places/NNS
#   like/IN
#   (Chunk Syria/NNP)
#   and/CC
#   (Chunk Burma/NNP)
#   ,/,
#   (Chunk Zimbabwe/NNP)
#   ,/,
#   (Chunk North/NNP Korea/NNP)
#   ,/,
#   and/CC
#   (Chunk Iran/NNP)
#   --/:
#   because/IN
#   the/DT
#   demands/NNS
#   of/IN
#   justice/NN
#   ,/,
#   and/CC
#   the/DT
#   peace/NN
#   of/IN
#   this/DT
#   world/NN
#   ,/,
#   require/VBP
#   their/PRP$
#   freedom/NN
#   ,/,
#   as/RB
#   well/RB
#   ./.)
# (S (/( (Chunk Applause/NNP) ./. )/))
# (S
#   (Chunk President/NNP George/NNP W./NNP Bush/NNP)
#   delivers/VBZ
#   his/PRP$
#   State/NN
#   of/IN
#   the/DT
#   (Chunk Union/NNP Address/NNP)
#   at/IN
#   the/DT
#   (Chunk Capitol/NNP)
#   ,/,
#   (Chunk Tuesday/NNP)
#   ,/,
#   (Chunk Jan/NNP)
#   ./.)
# (S 31/CD ,/, 2006/CD ./.)
# (S
#   (Chunk White/NNP House/NNP photo/NN)
#   by/IN
#   (Chunk Eric/NNP Draper/NNP No/NNP one/NN)
#   can/MD
#   deny/VB
#   the/DT
#   success/NN
#   of/IN
#   freedom/NN
#   ,/,
#   but/CC
#   some/DT
#   men/NNS
#   rage/VB
#   and/CC
#   fight/VB
#   against/IN
#   it/PRP
#   ./.)
# (S
#   And/CC
#   one/CD
#   of/IN
#   the/DT
#   main/JJ
#   sources/NNS
#   of/IN
#   reaction/NN
#   and/CC
#   opposition/NN
#   is/VBZ
#   radical/JJ
#   (Chunk Islam/NNP)
#   --/:
#   the/DT
#   perversion/NN
#   by/IN
#   a/DT
#   few/JJ
#   of/IN
#   a/DT
#   noble/JJ
#   faith/NN
#   into/IN
#   an/DT
#   ideology/NN
#   of/IN
#   terror/NN
#   and/CC
#   death/NN
#   ./.)
# (S
#   Terrorists/NNS
#   like/IN
#   bin/NN
#   (Chunk Laden/NNP)
#   are/VBP
#   serious/JJ
#   about/IN
#   mass/NN
#   murder/NN
#   --/:
#   and/CC
#   all/DT
#   of/IN
#   us/PRP
#   must/MD
#   take/VB
#   their/PRP$
#   declared/JJ
#   intentions/NNS
#   seriously/RB
#   ./.)
# (S
#   They/PRP
#   seek/VBP
#   to/TO
#   impose/VB
#   a/DT
#   heartless/NN
#   system/NN
#   of/IN
#   totalitarian/JJ
#   control/NN
#   throughout/IN
#   the/DT
#   (Chunk Middle/NNP East/NNP)
#   ,/,
#   and/CC
#   arm/NN
#   themselves/PRP
#   with/IN
#   weapons/NNS
#   of/IN
#   mass/NN
#   murder/NN
#   ./.)
# (S
#   Their/PRP$
#   aim/NN
#   is/VBZ
#   to/TO
#   seize/VB
#   power/NN
#   in/IN
#   (Chunk Iraq/NNP)
#   ,/,
#   and/CC
#   use/VB
#   it/PRP
#   as/IN
#   a/DT
#   safe/JJ
#   haven/NN
#   to/TO
#   launch/VB
#   attacks/NNS
#   against/IN
#   (Chunk America/NNP)
#   and/CC
#   the/DT
#   world/NN
#   ./.)
# (S
#   Lacking/VBG
#   the/DT
#   military/JJ
#   strength/NN
#   to/TO
#   challenge/VB
#   us/PRP
#   directly/RB
#   ,/,
#   the/DT
#   terrorists/NNS
#   have/VBP
#   chosen/VBN
#   the/DT
#   weapon/NN
#   of/IN
#   fear/NN
#   ./.)
# (S
#   When/WRB
#   they/PRP
#   murder/VBP
#   children/NNS
#   at/IN
#   a/DT
#   school/NN
#   in/IN
#   (Chunk Beslan/NNP)
#   ,/,
#   or/CC
#   blow/VB
#   up/RP
#   commuters/NNS
#   in/IN
#   (Chunk London/NNP)
#   ,/,
#   or/CC
#   behead/VB
#   a/DT
#   bound/NN
#   captive/NN
#   ,/,
#   the/DT
#   terrorists/NNS
#   hope/VBP
#   these/DT
#   horrors/NNS
#   will/MD
#   break/VB
#   our/PRP$
#   will/MD
#   ,/,
#   allowing/VBG
#   the/DT
#   violent/NN
#   to/TO
#   inherit/VB
#   the/DT
#   (Chunk Earth/NNP)
#   ./.)
# (S
#   But/CC
#   they/PRP
#   have/VBP
#   miscalculated/VBN
#   :/:
#   We/PRP
#   love/VBP
#   our/PRP$
#   freedom/NN
#   ,/,
#   and/CC
#   we/PRP
#   will/MD
#   fight/VB
#   to/TO
#   keep/VB
#   it/PRP
#   ./.)
# (S (/( (Chunk Applause/NNP) ./. )/))
# (S
#   In/IN
#   a/DT
#   time/NN
#   of/IN
#   testing/VBG
#   ,/,
#   we/PRP
#   can/MD
#   not/RB
#   find/VB
#   security/NN
#   by/IN
#   abandoning/VBG
#   our/PRP$
#   commitments/NNS
#   and/CC
#   retreating/VBG
#   within/IN
#   our/PRP$
#   borders/NNS
#   ./.)
# (S
#   If/IN
#   we/PRP
#   were/VBD
#   to/TO
#   leave/VB
#   these/DT
#   vicious/JJ
#   attackers/NNS
#   alone/RB
#   ,/,
#   they/PRP
#   would/MD
#   not/RB
#   leave/VB
#   us/PRP
#   alone/RB
#   ./.)
# (S
#   They/PRP
#   would/MD
#   simply/RB
#   move/VB
#   the/DT
#   battlefield/NN
#   to/TO
#   our/PRP$
#   own/JJ
#   shores/NNS
#   ./.)
# (S There/EX is/VBZ no/DT peace/NN in/IN retreat/NN ./.)
# (S And/CC there/EX is/VBZ no/DT honor/NN in/IN retreat/NN ./.)
# (S
#   By/IN
#   allowing/VBG
#   radical/JJ
#   (Chunk Islam/NNP)
#   to/TO
#   work/VB
#   its/PRP$
#   will/MD
#   --/:
#   by/IN
#   leaving/VBG
#   an/DT
#   assaulted/JJ
#   world/NN
#   to/TO
#   fend/VB
#   for/IN
#   itself/PRP
#   --/:
#   we/PRP
#   would/MD
#   signal/VB
#   to/TO
#   all/PDT
#   that/IN
#   we/PRP
#   no/DT
#   longer/RBR
#   believe/VBP
#   in/IN
#   our/PRP$
#   own/JJ
#   ideals/NNS
#   ,/,
#   or/CC
#   even/RB
#   in/IN
#   our/PRP$
#   own/JJ
#   courage/NN
#   ./.)
# (S
#   But/CC
#   our/PRP$
#   enemies/NNS
#   and/CC
#   our/PRP$
#   friends/NNS
#   can/MD
#   be/VB
#   certain/JJ
#   :/:
#   The/DT
#   (Chunk United/NNP)
#   States/NNPS
#   will/MD
#   not/RB
#   retreat/VB
#   from/IN
#   the/DT
#   world/NN
#   ,/,
#   and/CC
#   we/PRP
#   will/MD
#   never/RB
#   surrender/VB
#   to/TO
#   evil/VB
#   ./.)
# (S (/( (Chunk Applause/NNP) ./. )/))
# (S
#   (Chunk America/NNP)
#   rejects/VBZ
#   the/DT
#   false/JJ
#   comfort/NN
#   of/IN
#   isolationism/NN
#   ./.)
# (S
#   We/PRP
#   are/VBP
#   the/DT
#   nation/NN
#   that/IN
#   saved/VBD
#   liberty/NN
#   in/IN
#   (Chunk Europe/NNP)
#   ,/,
#   and/CC
#   liberated/VBD
#   death/NN
#   camps/NNS
#   ,/,
#   and/CC
#   helped/VBD
#   raise/VB
#   up/RP
#   democracies/NNS
#   ,/,
#   and/CC
#   faced/VBD
#   down/IN
#   an/DT
#   evil/JJ
#   empire/NN
#   ./.)
# (S
#   Once/RB
#   again/RB
#   ,/,
#   we/PRP
#   accept/VBP
#   the/DT
#   call/NN
#   of/IN
#   history/NN
#   to/TO
#   deliver/VB
#   the/DT
#   oppressed/VBN
#   and/CC
#   move/VB
#   this/DT
#   world/NN
#   toward/IN
#   peace/NN
#   ./.)
# (S
#   We/PRP
#   remain/VBP
#   on/IN
#   the/DT
#   offensive/JJ
#   against/IN
#   terror/NN
#   networks/NNS
#   ./.)
# (S
#   We/PRP
#   have/VBP
#   killed/VBN
#   or/CC
#   captured/VBN
#   many/JJ
#   of/IN
#   their/PRP$
#   leaders/NNS
#   --/:
#   and/CC
#   for/IN
#   the/DT
#   others/NNS
#   ,/,
#   their/PRP$
#   day/NN
#   will/MD
#   come/VB
#   ./.)
# (S
#   (Chunk President/NNP George/NNP W./NNP Bush/NNP)
#   greets/VBZ
#   members/NNS
#   of/IN
#   (Chunk Congress/NNP)
#   after/IN
#   his/PRP$
#   State/NN
#   of/IN
#   the/DT
#   (Chunk Union/NNP Address/NNP)
#   at/IN
#   the/DT
#   (Chunk Capitol/NNP)
#   ,/,
#   (Chunk Tuesday/NNP)
#   ,/,
#   (Chunk Jan/NNP)
#   ./.)
# (S 31/CD ,/, 2006/CD ./.)
# (S
#   (Chunk White/NNP House/NNP photo/NN)
#   by/IN
#   (Chunk Eric/NNP Draper/NNP)
#   We/PRP
#   remain/VBP
#   on/IN
#   the/DT
#   offensive/JJ
#   in/IN
#   (Chunk Afghanistan/NNP)
#   ,/,
#   where/WRB
#   a/DT
#   fine/JJ
#   (Chunk President/NNP)
#   and/CC
#   a/DT
#   (Chunk National/NNP Assembly/NNP)
#   are/VBP
#   fighting/VBG
#   terror/NN
#   while/IN
#   building/VBG
#   the/DT
#   institutions/NNS
#   of/IN
#   a/DT
#   new/JJ
#   democracy/NN
#   ./.)
# (S
#   We/PRP
#   're/VBP
#   on/IN
#   the/DT
#   offensive/JJ
#   in/IN
#   (Chunk Iraq/NNP)
#   ,/,
#   with/IN
#   a/DT
#   clear/JJ
#   plan/NN
#   for/IN
#   victory/NN
#   ./.)
# (S
#   First/RB
#   ,/,
#   we/PRP
#   (Chunk 're/VBP helping/VBG Iraqis/NNP)
#   build/VB
#   an/DT
#   inclusive/JJ
#   government/NN
#   ,/,
#   so/IN
#   that/DT
#   old/JJ
#   resentments/NNS
#   will/MD
#   be/VB
#   eased/VBN
#   and/CC
#   the/DT
#   insurgency/NN
#   will/MD
#   be/VB
#   marginalized/VBN
#   ./.)
# (S
#   Second/JJ
#   ,/,
#   we/PRP
#   're/VBP
#   continuing/VBG
#   reconstruction/NN
#   efforts/NNS
#   ,/,
#   and/CC
#   helping/VBG
#   the/DT
#   (Chunk Iraqi/NNP government/NN)
#   to/TO
#   fight/VB
#   corruption/NN
#   and/CC
#   build/VB
#   a/DT
#   modern/JJ
#   economy/NN
#   ,/,
#   so/IN
#   all/DT
#   (Chunk Iraqis/NNP)
#   can/MD
#   experience/VB
#   the/DT
#   benefits/NNS
#   of/IN
#   freedom/NN
#   ./.)
# (S
#   And/CC
#   ,/,
#   third/JJ
#   ,/,
#   we/PRP
#   're/VBP
#   striking/VBG
#   terrorist/JJ
#   targets/NNS
#   while/IN
#   we/PRP
#   train/VBP
#   Iraqi/JJ
#   forces/NNS
#   that/WDT
#   are/VBP
#   increasingly/RB
#   capable/JJ
#   of/IN
#   defeating/VBG
#   the/DT
#   enemy/NN
#   ./.)
# (S
#   (Chunk Iraqis/NNP)
#   are/VBP
#   showing/VBG
#   their/PRP$
#   courage/NN
#   every/DT
#   day/NN
#   ,/,
#   and/CC
#   we/PRP
#   are/VBP
#   proud/JJ
#   to/TO
#   be/VB
#   their/PRP$
#   allies/NNS
#   in/IN
#   the/DT
#   cause/NN
#   of/IN
#   freedom/NN
#   ./.)
# (S (/( (Chunk Applause/NNP) ./. )/))
# (S
#   Our/PRP$
#   work/NN
#   in/IN
#   (Chunk Iraq/NNP)
#   is/VBZ
#   difficult/JJ
#   because/IN
#   our/PRP$
#   enemy/NN
#   is/VBZ
#   brutal/JJ
#   ./.)
# (S
#   But/CC
#   that/DT
#   brutality/NN
#   has/VBZ
#   not/RB
#   stopped/VBN
#   the/DT
#   dramatic/JJ
#   progress/NN
#   of/IN
#   a/DT
#   new/JJ
#   democracy/NN
#   ./.)
# (S
#   In/IN
#   less/JJR
#   than/IN
#   three/CD
#   years/NNS
#   ,/,
#   the/DT
#   nation/NN
#   has/VBZ
#   gone/VBN
#   from/IN
#   dictatorship/NN
#   to/TO
#   liberation/NN
#   ,/,
#   to/TO
#   sovereignty/VB
#   ,/,
#   to/TO
#   a/DT
#   constitution/NN
#   ,/,
#   to/TO
#   national/JJ
#   elections/NNS
#   ./.)
# (S
#   At/IN
#   the/DT
#   same/JJ
#   time/NN
#   ,/,
#   our/PRP$
#   coalition/NN
#   has/VBZ
#   been/VBN
#   relentless/VBN
#   in/IN
#   shutting/VBG
#   off/RP
#   terrorist/JJ
#   infiltration/NN
#   ,/,
#   clearing/VBG
#   out/RP
#   insurgent/JJ
#   strongholds/NNS
#   ,/,
#   and/CC
#   turning/VBG
#   over/RP
#   territory/NN
#   to/TO
#   (Chunk Iraqi/NNP security/NN)
#   forces/NNS
#   ./.)
# (S
#   I/PRP
#   am/VBP
#   confident/JJ
#   in/IN
#   our/PRP$
#   plan/NN
#   for/IN
#   victory/NN
#   ;/:
#   I/PRP
#   am/VBP
#   confident/JJ
#   in/IN
#   the/DT
#   will/MD
#   of/IN
#   the/DT
#   (Chunk Iraqi/NNP)
#   people/NNS
#   ;/:
#   I/PRP
#   am/VBP
#   confident/JJ
#   in/IN
#   the/DT
#   skill/NN
#   and/CC
#   spirit/NN
#   of/IN
#   our/PRP$
#   military/JJ
#   ./.)
# (S
#   (Chunk Fellow/NNP)
#   citizens/NNS
#   ,/,
#   we/PRP
#   are/VBP
#   in/IN
#   this/DT
#   fight/NN
#   to/TO
#   win/VB
#   ,/,
#   and/CC
#   we/PRP
#   are/VBP
#   winning/VBG
#   ./.)
# (S (/( (Chunk Applause/NNP) ./. )/))
# (S
#   The/DT
#   road/NN
#   of/IN
#   victory/NN
#   is/VBZ
#   the/DT
#   road/NN
#   that/WDT
#   will/MD
#   take/VB
#   our/PRP$
#   troops/NNS
#   home/NN
#   ./.)
# (S
#   As/IN
#   we/PRP
#   make/VBP
#   progress/NN
#   on/IN
#   the/DT
#   ground/NN
#   ,/,
#   and/CC
#   (Chunk Iraqi/NNP)
#   forces/NNS
#   increasingly/RB
#   take/VBP
#   the/DT
#   lead/NN
#   ,/,
#   we/PRP
#   should/MD
#   be/VB
#   able/JJ
#   to/TO
#   further/JJ
#   decrease/VB
#   our/PRP$
#   troop/NN
#   levels/NNS
#   --/:
#   but/CC
#   those/DT
#   decisions/NNS
#   will/MD
#   be/VB
#   made/VBN
#   by/IN
#   our/PRP$
#   military/JJ
#   commanders/NNS
#   ,/,
#   not/RB
#   by/IN
#   politicians/NNS
#   in/IN
#   (Chunk Washington/NNP)
#   ,/,
#   (Chunk D.C/NNP)
#   ./.)
# (S (/( (Chunk Applause/NNP) ./. )/))
# (S
#   Our/PRP$
#   coalition/NN
#   has/VBZ
#   learned/VBN
#   from/IN
#   our/PRP$
#   experience/NN
#   in/IN
#   (Chunk Iraq/NNP)
#   ./.)
# (S
#   We/PRP
#   've/VBP
#   adjusted/VBN
#   our/PRP$
#   military/JJ
#   tactics/NNS
#   and/CC
#   changed/VBD
#   our/PRP$
#   approach/NN
#   to/TO
#   reconstruction/NN
#   ./.)
# (S
#   Along/IN
#   the/DT
#   way/NN
#   ,/,
#   we/PRP
#   have/VBP
#   benefitted/VBN
#   from/IN
#   responsible/JJ
#   criticism/NN
#   and/CC
#   counsel/NN
#   offered/VBN
#   by/IN
#   members/NNS
#   of/IN
#   (Chunk Congress/NNP)
#   of/IN
#   both/DT
#   parties/NNS
#   ./.)
# (S
#   In/IN
#   the/DT
#   coming/VBG
#   year/NN
#   ,/,
#   I/PRP
#   will/MD
#   continue/VB
#   to/TO
#   reach/VB
#   out/RP
#   and/CC
#   seek/VB
#   your/PRP$
#   good/JJ
#   advice/NN
#   ./.)
# (S
#   Yet/RB
#   ,/,
#   there/EX
#   is/VBZ
#   a/DT
#   difference/NN
#   between/IN
#   responsible/JJ
#   criticism/NN
#   that/WDT
#   aims/VBZ
#   for/IN
#   success/NN
#   ,/,
#   and/CC
#   defeatism/NN
#   that/WDT
#   refuses/VBZ
#   to/TO
#   acknowledge/VB
#   anything/NN
#   but/CC
#   failure/NN
#   ./.)
# (S (/( (Chunk Applause/NNP) ./. )/))
# (S
#   (Chunk Hindsight/NNP)
#   alone/RB
#   is/VBZ
#   not/RB
#   wisdom/JJ
#   ,/,
#   and/CC
#   second-guessing/NN
#   is/VBZ
#   not/RB
#   a/DT
#   strategy/NN
#   ./.)
# (S (/( (Chunk Applause/NNP) ./. )/))
# (S
#   With/IN
#   so/RB
#   much/JJ
#   in/IN
#   the/DT
#   balance/NN
#   ,/,
#   those/DT
#   of/IN
#   us/PRP
#   in/IN
#   public/JJ
#   office/NN
#   have/VBP
#   a/DT
#   duty/NN
#   to/TO
#   speak/VB
#   with/IN
#   candor/NN
#   ./.)
# (S
#   A/DT
#   sudden/JJ
#   withdrawal/NN
#   of/IN
#   our/PRP$
#   forces/NNS
#   from/IN
#   (Chunk Iraq/NNP)
#   would/MD
#   abandon/VB
#   our/PRP$
#   (Chunk Iraqi/NNP)
#   allies/NNS
#   to/TO
#   death/NN
#   and/CC
#   prison/NN
#   ,/,
#   would/MD
#   put/VB
#   men/NNS
#   like/IN
#   bin/NN
#   (Chunk Laden/NNP)
#   and/CC
#   (Chunk Zarqawi/NNP)
#   in/IN
#   charge/NN
#   of/IN
#   a/DT
#   strategic/JJ
#   country/NN
#   ,/,
#   and/CC
#   show/VBP
#   that/IN
#   a/DT
#   pledge/NN
#   from/IN
#   (Chunk America/NNP)
#   means/VBZ
#   little/JJ
#   ./.)
# (S
#   Members/NNS
#   of/IN
#   (Chunk Congress/NNP)
#   ,/,
#   however/RB
#   we/PRP
#   feel/VBP
#   about/IN
#   the/DT
#   decisions/NNS
#   and/CC
#   debates/NNS
#   of/IN
#   the/DT
#   past/NN
#   ,/,
#   our/PRP$
#   nation/NN
#   has/VBZ
#   only/RB
#   one/CD
#   option/NN
#   :/:
#   We/PRP
#   must/MD
#   keep/VB
#   our/PRP$
#   word/NN
#   ,/,
#   defeat/VB
#   our/PRP$
#   enemies/NNS
#   ,/,
#   and/CC
#   stand/VBP
#   behind/IN
#   the/DT
#   American/JJ
#   military/NN
#   in/IN
#   this/DT
#   vital/JJ
#   mission/NN
#   ./.)
# (S (/( (Chunk Applause/NNP) ./. )/))
# (S
#   (Chunk Laura/NNP Bush/NNP)
#   is/VBZ
#   applauded/VBN
#   as/IN
#   she/PRP
#   (Chunk is/VBZ introduced/VBN Tuesday/NNP evening/NN)
#   ,/,
#   (Chunk Jan/NNP)
#   ./.)
# (S
#   31/CD
#   ,/,
#   2006/CD
#   during/IN
#   the/DT
#   (Chunk State/NNP)
#   of/IN
#   the/DT
#   (Chunk Union/NNP Address/NNP)
#   at/IN
#   (Chunk United/NNP)
#   States/NNPS
#   (Chunk Capitol/NNP)
#   in/IN
#   (Chunk Washington/NNP)
#   ./.)
# (S
#   (Chunk White/NNP House/NNP photo/NN)
#   by/IN
#   (Chunk Eric/NNP Draper/NNP)
#   Our/PRP$
#   men/NNS
#   and/CC
#   women/NNS
#   in/IN
#   uniform/JJ
#   are/VBP
#   making/VBG
#   sacrifices/NNS
#   --/:
#   and/CC
#   showing/VBG
#   a/DT
#   sense/NN
#   of/IN
#   duty/NN
#   stronger/JJR
#   than/IN
#   all/DT
#   fear/NN
#   ./.)
# (S
#   They/PRP
#   know/VBP
#   what/WP
#   it/PRP
#   's/VBZ
#   like/IN
#   to/TO
#   fight/VB
#   house/NN
#   to/TO
#   house/NN
#   in/IN
#   a/DT
#   maze/NN
#   of/IN
#   streets/NNS
#   ,/,
#   to/TO
#   wear/VB
#   heavy/JJ
#   gear/NN
#   in/IN
#   the/DT
#   desert/NN
#   heat/NN
#   ,/,
#   to/TO
#   see/VB
#   a/DT
#   comrade/NN
#   killed/VBN
#   by/IN
#   a/DT
#   roadside/NN
#   bomb/NN
#   ./.)
# (S
#   And/CC
#   those/DT
#   who/WP
#   know/VBP
#   the/DT
#   costs/NNS
#   also/RB
#   know/VBP
#   the/DT
#   stakes/NNS
#   ./.)
# (S
#   Marine/JJ
#   (Chunk Staff/NNP Sergeant/NNP Dan/NNP Clay/NNP)
#   was/VBD
#   killed/VBN
#   last/JJ
#   month/NN
#   fighting/VBG
#   in/IN
#   (Chunk Fallujah/NNP)
#   ./.)
# (S
#   He/PRP
#   left/VBD
#   behind/RP
#   a/DT
#   letter/NN
#   to/TO
#   his/PRP$
#   family/NN
#   ,/,
#   but/CC
#   his/PRP$
#   words/NNS
#   could/MD
#   just/RB
#   as/RB
#   well/RB
#   be/VB
#   addressed/VBN
#   to/TO
#   every/DT
#   (Chunk American/NNP)
#   ./.)
# (S
#   Here/RB
#   is/VBZ
#   what/WP
#   (Chunk Dan/NNP)
#   wrote/VBD
#   :/:
#   ``/``
#   I/PRP
#   know/VBP
#   what/WP
#   honor/NN
#   is/VBZ
#   ./.)
# (S
#   .../:
#   It/PRP
#   has/VBZ
#   been/VBN
#   an/DT
#   honor/NN
#   to/TO
#   protect/VB
#   and/CC
#   serve/VB
#   all/DT
#   of/IN
#   you/PRP
#   ./.)
# (S
#   I/PRP
#   faced/VBD
#   death/NN
#   with/IN
#   the/DT
#   secure/NN
#   knowledge/NN
#   that/IN
#   you/PRP
#   would/MD
#   not/RB
#   have/VB
#   to/TO
#   .../:
#   ./.)
# (S Never/RB falter/NN !/.)
# (S
#   Do/VBP
#   n't/RB
#   hesitate/VB
#   to/TO
#   honor/VB
#   and/CC
#   support/VB
#   those/DT
#   of/IN
#   us/PRP
#   who/WP
#   have/VBP
#   the/DT
#   honor/NN
#   of/IN
#   protecting/VBG
#   that/DT
#   which/WDT
#   is/VBZ
#   worth/JJ
#   protecting/VBG
#   ./.
#   ''/'')
# (S
#   (Chunk Staff/NNP Sergeant/NNP Dan/NNP Clay/NNP)
#   's/POS
#   wife/NN
#   ,/,
#   (Chunk Lisa/NNP)
#   ,/,
#   and/CC
#   his/PRP$
#   mom/NN
#   and/CC
#   dad/NN
#   ,/,
#   (Chunk Sara/NNP Jo/NNP)
#   and/CC
#   (Chunk Bud/NNP)
#   ,/,
#   are/VBP
#   with/IN
#   us/PRP
#   this/DT
#   evening/NN
#   ./.)
# (S (Chunk Welcome/NNP) ./.)
# (S (/( (Chunk Applause/NNP) ./. )/))
# (S
#   Our/PRP$
#   nation/NN
#   is/VBZ
#   grateful/JJ
#   to/TO
#   the/DT
#   fallen/VBN
#   ,/,
#   who/WP
#   live/VBP
#   in/IN
#   the/DT
#   memory/NN
#   of/IN
#   our/PRP$
#   country/NN
#   ./.)
# (S
#   We/PRP
#   're/VBP
#   grateful/JJ
#   to/TO
#   all/DT
#   who/WP
#   volunteer/VBP
#   to/TO
#   wear/VB
#   our/PRP$
#   nation/NN
#   's/POS
#   uniform/NN
#   --/:
#   and/CC
#   as/IN
#   we/PRP
#   honor/VBP
#   our/PRP$
#   brave/NN
#   troops/NNS
#   ,/,
#   let/VB
#   us/PRP
#   never/RB
#   forget/VBP
#   the/DT
#   sacrifices/NNS
#   of/IN
#   (Chunk America/NNP)
#   's/POS
#   military/JJ
#   families/NNS
#   ./.)
# (S (/( (Chunk Applause/NNP) ./. )/))
# (S
#   Our/PRP$
#   offensive/JJ
#   against/IN
#   terror/NN
#   involves/VBZ
#   more/JJR
#   than/IN
#   military/JJ
#   action/NN
#   ./.)
# (S
#   Ultimately/RB
#   ,/,
#   the/DT
#   only/JJ
#   way/NN
#   to/TO
#   defeat/VB
#   the/DT
#   terrorists/NNS
#   is/VBZ
#   to/TO
#   defeat/VB
#   their/PRP$
#   dark/JJ
#   vision/NN
#   of/IN
#   hatred/VBN
#   and/CC
#   fear/VBN
#   by/IN
#   offering/VBG
#   the/DT
#   hopeful/JJ
#   alternative/NN
#   of/IN
#   political/JJ
#   freedom/NN
#   and/CC
#   peaceful/JJ
#   change/NN
#   ./.)
# (S
#   So/IN
#   the/DT
#   (Chunk United/NNP)
#   States/NNPS
#   of/IN
#   (Chunk America/NNP)
#   supports/NNS
#   democratic/JJ
#   reform/NN
#   across/IN
#   the/DT
#   broader/JJR
#   (Chunk Middle/NNP East/NNP)
#   ./.)
# (S
#   Elections/NNS
#   are/VBP
#   vital/JJ
#   ,/,
#   but/CC
#   they/PRP
#   are/VBP
#   only/RB
#   the/DT
#   beginning/NN
#   ./.)
# (S
#   Raising/VBG
#   up/RP
#   a/DT
#   democracy/NN
#   requires/VBZ
#   the/DT
#   rule/NN
#   of/IN
#   law/NN
#   ,/,
#   and/CC
#   protection/NN
#   of/IN
#   minorities/NNS
#   ,/,
#   and/CC
#   strong/JJ
#   ,/,
#   accountable/JJ
#   institutions/NNS
#   that/IN
#   last/JJ
#   longer/JJR
#   than/IN
#   a/DT
#   single/JJ
#   vote/NN
#   ./.)
# (S
#   The/DT
#   great/JJ
#   people/NNS
#   of/IN
#   (Chunk Egypt/NNP)
#   have/VBP
#   voted/VBN
#   in/IN
#   a/DT
#   multi-party/JJ
#   presidential/JJ
#   election/NN
#   --/:
#   and/CC
#   now/RB
#   their/PRP$
#   government/NN
#   should/MD
#   open/VB
#   paths/NNS
#   of/IN
#   peaceful/JJ
#   opposition/NN
#   that/WDT
#   will/MD
#   reduce/VB
#   the/DT
#   appeal/NN
#   of/IN
#   radicalism/NN
#   ./.)
# (S
#   The/DT
#   Palestinian/JJ
#   people/NNS
#   have/VBP
#   voted/VBN
#   in/IN
#   elections/NNS
#   ./.)
# (S
#   And/CC
#   now/RB
#   the/DT
#   leaders/NNS
#   of/IN
#   (Chunk Hamas/NNP)
#   must/MD
#   (Chunk recognize/VB Israel/NNP)
#   ,/,
#   disarm/NN
#   ,/,
#   reject/JJ
#   terrorism/NN
#   ,/,
#   and/CC
#   work/NN
#   for/IN
#   lasting/VBG
#   peace/NN
#   ./.)
# (S (/( (Chunk Applause/NNP) ./. )/))
# (S
#   (Chunk Saudi/NNP Arabia/NNP)
#   has/VBZ
#   taken/VBN
#   the/DT
#   first/JJ
#   steps/NNS
#   of/IN
#   reform/NN
#   --/:
#   now/RB
#   it/PRP
#   can/MD
#   offer/VB
#   its/PRP$
#   people/NNS
#   a/DT
#   better/JJR
#   future/NN
#   by/IN
#   pressing/VBG
#   forward/RB
#   with/IN
#   those/DT
#   efforts/NNS
#   ./.)
# (S
#   Democracies/NNS
#   in/IN
#   the/DT
#   (Chunk Middle/NNP East/NNP)
#   will/MD
#   not/RB
#   look/VB
#   like/IN
#   our/PRP$
#   own/JJ
#   ,/,
#   because/IN
#   they/PRP
#   will/MD
#   reflect/VB
#   the/DT
#   traditions/NNS
#   of/IN
#   their/PRP$
#   own/JJ
#   citizens/NNS
#   ./.)
# (S
#   Yet/RB
#   liberty/NN
#   is/VBZ
#   the/DT
#   future/NN
#   of/IN
#   every/DT
#   nation/NN
#   in/IN
#   the/DT
#   (Chunk Middle/NNP East/NNP)
#   ,/,
#   because/IN
#   liberty/NN
#   is/VBZ
#   the/DT
#   right/NN
#   and/CC
#   hope/NN
#   of/IN
#   all/DT
#   humanity/NN
#   ./.)
# (S (/( (Chunk Applause/NNP) ./. )/))
# (S
#   (Chunk President/NNP George/NNP W./NNP Bush/NNP)
#   waves/VBZ
#   toward/IN
#   the/DT
#   upper/JJ
#   visitors/NNS
#   gallery/NN
#   of/IN
#   the/DT
#   (Chunk House/NNP Chamber/NNP)
#   following/VBG
#   his/PRP$
#   State/NN
#   of/IN
#   the/DT
#   (Chunk Union/NNP)
#   remarks/NNS
#   (Chunk Tuesday/NNP)
#   ,/,
#   (Chunk Jan/NNP)
#   ./.)
# (S
#   31/CD
#   ,/,
#   2006/CD
#   at/IN
#   the/DT
#   (Chunk United/NNP)
#   States/NNPS
#   (Chunk Capitol/NNP)
#   ./.)
# (S
#   (Chunk White/NNP House/NNP photo/NN)
#   by/IN
#   (Chunk Eric/NNP Draper/NNP)
#   The/DT
#   same/JJ
#   is/VBZ
#   true/JJ
#   of/IN
#   (Chunk Iran/NNP)
#   ,/,
#   a/DT
#   nation/NN
#   now/RB
#   held/VBN
#   hostage/NN
#   by/IN
#   a/DT
#   small/JJ
#   clerical/JJ
#   elite/NN
#   that/WDT
#   is/VBZ
#   isolating/VBG
#   and/CC
#   repressing/VBG
#   its/PRP$
#   people/NNS
#   ./.)
# (S
#   The/DT
#   regime/NN
#   in/IN
#   that/DT
#   country/NN
#   sponsors/NNS
#   terrorists/NNS
#   in/IN
#   the/DT
#   Palestinian/JJ
#   territories/NNS
#   and/CC
#   in/IN
#   (Chunk Lebanon/NNP)
#   --/:
#   and/CC
#   that/DT
#   must/MD
#   come/VB
#   to/TO
#   an/DT
#   end/NN
#   ./.)
# (S (/( (Chunk Applause/NNP) ./. )/))
# (S
#   The/DT
#   Iranian/JJ
#   government/NN
#   is/VBZ
#   defying/VBG
#   the/DT
#   world/NN
#   with/IN
#   its/PRP$
#   nuclear/JJ
#   ambitions/NNS
#   ,/,
#   and/CC
#   the/DT
#   nations/NNS
#   of/IN
#   the/DT
#   world/NN
#   must/MD
#   not/RB
#   permit/VB
#   the/DT
#   Iranian/JJ
#   regime/NN
#   to/TO
#   gain/VB
#   nuclear/JJ
#   weapons/NNS
#   ./.)
# (S (/( (Chunk Applause/NNP) ./. )/))
# (S
#   (Chunk America/NNP)
#   will/MD
#   continue/VB
#   to/TO
#   rally/VB
#   the/DT
#   world/NN
#   to/TO
#   confront/VB
#   these/DT
#   threats/NNS
#   ./.)
# (S
#   (Chunk Tonight/NNP)
#   ,/,
#   let/VB
#   me/PRP
#   speak/VB
#   directly/RB
#   to/TO
#   the/DT
#   citizens/NNS
#   of/IN
#   (Chunk Iran/NNP)
#   :/:
#   (Chunk America/NNP)
#   respects/VBZ
#   you/PRP
#   ,/,
#   and/CC
#   we/PRP
#   respect/VBP
#   your/PRP$
#   country/NN
#   ./.)
# (S
#   We/PRP
#   respect/VBP
#   your/PRP$
#   right/NN
#   to/TO
#   choose/VB
#   your/PRP$
#   own/JJ
#   future/NN
#   and/CC
#   win/VB
#   your/PRP$
#   own/JJ
#   freedom/NN
#   ./.)
# (S
#   And/CC
#   our/PRP$
#   nation/NN
#   hopes/VBZ
#   one/CD
#   day/NN
#   to/TO
#   be/VB
#   the/DT
#   closest/JJS
#   of/IN
#   friends/NNS
#   with/IN
#   a/DT
#   free/JJ
#   and/CC
#   democratic/JJ
#   (Chunk Iran/NNP)
#   ./.)
# (S (/( (Chunk Applause/NNP) ./. )/))
# (S
#   To/TO
#   overcome/VB
#   dangers/NNS
#   in/IN
#   our/PRP$
#   world/NN
#   ,/,
#   we/PRP
#   must/MD
#   also/RB
#   take/VB
#   the/DT
#   offensive/JJ
#   by/IN
#   encouraging/VBG
#   economic/JJ
#   progress/NN
#   ,/,
#   and/CC
#   fighting/VBG
#   disease/NN
#   ,/,
#   and/CC
#   spreading/VBG
#   hope/NN
#   in/IN
#   hopeless/JJ
#   lands/NNS
#   ./.)
# (S
#   (Chunk Isolationism/NNP)
#   would/MD
#   not/RB
#   only/RB
#   tie/VB
#   our/PRP$
#   hands/NNS
#   in/IN
#   fighting/VBG
#   enemies/NNS
#   ,/,
#   it/PRP
#   would/MD
#   keep/VB
#   us/PRP
#   from/IN
#   helping/VBG
#   our/PRP$
#   friends/NNS
#   in/IN
#   desperate/JJ
#   need/NN
#   ./.)
# (S
#   We/PRP
#   show/VBP
#   compassion/JJ
#   abroad/RB
#   because/IN
#   Americans/NNPS
#   believe/VBP
#   in/IN
#   the/DT
#   (Chunk God-given/NNP dignity/NN)
#   and/CC
#   worth/NN
#   of/IN
#   a/DT
#   villager/NN
#   with/IN
#   (Chunk HIV/AIDS/NNP)
#   ,/,
#   or/CC
#   an/DT
#   infant/NN
#   with/IN
#   malaria/NNS
#   ,/,
#   or/CC
#   a/DT
#   refugee/JJ
#   fleeing/NN
#   genocide/NN
#   ,/,
#   or/CC
#   a/DT
#   young/JJ
#   girl/NN
#   sold/VBN
#   into/IN
#   slavery/NN
#   ./.)
# (S
#   We/PRP
#   also/RB
#   show/VBP
#   compassion/NN
#   abroad/RB
#   because/IN
#   regions/NNS
#   overwhelmed/VBN
#   by/IN
#   poverty/NN
#   ,/,
#   corruption/NN
#   ,/,
#   and/CC
#   despair/NN
#   are/VBP
#   sources/NNS
#   of/IN
#   terrorism/NN
#   ,/,
#   and/CC
#   organized/VBD
#   crime/NN
#   ,/,
#   and/CC
#   human/JJ
#   trafficking/NN
#   ,/,
#   and/CC
#   the/DT
#   drug/NN
#   trade/NN
#   ./.)
# (S
#   In/IN
#   recent/JJ
#   years/NNS
#   ,/,
#   you/PRP
#   and/CC
#   I/PRP
#   have/VBP
#   taken/VBN
#   unprecedented/JJ
#   action/NN
#   to/TO
#   (Chunk fight/VB AIDS/NNP)
#   and/CC
#   malaria/NNS
#   ,/,
#   expand/VBP
#   the/DT
#   education/NN
#   of/IN
#   girls/NNS
#   ,/,
#   and/CC
#   reward/RB
#   developing/VBG
#   nations/NNS
#   that/WDT
#   are/VBP
#   moving/VBG
#   forward/RB
#   with/IN
#   economic/JJ
#   and/CC
#   political/JJ
#   reform/NN
#   ./.)
# (S
#   For/IN
#   people/NNS
#   everywhere/RB
#   ,/,
#   the/DT
#   (Chunk United/NNP)
#   States/NNPS
#   is/VBZ
#   a/DT
#   partner/NN
#   for/IN
#   a/DT
#   better/JJR
#   life/NN
#   ./.)
# (S
#   Short-changing/VBG
#   these/DT
#   efforts/NNS
#   would/MD
#   increase/VB
#   the/DT
#   suffering/NN
#   and/CC
#   chaos/NN
#   of/IN
#   our/PRP$
#   world/NN
#   ,/,
#   undercut/JJ
#   our/PRP$
#   long-term/JJ
#   security/NN
#   ,/,
#   and/CC
#   dull/VB
#   the/DT
#   conscience/NN
#   of/IN
#   our/PRP$
#   country/NN
#   ./.)
# (S
#   I/PRP
#   urge/VBP
#   members/NNS
#   of/IN
#   (Chunk Congress/NNP)
#   to/TO
#   serve/VB
#   the/DT
#   interests/NNS
#   of/IN
#   (Chunk America/NNP)
#   by/IN
#   showing/VBG
#   the/DT
#   compassion/NN
#   of/IN
#   (Chunk America/NNP)
#   ./.)
# (S
#   Our/PRP$
#   country/NN
#   must/MD
#   also/RB
#   remain/VB
#   on/IN
#   the/DT
#   offensive/JJ
#   against/IN
#   terrorism/NN
#   here/RB
#   at/IN
#   home/NN
#   ./.)
# (S
#   The/DT
#   enemy/NN
#   has/VBZ
#   not/RB
#   lost/VBN
#   the/DT
#   desire/NN
#   or/CC
#   capability/NN
#   to/TO
#   attack/VB
#   us/PRP
#   ./.)
# (S
#   Fortunately/RB
#   ,/,
#   this/DT
#   nation/NN
#   has/VBZ
#   superb/VBN
#   professionals/NNS
#   in/IN
#   law/NN
#   enforcement/NN
#   ,/,
#   intelligence/NN
#   ,/,
#   the/DT
#   military/JJ
#   ,/,
#   and/CC
#   homeland/VBP
#   security/NN
#   ./.)
# (S
#   These/DT
#   men/NNS
#   and/CC
#   women/NNS
#   are/VBP
#   dedicating/VBG
#   their/PRP$
#   lives/NNS
#   ,/,
#   protecting/VBG
#   us/PRP
#   all/DT
#   ,/,
#   and/CC
#   they/PRP
#   deserve/VBP
#   our/PRP$
#   support/NN
#   and/CC
#   our/PRP$
#   thanks/NNS
#   ./.)
# (S (/( (Chunk Applause/NNP) ./. )/))
# (S
#   They/PRP
#   also/RB
#   deserve/VBP
#   the/DT
#   same/JJ
#   tools/NNS
#   they/PRP
#   already/RB
#   use/VBP
#   to/TO
#   fight/VB
#   drug/NN
#   trafficking/NN
#   and/CC
#   organized/VBN
#   crime/NN
#   --/:
#   so/RB
#   I/PRP
#   ask/VBP
#   you/PRP
#   to/TO
#   reauthorize/VB
#   the/DT
#   (Chunk Patriot/NNP Act/NNP)
#   ./.)
# (S (/( (Chunk Applause/NNP) ./. )/))
# (S
#   It/PRP
#   is/VBZ
#   said/VBD
#   that/IN
#   prior/JJ
#   to/TO
#   the/DT
#   attacks/NNS
#   of/IN
#   (Chunk September/NNP)
#   the/DT
#   11th/CD
#   ,/,
#   our/PRP$
#   government/NN
#   failed/VBD
#   to/TO
#   connect/VB
#   the/DT
#   dots/NNS
#   of/IN
#   the/DT
#   conspiracy/NN
#   ./.)
# (S
#   We/PRP
#   now/RB
#   know/VBP
#   that/IN
#   two/CD
#   of/IN
#   the/DT
#   hijackers/NNS
#   in/IN
#   the/DT
#   (Chunk United/NNP)
#   States/NNPS
#   placed/VBD
#   telephone/NN
#   calls/NNS
#   to/TO
#   (Chunk al/VB Qaeda/NNP)
#   operatives/VBZ
#   overseas/RB
#   ./.)
# (S
#   But/CC
#   we/PRP
#   did/VBD
#   not/RB
#   know/VB
#   about/IN
#   their/PRP$
#   plans/NNS
#   until/IN
#   it/PRP
#   was/VBD
#   too/RB
#   late/JJ
#   ./.)
# (S
#   So/RB
#   to/TO
#   prevent/VB
#   another/DT
#   attack/NN
#   --/:
#   based/VBN
#   on/IN
#   authority/NN
#   given/VBN
#   to/TO
#   me/PRP
#   by/IN
#   the/DT
#   (Chunk Constitution/NNP)
#   and/CC
#   by/IN
#   statute/NN
#   --/:
#   I/PRP
#   have/VBP
#   authorized/VBN
#   a/DT
#   terrorist/JJ
#   surveillance/NN
#   program/NN
#   to/TO
#   aggressively/RB
#   pursue/VB
#   the/DT
#   international/JJ
#   communications/NNS
#   of/IN
#   suspected/JJ
#   al/JJ
#   (Chunk Qaeda/NNP)
#   operatives/NNS
#   and/CC
#   affiliates/NNS
#   to/TO
#   and/CC
#   from/IN
#   (Chunk America/NNP)
#   ./.)
# (S
#   Previous/JJ
#   Presidents/NNS
#   have/VBP
#   used/VBN
#   the/DT
#   same/JJ
#   constitutional/JJ
#   authority/NN
#   I/PRP
#   have/VBP
#   ,/,
#   and/CC
#   federal/JJ
#   courts/NNS
#   have/VBP
#   approved/VBN
#   the/DT
#   use/NN
#   of/IN
#   that/DT
#   authority/NN
#   ./.)
# (S
#   Appropriate/JJ
#   members/NNS
#   of/IN
#   (Chunk Congress/NNP)
#   have/VBP
#   been/VBN
#   kept/VBN
#   informed/VBN
#   ./.)
# (S
#   The/DT
#   terrorist/JJ
#   surveillance/NN
#   program/NN
#   has/VBZ
#   helped/VBN
#   prevent/VB
#   terrorist/JJ
#   attacks/NNS
#   ./.)
# (S
#   It/PRP
#   remains/VBZ
#   essential/JJ
#   to/TO
#   the/DT
#   security/NN
#   of/IN
#   (Chunk America/NNP)
#   ./.)
# (S
#   If/IN
#   there/EX
#   are/VBP
#   people/NNS
#   inside/IN
#   our/PRP$
#   country/NN
#   who/WP
#   are/VBP
#   talking/VBG
#   with/IN
#   al/NN
#   (Chunk Qaeda/NNP)
#   ,/,
#   we/PRP
#   want/VBP
#   to/TO
#   know/VB
#   about/IN
#   it/PRP
#   ,/,
#   because/IN
#   we/PRP
#   will/MD
#   not/RB
#   sit/VB
#   back/RB
#   and/CC
#   wait/NN
#   to/TO
#   be/VB
#   hit/VBN
#   again/RB
#   ./.)
# (S (/( (Chunk Applause/NNP) ./. )/))
# (S
#   In/IN
#   all/PDT
#   these/DT
#   areas/NNS
#   --/:
#   from/IN
#   the/DT
#   disruption/NN
#   of/IN
#   terror/NN
#   networks/NNS
#   ,/,
#   to/TO
#   victory/NN
#   in/IN
#   (Chunk Iraq/NNP)
#   ,/,
#   to/TO
#   the/DT
#   spread/NN
#   of/IN
#   freedom/NN
#   and/CC
#   hope/NN
#   in/IN
#   troubled/JJ
#   regions/NNS
#   --/:
#   we/PRP
#   need/VBP
#   the/DT
#   support/NN
#   of/IN
#   our/PRP$
#   friends/NNS
#   and/CC
#   allies/NNS
#   ./.)
# (S
#   To/TO
#   draw/VB
#   that/DT
#   support/NN
#   ,/,
#   we/PRP
#   must/MD
#   always/RB
#   be/VB
#   clear/JJ
#   in/IN
#   our/PRP$
#   principles/NNS
#   and/CC
#   willing/JJ
#   to/TO
#   act/VB
#   ./.)
# (S
#   The/DT
#   only/JJ
#   alternative/NN
#   to/TO
#   American/JJ
#   leadership/NN
#   is/VBZ
#   a/DT
#   dramatically/RB
#   more/RBR
#   dangerous/JJ
#   and/CC
#   anxious/JJ
#   world/NN
#   ./.)
# (S
#   Yet/CC
#   we/PRP
#   also/RB
#   choose/VBP
#   to/TO
#   lead/VB
#   because/IN
#   it/PRP
#   is/VBZ
#   a/DT
#   privilege/NN
#   to/TO
#   serve/VB
#   the/DT
#   values/NNS
#   that/WDT
#   gave/VBD
#   us/PRP
#   birth/NN
#   ./.)
# (S
#   American/JJ
#   leaders/NNS
#   --/:
#   from/IN
#   (Chunk Roosevelt/NNP)
#   to/TO
#   (Chunk Truman/NNP)
#   to/TO
#   (Chunk Kennedy/NNP)
#   to/TO
#   (Chunk Reagan/NNP)
#   --/:
#   rejected/VBD
#   isolation/NN
#   and/CC
#   retreat/NN
#   ,/,
#   because/IN
#   they/PRP
#   knew/VBD
#   that/IN
#   (Chunk America/NNP)
#   is/VBZ
#   always/RB
#   more/RBR
#   secure/JJ
#   when/WRB
#   freedom/NN
#   is/VBZ
#   on/IN
#   the/DT
#   march/NN
#   ./.)
# (S
#   Our/PRP$
#   own/JJ
#   generation/NN
#   is/VBZ
#   in/IN
#   a/DT
#   long/JJ
#   war/NN
#   against/IN
#   a/DT
#   determined/JJ
#   enemy/NN
#   --/:
#   a/DT
#   war/NN
#   that/WDT
#   will/MD
#   be/VB
#   fought/VBN
#   by/IN
#   Presidents/NNS
#   of/IN
#   both/DT
#   parties/NNS
#   ,/,
#   who/WP
#   will/MD
#   need/VB
#   steady/JJ
#   bipartisan/JJ
#   support/NN
#   from/IN
#   the/DT
#   (Chunk Congress/NNP)
#   ./.)
# (S And/CC tonight/NN I/PRP ask/VBP for/IN yours/NNS ./.)
# (S
#   Together/RB
#   ,/,
#   let/VB
#   us/PRP
#   protect/VB
#   our/PRP$
#   country/NN
#   ,/,
#   support/VB
#   the/DT
#   men/NNS
#   and/CC
#   women/NNS
#   who/WP
#   defend/VBP
#   us/PRP
#   ,/,
#   and/CC
#   lead/VB
#   this/DT
#   world/NN
#   toward/IN
#   freedom/NN
#   ./.)
# (S (/( (Chunk Applause/NNP) ./. )/))
# (S
#   Here/RB
#   at/IN
#   home/NN
#   ,/,
#   (Chunk America/NNP)
#   also/RB
#   has/VBZ
#   a/DT
#   great/JJ
#   opportunity/NN
#   :/:
#   We/PRP
#   will/MD
#   build/VB
#   the/DT
#   prosperity/NN
#   of/IN
#   our/PRP$
#   country/NN
#   by/IN
#   strengthening/VBG
#   our/PRP$
#   economic/JJ
#   leadership/NN
#   in/IN
#   the/DT
#   world/NN
#   ./.)
# (S
#   Our/PRP$
#   economy/NN
#   is/VBZ
#   healthy/JJ
#   and/CC
#   vigorous/JJ
#   ,/,
#   and/CC
#   growing/VBG
#   faster/RBR
#   than/IN
#   other/JJ
#   major/JJ
#   industrialized/VBN
#   nations/NNS
#   ./.)
# (S
#   In/IN
#   the/DT
#   last/JJ
#   two-and-a-half/JJ
#   years/NNS
#   ,/,
#   (Chunk America/NNP)
#   has/VBZ
#   created/VBN
#   4.6/CD
#   million/CD
#   new/JJ
#   jobs/NNS
#   --/:
#   more/JJR
#   than/IN
#   (Chunk Japan/NNP)
#   and/CC
#   the/DT
#   (Chunk European/NNP Union/NNP)
#   combined/VBD
#   ./.)
# (S (/( (Chunk Applause/NNP) ./. )/))
# (S
#   Even/RB
#   in/IN
#   the/DT
#   face/NN
#   of/IN
#   higher/JJR
#   energy/NN
#   prices/NNS
#   and/CC
#   natural/JJ
#   disasters/NNS
#   ,/,
#   the/DT
#   American/JJ
#   people/NNS
#   have/VBP
#   turned/VBN
#   in/IN
#   an/DT
#   economic/JJ
#   performance/NN
#   that/WDT
#   is/VBZ
#   the/DT
#   envy/NN
#   of/IN
#   the/DT
#   world/NN
#   ./.)
# (S
#   The/DT
#   American/JJ
#   economy/NN
#   is/VBZ
#   preeminent/JJ
#   ,/,
#   but/CC
#   we/PRP
#   can/MD
#   not/RB
#   afford/VB
#   to/TO
#   be/VB
#   complacent/JJ
#   ./.)
# (S
#   In/IN
#   a/DT
#   dynamic/JJ
#   world/NN
#   economy/NN
#   ,/,
#   we/PRP
#   are/VBP
#   seeing/VBG
#   new/JJ
#   competitors/NNS
#   ,/,
#   like/IN
#   (Chunk China/NNP)
#   and/CC
#   (Chunk India/NNP)
#   ,/,
#   and/CC
#   this/DT
#   creates/VBZ
#   uncertainty/NN
#   ,/,
#   which/WDT
#   makes/VBZ
#   it/PRP
#   easier/JJR
#   to/TO
#   feed/VB
#   people/NNS
#   's/POS
#   fears/NNS
#   ./.)
# (S
#   So/IN
#   we/PRP
#   're/VBP
#   seeing/VBG
#   some/DT
#   old/JJ
#   temptations/NNS
#   return/NN
#   ./.)
# (S
#   Protectionists/NNS
#   want/VBP
#   to/TO
#   escape/VB
#   competition/NN
#   ,/,
#   pretending/VBG
#   that/IN
#   we/PRP
#   can/MD
#   keep/VB
#   our/PRP$
#   high/JJ
#   standard/NN
#   of/IN
#   living/NN
#   while/IN
#   walling/VBG
#   off/RP
#   our/PRP$
#   economy/NN
#   ./.)
# (S
#   Others/NNS
#   say/VBP
#   that/IN
#   the/DT
#   government/NN
#   needs/VBZ
#   to/TO
#   take/VB
#   a/DT
#   larger/JJR
#   role/NN
#   in/IN
#   directing/VBG
#   the/DT
#   economy/NN
#   ,/,
#   centralizing/VBG
#   more/JJR
#   power/NN
#   in/IN
#   (Chunk Washington/NNP)
#   and/CC
#   increasing/VBG
#   taxes/NNS
#   ./.)
# (S
#   We/PRP
#   hear/VBP
#   claims/NNS
#   that/IN
#   immigrants/NNS
#   are/VBP
#   somehow/RB
#   bad/JJ
#   for/IN
#   the/DT
#   economy/NN
#   --/:
#   even/RB
#   though/IN
#   this/DT
#   economy/NN
#   could/MD
#   not/RB
#   function/VB
#   without/IN
#   them/PRP
#   ./.)
# (S (/( (Chunk Applause/NNP) ./. )/))
# (S
#   All/PDT
#   these/DT
#   are/VBP
#   forms/NNS
#   of/IN
#   economic/JJ
#   retreat/NN
#   ,/,
#   and/CC
#   they/PRP
#   lead/VBP
#   in/IN
#   the/DT
#   same/JJ
#   direction/NN
#   --/:
#   toward/IN
#   a/DT
#   stagnant/JJ
#   and/CC
#   second-rate/JJ
#   economy/NN
#   ./.)
# (S
#   (Chunk Tonight/NNP)
#   I/PRP
#   will/MD
#   set/VB
#   out/RP
#   a/DT
#   better/JJR
#   path/NN
#   :/:
#   an/DT
#   agenda/NN
#   for/IN
#   a/DT
#   nation/NN
#   that/WDT
#   competes/VBZ
#   with/IN
#   confidence/NN
#   ;/:
#   an/DT
#   agenda/NN
#   that/WDT
#   will/MD
#   raise/VB
#   standards/NNS
#   of/IN
#   living/NN
#   and/CC
#   generate/VB
#   new/JJ
#   jobs/NNS
#   ./.)
# (S
#   Americans/NNPS
#   should/MD
#   not/RB
#   fear/VB
#   our/PRP$
#   economic/JJ
#   future/NN
#   ,/,
#   because/IN
#   we/PRP
#   intend/VBP
#   to/TO
#   shape/VB
#   it/PRP
#   ./.)
# (S
#   (Chunk Keeping/VBG America/NNP)
#   competitive/JJ
#   begins/NNS
#   with/IN
#   keeping/VBG
#   our/PRP$
#   economy/NN
#   growing/VBG
#   ./.)
# (S
#   And/CC
#   our/PRP$
#   economy/NN
#   grows/VBZ
#   when/WRB
#   Americans/NNPS
#   have/VBP
#   more/JJR
#   of/IN
#   their/PRP$
#   own/JJ
#   money/NN
#   to/TO
#   spend/VB
#   ,/,
#   save/VB
#   ,/,
#   and/CC
#   invest/JJS
#   ./.)
# (S
#   In/IN
#   the/DT
#   last/JJ
#   five/CD
#   years/NNS
#   ,/,
#   the/DT
#   tax/NN
#   relief/NN
#   you/PRP
#   passed/VBN
#   has/VBZ
#   left/VBN
#   $/$
#   880/CD
#   billion/CD
#   in/IN
#   the/DT
#   hands/NNS
#   of/IN
#   American/JJ
#   workers/NNS
#   ,/,
#   investors/NNS
#   ,/,
#   small/JJ
#   businesses/NNS
#   ,/,
#   and/CC
#   families/NNS
#   --/:
#   and/CC
#   they/PRP
#   have/VBP
#   used/VBN
#   it/PRP
#   to/TO
#   help/VB
#   produce/VB
#   more/JJR
#   than/IN
#   four/CD
#   years/NNS
#   of/IN
#   uninterrupted/JJ
#   economic/JJ
#   growth/NN
#   ./.)
# (S (/( (Chunk Applause/NNP) ./. )/))
# (S
#   Yet/RB
#   the/DT
#   tax/NN
#   relief/NN
#   is/VBZ
#   set/VBN
#   to/TO
#   expire/VB
#   in/IN
#   the/DT
#   next/JJ
#   few/JJ
#   years/NNS
#   ./.)
# (S
#   If/IN
#   we/PRP
#   do/VBP
#   nothing/NN
#   ,/,
#   (Chunk American/NNP)
#   families/NNS
#   will/MD
#   face/VB
#   a/DT
#   massive/JJ
#   tax/NN
#   increase/NN
#   they/PRP
#   do/VBP
#   not/RB
#   expect/VB
#   and/CC
#   will/MD
#   not/RB
#   welcome/VB
#   ./.)
# (S
#   Because/IN
#   (Chunk America/NNP)
#   needs/VBZ
#   more/JJR
#   than/IN
#   a/DT
#   temporary/JJ
#   expansion/NN
#   ,/,
#   we/PRP
#   need/VBP
#   more/JJR
#   than/IN
#   temporary/JJ
#   tax/NN
#   relief/NN
#   ./.)
# (S
#   I/PRP
#   urge/VBP
#   the/DT
#   (Chunk Congress/NNP)
#   to/TO
#   act/VB
#   responsibly/RB
#   ,/,
#   and/CC
#   make/VB
#   the/DT
#   tax/NN
#   cuts/NNS
#   permanent/NN
#   ./.)
# (S (/( (Chunk Applause/NNP) ./. )/))
# (S
#   (Chunk Keeping/VBG America/NNP)
#   competitive/JJ
#   requires/VBZ
#   us/PRP
#   to/TO
#   be/VB
#   good/JJ
#   stewards/NNS
#   of/IN
#   tax/NN
#   dollars/NNS
#   ./.)
# (S
#   Every/DT
#   year/NN
#   of/IN
#   my/PRP$
#   presidency/NN
#   ,/,
#   we/PRP
#   've/VBP
#   reduced/VBN
#   the/DT
#   growth/NN
#   of/IN
#   non-security/JJ
#   discretionary/JJ
#   spending/NN
#   ,/,
#   and/CC
#   last/JJ
#   year/NN
#   you/PRP
#   passed/VBD
#   bills/NNS
#   that/IN
#   cut/VBD
#   this/DT
#   spending/NN
#   ./.)
# (S
#   This/DT
#   year/NN
#   my/PRP$
#   budget/NN
#   will/MD
#   cut/VB
#   it/PRP
#   again/RB
#   ,/,
#   and/CC
#   reduce/VB
#   or/CC
#   eliminate/VB
#   more/JJR
#   than/IN
#   140/CD
#   programs/NNS
#   that/WDT
#   are/VBP
#   performing/VBG
#   poorly/RB
#   or/CC
#   not/RB
#   fulfilling/JJ
#   essential/JJ
#   priorities/NNS
#   ./.)
# (S
#   By/IN
#   passing/VBG
#   these/DT
#   reforms/NNS
#   ,/,
#   we/PRP
#   will/MD
#   save/VB
#   the/DT
#   (Chunk American/NNP taxpayer/NN)
#   another/DT
#   $/$
#   14/CD
#   billion/CD
#   next/JJ
#   year/NN
#   ,/,
#   and/CC
#   stay/VB
#   on/IN
#   track/NN
#   to/TO
#   cut/VB
#   the/DT
#   deficit/NN
#   in/IN
#   half/NN
#   by/IN
#   2009/CD
#   ./.)
# (S (/( (Chunk Applause/NNP) ./. )/))
# (S
#   I/PRP
#   am/VBP
#   pleased/JJ
#   that/IN
#   members/NNS
#   of/IN
#   (Chunk Congress/NNP)
#   are/VBP
#   working/VBG
#   on/IN
#   earmark/NN
#   reform/NN
#   ,/,
#   because/IN
#   the/DT
#   federal/JJ
#   budget/NN
#   has/VBZ
#   too/RB
#   many/JJ
#   special/JJ
#   interest/NN
#   projects/NNS
#   ./.)
# (S (/( (Chunk Applause/NNP) ./. )/))
# (S
#   And/CC
#   we/PRP
#   can/MD
#   tackle/VB
#   this/DT
#   problem/NN
#   together/RB
#   ,/,
#   if/IN
#   you/PRP
#   pass/VBP
#   the/DT
#   line-item/JJ
#   veto/NN
#   ./.)
# (S (/( (Chunk Applause/NNP) ./. )/))
# (S
#   We/PRP
#   must/MD
#   also/RB
#   confront/VB
#   the/DT
#   larger/JJR
#   challenge/NN
#   of/IN
#   mandatory/JJ
#   spending/NN
#   ,/,
#   or/CC
#   entitlements/NNS
#   ./.)
# (S
#   This/DT
#   year/NN
#   ,/,
#   the/DT
#   first/JJ
#   of/IN
#   about/RB
#   78/CD
#   million/CD
#   baby/NN
#   boomers/NNS
#   turn/VBP
#   60/CD
#   ,/,
#   including/VBG
#   two/CD
#   of/IN
#   my/PRP$
#   (Chunk Dad/NNP)
#   's/POS
#   favorite/JJ
#   people/NNS
#   --/:
#   me/PRP
#   and/CC
#   (Chunk President/NNP Clinton/NNP)
#   ./.)
# (S (/( (Chunk Laughter/NNP) ./. )/))
# (S
#   This/DT
#   milestone/NN
#   is/VBZ
#   more/JJR
#   than/IN
#   a/DT
#   personal/JJ
#   crisis/NN
#   --/:
#   (/(
#   laughter/NN
#   )/)
#   --/:
#   it/PRP
#   is/VBZ
#   a/DT
#   national/JJ
#   challenge/NN
#   ./.)
# (S
#   The/DT
#   retirement/NN
#   of/IN
#   the/DT
#   baby/NN
#   boom/NN
#   generation/NN
#   will/MD
#   put/VB
#   unprecedented/JJ
#   strains/NNS
#   on/IN
#   the/DT
#   federal/JJ
#   government/NN
#   ./.)
# (S
#   By/IN
#   2030/CD
#   ,/,
#   spending/VBG
#   for/IN
#   (Chunk Social/NNP Security/NNP)
#   ,/,
#   (Chunk Medicare/NNP)
#   and/CC
#   (Chunk Medicaid/NNP)
#   alone/RB
#   will/MD
#   be/VB
#   almost/RB
#   60/CD
#   percent/NN
#   of/IN
#   the/DT
#   entire/JJ
#   federal/JJ
#   budget/NN
#   ./.)
# (S
#   And/CC
#   that/DT
#   will/MD
#   present/VB
#   future/JJ
#   Congresses/NNS
#   with/IN
#   impossible/JJ
#   choices/NNS
#   --/:
#   staggering/VBG
#   tax/NN
#   increases/NNS
#   ,/,
#   immense/JJ
#   deficits/NNS
#   ,/,
#   or/CC
#   deep/JJ
#   cuts/NNS
#   in/IN
#   every/DT
#   category/NN
#   of/IN
#   spending/NN
#   ./.)
# (S
#   (Chunk Congress/NNP)
#   did/VBD
#   not/RB
#   act/VB
#   last/JJ
#   year/NN
#   on/IN
#   my/PRP$
#   proposal/NN
#   to/TO
#   (Chunk save/VB Social/NNP Security/NNP)
#   --/:
#   (/(
#   applause/NN
#   )/)
#   --/:
#   yet/RB
#   the/DT
#   rising/VBG
#   cost/NN
#   of/IN
#   entitlements/NNS
#   is/VBZ
#   a/DT
#   problem/NN
#   that/WDT
#   is/VBZ
#   not/RB
#   going/VBG
#   away/RB
#   ./.)
# (S (/( (Chunk Applause/NNP) ./. )/))
# (S
#   And/CC
#   every/DT
#   year/NN
#   we/PRP
#   fail/VBP
#   to/TO
#   act/VB
#   ,/,
#   the/DT
#   situation/NN
#   gets/VBZ
#   worse/JJR
#   ./.)
# (S
#   So/RB
#   tonight/JJ
#   ,/,
#   I/PRP
#   ask/VBP
#   you/PRP
#   to/TO
#   join/VB
#   me/PRP
#   in/IN
#   creating/VBG
#   a/DT
#   commission/NN
#   to/TO
#   examine/VB
#   the/DT
#   full/JJ
#   impact/NN
#   of/IN
#   baby/NN
#   boom/NN
#   retirements/NNS
#   on/IN
#   (Chunk Social/NNP Security/NNP)
#   ,/,
#   (Chunk Medicare/NNP)
#   ,/,
#   and/CC
#   (Chunk Medicaid/NNP)
#   ./.)
# (S
#   This/DT
#   commission/NN
#   should/MD
#   include/VB
#   members/NNS
#   of/IN
#   (Chunk Congress/NNP)
#   of/IN
#   both/DT
#   parties/NNS
#   ,/,
#   and/CC
#   offer/VBP
#   bipartisan/JJ
#   solutions/NNS
#   ./.)
# (S
#   We/PRP
#   need/VBP
#   to/TO
#   put/VB
#   aside/RP
#   partisan/JJ
#   politics/NNS
#   and/CC
#   work/NN
#   together/RB
#   and/CC
#   get/VB
#   this/DT
#   problem/NN
#   solved/VBD
#   ./.)
# (S (/( (Chunk Applause/NNP) ./. )/))
# (S
#   (Chunk Keeping/VBG America/NNP)
#   competitive/JJ
#   requires/VBZ
#   us/PRP
#   to/TO
#   open/VB
#   more/JJR
#   markets/NNS
#   for/IN
#   all/DT
#   that/DT
#   Americans/NNPS
#   make/VBP
#   and/CC
#   grow/VB
#   ./.)
# (S
#   One/CD
#   out/NN
#   of/IN
#   every/DT
#   five/CD
#   factory/NN
#   jobs/NNS
#   in/IN
#   (Chunk America/NNP)
#   is/VBZ
#   related/VBN
#   to/TO
#   global/JJ
#   trade/NN
#   ,/,
#   and/CC
#   we/PRP
#   want/VBP
#   people/NNS
#   everywhere/RB
#   to/TO
#   (Chunk buy/VB American/NNP)
#   ./.)
# (S
#   With/IN
#   open/JJ
#   markets/NNS
#   and/CC
#   a/DT
#   level/JJ
#   playing/NN
#   field/NN
#   ,/,
#   no/DT
#   one/NN
#   can/MD
#   out-produce/VB
#   or/CC
#   out-compete/VB
#   the/DT
#   American/JJ
#   worker/NN
#   ./.)
# (S (/( (Chunk Applause/NNP) ./. )/))
# (S
#   (Chunk Keeping/VBG America/NNP)
#   competitive/JJ
#   requires/VBZ
#   an/DT
#   immigration/NN
#   system/NN
#   that/WDT
#   upholds/VBZ
#   our/PRP$
#   laws/NNS
#   ,/,
#   reflects/VBZ
#   our/PRP$
#   values/NNS
#   ,/,
#   and/CC
#   serves/VBZ
#   the/DT
#   interests/NNS
#   of/IN
#   our/PRP$
#   economy/NN
#   ./.)
# (S
#   Our/PRP$
#   nation/NN
#   needs/VBZ
#   orderly/JJ
#   and/CC
#   secure/JJ
#   borders/NNS
#   ./.)
# (S (/( (Chunk Applause/NNP) ./. )/))
# (S
#   To/TO
#   meet/VB
#   this/DT
#   goal/NN
#   ,/,
#   we/PRP
#   must/MD
#   have/VB
#   stronger/JJR
#   immigration/NN
#   enforcement/NN
#   and/CC
#   border/NN
#   protection/NN
#   ./.)
# (S (/( (Chunk Applause/NNP) ./. )/))
# (S
#   And/CC
#   we/PRP
#   must/MD
#   have/VB
#   a/DT
#   rational/JJ
#   ,/,
#   humane/JJ
#   guest/JJS
#   worker/NN
#   program/NN
#   that/WDT
#   rejects/VBZ
#   amnesty/JJ
#   ,/,
#   allows/VBZ
#   temporary/JJ
#   jobs/NNS
#   for/IN
#   people/NNS
#   who/WP
#   seek/VBP
#   them/PRP
#   legally/RB
#   ,/,
#   and/CC
#   reduces/NNS
#   smuggling/VBG
#   and/CC
#   crime/NN
#   at/IN
#   the/DT
#   border/NN
#   ./.)
# (S (/( (Chunk Applause/NNP) ./. )/))
# (S
#   (Chunk Keeping/VBG America/NNP)
#   competitive/JJ
#   requires/VBZ
#   affordable/JJ
#   health/NN
#   care/NN
#   ./.)
# (S (/( (Chunk Applause/NNP) ./. )/))
# (S
#   Our/PRP$
#   government/NN
#   has/VBZ
#   a/DT
#   responsibility/NN
#   to/TO
#   provide/VB
#   health/NN
#   care/NN
#   for/IN
#   the/DT
#   poor/JJ
#   and/CC
#   the/DT
#   elderly/JJ
#   ,/,
#   and/CC
#   we/PRP
#   are/VBP
#   meeting/VBG
#   that/IN
#   responsibility/NN
#   ./.)
# (S (/( (Chunk Applause/NNP) ./. )/))
# (S
#   For/IN
#   all/DT
#   Americans/NNPS
#   --/:
#   for/IN
#   all/DT
#   Americans/NNPS
#   ,/,
#   we/PRP
#   must/MD
#   confront/VB
#   the/DT
#   rising/VBG
#   cost/NN
#   of/IN
#   care/NN
#   ,/,
#   strengthen/VB
#   the/DT
#   doctor-patient/JJ
#   relationship/NN
#   ,/,
#   and/CC
#   help/NN
#   people/NNS
#   afford/VBP
#   the/DT
#   insurance/NN
#   coverage/NN
#   they/PRP
#   need/VBP
#   ./.)
# (S (/( (Chunk Applause/NNP) ./. )/))
# (S
#   We/PRP
#   will/MD
#   make/VB
#   wider/JJR
#   use/NN
#   of/IN
#   electronic/JJ
#   records/NNS
#   and/CC
#   other/JJ
#   health/NN
#   information/NN
#   technology/NN
#   ,/,
#   to/TO
#   help/VB
#   control/VB
#   costs/NNS
#   and/CC
#   reduce/VB
#   dangerous/JJ
#   medical/JJ
#   errors/NNS
#   ./.)
# (S
#   We/PRP
#   will/MD
#   strengthen/VB
#   health/NN
#   savings/NNS
#   accounts/NNS
#   --/:
#   making/VBG
#   sure/JJ
#   individuals/NNS
#   and/CC
#   small/JJ
#   business/NN
#   employees/NNS
#   can/MD
#   buy/VB
#   insurance/NN
#   with/IN
#   the/DT
#   same/JJ
#   advantages/VBZ
#   that/IN
#   people/NNS
#   working/VBG
#   for/IN
#   big/JJ
#   businesses/NNS
#   now/RB
#   get/VBP
#   ./.)
# (S (/( (Chunk Applause/NNP) ./. )/))
# (S
#   We/PRP
# ...
#   ,/,
#   which/WDT
#   is/VBZ
#   raising/VBG
#   standards/NNS
#   and/CC
#   lifting/VBG
#   test/NN
#   scores/NNS
#   across/IN
#   our/PRP$
#   country/NN
#   ./.)
# (S
#   (Chunk Tonight/NNP)
#   I/PRP
#   propose/VBP
#   to/TO
#   train/VB
#   70,000/CD
#   high/JJ
#   school/NN
#   teachers/NNS
#   to/TO
#   lead/VB
#   advanced-placement/JJ
#   courses/NNS
#   in/IN
#   math/NN
#   and/CC
#   science/NN
#   ,/,
#   bring/VBG
#   30,000/CD
#   math/NN
#   and/CC
#   science/NN
#   professionals/NNS
#   to/TO
#   teach/VB
#   in/IN
#   classrooms/NNS
#   ,/,
#   and/CC
#   give/VB
#   early/JJ
#   help/NN
#   to/TO
#   students/NNS
#   who/WP
#   struggle/VBP
#   with/IN
#   math/NN
#   ,/,
#   so/IN
#   they/PRP
#   have/VBP
#   a/DT
#   better/JJR
#   chance/NN
#   at/IN
#   good/JJ
#   ,/,
#   high-wage/JJ
#   jobs/NNS
#   ./.)
# (S
#   If/IN
#   we/PRP
#   ensure/VB
#   that/IN
#   (Chunk America/NNP)
#   's/POS
#   children/NNS
#   succeed/VB
#   in/IN
#   life/NN
#   ,/,
#   they/PRP
#   will/MD
#   ensure/VB
#   that/IN
#   (Chunk America/NNP)
#   succeeds/VBZ
#   in/IN
#   the/DT
#   world/NN
#   ./.)
# (S (/( (Chunk Applause/NNP) ./. )/))
# (S
#   Preparing/VBG
#   our/PRP$
#   nation/NN
#   to/TO
#   compete/VB
#   in/IN
#   the/DT
#   world/NN
#   is/VBZ
#   a/DT
#   goal/NN
#   that/IN
#   all/DT
#   of/IN
#   us/PRP
#   can/MD
#   share/NN
#   ./.)
# (S
#   I/PRP
#   urge/VBP
#   you/PRP
#   to/TO
#   support/VB
#   the/DT
#   American/JJ
#   (Chunk Competitiveness/NNP Initiative/NNP)
#   ,/,
#   and/CC
#   together/RB
#   we/PRP
#   will/MD
#   show/VB
#   the/DT
#   world/NN
#   what/WP
#   the/DT
#   American/JJ
#   people/NNS
#   can/MD
#   achieve/VB
#   ./.)
# (S
#   (Chunk America/NNP)
#   is/VBZ
#   a/DT
#   great/JJ
#   force/NN
#   for/IN
#   freedom/NN
#   and/CC
#   prosperity/NN
#   ./.)
# (S
#   Yet/RB
#   our/PRP$
#   greatness/NN
#   is/VBZ
#   not/RB
#   measured/VBN
#   in/IN
#   power/NN
#   or/CC
#   luxuries/NNS
#   ,/,
#   but/CC
#   by/IN
#   who/WP
#   we/PRP
#   are/VBP
#   and/CC
#   how/WRB
#   we/PRP
#   treat/VBP
#   one/CD
#   another/DT
#   ./.)
# (S
#   So/IN
#   we/PRP
#   strive/VBP
#   to/TO
#   be/VB
#   a/DT
#   compassionate/NN
#   ,/,
#   decent/NN
#   ,/,
#   hopeful/JJ
#   society/NN
#   ./.)
# (S
#   In/IN
#   recent/JJ
#   years/NNS
#   ,/,
#   (Chunk America/NNP)
#   has/VBZ
#   become/VBN
#   a/DT
#   more/RBR
#   hopeful/JJ
#   nation/NN
#   ./.)
# (S
#   Violent/JJ
#   crime/NN
#   rates/NNS
#   have/VBP
#   fallen/VBN
#   to/TO
#   their/PRP$
#   lowest/JJS
#   levels/NNS
#   since/IN
#   the/DT
#   1970s/CD
#   ./.)
# (S
#   Welfare/NN
#   cases/NNS
#   have/VBP
#   dropped/VBN
#   by/IN
#   more/JJR
#   than/IN
#   half/NN
#   over/IN
#   the/DT
#   past/JJ
#   decade/NN
#   ./.)
# (S
#   Drug/NN
#   use/NN
#   among/IN
#   youth/NN
#   is/VBZ
#   down/RB
#   19/CD
#   percent/NN
#   since/IN
#   2001/CD
#   ./.)
# (S
#   There/EX
#   are/VBP
#   fewer/JJR
#   abortions/NNS
#   in/IN
#   (Chunk America/NNP)
#   than/IN
#   at/IN
#   any/DT
#   point/NN
#   in/IN
#   the/DT
#   last/JJ
#   three/CD
#   decades/NNS
#   ,/,
#   and/CC
#   the/DT
#   number/NN
#   of/IN
#   children/NNS
#   born/VBN
#   to/TO
#   teenage/VB
#   mothers/NNS
#   has/VBZ
#   been/VBN
#   falling/VBG
#   for/IN
#   a/DT
#   dozen/NN
#   years/NNS
#   in/IN
#   a/DT
#   row/NN
#   ./.)
# (S (/( (Chunk Applause/NNP) ./. )/))
# (S
#   These/DT
#   gains/NNS
#   are/VBP
#   evidence/NN
#   of/IN
#   a/DT
#   quiet/JJ
#   transformation/NN
#   --/:
#   a/DT
#   revolution/NN
#   of/IN
#   conscience/NN
#   ,/,
#   in/IN
#   which/WDT
#   a/DT
#   rising/VBG
#   generation/NN
#   is/VBZ
#   finding/VBG
#   that/IN
#   a/DT
#   life/NN
#   of/IN
#   personal/JJ
#   responsibility/NN
#   is/VBZ
#   a/DT
#   life/NN
#   of/IN
#   fulfillment/NN
#   ./.)
# (S (Chunk Government/NNP) has/VBZ played/VBN a/DT role/NN ./.)
# (S
#   (Chunk Wise/NNP)
#   policies/NNS
#   ,/,
#   such/JJ
#   as/IN
#   welfare/NN
#   reform/NN
#   and/CC
#   drug/NN
#   education/NN
#   and/CC
#   support/NN
#   for/IN
#   abstinence/NN
#   and/CC
#   adoption/NN
#   have/VBP
#   made/VBN
#   a/DT
#   difference/NN
#   in/IN
#   the/DT
#   character/NN
#   of/IN
#   our/PRP$
#   country/NN
#   ./.)
# (S
#   And/CC
#   everyone/NN
#   here/RB
#   tonight/RB
#   ,/,
#   (Chunk Democrat/NNP)
#   and/CC
#   (Chunk Republican/NNP)
#   ,/,
#   has/VBZ
#   a/DT
#   right/NN
#   to/TO
#   be/VB
#   proud/JJ
#   of/IN
#   this/DT
#   record/NN
#   ./.)
# (S (/( (Chunk Applause/NNP) ./. )/))
# (S
#   Yet/RB
#   many/JJ
#   Americans/NNPS
#   ,/,
#   especially/RB
#   parents/NNS
#   ,/,
#   still/RB
#   have/VBP
#   deep/JJ
#   concerns/NNS
#   about/IN
#   the/DT
#   direction/NN
#   of/IN
#   our/PRP$
#   culture/NN
#   ,/,
#   and/CC
#   the/DT
#   health/NN
#   of/IN
#   our/PRP$
#   most/JJS
#   basic/JJ
#   institutions/NNS
#   ./.)
# (S
#   They/PRP
#   're/VBP
#   concerned/VBN
#   about/IN
#   unethical/JJ
#   conduct/NN
#   by/IN
#   public/JJ
#   officials/NNS
#   ,/,
#   and/CC
#   discouraged/VBN
#   by/IN
#   activist/NN
#   courts/NNS
#   that/WDT
#   try/VBP
#   to/TO
#   redefine/VB
#   marriage/NN
#   ./.)
# (S
#   They/PRP
#   worry/VBP
#   about/IN
#   children/NNS
#   in/IN
#   our/PRP$
#   society/NN
#   who/WP
#   need/VBP
#   direction/NN
#   and/CC
#   love/NN
#   ,/,
#   and/CC
#   about/IN
#   fellow/JJ
#   citizens/NNS
#   still/RB
#   displaced/VBN
#   by/IN
#   natural/JJ
#   disaster/NN
#   ,/,
#   and/CC
#   about/IN
#   suffering/VBG
#   caused/VBN
#   by/IN
#   treatable/JJ
#   diseases/NNS
#   ./.)
# (S
#   As/IN
#   we/PRP
#   look/VBP
#   at/IN
#   these/DT
#   challenges/NNS
#   ,/,
#   we/PRP
#   must/MD
#   never/RB
#   give/VB
#   in/IN
#   to/TO
#   the/DT
#   belief/NN
#   that/IN
#   (Chunk America/NNP)
#   is/VBZ
#   in/IN
#   decline/NN
#   ,/,
#   or/CC
#   that/IN
#   our/PRP$
#   culture/NN
#   is/VBZ
#   doomed/VBN
#   to/TO
#   unravel/VB
#   ./.)
# (S
#   The/DT
#   American/JJ
#   people/NNS
#   know/VBP
#   better/JJR
#   than/IN
#   that/DT
#   ./.)
# (S
#   We/PRP
#   have/VBP
#   proven/VBN
#   the/DT
#   pessimists/NNS
#   wrong/JJ
#   before/RB
#   --/:
#   and/CC
#   we/PRP
#   will/MD
#   do/VB
#   it/PRP
#   again/RB
#   ./.)
# (S (/( (Chunk Applause/NNP) ./. )/))
# (S
#   A/DT
#   hopeful/JJ
#   society/NN
#   depends/VBZ
#   on/IN
#   courts/NNS
#   that/IN
#   deliver/VBP
#   equal/JJ
#   justice/NN
#   under/IN
#   the/DT
#   law/NN
#   ./.)
# (S
#   The/DT
#   (Chunk Supreme/NNP Court/NNP)
#   now/RB
#   has/VBZ
#   two/CD
#   superb/JJ
#   new/JJ
#   members/NNS
#   --/:
#   new/JJ
#   members/NNS
#   on/IN
#   its/PRP$
#   bench/NN
#   :/:
#   Chief/JJ
#   (Chunk Justice/NNP John/NNP Roberts/NNP)
#   and/CC
#   (Chunk Justice/NNP Sam/NNP Alito/NNP)
#   ./.)
# (S (/( (Chunk Applause/NNP) ./. )/))
# (S
#   I/PRP
#   thank/VBD
#   the/DT
#   (Chunk Senate/NNP)
#   for/IN
#   confirming/VBG
#   both/DT
#   of/IN
#   them/PRP
#   ./.)
# (S
#   I/PRP
#   will/MD
#   continue/VB
#   to/TO
#   nominate/VB
#   men/NNS
#   and/CC
#   women/NNS
#   who/WP
#   understand/VBP
#   that/IN
#   judges/NNS
#   must/MD
#   be/VB
#   servants/NNS
#   of/IN
#   the/DT
#   law/NN
#   ,/,
#   and/CC
#   not/RB
#   legislate/VB
#   from/IN
#   the/DT
#   bench/NN
#   ./.)
# (S (/( (Chunk Applause/NNP) ./. )/))
# (S
#   Today/NN
#   marks/VBZ
#   the/DT
#   official/JJ
#   retirement/NN
#   of/IN
#   a/DT
#   very/RB
#   special/JJ
#   (Chunk American/NNP)
#   ./.)
# (S
#   For/IN
#   24/CD
#   years/NNS
#   of/IN
#   faithful/JJ
#   service/NN
#   to/TO
#   our/PRP$
#   nation/NN
#   ,/,
#   the/DT
#   (Chunk United/NNP)
#   States/NNPS
#   is/VBZ
#   grateful/JJ
#   to/TO
#   (Chunk Justice/NNP Sandra/NNP Day/NNP O'Connor/NNP)
#   ./.)
# (S (/( (Chunk Applause/NNP) ./. )/))
# (S
#   A/DT
#   hopeful/JJ
#   society/NN
#   has/VBZ
#   institutions/NNS
#   of/IN
#   science/NN
#   and/CC
#   medicine/NN
#   that/WDT
#   do/VBP
#   not/RB
#   cut/VB
#   ethical/JJ
#   corners/NNS
#   ,/,
#   and/CC
#   that/IN
#   recognize/VBP
#   the/DT
#   matchless/NN
#   value/NN
#   of/IN
#   every/DT
#   life/NN
#   ./.)
# (S
#   (Chunk Tonight/NNP)
#   I/PRP
#   ask/VBP
#   you/PRP
#   to/TO
#   pass/VB
#   legislation/NN
#   to/TO
#   prohibit/VB
#   the/DT
#   most/RBS
#   egregious/JJ
#   abuses/NNS
#   of/IN
#   medical/JJ
#   research/NN
#   :/:
#   human/JJ
#   cloning/VBG
#   in/IN
#   all/DT
#   its/PRP$
#   forms/NNS
#   ,/,
#   creating/VBG
#   or/CC
#   implanting/VBG
#   embryos/NN
#   for/IN
#   experiments/NNS
#   ,/,
#   creating/VBG
#   human-animal/JJ
#   hybrids/NNS
#   ,/,
#   and/CC
#   buying/NN
#   ,/,
#   selling/NN
#   ,/,
#   or/CC
#   patenting/VBG
#   human/JJ
#   embryos/NN
#   ./.)
# (S
#   (Chunk Human/NNP life/NN)
#   is/VBZ
#   a/DT
#   gift/NN
#   from/IN
#   our/PRP$
#   (Chunk Creator/NNP)
#   --/:
#   and/CC
#   that/IN
#   gift/NN
#   should/MD
#   never/RB
#   be/VB
#   discarded/VBN
#   ,/,
#   devalued/VBD
#   or/CC
#   put/VB
#   up/RP
#   for/IN
#   sale/NN
#   ./.)
# (S (/( (Chunk Applause/NNP) ./. )/))
# (S
#   A/DT
#   hopeful/JJ
#   society/NN
#   expects/VBZ
#   elected/VBN
#   officials/NNS
#   to/TO
#   uphold/VB
#   the/DT
#   public/JJ
#   trust/NN
#   ./.)
# (S (/( (Chunk Applause/NNP) ./. )/))
# (S
#   Honorable/JJ
#   people/NNS
#   in/IN
#   both/DT
#   parties/NNS
#   are/VBP
#   working/VBG
#   on/IN
#   reforms/NNS
#   to/TO
#   strengthen/VB
#   the/DT
#   ethical/JJ
#   standards/NNS
#   of/IN
#   (Chunk Washington/NNP)
#   --/:
#   I/PRP
#   support/VBP
#   your/PRP$
#   efforts/NNS
#   ./.)
# (S
#   Each/DT
#   of/IN
#   us/PRP
#   has/VBZ
#   made/VBN
#   a/DT
#   pledge/NN
#   to/TO
#   be/VB
#   worthy/JJ
#   of/IN
#   public/JJ
#   responsibility/NN
#   --/:
#   and/CC
#   that/DT
#   is/VBZ
#   a/DT
#   pledge/NN
#   we/PRP
#   must/MD
#   never/RB
#   forget/VB
#   ,/,
#   never/RB
#   dismiss/NN
#   ,/,
#   and/CC
#   never/RB
#   betray/NN
#   ./.)
# (S (/( (Chunk Applause/NNP) ./. )/))
# (S
#   As/IN
#   we/PRP
#   renew/VBP
#   the/DT
#   promise/NN
#   of/IN
#   our/PRP$
#   institutions/NNS
#   ,/,
#   let/VB
#   us/PRP
#   also/RB
#   show/VBP
#   the/DT
#   character/NN
#   of/IN
#   (Chunk America/NNP)
#   in/IN
#   our/PRP$
#   compassion/NN
#   and/CC
#   care/NN
#   for/IN
#   one/CD
#   another/DT
#   ./.)
# (S
#   A/DT
#   hopeful/JJ
#   society/NN
#   gives/VBZ
#   special/JJ
#   attention/NN
#   to/TO
#   children/NNS
#   who/WP
#   lack/VBP
#   direction/NN
#   and/CC
#   love/NN
#   ./.)
# (S
#   Through/IN
#   the/DT
#   (Chunk Helping/NNP America/NNP)
#   's/POS
#   (Chunk Youth/NNP Initiative/NNP)
#   ,/,
#   we/PRP
#   are/VBP
#   encouraging/VBG
#   caring/VBG
#   adults/NNS
#   to/TO
#   get/VB
#   involved/VBN
#   in/IN
#   the/DT
#   life/NN
#   of/IN
#   a/DT
#   child/NN
#   --/:
#   and/CC
#   this/DT
#   good/JJ
#   work/NN
#   is/VBZ
#   being/VBG
#   led/VBN
#   by/IN
#   our/PRP$
#   (Chunk First/NNP Lady/NNP)
#   ,/,
#   (Chunk Laura/NNP Bush/NNP)
#   ./.)
# (S (/( (Chunk Applause/NNP) ./. )/))
# (S
#   This/DT
#   year/NN
#   we/PRP
#   will/MD
#   add/VB
#   resources/NNS
#   to/TO
#   encourage/VB
#   young/JJ
#   people/NNS
#   to/TO
#   stay/VB
#   in/IN
#   school/NN
#   ,/,
#   so/RB
#   more/JJR
#   of/IN
#   (Chunk America/NNP)
#   's/POS
#   youth/NN
#   can/MD
#   raise/VB
#   their/PRP$
#   sights/NNS
#   and/CC
#   achieve/VBP
#   their/PRP$
#   dreams/NNS
#   ./.)
# (S
#   A/DT
#   hopeful/JJ
#   society/NN
#   comes/VBZ
#   to/TO
#   the/DT
#   aid/NN
#   of/IN
#   fellow/JJ
#   citizens/NNS
#   in/IN
#   times/NNS
#   of/IN
#   suffering/NN
#   and/CC
#   emergency/NN
#   --/:
#   and/CC
#   stays/NNS
#   at/IN
#   it/PRP
#   until/IN
#   they/PRP
#   're/VBP
#   back/RB
#   on/IN
#   their/PRP$
#   feet/NNS
#   ./.)
# (S
#   So/RB
#   far/RB
#   the/DT
#   federal/JJ
#   government/NN
#   has/VBZ
#   committed/VBN
#   $/$
#   85/CD
#   billion/CD
#   to/TO
#   the/DT
#   people/NNS
#   of/IN
#   the/DT
#   (Chunk Gulf/NNP Coast/NNP)
#   and/CC
#   (Chunk New/NNP Orleans/NNP)
#   ./.)
# (S
#   We/PRP
#   're/VBP
#   removing/VBG
#   debris/NN
#   and/CC
#   repairing/NN
#   highways/NNS
#   and/CC
#   rebuilding/VBG
#   stronger/JJR
#   levees/NNS
#   ./.)
# (S
#   We/PRP
#   're/VBP
#   providing/VBG
#   business/NN
#   loans/NNS
#   and/CC
#   housing/NN
#   assistance/NN
#   ./.)
# (S
#   Yet/RB
#   as/IN
#   we/PRP
#   meet/VBP
#   these/DT
#   immediate/JJ
#   needs/NNS
#   ,/,
#   we/PRP
#   must/MD
#   also/RB
#   address/VB
#   deeper/JJR
#   challenges/NNS
#   that/WDT
#   existed/VBD
#   before/IN
#   the/DT
#   storm/NN
#   arrived/VBD
#   ./.)
# (S
#   In/IN
#   (Chunk New/NNP Orleans/NNP)
#   and/CC
#   in/IN
#   other/JJ
#   places/NNS
#   ,/,
#   many/JJ
#   of/IN
#   our/PRP$
#   fellow/JJ
#   citizens/NNS
#   have/VBP
#   felt/VBN
#   excluded/VBN
#   from/IN
#   the/DT
#   promise/NN
#   of/IN
#   our/PRP$
#   country/NN
#   ./.)
# (S
#   The/DT
#   answer/NN
#   is/VBZ
#   not/RB
#   only/RB
#   temporary/JJ
#   relief/NN
#   ,/,
#   but/CC
#   schools/NNS
#   that/WDT
#   teach/VBP
#   every/DT
#   child/NN
#   ,/,
#   and/CC
#   job/NN
#   skills/NNS
#   that/IN
#   bring/VBG
#   upward/JJ
#   mobility/NN
#   ,/,
#   and/CC
#   more/JJR
#   opportunities/NNS
#   to/TO
#   own/VB
#   a/DT
#   home/NN
#   and/CC
#   start/VB
#   a/DT
#   business/NN
#   ./.)
# (S
#   As/IN
#   we/PRP
#   recover/VBP
#   from/IN
#   a/DT
#   disaster/NN
#   ,/,
#   let/VB
#   us/PRP
#   also/RB
#   work/NN
#   for/IN
#   the/DT
#   day/NN
#   when/WRB
#   all/DT
#   Americans/NNPS
#   are/VBP
#   protected/VBN
#   by/IN
#   justice/NN
#   ,/,
#   equal/JJ
#   in/IN
#   hope/NN
#   ,/,
#   and/CC
#   rich/JJ
#   in/IN
#   opportunity/NN
#   ./.)
# (S (/( (Chunk Applause/NNP) ./. )/))
# (S
#   A/DT
#   hopeful/JJ
#   society/NN
#   acts/NNS
#   boldly/RB
#   to/TO
#   fight/VB
#   diseases/NNS
#   like/IN
#   (Chunk HIV/AIDS/NNP)
#   ,/,
#   which/WDT
#   can/MD
#   be/VB
#   prevented/VBN
#   ,/,
#   and/CC
#   treated/VBD
#   ,/,
#   and/CC
#   defeated/VBD
#   ./.)
# (S
#   More/JJR
#   than/IN
#   a/DT
#   million/CD
#   Americans/NNPS
#   live/VBP
#   with/IN
#   (Chunk HIV/NNP)
#   ,/,
#   and/CC
#   half/NN
#   of/IN
#   all/DT
#   (Chunk AIDS/NNP)
#   cases/NNS
#   occur/VBP
#   among/IN
#   African/JJ
#   Americans/NNPS
#   ./.)
# (S
#   I/PRP
#   (Chunk ask/VBP Congress/NNP)
#   to/TO
#   reform/VB
#   and/CC
#   reauthorize/VB
#   the/DT
#   (Chunk Ryan/NNP White/NNP Act/NNP)
#   ,/,
#   and/CC
#   provide/VB
#   new/JJ
#   funding/NN
#   to/TO
#   states/NNS
#   ,/,
#   so/IN
#   we/PRP
#   end/VBP
#   the/DT
#   waiting/NN
#   lists/NNS
#   for/IN
#   (Chunk AIDS/NNP)
#   medicines/NNS
#   in/IN
#   (Chunk America/NNP)
#   ./.)
# (S (/( (Chunk Applause/NNP) ./. )/))
# (S
#   We/PRP
#   will/MD
#   also/RB
#   lead/VB
#   a/DT
#   nationwide/JJ
#   effort/NN
#   ,/,
#   working/VBG
#   closely/RB
#   with/IN
#   African/JJ
#   American/JJ
#   churches/NNS
#   and/CC
#   faith-based/JJ
#   groups/NNS
#   ,/,
#   to/TO
#   deliver/VB
#   rapid/JJ
#   (Chunk HIV/NNP)
#   tests/NNS
#   to/TO
#   millions/NNS
#   ,/,
#   end/VBP
#   the/DT
#   stigma/NN
#   of/IN
#   (Chunk AIDS/NNP)
#   ,/,
#   and/CC
#   come/VB
#   closer/JJR
#   to/TO
#   the/DT
#   day/NN
#   when/WRB
#   there/EX
#   are/VBP
#   no/DT
#   new/JJ
#   infections/NNS
#   in/IN
#   (Chunk America/NNP)
#   ./.)
# (S (/( (Chunk Applause/NNP) ./. )/))
# (S
#   (Chunk Fellow/NNP)
#   citizens/NNS
#   ,/,
#   we/PRP
#   've/VBP
#   been/VBN
#   called/VBN
#   to/TO
#   leadership/NN
#   in/IN
#   a/DT
#   period/NN
#   of/IN
#   consequence/NN
#   ./.)
# (S
#   We/PRP
#   've/VBP
#   entered/VBN
#   a/DT
#   great/JJ
#   ideological/JJ
#   conflict/NN
#   we/PRP
#   did/VBD
#   nothing/NN
#   to/TO
#   invite/VB
#   ./.)
# (S
#   We/PRP
#   see/VBP
#   great/JJ
#   changes/NNS
#   in/IN
#   science/NN
#   and/CC
#   commerce/NN
#   that/WDT
#   will/MD
#   influence/VB
#   all/DT
#   our/PRP$
#   lives/NNS
#   ./.)
# (S
#   Sometimes/RB
#   it/PRP
#   can/MD
#   seem/VB
#   that/DT
#   history/NN
#   is/VBZ
#   turning/VBG
#   in/IN
#   a/DT
#   wide/JJ
#   arc/NN
#   ,/,
#   toward/IN
#   an/DT
#   unknown/JJ
#   shore/NN
#   ./.)
# (S
#   Yet/CC
#   the/DT
#   destination/NN
#   of/IN
#   history/NN
#   is/VBZ
#   determined/VBN
#   by/IN
#   human/JJ
#   action/NN
#   ,/,
#   and/CC
#   every/DT
#   great/JJ
#   movement/NN
#   of/IN
#   history/NN
#   comes/VBZ
#   to/TO
#   a/DT
#   point/NN
#   of/IN
#   choosing/NN
#   ./.)
# (S
#   (Chunk Lincoln/NNP)
#   could/MD
#   have/VB
#   accepted/VBN
#   peace/NN
#   at/IN
#   the/DT
#   cost/NN
#   of/IN
#   disunity/NN
#   and/CC
#   continued/JJ
#   slavery/NN
#   ./.)
# (S
#   (Chunk Martin/NNP Luther/NNP King/NNP)
#   could/MD
#   have/VB
#   stopped/VBN
#   at/IN
#   (Chunk Birmingham/NNP)
#   or/CC
#   at/IN
#   (Chunk Selma/NNP)
#   ,/,
#   and/CC
#   achieved/VBD
#   only/RB
#   half/PDT
#   a/DT
#   victory/NN
#   over/IN
#   segregation/NN
#   ./.)
# (S
#   The/DT
#   (Chunk United/NNP)
#   States/NNPS
#   could/MD
#   have/VB
#   accepted/VBN
#   the/DT
#   permanent/JJ
#   division/NN
#   of/IN
#   (Chunk Europe/NNP)
#   ,/,
#   and/CC
#   been/VBN
#   complicit/NNS
#   in/IN
#   the/DT
#   oppression/NN
#   of/IN
#   others/NNS
#   ./.)
# (S
#   Today/NN
#   ,/,
#   having/VBG
#   come/VBN
#   far/RB
#   in/IN
#   our/PRP$
#   own/JJ
#   historical/JJ
#   journey/NN
#   ,/,
#   we/PRP
#   must/MD
#   decide/VB
#   :/:
#   Will/MD
#   we/PRP
#   turn/VB
#   back/RP
#   ,/,
#   or/CC
#   finish/VB
#   well/RB
#   ?/.)
# (S
#   Before/IN
#   history/NN
#   is/VBZ
#   written/VBN
#   down/RP
#   in/IN
#   books/NNS
#   ,/,
#   it/PRP
#   is/VBZ
#   written/VBN
#   in/IN
#   courage/NN
#   ./.)
# (S
#   Like/IN
#   Americans/NNPS
#   before/IN
#   us/PRP
#   ,/,
#   we/PRP
#   will/MD
#   show/VB
#   that/DT
#   courage/NN
#   and/CC
#   we/PRP
#   will/MD
#   finish/VB
#   well/RB
#   ./.)
# (S We/PRP will/MD lead/VB freedom/NN 's/POS advance/NN ./.)
# (S
#   We/PRP
#   will/MD
#   compete/VB
#   and/CC
#   excel/VB
#   in/IN
#   the/DT
#   global/JJ
#   economy/NN
#   ./.)
# (S
#   We/PRP
#   will/MD
#   renew/VB
#   the/DT
#   defining/VBG
#   moral/JJ
#   commitments/NNS
#   of/IN
#   this/DT
#   land/NN
#   ./.)
# (S
#   And/CC
#   so/RB
#   we/PRP
#   move/VBP
#   forward/RB
#   --/:
#   optimistic/JJ
#   about/IN
#   our/PRP$
#   country/NN
#   ,/,
#   faithful/JJ
#   to/TO
#   its/PRP$
#   cause/NN
#   ,/,
#   and/CC
#   confident/NN
#   of/IN
#   the/DT
#   victories/NNS
#   to/TO
#   come/VB
#   ./.)
# (S (Chunk May/NNP God/NNP bless/NN) (Chunk America/NNP) ./.)
# (S (/( (Chunk Applause/NNP) ./. )/))

# %% [markdown]
# # Lesson 6 - Chinking

# %% [markdown]
# - You chink something from a chunk - it's the removal of words from a chunk.

# %%
def process_content():
    try:
        for i in tokenized[:100]:
            words = nltk.word_tokenize(i)
            tagged = nltk.pos_tag(words)
            
            # below is chunking all groups of words, and then chinking (getting rid of)
            # verbs, prepositions, & determiners
            chunk_gram = r"""Chunk: {<.*>+}
                                    }<VB.?|IN|DT|TO>+{""" 
            
            chunk_parser = nltk.RegexpParser(chunk_gram)
            chunked = chunk_parser.parse(tagged)
            
            print(chunked)
            # chunked.draw()
            
    except Exception as e:
        print(str(e))
        
process_content()
# Out:
# (S
#   (Chunk PRESIDENT/NNP GEORGE/NNP W./NNP BUSH/NNP 'S/POS ADDRESS/NNP)
#   BEFORE/IN
#   (Chunk A/NNP JOINT/NNP SESSION/NNP)
#   OF/IN
#   (Chunk THE/NNP CONGRESS/NNP ON/NNP THE/NNP STATE/NNP)
#   OF/IN
#   (Chunk
#     THE/NNP
#     UNION/NNP
#     January/NNP
#     31/CD
#     ,/,
#     2006/CD
#     THE/NNP
#     PRESIDENT/NNP
#     :/:
#     Thank/NNP
#     you/PRP)
#   all/DT
#   (Chunk ./.))
# (S
#   (Chunk
#     Mr./NNP
#     Speaker/NNP
#     ,/,
#     Vice/NNP
#     President/NNP
#     Cheney/NNP
#     ,/,
#     members/NNS)
#   of/IN
#   (Chunk Congress/NNP ,/, members/NNS)
#   of/IN
#   the/DT
#   (Chunk
#     Supreme/NNP
#     Court/NNP
#     and/CC
#     diplomatic/JJ
#     corps/NN
#     ,/,
#     distinguished/JJ
#     guests/NNS
#     ,/,
#     and/CC
#     fellow/JJ
#     citizens/NNS
#     :/:)
#   Today/VB
#   (Chunk our/PRP$ nation/NN)
#   lost/VBD
#   a/DT
#   beloved/VBN
#   (Chunk ,/, graceful/JJ ,/, courageous/JJ woman/NN who/WP)
#   called/VBD
#   (Chunk America/NNP)
#   to/TO
#   (Chunk its/PRP$ founding/NN ideals/NNS and/CC)
#   carried/VBD
#   on/IN
#   a/DT
#   (Chunk noble/JJ dream/NN ./.))
# (S
#   (Chunk Tonight/NN we/PRP)
#   are/VBP
#   comforted/VBN
#   by/IN
#   the/DT
#   (Chunk hope/NN)
#   of/IN
#   a/DT
#   (Chunk glad/JJ reunion/NN)
#   with/IN
#   the/DT
#   (Chunk husband/NN who/WP)
#   was/VBD
#   taken/VBN
#   (Chunk so/RB long/RB ago/RB ,/, and/CC we/PRP)
#   are/VBP
#   (Chunk grateful/JJ)
#   for/IN
#   the/DT
#   (Chunk good/JJ life/NN)
#   of/IN
#   (Chunk Coretta/NNP Scott/NNP King/NNP ./.))
# (S (Chunk (/( Applause/NNP ./. )/)))
# (S
#   (Chunk President/NNP George/NNP W./NNP Bush/NNP)
#   reacts/VBZ
#   to/TO
#   applause/VB
#   during/IN
#   (Chunk his/PRP$ State/NNP)
#   of/IN
#   the/DT
#   (Chunk Union/NNP Address/NNP)
#   at/IN
#   the/DT
#   (Chunk Capitol/NNP ,/, Tuesday/NNP ,/, Jan/NNP ./.))
# (S (Chunk 31/CD ,/, 2006/CD ./.))
# (S
#   (Chunk White/NNP House/NNP photo/NN)
#   by/IN
#   (Chunk Eric/NNP DraperEvery/NNP time/NN I/PRP)
#   'm/VBP
#   (Chunk invited/JJ)
#   to/TO
#   this/DT
#   (Chunk rostrum/NN ,/, I/PRP)
#   'm/VBP
#   humbled/VBN
#   by/IN
#   the/DT
#   (Chunk privilege/NN ,/, and/CC mindful/NN)
#   of/IN
#   the/DT
#   (Chunk history/NN we/PRP)
#   've/VBP
#   seen/VBN
#   (Chunk together/RB ./.))
# (S
#   (Chunk We/PRP)
#   have/VBP
#   gathered/VBN
#   under/IN
#   this/DT
#   (Chunk Capitol/NNP dome/NN)
#   in/IN
#   (Chunk moments/NNS)
#   of/IN
#   (Chunk
#     national/JJ
#     mourning/NN
#     and/CC
#     national/JJ
#     achievement/NN
#     ./.))
# (S
#   (Chunk We/PRP)
#   have/VBP
#   served/VBN
#   (Chunk America/NNP)
#   through/IN
#   (Chunk one/CD)
#   of/IN
#   the/DT
#   (Chunk most/RBS consequential/JJ periods/NNS)
#   of/IN
#   (Chunk our/PRP$ history/NN --/: and/CC it/PRP)
#   has/VBZ
#   been/VBN
#   (Chunk my/PRP$ honor/NN)
#   to/TO
#   serve/VB
#   with/IN
#   (Chunk you/PRP ./.))
# (S
#   In/IN
#   a/DT
#   (Chunk system/NN)
#   of/IN
#   (Chunk
#     two/CD
#     parties/NNS
#     ,/,
#     two/CD
#     chambers/NNS
#     ,/,
#     and/CC
#     two/CD
#     elected/JJ
#     branches/NNS
#     ,/,
#     there/EX
#     will/MD
#     always/RB)
#   be/VB
#   (Chunk differences/NNS and/CC debate/NN ./.))
# (S
#   (Chunk But/CC even/RB tough/JJ debates/NNS can/MD)
#   be/VB
#   conducted/VBN
#   in/IN
#   a/DT
#   (Chunk
#     civil/JJ
#     tone/NN
#     ,/,
#     and/CC
#     our/PRP$
#     differences/NNS
#     can/MD
#     not/RB)
#   be/VB
#   allowed/VBN
#   to/TO
#   harden/VB
#   into/IN
#   (Chunk anger/NN ./.))
# (S
#   To/TO
#   confront/VB
#   the/DT
#   (Chunk great/JJ issues/NNS)
#   before/IN
#   (Chunk us/PRP ,/, we/PRP must/MD)
#   act/VB
#   in/IN
#   a/DT
#   (Chunk spirit/NN)
#   of/IN
#   (Chunk goodwill/NN and/CC respect/NN)
#   for/IN
#   (Chunk one/CD)
#   another/DT
#   (Chunk --/: and/CC I/PRP will/MD)
#   do/VB
#   (Chunk my/PRP$ part/NN ./.))
# (S
#   (Chunk Tonight/NNP)
#   the/DT
#   (Chunk state/NN)
#   of/IN
#   (Chunk our/PRP$ Union/NNP)
#   is/VBZ
#   (Chunk strong/JJ --/: and/CC together/RB we/PRP will/MD)
#   make/VB
#   (Chunk it/PRP stronger/JJR ./.))
# (S (Chunk (/( Applause/NNP ./. )/)))
# (S
#   In/IN
#   this/DT
#   (Chunk decisive/JJ year/NN ,/, you/PRP and/CC I/PRP will/MD)
#   make/VB
#   (Chunk choices/NNS that/WDT)
#   determine/VBP
#   both/DT
#   the/DT
#   (Chunk future/NN and/CC)
#   the/DT
#   (Chunk character/NN)
#   of/IN
#   (Chunk our/PRP$ country/NN ./.))
# (S
#   (Chunk We/PRP will/MD)
#   choose/VB
#   to/TO
#   act/VB
#   (Chunk confidently/RB)
#   in/IN
#   pursuing/VBG
#   the/DT
#   (Chunk enemies/NNS)
#   of/IN
#   (Chunk freedom/NN --/: or/CC retreat/NN)
#   from/IN
#   (Chunk our/PRP$ duties/NNS)
#   in/IN
#   the/DT
#   (Chunk hope/NN)
#   of/IN
#   an/DT
#   (Chunk easier/JJR life/NN ./.))
# (S
#   (Chunk We/PRP will/MD)
#   choose/VB
#   to/TO
#   build/VB
#   (Chunk our/PRP$ prosperity/NN)
#   by/IN
#   leading/VBG
#   the/DT
#   (Chunk world/NN economy/NN --/: or/CC)
#   shut/VB
#   (Chunk ourselves/PRP off/RP)
#   from/IN
#   (Chunk trade/NN and/CC opportunity/NN ./.))
# (S
#   In/IN
#   a/DT
#   (Chunk complex/JJ and/CC challenging/JJ time/NN ,/,)
#   the/DT
#   (Chunk road/NN)
#   of/IN
#   (Chunk isolationism/NN and/CC protectionism/NN may/MD)
#   seem/VB
#   (Chunk broad/JJ and/CC inviting/NN --/: yet/CC it/PRP)
#   ends/VBZ
#   in/IN
#   (Chunk danger/NN and/CC decline/NN ./.))
# (S
#   The/DT
#   (Chunk only/JJ way/NN)
#   to/TO
#   protect/VB
#   (Chunk our/PRP$ people/NNS ,/,)
#   the/DT
#   (Chunk only/JJ way/NN)
#   to/TO
#   secure/VB
#   the/DT
#   (Chunk peace/NN ,/,)
#   the/DT
#   (Chunk only/JJ way/NN)
#   to/TO
#   control/VB
#   (Chunk our/PRP$ destiny/NN)
#   is/VBZ
#   by/IN
#   (Chunk our/PRP$ leadership/NN --/:)
#   so/IN
#   the/DT
#   (Chunk United/NNP States/NNPS)
#   of/IN
#   (Chunk America/NNP will/MD)
#   continue/VB
#   to/TO
#   lead/VB
#   (Chunk ./.))
# (S (Chunk (/( Applause/NNP ./. )/)))
# (S
#   (Chunk Abroad/RB ,/, our/PRP$ nation/NN)
#   is/VBZ
#   committed/VBN
#   to/TO
#   an/DT
#   (Chunk historic/JJ ,/, long-term/JJ goal/NN --/: we/PRP)
#   seek/VBP
#   the/DT
#   (Chunk end/NN)
#   of/IN
#   (Chunk tyranny/NN)
#   in/IN
#   (Chunk our/PRP$ world/NN ./.))
# (S
#   Some/DT
#   dismiss/VBP
#   that/DT
#   (Chunk goal/NN)
#   as/IN
#   (Chunk misguided/JJ idealism/NN ./.))
# (S
#   In/IN
#   (Chunk reality/NN ,/,)
#   the/DT
#   (Chunk future/JJ security/NN)
#   of/IN
#   (Chunk America/NNP)
#   depends/VBZ
#   on/IN
#   (Chunk it/PRP ./.))
# (S
#   On/IN
#   (Chunk September/NNP)
#   the/DT
#   (Chunk 11th/CD ,/, 2001/CD ,/, we/PRP)
#   found/VBD
#   that/IN
#   (Chunk problems/NNS)
#   originating/VBG
#   in/IN
#   a/DT
#   (Chunk
#     failed/JJ
#     and/CC
#     oppressive/JJ
#     state/NN
#     7,000/CD
#     miles/NNS
#     away/RB
#     could/MD)
#   bring/VB
#   (Chunk murder/NN and/CC destruction/NN)
#   to/TO
#   (Chunk our/PRP$ country/NN ./.))
# (S
#   (Chunk Dictatorships/NNP shelter/NN terrorists/NNS ,/, and/CC)
#   feed/VB
#   (Chunk
#     resentment/NN
#     and/CC
#     radicalism/NN
#     ,/,
#     and/CC
#     seek/JJ
#     weapons/NNS)
#   of/IN
#   (Chunk mass/NN destruction/NN ./.))
# (S
#   (Chunk Democracies/NNS)
#   replace/VB
#   (Chunk resentment/NN)
#   with/IN
#   (Chunk hope/NN ,/,)
#   respect/VB
#   the/DT
#   (Chunk rights/NNS)
#   of/IN
#   (Chunk
#     their/PRP$
#     citizens/NNS
#     and/CC
#     their/PRP$
#     neighbors/NNS
#     ,/,
#     and/CC)
#   join/VB
#   the/DT
#   (Chunk fight/NN)
#   against/IN
#   (Chunk terror/NN ./.))
# (S
#   Every/DT
#   (Chunk step/NN)
#   toward/IN
#   (Chunk freedom/NN)
#   in/IN
#   the/DT
#   (Chunk world/NN)
#   makes/VBZ
#   (Chunk our/PRP$ country/NN safer/NN --/:)
#   so/IN
#   (Chunk we/PRP will/MD)
#   act/VB
#   (Chunk boldly/RB)
#   in/IN
#   (Chunk freedom/NN 's/POS cause/NN ./.))
# (S (Chunk (/( Applause/NNP ./. )/)))
# (S
#   (Chunk Far/RB)
#   from/IN
#   being/VBG
#   a/DT
#   (Chunk hopeless/NN dream/NN ,/,)
#   the/DT
#   (Chunk advance/NN)
#   of/IN
#   (Chunk freedom/NN)
#   is/VBZ
#   the/DT
#   (Chunk great/JJ story/NN)
#   of/IN
#   (Chunk our/PRP$ time/NN ./.))
# (S
#   In/IN
#   (Chunk 1945/CD ,/, there/EX)
#   were/VBD
#   (Chunk about/RB two/CD dozen/NN lonely/RB)
#   democracies/VBZ
#   in/IN
#   the/DT
#   (Chunk world/NN ./.))
# (S (Chunk Today/NN ,/, there/EX) are/VBP (Chunk 122/CD ./.))
# (S
#   (Chunk And/CC we/PRP)
#   're/VBP
#   writing/VBG
#   a/DT
#   (Chunk new/JJ chapter/NN)
#   in/IN
#   the/DT
#   (Chunk story/NN)
#   of/IN
#   (Chunk self-government/JJ --/:)
#   with/IN
#   (Chunk women/NNS)
#   lining/VBG
#   (Chunk up/RP)
#   to/TO
#   vote/VB
#   in/IN
#   (Chunk Afghanistan/NNP ,/, and/CC millions/NNS)
#   of/IN
#   (Chunk Iraqis/NNP)
#   marking/VBG
#   (Chunk their/PRP$ liberty/NN)
#   with/IN
#   (Chunk purple/JJ ink/NN ,/, and/CC men/NNS and/CC women/NNS)
#   from/IN
#   (Chunk Lebanon/NNP)
#   to/TO
#   (Chunk Egypt/NNP)
#   debating/VBG
#   the/DT
#   (Chunk rights/NNS)
#   of/IN
#   (Chunk individuals/NNS and/CC)
#   the/DT
#   (Chunk necessity/NN)
#   of/IN
#   (Chunk freedom/NN ./.))
# (S
#   At/IN
#   the/DT
#   (Chunk start/NN)
#   of/IN
#   (Chunk 2006/CD ,/, more/JJR)
#   than/IN
#   (Chunk half/PDT)
#   the/DT
#   (Chunk people/NNS)
#   of/IN
#   (Chunk our/PRP$ world/NN)
#   live/VBP
#   in/IN
#   (Chunk democratic/JJ nations/NNS ./.))
# (S
#   (Chunk And/CC we/PRP)
#   do/VBP
#   (Chunk not/RB)
#   forget/VB
#   the/DT
#   (Chunk other/JJ half/NN --/:)
#   in/IN
#   (Chunk places/NNS)
#   like/IN
#   (Chunk
#     Syria/NNP
#     and/CC
#     Burma/NNP
#     ,/,
#     Zimbabwe/NNP
#     ,/,
#     North/NNP
#     Korea/NNP
#     ,/,
#     and/CC
#     Iran/NNP
#     --/:)
#   because/IN
#   the/DT
#   (Chunk demands/NNS)
#   of/IN
#   (Chunk justice/NN ,/, and/CC)
#   the/DT
#   (Chunk peace/NN)
#   of/IN
#   this/DT
#   (Chunk world/NN ,/,)
#   require/VBP
#   (Chunk their/PRP$ freedom/NN ,/, as/RB well/RB ./.))
# (S (Chunk (/( Applause/NNP ./. )/)))
# (S
#   (Chunk President/NNP George/NNP W./NNP Bush/NNP)
#   delivers/VBZ
#   (Chunk his/PRP$ State/NN)
#   of/IN
#   the/DT
#   (Chunk Union/NNP Address/NNP)
#   at/IN
#   the/DT
#   (Chunk Capitol/NNP ,/, Tuesday/NNP ,/, Jan/NNP ./.))
# (S (Chunk 31/CD ,/, 2006/CD ./.))
# (S
#   (Chunk White/NNP House/NNP photo/NN)
#   by/IN
#   (Chunk Eric/NNP Draper/NNP No/NNP one/NN can/MD)
#   deny/VB
#   the/DT
#   (Chunk success/NN)
#   of/IN
#   (Chunk freedom/NN ,/, but/CC)
#   some/DT
#   (Chunk men/NNS)
#   rage/VB
#   (Chunk and/CC)
#   fight/VB
#   against/IN
#   (Chunk it/PRP ./.))
# (S
#   (Chunk And/CC one/CD)
#   of/IN
#   the/DT
#   (Chunk main/JJ sources/NNS)
#   of/IN
#   (Chunk reaction/NN and/CC opposition/NN)
#   is/VBZ
#   (Chunk radical/JJ Islam/NNP --/:)
#   the/DT
#   (Chunk perversion/NN)
#   by/IN
#   a/DT
#   (Chunk few/JJ)
#   of/IN
#   a/DT
#   (Chunk noble/JJ faith/NN)
#   into/IN
#   an/DT
#   (Chunk ideology/NN)
#   of/IN
#   (Chunk terror/NN and/CC death/NN ./.))
# (S
#   (Chunk Terrorists/NNS)
#   like/IN
#   (Chunk bin/NN Laden/NNP)
#   are/VBP
#   (Chunk serious/JJ)
#   about/IN
#   (Chunk mass/NN murder/NN --/: and/CC)
#   all/DT
#   of/IN
#   (Chunk us/PRP must/MD)
#   take/VB
#   (Chunk their/PRP$ declared/JJ intentions/NNS seriously/RB ./.))
# (S
#   (Chunk They/PRP)
#   seek/VBP
#   to/TO
#   impose/VB
#   a/DT
#   (Chunk heartless/NN system/NN)
#   of/IN
#   (Chunk totalitarian/JJ control/NN)
#   throughout/IN
#   the/DT
#   (Chunk Middle/NNP East/NNP ,/, and/CC arm/NN themselves/PRP)
#   with/IN
#   (Chunk weapons/NNS)
#   of/IN
#   (Chunk mass/NN murder/NN ./.))
# (S
#   (Chunk Their/PRP$ aim/NN)
#   is/VBZ
#   to/TO
#   seize/VB
#   (Chunk power/NN)
#   in/IN
#   (Chunk Iraq/NNP ,/, and/CC)
#   use/VB
#   (Chunk it/PRP)
#   as/IN
#   a/DT
#   (Chunk safe/JJ haven/NN)
#   to/TO
#   launch/VB
#   (Chunk attacks/NNS)
#   against/IN
#   (Chunk America/NNP and/CC)
#   the/DT
#   (Chunk world/NN ./.))
# (S
#   Lacking/VBG
#   the/DT
#   (Chunk military/JJ strength/NN)
#   to/TO
#   challenge/VB
#   (Chunk us/PRP directly/RB ,/,)
#   the/DT
#   (Chunk terrorists/NNS)
#   have/VBP
#   chosen/VBN
#   the/DT
#   (Chunk weapon/NN)
#   of/IN
#   (Chunk fear/NN ./.))
# (S
#   (Chunk When/WRB they/PRP)
#   murder/VBP
#   (Chunk children/NNS)
#   at/IN
#   a/DT
#   (Chunk school/NN)
#   in/IN
#   (Chunk Beslan/NNP ,/, or/CC)
#   blow/VB
#   (Chunk up/RP commuters/NNS)
#   in/IN
#   (Chunk London/NNP ,/, or/CC)
#   behead/VB
#   a/DT
#   (Chunk bound/NN captive/NN ,/,)
#   the/DT
#   (Chunk terrorists/NNS)
#   hope/VBP
#   these/DT
#   (Chunk horrors/NNS will/MD)
#   break/VB
#   (Chunk our/PRP$ will/MD ,/,)
#   allowing/VBG
#   the/DT
#   (Chunk violent/NN)
#   to/TO
#   inherit/VB
#   the/DT
#   (Chunk Earth/NNP ./.))
# (S
#   (Chunk But/CC they/PRP)
#   have/VBP
#   miscalculated/VBN
#   (Chunk :/: We/PRP)
#   love/VBP
#   (Chunk our/PRP$ freedom/NN ,/, and/CC we/PRP will/MD)
#   fight/VB
#   to/TO
#   keep/VB
#   (Chunk it/PRP ./.))
# (S (Chunk (/( Applause/NNP ./. )/)))
# (S
#   In/IN
#   a/DT
#   (Chunk time/NN)
#   of/IN
#   testing/VBG
#   (Chunk ,/, we/PRP can/MD not/RB)
#   find/VB
#   (Chunk security/NN)
#   by/IN
#   abandoning/VBG
#   (Chunk our/PRP$ commitments/NNS and/CC)
#   retreating/VBG
#   within/IN
#   (Chunk our/PRP$ borders/NNS ./.))
# (S
#   If/IN
#   (Chunk we/PRP)
#   were/VBD
#   to/TO
#   leave/VB
#   these/DT
#   (Chunk
#     vicious/JJ
#     attackers/NNS
#     alone/RB
#     ,/,
#     they/PRP
#     would/MD
#     not/RB)
#   leave/VB
#   (Chunk us/PRP alone/RB ./.))
# (S
#   (Chunk They/PRP would/MD simply/RB)
#   move/VB
#   the/DT
#   (Chunk battlefield/NN)
#   to/TO
#   (Chunk our/PRP$ own/JJ shores/NNS ./.))
# (S
#   (Chunk There/EX)
#   is/VBZ
#   no/DT
#   (Chunk peace/NN)
#   in/IN
#   (Chunk retreat/NN ./.))
# (S
#   (Chunk And/CC there/EX)
#   is/VBZ
#   no/DT
#   (Chunk honor/NN)
#   in/IN
#   (Chunk retreat/NN ./.))
# (S
#   By/IN
#   allowing/VBG
#   (Chunk radical/JJ Islam/NNP)
#   to/TO
#   work/VB
#   (Chunk its/PRP$ will/MD --/:)
#   by/IN
#   leaving/VBG
#   an/DT
#   (Chunk assaulted/JJ world/NN)
#   to/TO
#   fend/VB
#   for/IN
#   (Chunk itself/PRP --/: we/PRP would/MD)
#   signal/VB
#   to/TO
#   (Chunk all/PDT)
#   that/IN
#   (Chunk we/PRP)
#   no/DT
#   (Chunk longer/RBR)
#   believe/VBP
#   in/IN
#   (Chunk our/PRP$ own/JJ ideals/NNS ,/, or/CC even/RB)
#   in/IN
#   (Chunk our/PRP$ own/JJ courage/NN ./.))
# (S
#   (Chunk
#     But/CC
#     our/PRP$
#     enemies/NNS
#     and/CC
#     our/PRP$
#     friends/NNS
#     can/MD)
#   be/VB
#   (Chunk certain/JJ :/:)
#   The/DT
#   (Chunk United/NNP States/NNPS will/MD not/RB)
#   retreat/VB
#   from/IN
#   the/DT
#   (Chunk world/NN ,/, and/CC we/PRP will/MD never/RB)
#   surrender/VB
#   to/TO
#   evil/VB
#   (Chunk ./.))
# (S (Chunk (/( Applause/NNP ./. )/)))
# (S
#   (Chunk America/NNP)
#   rejects/VBZ
#   the/DT
#   (Chunk false/JJ comfort/NN)
#   of/IN
#   (Chunk isolationism/NN ./.))
# (S
#   (Chunk We/PRP)
#   are/VBP
#   the/DT
#   (Chunk nation/NN)
#   that/IN
#   saved/VBD
#   (Chunk liberty/NN)
#   in/IN
#   (Chunk Europe/NNP ,/, and/CC)
#   liberated/VBD
#   (Chunk death/NN camps/NNS ,/, and/CC)
#   helped/VBD
#   raise/VB
#   (Chunk up/RP democracies/NNS ,/, and/CC)
#   faced/VBD
#   down/IN
#   an/DT
#   (Chunk evil/JJ empire/NN ./.))
# (S
#   (Chunk Once/RB again/RB ,/, we/PRP)
#   accept/VBP
#   the/DT
#   (Chunk call/NN)
#   of/IN
#   (Chunk history/NN)
#   to/TO
#   deliver/VB
#   the/DT
#   oppressed/VBN
#   (Chunk and/CC)
#   move/VB
#   this/DT
#   (Chunk world/NN)
#   toward/IN
#   (Chunk peace/NN ./.))
# (S
#   (Chunk We/PRP)
#   remain/VBP
#   on/IN
#   the/DT
#   (Chunk offensive/JJ)
#   against/IN
#   (Chunk terror/NN networks/NNS ./.))
# (S
#   (Chunk We/PRP)
#   have/VBP
#   killed/VBN
#   (Chunk or/CC)
#   captured/VBN
#   (Chunk many/JJ)
#   of/IN
#   (Chunk their/PRP$ leaders/NNS --/: and/CC)
#   for/IN
#   the/DT
#   (Chunk others/NNS ,/, their/PRP$ day/NN will/MD)
#   come/VB
#   (Chunk ./.))
# (S
#   (Chunk President/NNP George/NNP W./NNP Bush/NNP)
#   greets/VBZ
#   (Chunk members/NNS)
#   of/IN
#   (Chunk Congress/NNP)
#   after/IN
#   (Chunk his/PRP$ State/NN)
#   of/IN
#   the/DT
#   (Chunk Union/NNP Address/NNP)
#   at/IN
#   the/DT
#   (Chunk Capitol/NNP ,/, Tuesday/NNP ,/, Jan/NNP ./.))
# (S (Chunk 31/CD ,/, 2006/CD ./.))
# (S
#   (Chunk White/NNP House/NNP photo/NN)
#   by/IN
#   (Chunk Eric/NNP Draper/NNP We/PRP)
#   remain/VBP
#   on/IN
#   the/DT
#   (Chunk offensive/JJ)
#   in/IN
#   (Chunk Afghanistan/NNP ,/, where/WRB)
#   a/DT
#   (Chunk fine/JJ President/NNP and/CC)
#   a/DT
#   (Chunk National/NNP Assembly/NNP)
#   are/VBP
#   fighting/VBG
#   (Chunk terror/NN)
#   while/IN
#   building/VBG
#   the/DT
#   (Chunk institutions/NNS)
#   of/IN
#   a/DT
#   (Chunk new/JJ democracy/NN ./.))
# (S
#   (Chunk We/PRP)
#   're/VBP
#   on/IN
#   the/DT
#   (Chunk offensive/JJ)
#   in/IN
#   (Chunk Iraq/NNP ,/,)
#   with/IN
#   a/DT
#   (Chunk clear/JJ plan/NN)
#   for/IN
#   (Chunk victory/NN ./.))
# (S
#   (Chunk First/RB ,/, we/PRP)
#   're/VBP
#   helping/VBG
#   (Chunk Iraqis/NNP)
#   build/VB
#   an/DT
#   (Chunk inclusive/JJ government/NN ,/,)
#   so/IN
#   that/DT
#   (Chunk old/JJ resentments/NNS will/MD)
#   be/VB
#   eased/VBN
#   (Chunk and/CC)
#   the/DT
#   (Chunk insurgency/NN will/MD)
#   be/VB
#   marginalized/VBN
#   (Chunk ./.))
# (S
#   (Chunk Second/JJ ,/, we/PRP)
#   're/VBP
#   continuing/VBG
#   (Chunk reconstruction/NN efforts/NNS ,/, and/CC)
#   helping/VBG
#   the/DT
#   (Chunk Iraqi/NNP government/NN)
#   to/TO
#   fight/VB
#   (Chunk corruption/NN and/CC)
#   build/VB
#   a/DT
#   (Chunk modern/JJ economy/NN ,/,)
#   so/IN
#   all/DT
#   (Chunk Iraqis/NNP can/MD)
#   experience/VB
#   the/DT
#   (Chunk benefits/NNS)
#   of/IN
#   (Chunk freedom/NN ./.))
# (S
#   (Chunk And/CC ,/, third/JJ ,/, we/PRP)
#   're/VBP
#   striking/VBG
#   (Chunk terrorist/JJ targets/NNS)
#   while/IN
#   (Chunk we/PRP)
#   train/VBP
#   (Chunk Iraqi/JJ forces/NNS that/WDT)
#   are/VBP
#   (Chunk increasingly/RB capable/JJ)
#   of/IN
#   defeating/VBG
#   the/DT
#   (Chunk enemy/NN ./.))
# (S
#   (Chunk Iraqis/NNP)
#   are/VBP
#   showing/VBG
#   (Chunk their/PRP$ courage/NN)
#   every/DT
#   (Chunk day/NN ,/, and/CC we/PRP)
#   are/VBP
#   (Chunk proud/JJ)
#   to/TO
#   be/VB
#   (Chunk their/PRP$ allies/NNS)
#   in/IN
#   the/DT
#   (Chunk cause/NN)
#   of/IN
#   (Chunk freedom/NN ./.))
# (S (Chunk (/( Applause/NNP ./. )/)))
# (S
#   (Chunk Our/PRP$ work/NN)
#   in/IN
#   (Chunk Iraq/NNP)
#   is/VBZ
#   (Chunk difficult/JJ)
#   because/IN
#   (Chunk our/PRP$ enemy/NN)
#   is/VBZ
#   (Chunk brutal/JJ ./.))
# (S
#   (Chunk But/CC)
#   that/DT
#   (Chunk brutality/NN)
#   has/VBZ
#   (Chunk not/RB)
#   stopped/VBN
#   the/DT
#   (Chunk dramatic/JJ progress/NN)
#   of/IN
#   a/DT
#   (Chunk new/JJ democracy/NN ./.))
# (S
#   In/IN
#   (Chunk less/JJR)
#   than/IN
#   (Chunk three/CD years/NNS ,/,)
#   the/DT
#   (Chunk nation/NN)
#   has/VBZ
#   gone/VBN
#   from/IN
#   (Chunk dictatorship/NN)
#   to/TO
#   (Chunk liberation/NN ,/,)
#   to/TO
#   sovereignty/VB
#   (Chunk ,/,)
#   to/TO
#   a/DT
#   (Chunk constitution/NN ,/,)
#   to/TO
#   (Chunk national/JJ elections/NNS ./.))
# (S
#   At/IN
#   the/DT
#   (Chunk same/JJ time/NN ,/, our/PRP$ coalition/NN)
#   has/VBZ
#   been/VBN
#   relentless/VBN
#   in/IN
#   shutting/VBG
#   (Chunk off/RP terrorist/JJ infiltration/NN ,/,)
#   clearing/VBG
#   (Chunk out/RP insurgent/JJ strongholds/NNS ,/, and/CC)
#   turning/VBG
#   (Chunk over/RP territory/NN)
#   to/TO
#   (Chunk Iraqi/NNP security/NN forces/NNS ./.))
# (S
#   (Chunk I/PRP)
#   am/VBP
#   (Chunk confident/JJ)
#   in/IN
#   (Chunk our/PRP$ plan/NN)
#   for/IN
#   (Chunk victory/NN ;/: I/PRP)
#   am/VBP
#   (Chunk confident/JJ)
#   in/IN
#   the/DT
#   (Chunk will/MD)
#   of/IN
#   the/DT
#   (Chunk Iraqi/NNP people/NNS ;/: I/PRP)
#   am/VBP
#   (Chunk confident/JJ)
#   in/IN
#   the/DT
#   (Chunk skill/NN and/CC spirit/NN)
#   of/IN
#   (Chunk our/PRP$ military/JJ ./.))
# (S
#   (Chunk Fellow/NNP citizens/NNS ,/, we/PRP)
#   are/VBP
#   in/IN
#   this/DT
#   (Chunk fight/NN)
#   to/TO
#   win/VB
#   (Chunk ,/, and/CC we/PRP)
#   are/VBP
#   winning/VBG
#   (Chunk ./.))
# (S (Chunk (/( Applause/NNP ./. )/)))
# (S
#   The/DT
#   (Chunk road/NN)
#   of/IN
#   (Chunk victory/NN)
#   is/VBZ
#   the/DT
#   (Chunk road/NN that/WDT will/MD)
#   take/VB
#   (Chunk our/PRP$ troops/NNS home/NN ./.))
# (S
#   As/IN
#   (Chunk we/PRP)
#   make/VBP
#   (Chunk progress/NN)
#   on/IN
#   the/DT
#   (Chunk ground/NN ,/, and/CC Iraqi/NNP forces/NNS increasingly/RB)
#   take/VBP
#   the/DT
#   (Chunk lead/NN ,/, we/PRP should/MD)
#   be/VB
#   (Chunk able/JJ)
#   to/TO
#   (Chunk further/JJ)
#   decrease/VB
#   (Chunk our/PRP$ troop/NN levels/NNS --/: but/CC)
#   those/DT
#   (Chunk decisions/NNS will/MD)
#   be/VB
#   made/VBN
#   by/IN
#   (Chunk our/PRP$ military/JJ commanders/NNS ,/, not/RB)
#   by/IN
#   (Chunk politicians/NNS)
#   in/IN
#   (Chunk Washington/NNP ,/, D.C/NNP ./.))
# (S (Chunk (/( Applause/NNP ./. )/)))
# (S
#   (Chunk Our/PRP$ coalition/NN)
#   has/VBZ
#   learned/VBN
#   from/IN
#   (Chunk our/PRP$ experience/NN)
#   in/IN
#   (Chunk Iraq/NNP ./.))
# (S
#   (Chunk We/PRP)
#   've/VBP
#   adjusted/VBN
#   (Chunk our/PRP$ military/JJ tactics/NNS and/CC)
#   changed/VBD
#   (Chunk our/PRP$ approach/NN)
#   to/TO
#   (Chunk reconstruction/NN ./.))
# (S
#   Along/IN
#   the/DT
#   (Chunk way/NN ,/, we/PRP)
#   have/VBP
#   benefitted/VBN
#   from/IN
#   (Chunk responsible/JJ criticism/NN and/CC counsel/NN)
#   offered/VBN
#   by/IN
#   (Chunk members/NNS)
#   of/IN
#   (Chunk Congress/NNP)
#   of/IN
#   both/DT
#   (Chunk parties/NNS ./.))
# (S
#   In/IN
#   the/DT
#   coming/VBG
#   (Chunk year/NN ,/, I/PRP will/MD)
#   continue/VB
#   to/TO
#   reach/VB
#   (Chunk out/RP and/CC)
#   seek/VB
#   (Chunk your/PRP$ good/JJ advice/NN ./.))
# (S
#   (Chunk Yet/RB ,/, there/EX)
#   is/VBZ
#   a/DT
#   (Chunk difference/NN)
#   between/IN
#   (Chunk responsible/JJ criticism/NN that/WDT)
#   aims/VBZ
#   for/IN
#   (Chunk success/NN ,/, and/CC defeatism/NN that/WDT)
#   refuses/VBZ
#   to/TO
#   acknowledge/VB
#   (Chunk anything/NN but/CC failure/NN ./.))
# (S (Chunk (/( Applause/NNP ./. )/)))
# (S
#   (Chunk Hindsight/NNP alone/RB)
#   is/VBZ
#   (Chunk not/RB wisdom/JJ ,/, and/CC second-guessing/NN)
#   is/VBZ
#   (Chunk not/RB)
#   a/DT
#   (Chunk strategy/NN ./.))
# (S (Chunk (/( Applause/NNP ./. )/)))
# (S
#   With/IN
#   (Chunk so/RB much/JJ)
#   in/IN
#   the/DT
#   (Chunk balance/NN ,/,)
#   those/DT
#   of/IN
#   (Chunk us/PRP)
#   in/IN
#   (Chunk public/JJ office/NN)
#   have/VBP
#   a/DT
#   (Chunk duty/NN)
#   to/TO
#   speak/VB
#   with/IN
#   (Chunk candor/NN ./.))
# (S
#   A/DT
#   (Chunk sudden/JJ withdrawal/NN)
#   of/IN
#   (Chunk our/PRP$ forces/NNS)
#   from/IN
#   (Chunk Iraq/NNP would/MD)
#   abandon/VB
#   (Chunk our/PRP$ Iraqi/NNP allies/NNS)
#   to/TO
#   (Chunk death/NN and/CC prison/NN ,/, would/MD)
#   put/VB
#   (Chunk men/NNS)
#   like/IN
#   (Chunk bin/NN Laden/NNP and/CC Zarqawi/NNP)
#   in/IN
#   (Chunk charge/NN)
#   of/IN
#   a/DT
#   (Chunk strategic/JJ country/NN ,/, and/CC)
#   show/VBP
#   that/IN
#   a/DT
#   (Chunk pledge/NN)
#   from/IN
#   (Chunk America/NNP)
#   means/VBZ
#   (Chunk little/JJ ./.))
# (S
#   (Chunk Members/NNS)
#   of/IN
#   (Chunk Congress/NNP ,/, however/RB we/PRP)
#   feel/VBP
#   about/IN
#   the/DT
#   (Chunk decisions/NNS and/CC debates/NNS)
#   of/IN
#   the/DT
#   (Chunk past/NN ,/, our/PRP$ nation/NN)
#   has/VBZ
#   (Chunk only/RB one/CD option/NN :/: We/PRP must/MD)
#   keep/VB
#   (Chunk our/PRP$ word/NN ,/,)
#   defeat/VB
#   (Chunk our/PRP$ enemies/NNS ,/, and/CC)
#   stand/VBP
#   behind/IN
#   the/DT
#   (Chunk American/JJ military/NN)
#   in/IN
#   this/DT
#   (Chunk vital/JJ mission/NN ./.))
# (S (Chunk (/( Applause/NNP ./. )/)))
# (S
#   (Chunk Laura/NNP Bush/NNP)
#   is/VBZ
#   applauded/VBN
#   as/IN
#   (Chunk she/PRP)
#   is/VBZ
#   introduced/VBN
#   (Chunk Tuesday/NNP evening/NN ,/, Jan/NNP ./.))
# (S
#   (Chunk 31/CD ,/, 2006/CD)
#   during/IN
#   the/DT
#   (Chunk State/NNP)
#   of/IN
#   the/DT
#   (Chunk Union/NNP Address/NNP)
#   at/IN
#   (Chunk United/NNP States/NNPS Capitol/NNP)
#   in/IN
#   (Chunk Washington/NNP ./.))
# (S
#   (Chunk White/NNP House/NNP photo/NN)
#   by/IN
#   (Chunk Eric/NNP Draper/NNP Our/PRP$ men/NNS and/CC women/NNS)
#   in/IN
#   (Chunk uniform/JJ)
#   are/VBP
#   making/VBG
#   (Chunk sacrifices/NNS --/: and/CC)
#   showing/VBG
#   a/DT
#   (Chunk sense/NN)
#   of/IN
#   (Chunk duty/NN stronger/JJR)
#   than/IN
#   all/DT
#   (Chunk fear/NN ./.))
# (S
#   (Chunk They/PRP)
#   know/VBP
#   (Chunk what/WP it/PRP)
#   's/VBZ
#   like/IN
#   to/TO
#   fight/VB
#   (Chunk house/NN)
#   to/TO
#   (Chunk house/NN)
#   in/IN
#   a/DT
#   (Chunk maze/NN)
#   of/IN
#   (Chunk streets/NNS ,/,)
#   to/TO
#   wear/VB
#   (Chunk heavy/JJ gear/NN)
#   in/IN
#   the/DT
#   (Chunk desert/NN heat/NN ,/,)
#   to/TO
#   see/VB
#   a/DT
#   (Chunk comrade/NN)
#   killed/VBN
#   by/IN
#   a/DT
#   (Chunk roadside/NN bomb/NN ./.))
# (S
#   (Chunk And/CC)
#   those/DT
#   (Chunk who/WP)
#   know/VBP
#   the/DT
#   (Chunk costs/NNS also/RB)
#   know/VBP
#   the/DT
#   (Chunk stakes/NNS ./.))
# (S
#   (Chunk Marine/JJ Staff/NNP Sergeant/NNP Dan/NNP Clay/NNP)
#   was/VBD
#   killed/VBN
#   (Chunk last/JJ month/NN)
#   fighting/VBG
#   in/IN
#   (Chunk Fallujah/NNP ./.))
# (S
#   (Chunk He/PRP)
#   left/VBD
#   (Chunk behind/RP)
#   a/DT
#   (Chunk letter/NN)
#   to/TO
#   (Chunk
#     his/PRP$
#     family/NN
#     ,/,
#     but/CC
#     his/PRP$
#     words/NNS
#     could/MD
#     just/RB
#     as/RB
#     well/RB)
#   be/VB
#   addressed/VBN
#   to/TO
#   every/DT
#   (Chunk American/NNP ./.))
# (S
#   (Chunk Here/RB)
#   is/VBZ
#   (Chunk what/WP Dan/NNP)
#   wrote/VBD
#   (Chunk :/: ``/`` I/PRP)
#   know/VBP
#   (Chunk what/WP honor/NN)
#   is/VBZ
#   (Chunk ./.))
# (S
#   (Chunk .../: It/PRP)
#   has/VBZ
#   been/VBN
#   an/DT
#   (Chunk honor/NN)
#   to/TO
#   protect/VB
#   (Chunk and/CC)
#   serve/VB
#   all/DT
#   of/IN
#   (Chunk you/PRP ./.))
# (S
#   (Chunk I/PRP)
#   faced/VBD
#   (Chunk death/NN)
#   with/IN
#   the/DT
#   (Chunk secure/NN knowledge/NN)
#   that/IN
#   (Chunk you/PRP would/MD not/RB)
#   have/VB
#   to/TO
#   (Chunk .../: ./.))

# %% [markdown]
# # Lesson 7 - Named Entity Recognition

# %% [markdown]
# | NE Type | Examples |
# | --- | --- |
# |ORGANIZATION | Georgia-Pacific Corp., WHO |
# |PERSON	| Eddy Bonte, President Obama |
# |LOCATION | Murray River, Mount Everest |
# |DATE | June, 2008-06-29 |
# |TIME | two fifty a m, 1:30 p.m. |
# |MONEY | 175 million Canadian Dollars, GBP 10.40 |
# |PERCENT | twenty pct, 18.75 % |
# |FACILITY | Washington Monument, Stonehenge |
# |GPE | South East Asia, Midlothian |
#
# - Note: error rates and false positives are pretty high with named entity recognition.

# %%
def process_content():
    try:
        for i in tokenized:
            words = nltk.word_tokenize(i)
            tagged = nltk.pos_tag(words)
            
            named_ent = nltk.ne_chunk(tagged)
            print(named_ent)
            
    except Exception as e:
        print(str(e))
        
process_content()
# Out:
# (S
#   PRESIDENT/NNP
#   (PERSON GEORGE/NNP W./NNP BUSH/NNP)
#   'S/POS
#   (ORGANIZATION ADDRESS/NNP)
#   BEFORE/IN
#   A/NNP
#   (ORGANIZATION JOINT/NNP)
#   SESSION/NNP
#   OF/IN
#   (ORGANIZATION THE/NNP)
#   (ORGANIZATION CONGRESS/NNP)
#   ON/NNP
#   THE/NNP
#   (ORGANIZATION STATE/NNP OF/IN)
#   (ORGANIZATION THE/NNP)
#   (ORGANIZATION UNION/NNP)
#   January/NNP
#   31/CD
#   ,/,
#   2006/CD
#   (ORGANIZATION THE/NNP)
#   PRESIDENT/NNP
#   :/:
#   Thank/NNP
#   you/PRP
#   all/DT
#   ./.)
# (S
#   (PERSON Mr./NNP Speaker/NNP)
#   ,/,
#   Vice/NNP
#   President/NNP
#   (PERSON Cheney/NNP)
#   ,/,
#   members/NNS
#   of/IN
#   (ORGANIZATION Congress/NNP)
#   ,/,
#   members/NNS
#   of/IN
#   the/DT
#   (ORGANIZATION Supreme/NNP Court/NNP)
#   and/CC
#   diplomatic/JJ
#   corps/NN
#   ,/,
#   distinguished/JJ
#   guests/NNS
#   ,/,
#   and/CC
#   fellow/JJ
#   citizens/NNS
#   :/:
#   Today/VB
#   our/PRP$
#   nation/NN
#   lost/VBD
#   a/DT
#   beloved/VBN
#   ,/,
#   graceful/JJ
#   ,/,
#   courageous/JJ
#   woman/NN
#   who/WP
#   called/VBD
#   (GPE America/NNP)
#   to/TO
#   its/PRP$
#   founding/NN
#   ideals/NNS
#   and/CC
#   carried/VBD
#   on/IN
#   a/DT
#   noble/JJ
#   dream/NN
#   ./.)
# (S
#   Tonight/NN
#   we/PRP
#   are/VBP
#   comforted/VBN
#   by/IN
#   the/DT
#   hope/NN
#   of/IN
#   a/DT
#   glad/JJ
#   reunion/NN
#   with/IN
#   the/DT
#   husband/NN
#   who/WP
#   was/VBD
#   taken/VBN
#   so/RB
#   long/RB
#   ago/RB
#   ,/,
#   and/CC
#   we/PRP
#   are/VBP
#   grateful/JJ
#   for/IN
#   the/DT
#   good/JJ
#   life/NN
#   of/IN
#   (ORGANIZATION Coretta/NNP Scott/NNP King/NNP)
#   ./.)
# (S (/( (ORGANIZATION Applause/NNP) ./. )/))
# (S
#   President/NNP
#   (PERSON George/NNP W./NNP Bush/NNP)
#   reacts/VBZ
#   to/TO
#   applause/VB
#   during/IN
#   his/PRP$
#   State/NNP
#   of/IN
#   the/DT
#   (ORGANIZATION Union/NNP Address/NNP)
#   at/IN
#   the/DT
#   (GPE Capitol/NNP)
#   ,/,
#   Tuesday/NNP
#   ,/,
#   (PERSON Jan/NNP)
#   ./.)
# (S 31/CD ,/, 2006/CD ./.)
# (S
#   (FACILITY White/NNP)
#   (ORGANIZATION House/NNP)
#   photo/NN
#   by/IN
#   (PERSON Eric/NNP)
#   DraperEvery/NNP
#   time/NN
#   I/PRP
#   'm/VBP
#   invited/JJ
#   to/TO
#   this/DT
#   rostrum/NN
#   ,/,
#   I/PRP
#   'm/VBP
#   humbled/VBN
#   by/IN
#   the/DT
#   privilege/NN
#   ,/,
#   and/CC
#   mindful/NN
#   of/IN
#   the/DT
#   history/NN
#   we/PRP
#   've/VBP
#   seen/VBN
#   together/RB
#   ./.)
# (S
#   We/PRP
#   have/VBP
#   gathered/VBN
#   under/IN
#   this/DT
#   Capitol/NNP
#   dome/NN
#   in/IN
#   moments/NNS
#   of/IN
#   national/JJ
#   mourning/NN
#   and/CC
#   national/JJ
#   achievement/NN
#   ./.)
# (S
#   We/PRP
#   have/VBP
#   served/VBN
#   (GPE America/NNP)
#   through/IN
#   one/CD
#   of/IN
#   the/DT
#   most/RBS
#   consequential/JJ
#   periods/NNS
#   of/IN
#   our/PRP$
#   history/NN
#   --/:
#   and/CC
#   it/PRP
#   has/VBZ
#   been/VBN
#   my/PRP$
#   honor/NN
#   to/TO
#   serve/VB
#   with/IN
#   you/PRP
#   ./.)
# (S
#   In/IN
#   a/DT
#   system/NN
#   of/IN
#   two/CD
#   parties/NNS
#   ,/,
#   two/CD
#   chambers/NNS
#   ,/,
#   and/CC
#   two/CD
#   elected/JJ
#   branches/NNS
#   ,/,
#   there/EX
#   will/MD
#   always/RB
#   be/VB
#   differences/NNS
#   and/CC
#   debate/NN
#   ./.)
# (S
#   But/CC
#   even/RB
#   tough/JJ
#   debates/NNS
#   can/MD
#   be/VB
#   conducted/VBN
#   in/IN
#   a/DT
#   civil/JJ
#   tone/NN
#   ,/,
#   and/CC
#   our/PRP$
#   differences/NNS
#   can/MD
#   not/RB
#   be/VB
#   allowed/VBN
#   to/TO
#   harden/VB
#   into/IN
#   anger/NN
#   ./.)
# (S
#   To/TO
#   confront/VB
#   the/DT
#   great/JJ
#   issues/NNS
#   before/IN
#   us/PRP
#   ,/,
#   we/PRP
#   must/MD
#   act/VB
#   in/IN
#   a/DT
#   spirit/NN
#   of/IN
#   goodwill/NN
#   and/CC
#   respect/NN
#   for/IN
#   one/CD
#   another/DT
#   --/:
#   and/CC
#   I/PRP
#   will/MD
#   do/VB
#   my/PRP$
#   part/NN
#   ./.)
# (S
#   Tonight/NNP
#   the/DT
#   state/NN
#   of/IN
#   our/PRP$
#   (ORGANIZATION Union/NNP)
#   is/VBZ
#   strong/JJ
#   --/:
#   and/CC
#   together/RB
#   we/PRP
#   will/MD
#   make/VB
#   it/PRP
#   stronger/JJR
#   ./.)
# (S (/( (ORGANIZATION Applause/NNP) ./. )/))
# (S
#   In/IN
#   this/DT
#   decisive/JJ
#   year/NN
#   ,/,
#   you/PRP
#   and/CC
#   I/PRP
#   will/MD
#   make/VB
#   choices/NNS
#   that/WDT
#   determine/VBP
#   both/DT
#   the/DT
#   future/NN
#   and/CC
#   the/DT
#   character/NN
#   of/IN
#   our/PRP$
#   country/NN
#   ./.)
# (S
#   We/PRP
#   will/MD
#   choose/VB
#   to/TO
#   act/VB
#   confidently/RB
#   in/IN
#   pursuing/VBG
#   the/DT
#   enemies/NNS
#   of/IN
#   freedom/NN
#   --/:
#   or/CC
#   retreat/NN
#   from/IN
#   our/PRP$
#   duties/NNS
#   in/IN
#   the/DT
#   hope/NN
#   of/IN
#   an/DT
#   easier/JJR
#   life/NN
#   ./.)
# (S
#   We/PRP
#   will/MD
#   choose/VB
#   to/TO
#   build/VB
#   our/PRP$
#   prosperity/NN
#   by/IN
#   leading/VBG
#   the/DT
#   world/NN
#   economy/NN
#   --/:
#   or/CC
#   shut/VB
#   ourselves/PRP
#   off/RP
#   from/IN
#   trade/NN
#   and/CC
#   opportunity/NN
#   ./.)
# (S
#   In/IN
#   a/DT
#   complex/JJ
#   and/CC
#   challenging/JJ
#   time/NN
#   ,/,
#   the/DT
#   road/NN
#   of/IN
#   isolationism/NN
#   and/CC
#   protectionism/NN
#   may/MD
#   seem/VB
#   broad/JJ
#   and/CC
#   inviting/NN
#   --/:
#   yet/CC
#   it/PRP
#   ends/VBZ
#   in/IN
#   danger/NN
#   and/CC
#   decline/NN
#   ./.)
# (S
#   The/DT
#   only/JJ
#   way/NN
#   to/TO
#   protect/VB
#   our/PRP$
#   people/NNS
#   ,/,
#   the/DT
#   only/JJ
#   way/NN
#   to/TO
#   secure/VB
#   the/DT
#   peace/NN
#   ,/,
#   the/DT
#   only/JJ
#   way/NN
#   to/TO
#   control/VB
#   our/PRP$
#   destiny/NN
#   is/VBZ
#   by/IN
#   our/PRP$
#   leadership/NN
#   --/:
#   so/IN
#   the/DT
#   (GPE United/NNP States/NNPS)
#   of/IN
#   (GPE America/NNP)
#   will/MD
#   continue/VB
#   to/TO
#   lead/VB
#   ./.)
# (S (/( (ORGANIZATION Applause/NNP) ./. )/))
# (S
#   Abroad/RB
#   ,/,
#   our/PRP$
#   nation/NN
#   is/VBZ
#   committed/VBN
#   to/TO
#   an/DT
#   historic/JJ
#   ,/,
#   long-term/JJ
#   goal/NN
#   --/:
#   we/PRP
#   seek/VBP
#   the/DT
#   end/NN
#   of/IN
#   tyranny/NN
#   in/IN
#   our/PRP$
#   world/NN
#   ./.)
# (S
#   Some/DT
#   dismiss/VBP
#   that/DT
#   goal/NN
#   as/IN
#   misguided/JJ
#   idealism/NN
#   ./.)
# (S
#   In/IN
#   reality/NN
#   ,/,
#   the/DT
#   future/JJ
#   security/NN
#   of/IN
#   (GPE America/NNP)
#   depends/VBZ
#   on/IN
#   it/PRP
#   ./.)
# (S
#   On/IN
#   September/NNP
#   the/DT
#   11th/CD
#   ,/,
#   2001/CD
#   ,/,
#   we/PRP
#   found/VBD
#   that/IN
#   problems/NNS
#   originating/VBG
#   in/IN
#   a/DT
#   failed/JJ
#   and/CC
#   oppressive/JJ
#   state/NN
#   7,000/CD
#   miles/NNS
#   away/RB
#   could/MD
#   bring/VB
#   murder/NN
#   and/CC
#   destruction/NN
#   to/TO
#   our/PRP$
#   country/NN
#   ./.)
# (S
#   (GPE Dictatorships/NNP)
#   shelter/NN
#   terrorists/NNS
#   ,/,
#   and/CC
#   feed/VB
#   resentment/NN
#   and/CC
#   radicalism/NN
#   ,/,
#   and/CC
#   seek/JJ
#   weapons/NNS
#   of/IN
#   mass/NN
#   destruction/NN
#   ./.)
# (S
#   Democracies/NNS
#   replace/VB
#   resentment/NN
#   with/IN
#   hope/NN
#   ,/,
#   respect/VB
#   the/DT
#   rights/NNS
#   of/IN
#   their/PRP$
#   citizens/NNS
#   and/CC
#   their/PRP$
#   neighbors/NNS
#   ,/,
#   and/CC
#   join/VB
#   the/DT
#   fight/NN
#   against/IN
#   terror/NN
#   ./.)
# (S
#   Every/DT
#   step/NN
#   toward/IN
#   freedom/NN
#   in/IN
#   the/DT
#   world/NN
#   makes/VBZ
#   our/PRP$
#   country/NN
#   safer/NN
#   --/:
#   so/IN
#   we/PRP
#   will/MD
#   act/VB
#   boldly/RB
#   in/IN
#   freedom/NN
#   's/POS
#   cause/NN
#   ./.)
# (S (/( (ORGANIZATION Applause/NNP) ./. )/))
# (S
#   Far/RB
#   from/IN
#   being/VBG
#   a/DT
#   hopeless/NN
#   dream/NN
#   ,/,
#   the/DT
#   advance/NN
#   of/IN
#   freedom/NN
#   is/VBZ
#   the/DT
#   great/JJ
#   story/NN
#   of/IN
#   our/PRP$
#   time/NN
#   ./.)
# (S
#   In/IN
#   1945/CD
#   ,/,
#   there/EX
#   were/VBD
#   about/RB
#   two/CD
#   dozen/NN
#   lonely/RB
#   democracies/VBZ
#   in/IN
#   the/DT
#   world/NN
#   ./.)
# (S Today/NN ,/, there/EX are/VBP 122/CD ./.)
# (S
#   And/CC
#   we/PRP
#   're/VBP
#   writing/VBG
#   a/DT
#   new/JJ
#   chapter/NN
#   in/IN
#   the/DT
#   story/NN
#   of/IN
#   self-government/JJ
#   --/:
#   with/IN
#   women/NNS
#   lining/VBG
#   up/RP
#   to/TO
#   vote/VB
#   in/IN
#   (GPE Afghanistan/NNP)
#   ,/,
#   and/CC
#   millions/NNS
#   of/IN
#   (GPE Iraqis/NNP)
#   marking/VBG
#   their/PRP$
#   liberty/NN
#   with/IN
#   purple/JJ
#   ink/NN
#   ,/,
#   and/CC
#   men/NNS
#   and/CC
#   women/NNS
#   from/IN
#   (GPE Lebanon/NNP)
#   to/TO
#   (GPE Egypt/NNP)
#   debating/VBG
#   the/DT
#   rights/NNS
#   of/IN
#   individuals/NNS
#   and/CC
#   the/DT
#   necessity/NN
#   of/IN
#   freedom/NN
#   ./.)
# (S
#   At/IN
#   the/DT
#   start/NN
#   of/IN
#   2006/CD
#   ,/,
#   more/JJR
#   than/IN
#   half/PDT
#   the/DT
#   people/NNS
#   of/IN
#   our/PRP$
#   world/NN
#   live/VBP
#   in/IN
#   democratic/JJ
#   nations/NNS
#   ./.)
# (S
#   And/CC
#   we/PRP
#   do/VBP
#   not/RB
#   forget/VB
#   the/DT
#   other/JJ
#   half/NN
#   --/:
#   in/IN
#   places/NNS
#   like/IN
#   (GSP Syria/NNP)
#   and/CC
#   (GPE Burma/NNP)
#   ,/,
#   (GPE Zimbabwe/NNP)
#   ,/,
#   (GPE North/NNP Korea/NNP)
#   ,/,
#   and/CC
#   (GPE Iran/NNP)
#   --/:
#   because/IN
#   the/DT
#   demands/NNS
#   of/IN
#   justice/NN
#   ,/,
#   and/CC
#   the/DT
#   peace/NN
#   of/IN
#   this/DT
#   world/NN
#   ,/,
#   require/VBP
#   their/PRP$
#   freedom/NN
#   ,/,
#   as/RB
#   well/RB
#   ./.)
# (S (/( (ORGANIZATION Applause/NNP) ./. )/))
# (S
#   President/NNP
#   (PERSON George/NNP W./NNP Bush/NNP)
#   delivers/VBZ
#   his/PRP$
#   State/NN
#   of/IN
#   the/DT
#   (ORGANIZATION Union/NNP Address/NNP)
#   at/IN
#   the/DT
#   (GPE Capitol/NNP)
#   ,/,
#   Tuesday/NNP
#   ,/,
#   (PERSON Jan/NNP)
#   ./.)
# (S 31/CD ,/, 2006/CD ./.)
# (S
#   (FACILITY White/NNP)
#   (ORGANIZATION House/NNP)
#   photo/NN
#   by/IN
#   (PERSON Eric/NNP Draper/NNP No/NNP)
#   one/NN
#   can/MD
#   deny/VB
#   the/DT
#   success/NN
#   of/IN
#   freedom/NN
#   ,/,
#   but/CC
#   some/DT
#   men/NNS
#   rage/VB
#   and/CC
#   fight/VB
#   against/IN
#   it/PRP
#   ./.)
# (S
#   And/CC
#   one/CD
#   of/IN
#   the/DT
#   main/JJ
#   sources/NNS
#   of/IN
#   reaction/NN
#   and/CC
#   opposition/NN
#   is/VBZ
#   radical/JJ
#   Islam/NNP
#   --/:
#   the/DT
#   perversion/NN
#   by/IN
#   a/DT
#   few/JJ
#   of/IN
#   a/DT
#   noble/JJ
#   faith/NN
#   into/IN
#   an/DT
#   ideology/NN
#   of/IN
#   terror/NN
#   and/CC
#   death/NN
#   ./.)
# (S
#   Terrorists/NNS
#   like/IN
#   bin/NN
#   Laden/NNP
#   are/VBP
#   serious/JJ
#   about/IN
#   mass/NN
#   murder/NN
#   --/:
#   and/CC
#   all/DT
#   of/IN
#   us/PRP
#   must/MD
#   take/VB
#   their/PRP$
#   declared/JJ
#   intentions/NNS
#   seriously/RB
#   ./.)
# (S
#   They/PRP
#   seek/VBP
#   to/TO
#   impose/VB
#   a/DT
#   heartless/NN
#   system/NN
#   of/IN
#   totalitarian/JJ
#   control/NN
#   throughout/IN
#   the/DT
#   (GPE Middle/NNP East/NNP)
#   ,/,
#   and/CC
#   arm/NN
#   themselves/PRP
#   with/IN
#   weapons/NNS
#   of/IN
#   mass/NN
#   murder/NN
#   ./.)
# (S
#   Their/PRP$
#   aim/NN
#   is/VBZ
#   to/TO
#   seize/VB
#   power/NN
#   in/IN
#   (GPE Iraq/NNP)
#   ,/,
#   and/CC
#   use/VB
#   it/PRP
#   as/IN
#   a/DT
#   safe/JJ
#   haven/NN
#   to/TO
#   launch/VB
#   attacks/NNS
#   against/IN
#   (GPE America/NNP)
#   and/CC
#   the/DT
#   world/NN
#   ./.)
# (S
#   Lacking/VBG
#   the/DT
#   military/JJ
#   strength/NN
#   to/TO
#   challenge/VB
#   us/PRP
#   directly/RB
#   ,/,
#   the/DT
#   terrorists/NNS
#   have/VBP
#   chosen/VBN
#   the/DT
#   weapon/NN
#   of/IN
#   fear/NN
#   ./.)
# (S
#   When/WRB
#   they/PRP
#   murder/VBP
#   children/NNS
#   at/IN
#   a/DT
#   school/NN
#   in/IN
#   (GPE Beslan/NNP)
#   ,/,
#   or/CC
#   blow/VB
#   up/RP
#   commuters/NNS
#   in/IN
#   (GPE London/NNP)
#   ,/,
#   or/CC
#   behead/VB
#   a/DT
#   bound/NN
#   captive/NN
#   ,/,
#   the/DT
#   terrorists/NNS
#   hope/VBP
#   these/DT
#   horrors/NNS
#   will/MD
#   break/VB
#   our/PRP$
#   will/MD
#   ,/,
#   allowing/VBG
#   the/DT
#   violent/NN
#   to/TO
#   inherit/VB
#   the/DT
#   (LOCATION Earth/NNP)
#   ./.)
# (S
#   But/CC
#   they/PRP
#   have/VBP
#   miscalculated/VBN
#   :/:
#   We/PRP
#   love/VBP
#   our/PRP$
#   freedom/NN
#   ,/,
#   and/CC
#   we/PRP
#   will/MD
#   fight/VB
#   to/TO
#   keep/VB
#   it/PRP
#   ./.)
# (S (/( (ORGANIZATION Applause/NNP) ./. )/))
# (S
#   In/IN
#   a/DT
#   time/NN
#   of/IN
#   testing/VBG
#   ,/,
#   we/PRP
#   can/MD
#   not/RB
#   find/VB
#   security/NN
#   by/IN
#   abandoning/VBG
#   our/PRP$
#   commitments/NNS
#   and/CC
#   retreating/VBG
#   within/IN
#   our/PRP$
#   borders/NNS
#   ./.)
# (S
#   If/IN
#   we/PRP
#   were/VBD
#   to/TO
#   leave/VB
#   these/DT
#   vicious/JJ
#   attackers/NNS
#   alone/RB
#   ,/,
#   they/PRP
#   would/MD
#   not/RB
#   leave/VB
#   us/PRP
#   alone/RB
#   ./.)
# (S
#   They/PRP
#   would/MD
#   simply/RB
#   move/VB
#   the/DT
#   battlefield/NN
#   to/TO
#   our/PRP$
#   own/JJ
#   shores/NNS
#   ./.)
# (S There/EX is/VBZ no/DT peace/NN in/IN retreat/NN ./.)
# (S And/CC there/EX is/VBZ no/DT honor/NN in/IN retreat/NN ./.)
# (S
#   By/IN
#   allowing/VBG
#   radical/JJ
#   Islam/NNP
#   to/TO
#   work/VB
#   its/PRP$
#   will/MD
#   --/:
#   by/IN
#   leaving/VBG
#   an/DT
#   assaulted/JJ
#   world/NN
#   to/TO
#   fend/VB
#   for/IN
#   itself/PRP
#   --/:
#   we/PRP
#   would/MD
#   signal/VB
#   to/TO
#   all/PDT
#   that/IN
#   we/PRP
#   no/DT
#   longer/RBR
#   believe/VBP
#   in/IN
#   our/PRP$
#   own/JJ
#   ideals/NNS
#   ,/,
#   or/CC
#   even/RB
#   in/IN
#   our/PRP$
#   own/JJ
#   courage/NN
#   ./.)
# (S
#   But/CC
#   our/PRP$
#   enemies/NNS
#   and/CC
#   our/PRP$
#   friends/NNS
#   can/MD
#   be/VB
#   certain/JJ
#   :/:
#   The/DT
#   (GPE United/NNP States/NNPS)
#   will/MD
#   not/RB
#   retreat/VB
#   from/IN
#   the/DT
#   world/NN
#   ,/,
#   and/CC
#   we/PRP
#   will/MD
#   never/RB
#   surrender/VB
#   to/TO
#   evil/VB
#   ./.)
# (S (/( (ORGANIZATION Applause/NNP) ./. )/))
# (S
#   (GPE America/NNP)
#   rejects/VBZ
#   the/DT
#   false/JJ
#   comfort/NN
#   of/IN
#   isolationism/NN
#   ./.)
# (S
#   We/PRP
#   are/VBP
#   the/DT
#   nation/NN
#   that/IN
#   saved/VBD
#   liberty/NN
#   in/IN
#   (GPE Europe/NNP)
#   ,/,
#   and/CC
#   liberated/VBD
#   death/NN
#   camps/NNS
#   ,/,
#   and/CC
#   helped/VBD
#   raise/VB
#   up/RP
#   democracies/NNS
#   ,/,
#   and/CC
#   faced/VBD
#   down/IN
#   an/DT
#   evil/JJ
#   empire/NN
#   ./.)
# (S
#   Once/RB
#   again/RB
#   ,/,
#   we/PRP
#   accept/VBP
#   the/DT
#   call/NN
#   of/IN
#   history/NN
#   to/TO
#   deliver/VB
#   the/DT
#   oppressed/VBN
#   and/CC
#   move/VB
#   this/DT
#   world/NN
#   toward/IN
#   peace/NN
#   ./.)
# (S
#   We/PRP
#   remain/VBP
#   on/IN
#   the/DT
#   offensive/JJ
#   against/IN
#   terror/NN
#   networks/NNS
#   ./.)
# (S
#   We/PRP
#   have/VBP
#   killed/VBN
#   or/CC
#   captured/VBN
#   many/JJ
#   of/IN
#   their/PRP$
#   leaders/NNS
#   --/:
#   and/CC
#   for/IN
#   the/DT
#   others/NNS
#   ,/,
#   their/PRP$
#   day/NN
#   will/MD
#   come/VB
#   ./.)
# (S
#   President/NNP
#   (PERSON George/NNP W./NNP Bush/NNP)
#   greets/VBZ
#   members/NNS
#   of/IN
#   (ORGANIZATION Congress/NNP)
#   after/IN
#   his/PRP$
#   State/NN
#   of/IN
#   the/DT
#   (ORGANIZATION Union/NNP Address/NNP)
#   at/IN
#   the/DT
#   (GPE Capitol/NNP)
#   ,/,
#   Tuesday/NNP
#   ,/,
#   (PERSON Jan/NNP)
#   ./.)
# (S 31/CD ,/, 2006/CD ./.)
# (S
#   (FACILITY White/NNP)
#   (ORGANIZATION House/NNP)
#   photo/NN
#   by/IN
#   (PERSON Eric/NNP Draper/NNP)
#   We/PRP
#   remain/VBP
#   on/IN
#   the/DT
#   offensive/JJ
#   in/IN
#   (GPE Afghanistan/NNP)
#   ,/,
#   where/WRB
#   a/DT
#   fine/JJ
#   President/NNP
#   and/CC
#   a/DT
#   (ORGANIZATION National/NNP Assembly/NNP)
#   are/VBP
#   fighting/VBG
#   terror/NN
#   while/IN
#   building/VBG
#   the/DT
#   institutions/NNS
#   of/IN
#   a/DT
#   new/JJ
#   democracy/NN
#   ./.)
# (S
#   We/PRP
#   're/VBP
#   on/IN
#   the/DT
#   offensive/JJ
#   in/IN
#   (GPE Iraq/NNP)
#   ,/,
#   with/IN
#   a/DT
#   clear/JJ
#   plan/NN
#   for/IN
#   victory/NN
#   ./.)
# (S
#   First/RB
#   ,/,
#   we/PRP
#   're/VBP
#   helping/VBG
#   (GPE Iraqis/NNP)
#   build/VB
#   an/DT
#   inclusive/JJ
#   government/NN
#   ,/,
#   so/IN
#   that/DT
#   old/JJ
#   resentments/NNS
#   will/MD
#   be/VB
#   eased/VBN
#   and/CC
#   the/DT
#   insurgency/NN
#   will/MD
#   be/VB
#   marginalized/VBN
#   ./.)
# (S
#   (GPE Second/JJ)
#   ,/,
#   we/PRP
#   're/VBP
#   continuing/VBG
#   reconstruction/NN
#   efforts/NNS
#   ,/,
#   and/CC
#   helping/VBG
#   the/DT
#   (GPE Iraqi/NNP)
#   government/NN
#   to/TO
#   fight/VB
#   corruption/NN
#   and/CC
#   build/VB
#   a/DT
#   modern/JJ
#   economy/NN
#   ,/,
#   so/IN
#   all/DT
#   (GPE Iraqis/NNP)
#   can/MD
#   experience/VB
#   the/DT
#   benefits/NNS
#   of/IN
#   freedom/NN
#   ./.)
# (S
#   And/CC
#   ,/,
#   third/JJ
#   ,/,
#   we/PRP
#   're/VBP
#   striking/VBG
#   terrorist/JJ
#   targets/NNS
#   while/IN
#   we/PRP
#   train/VBP
#   (GPE Iraqi/JJ)
#   forces/NNS
#   that/WDT
#   are/VBP
#   increasingly/RB
#   capable/JJ
#   of/IN
#   defeating/VBG
#   the/DT
#   enemy/NN
#   ./.)
# (S
#   (GPE Iraqis/NNP)
#   are/VBP
#   showing/VBG
#   their/PRP$
#   courage/NN
#   every/DT
#   day/NN
#   ,/,
#   and/CC
#   we/PRP
#   are/VBP
#   proud/JJ
#   to/TO
#   be/VB
#   their/PRP$
#   allies/NNS
#   in/IN
#   the/DT
#   cause/NN
#   of/IN
#   freedom/NN
#   ./.)
# (S (/( (ORGANIZATION Applause/NNP) ./. )/))
# (S
#   Our/PRP$
#   work/NN
#   in/IN
#   (GPE Iraq/NNP)
#   is/VBZ
#   difficult/JJ
#   because/IN
#   our/PRP$
#   enemy/NN
#   is/VBZ
#   brutal/JJ
#   ./.)
# (S
#   But/CC
#   that/DT
#   brutality/NN
#   has/VBZ
#   not/RB
#   stopped/VBN
#   the/DT
#   dramatic/JJ
#   progress/NN
#   of/IN
#   a/DT
#   new/JJ
#   democracy/NN
#   ./.)
# (S
#   In/IN
#   less/JJR
#   than/IN
#   three/CD
#   years/NNS
#   ,/,
#   the/DT
#   nation/NN
#   has/VBZ
#   gone/VBN
#   from/IN
#   dictatorship/NN
#   to/TO
#   liberation/NN
#   ,/,
#   to/TO
#   sovereignty/VB
#   ,/,
#   to/TO
#   a/DT
#   constitution/NN
#   ,/,
#   to/TO
#   national/JJ
#   elections/NNS
#   ./.)
# (S
#   At/IN
#   the/DT
#   same/JJ
#   time/NN
#   ,/,
#   our/PRP$
#   coalition/NN
#   has/VBZ
#   been/VBN
#   relentless/VBN
#   in/IN
#   shutting/VBG
#   off/RP
#   terrorist/JJ
#   infiltration/NN
#   ,/,
#   clearing/VBG
#   out/RP
#   insurgent/JJ
#   strongholds/NNS
#   ,/,
#   and/CC
#   turning/VBG
#   over/RP
#   territory/NN
#   to/TO
#   (GPE Iraqi/NNP)
#   security/NN
#   forces/NNS
#   ./.)
# (S
#   I/PRP
#   am/VBP
#   confident/JJ
#   in/IN
#   our/PRP$
#   plan/NN
#   for/IN
#   victory/NN
#   ;/:
#   I/PRP
#   am/VBP
#   confident/JJ
#   in/IN
#   the/DT
#   will/MD
#   of/IN
#   the/DT
#   (GPE Iraqi/NNP)
#   people/NNS
#   ;/:
#   I/PRP
#   am/VBP
#   confident/JJ
#   in/IN
#   the/DT
#   skill/NN
#   and/CC
#   spirit/NN
#   of/IN
#   our/PRP$
#   military/JJ
#   ./.)
# (S
#   (GPE Fellow/NNP)
#   citizens/NNS
#   ,/,
#   we/PRP
#   are/VBP
#   in/IN
#   this/DT
#   fight/NN
#   to/TO
#   win/VB
#   ,/,
#   and/CC
#   we/PRP
#   are/VBP
#   winning/VBG
#   ./.)
# (S (/( (ORGANIZATION Applause/NNP) ./. )/))
# (S
#   The/DT
#   road/NN
#   of/IN
#   victory/NN
#   is/VBZ
#   the/DT
#   road/NN
#   that/WDT
#   will/MD
#   take/VB
#   our/PRP$
#   troops/NNS
#   home/NN
#   ./.)
# (S
#   As/IN
#   we/PRP
#   make/VBP
#   progress/NN
#   on/IN
#   the/DT
#   ground/NN
#   ,/,
#   and/CC
#   (GPE Iraqi/NNP)
#   forces/NNS
#   increasingly/RB
#   take/VBP
#   the/DT
#   lead/NN
#   ,/,
#   we/PRP
#   should/MD
#   be/VB
#   able/JJ
#   to/TO
#   further/JJ
#   decrease/VB
#   our/PRP$
#   troop/NN
#   levels/NNS
#   --/:
#   but/CC
#   those/DT
#   decisions/NNS
#   will/MD
#   be/VB
#   made/VBN
#   by/IN
#   our/PRP$
#   military/JJ
#   commanders/NNS
#   ,/,
#   not/RB
#   by/IN
#   politicians/NNS
#   in/IN
#   (GPE Washington/NNP)
#   ,/,
#   D.C/NNP
#   ./.)
# (S (/( (ORGANIZATION Applause/NNP) ./. )/))
# (S
#   Our/PRP$
#   coalition/NN
#   has/VBZ
#   learned/VBN
#   from/IN
#   our/PRP$
#   experience/NN
#   in/IN
#   (GPE Iraq/NNP)
#   ./.)
# (S
#   We/PRP
#   've/VBP
#   adjusted/VBN
#   our/PRP$
#   military/JJ
#   tactics/NNS
#   and/CC
#   changed/VBD
#   our/PRP$
#   approach/NN
#   to/TO
#   reconstruction/NN
#   ./.)
# (S
#   Along/IN
#   the/DT
#   way/NN
#   ,/,
#   we/PRP
#   have/VBP
#   benefitted/VBN
#   from/IN
#   responsible/JJ
#   criticism/NN
#   and/CC
#   counsel/NN
#   offered/VBN
#   by/IN
#   members/NNS
#   of/IN
#   (ORGANIZATION Congress/NNP)
#   of/IN
#   both/DT
#   parties/NNS
#   ./.)
# (S
#   In/IN
#   the/DT
#   coming/VBG
#   year/NN
#   ,/,
#   I/PRP
#   will/MD
#   continue/VB
#   to/TO
#   reach/VB
#   out/RP
#   and/CC
#   seek/VB
#   your/PRP$
#   good/JJ
#   advice/NN
#   ./.)
# (S
#   Yet/RB
#   ,/,
#   there/EX
#   is/VBZ
#   a/DT
#   difference/NN
#   between/IN
#   responsible/JJ
#   criticism/NN
#   that/WDT
#   aims/VBZ
#   for/IN
#   success/NN
#   ,/,
#   and/CC
#   defeatism/NN
#   that/WDT
#   refuses/VBZ
#   to/TO
#   acknowledge/VB
#   anything/NN
#   but/CC
#   failure/NN
#   ./.)
# (S (/( (ORGANIZATION Applause/NNP) ./. )/))
# (S
#   (PERSON Hindsight/NNP)
#   alone/RB
#   is/VBZ
#   not/RB
#   wisdom/JJ
#   ,/,
#   and/CC
#   second-guessing/NN
#   is/VBZ
#   not/RB
#   a/DT
#   strategy/NN
#   ./.)
# (S (/( (ORGANIZATION Applause/NNP) ./. )/))
# (S
#   With/IN
#   so/RB
#   much/JJ
#   in/IN
#   the/DT
#   balance/NN
#   ,/,
#   those/DT
#   of/IN
#   us/PRP
#   in/IN
#   public/JJ
#   office/NN
#   have/VBP
#   a/DT
#   duty/NN
#   to/TO
#   speak/VB
#   with/IN
#   candor/NN
#   ./.)
# (S
#   A/DT
#   sudden/JJ
#   withdrawal/NN
#   of/IN
#   our/PRP$
#   forces/NNS
#   from/IN
#   (GPE Iraq/NNP)
#   would/MD
#   abandon/VB
#   our/PRP$
#   (GPE Iraqi/NNP)
#   allies/NNS
#   to/TO
#   death/NN
#   and/CC
#   prison/NN
#   ,/,
#   would/MD
#   put/VB
#   men/NNS
#   like/IN
#   bin/NN
#   (PERSON Laden/NNP)
#   and/CC
#   (GPE Zarqawi/NNP)
#   in/IN
#   charge/NN
#   of/IN
#   a/DT
#   strategic/JJ
#   country/NN
#   ,/,
#   and/CC
#   show/VBP
#   that/IN
#   a/DT
#   pledge/NN
#   from/IN
#   (GPE America/NNP)
#   means/VBZ
#   little/JJ
#   ./.)
# (S
#   Members/NNS
#   of/IN
#   (ORGANIZATION Congress/NNP)
#   ,/,
#   however/RB
#   we/PRP
#   feel/VBP
#   about/IN
#   the/DT
#   decisions/NNS
#   and/CC
#   debates/NNS
#   of/IN
#   the/DT
#   past/NN
#   ,/,
#   our/PRP$
#   nation/NN
#   has/VBZ
#   only/RB
#   one/CD
#   option/NN
#   :/:
#   We/PRP
#   must/MD
#   keep/VB
#   our/PRP$
#   word/NN
#   ,/,
#   defeat/VB
#   our/PRP$
#   enemies/NNS
#   ,/,
#   and/CC
#   stand/VBP
#   behind/IN
#   the/DT
#   (GPE American/JJ)
#   military/NN
#   in/IN
#   this/DT
#   vital/JJ
#   mission/NN
#   ./.)
# (S (/( (ORGANIZATION Applause/NNP) ./. )/))
# (S
#   (PERSON Laura/NNP)
#   (ORGANIZATION Bush/NNP)
#   is/VBZ
#   applauded/VBN
#   as/IN
#   she/PRP
#   is/VBZ
#   introduced/VBN
#   Tuesday/NNP
#   evening/NN
#   ,/,
#   (PERSON Jan/NNP)
#   ./.)
# (S
#   31/CD
#   ,/,
#   2006/CD
#   during/IN
#   the/DT
#   State/NNP
#   of/IN
#   the/DT
#   (ORGANIZATION Union/NNP Address/NNP)
#   at/IN
#   (GPE United/NNP States/NNPS)
#   Capitol/NNP
#   in/IN
#   (GPE Washington/NNP)
#   ./.)
# (S
#   (FACILITY White/NNP)
#   (ORGANIZATION House/NNP)
#   photo/NN
#   by/IN
#   (PERSON Eric/NNP Draper/NNP)
#   Our/PRP$
#   men/NNS
#   and/CC
#   women/NNS
#   in/IN
#   uniform/JJ
#   are/VBP
#   making/VBG
#   sacrifices/NNS
#   --/:
#   and/CC
#   showing/VBG
#   a/DT
#   sense/NN
#   of/IN
#   duty/NN
#   stronger/JJR
#   than/IN
#   all/DT
#   fear/NN
#   ./.)
# (S
#   They/PRP
#   know/VBP
#   what/WP
#   it/PRP
#   's/VBZ
#   like/IN
#   to/TO
#   fight/VB
#   house/NN
#   to/TO
#   house/NN
#   in/IN
#   a/DT
#   maze/NN
#   of/IN
#   streets/NNS
#   ,/,
#   to/TO
#   wear/VB
#   heavy/JJ
#   gear/NN
#   in/IN
#   the/DT
#   desert/NN
#   heat/NN
#   ,/,
#   to/TO
#   see/VB
#   a/DT
#   comrade/NN
#   killed/VBN
#   by/IN
#   a/DT
#   roadside/NN
#   bomb/NN
#   ./.)
# (S
#   And/CC
#   those/DT
#   who/WP
#   know/VBP
#   the/DT
#   costs/NNS
#   also/RB
#   know/VBP
#   the/DT
#   stakes/NNS
#   ./.)
# (S
#   (PERSON Marine/JJ)
#   (PERSON Staff/NNP Sergeant/NNP Dan/NNP Clay/NNP)
#   was/VBD
#   killed/VBN
#   last/JJ
#   month/NN
#   fighting/VBG
#   in/IN
#   (GPE Fallujah/NNP)
#   ./.)
# (S
#   He/PRP
#   left/VBD
#   behind/RP
#   a/DT
#   letter/NN
#   to/TO
#   his/PRP$
#   family/NN
#   ,/,
#   but/CC
#   his/PRP$
#   words/NNS
#   could/MD
#   just/RB
#   as/RB
#   well/RB
#   be/VB
#   addressed/VBN
#   to/TO
#   every/DT
#   (GPE American/NNP)
#   ./.)
# (S
#   Here/RB
#   is/VBZ
#   what/WP
#   (PERSON Dan/NNP)
#   wrote/VBD
#   :/:
#   ``/``
#   I/PRP
#   know/VBP
#   what/WP
#   honor/NN
#   is/VBZ
#   ./.)
# (S
#   .../:
#   It/PRP
#   has/VBZ
#   been/VBN
#   an/DT
#   honor/NN
#   to/TO
#   protect/VB
#   and/CC
#   serve/VB
#   all/DT
#   of/IN
#   you/PRP
#   ./.)
# (S
#   I/PRP
#   faced/VBD
#   death/NN
#   with/IN
#   the/DT
#   secure/NN
#   knowledge/NN
#   that/IN
#   you/PRP
#   would/MD
#   not/RB
#   have/VB
#   to/TO
#   .../:
#   ./.)
# (S Never/RB falter/NN !/.)
# (S
#   Do/VBP
#   n't/RB
#   hesitate/VB
#   to/TO
#   honor/VB
#   and/CC
#   support/VB
#   those/DT
#   of/IN
#   us/PRP
#   who/WP
#   have/VBP
#   the/DT
#   honor/NN
#   of/IN
#   protecting/VBG
#   that/DT
#   which/WDT
#   is/VBZ
#   worth/JJ
#   protecting/VBG
#   ./.
#   ''/'')
# (S
#   Staff/NNP
#   Sergeant/NNP
#   (PERSON Dan/NNP Clay/NNP)
#   's/POS
#   wife/NN
#   ,/,
#   (PERSON Lisa/NNP)
#   ,/,
#   and/CC
#   his/PRP$
#   mom/NN
#   and/CC
#   dad/NN
#   ,/,
#   (PERSON Sara/NNP Jo/NNP)
#   and/CC
#   (PERSON Bud/NNP)
#   ,/,
#   are/VBP
#   with/IN
#   us/PRP
#   this/DT
#   evening/NN
#   ./.)
# (S (GPE Welcome/NNP) ./.)
# (S (/( (ORGANIZATION Applause/NNP) ./. )/))
# (S
#   Our/PRP$
#   nation/NN
#   is/VBZ
#   grateful/JJ
#   to/TO
#   the/DT
#   fallen/VBN
#   ,/,
#   who/WP
#   live/VBP
#   in/IN
#   the/DT
#   memory/NN
#   of/IN
#   our/PRP$
#   country/NN
#   ./.)
# (S
#   We/PRP
#   're/VBP
#   grateful/JJ
#   to/TO
#   all/DT
#   who/WP
#   volunteer/VBP
#   to/TO
#   wear/VB
#   our/PRP$
#   nation/NN
#   's/POS
#   uniform/NN
#   --/:
#   and/CC
#   as/IN
#   we/PRP
#   honor/VBP
#   our/PRP$
#   brave/NN
#   troops/NNS
#   ,/,
#   let/VB
#   us/PRP
#   never/RB
#   forget/VBP
#   the/DT
#   sacrifices/NNS
#   of/IN
#   (GPE America/NNP)
#   's/POS
#   military/JJ
#   families/NNS
#   ./.)
# (S (/( (ORGANIZATION Applause/NNP) ./. )/))
# (S
#   Our/PRP$
#   offensive/JJ
#   against/IN
#   terror/NN
#   involves/VBZ
#   more/JJR
#   than/IN
#   military/JJ
#   action/NN
#   ./.)
# (S
#   Ultimately/RB
#   ,/,
#   the/DT
#   only/JJ
#   way/NN
#   to/TO
#   defeat/VB
#   the/DT
#   terrorists/NNS
#   is/VBZ
#   to/TO
#   defeat/VB
#   their/PRP$
#   dark/JJ
#   vision/NN
#   of/IN
#   hatred/VBN
#   and/CC
#   fear/VBN
#   by/IN
#   offering/VBG
#   the/DT
#   hopeful/JJ
#   alternative/NN
#   of/IN
#   political/JJ
#   freedom/NN
#   and/CC
#   peaceful/JJ
#   change/NN
#   ./.)
# (S
#   So/IN
#   the/DT
#   (GPE United/NNP States/NNPS)
#   of/IN
#   (GPE America/NNP)
#   supports/NNS
#   democratic/JJ
#   reform/NN
#   across/IN
#   the/DT
#   broader/JJR
#   (GPE Middle/NNP East/NNP)
#   ./.)
# (S
#   Elections/NNS
#   are/VBP
#   vital/JJ
#   ,/,
#   but/CC
#   they/PRP
#   are/VBP
#   only/RB
#   the/DT
#   beginning/NN
#   ./.)
# (S
#   Raising/VBG
#   up/RP
#   a/DT
#   democracy/NN
#   requires/VBZ
#   the/DT
#   rule/NN
#   of/IN
#   law/NN
#   ,/,
#   and/CC
#   protection/NN
#   of/IN
#   minorities/NNS
#   ,/,
#   and/CC
#   strong/JJ
#   ,/,
#   accountable/JJ
#   institutions/NNS
#   that/IN
#   last/JJ
#   longer/JJR
#   than/IN
#   a/DT
#   single/JJ
#   vote/NN
#   ./.)
# (S
#   The/DT
#   great/JJ
#   people/NNS
#   of/IN
#   (GPE Egypt/NNP)
#   have/VBP
#   voted/VBN
#   in/IN
#   a/DT
#   multi-party/JJ
#   presidential/JJ
#   election/NN
#   --/:
#   and/CC
#   now/RB
#   their/PRP$
#   government/NN
#   should/MD
#   open/VB
#   paths/NNS
#   of/IN
#   peaceful/JJ
#   opposition/NN
#   that/WDT
#   will/MD
#   reduce/VB
#   the/DT
#   appeal/NN
#   of/IN
#   radicalism/NN
#   ./.)
# (S
#   The/DT
#   (GPE Palestinian/JJ)
#   people/NNS
#   have/VBP
#   voted/VBN
#   in/IN
#   elections/NNS
#   ./.)
# (S
#   And/CC
#   now/RB
#   the/DT
#   leaders/NNS
#   of/IN
#   (GPE Hamas/NNP)
#   must/MD
#   recognize/VB
#   (GPE Israel/NNP)
#   ,/,
#   disarm/NN
#   ,/,
#   reject/JJ
#   terrorism/NN
#   ,/,
#   and/CC
#   work/NN
#   for/IN
#   lasting/VBG
#   peace/NN
#   ./.)
# (S (/( (ORGANIZATION Applause/NNP) ./. )/))
# (S
#   (GPE Saudi/NNP)
#   (PERSON Arabia/NNP)
#   has/VBZ
#   taken/VBN
#   the/DT
#   first/JJ
#   steps/NNS
#   of/IN
#   reform/NN
#   --/:
#   now/RB
#   it/PRP
#   can/MD
#   offer/VB
#   its/PRP$
#   people/NNS
#   a/DT
#   better/JJR
#   future/NN
#   by/IN
#   pressing/VBG
#   forward/RB
#   with/IN
#   those/DT
#   efforts/NNS
#   ./.)
# (S
#   Democracies/NNS
#   in/IN
#   the/DT
#   (GPE Middle/NNP East/NNP)
#   will/MD
#   not/RB
#   look/VB
#   like/IN
#   our/PRP$
#   own/JJ
#   ,/,
#   because/IN
#   they/PRP
#   will/MD
#   reflect/VB
#   the/DT
#   traditions/NNS
#   of/IN
#   their/PRP$
#   own/JJ
#   citizens/NNS
#   ./.)
# (S
#   Yet/RB
#   liberty/NN
#   is/VBZ
#   the/DT
#   future/NN
#   of/IN
#   every/DT
#   nation/NN
#   in/IN
#   the/DT
#   (GPE Middle/NNP East/NNP)
#   ,/,
#   because/IN
#   liberty/NN
#   is/VBZ
#   the/DT
#   right/NN
#   and/CC
#   hope/NN
#   of/IN
#   all/DT
#   humanity/NN
#   ./.)
# (S (/( (ORGANIZATION Applause/NNP) ./. )/))
# (S
#   President/NNP
#   (PERSON George/NNP W./NNP Bush/NNP)
#   waves/VBZ
#   toward/IN
#   the/DT
#   upper/JJ
#   visitors/NNS
#   gallery/NN
#   of/IN
#   the/DT
#   (ORGANIZATION House/NNP)
#   Chamber/NNP
#   following/VBG
#   his/PRP$
#   State/NN
#   of/IN
#   the/DT
#   (ORGANIZATION Union/NNP)
#   remarks/NNS
#   Tuesday/NNP
#   ,/,
#   (PERSON Jan/NNP)
#   ./.)
# (S
#   31/CD
#   ,/,
#   2006/CD
#   at/IN
#   the/DT
#   (GPE United/NNP States/NNPS)
#   Capitol/NNP
#   ./.)
# (S
#   (FACILITY White/NNP)
#   (ORGANIZATION House/NNP)
#   photo/NN
#   by/IN
#   (PERSON Eric/NNP Draper/NNP)
#   The/DT
#   same/JJ
#   is/VBZ
#   true/JJ
#   of/IN
#   (GPE Iran/NNP)
#   ,/,
#   a/DT
#   nation/NN
#   now/RB
#   held/VBN
#   hostage/NN
#   by/IN
#   a/DT
#   small/JJ
#   clerical/JJ
#   elite/NN
#   that/WDT
#   is/VBZ
#   isolating/VBG
#   and/CC
#   repressing/VBG
#   its/PRP$
#   people/NNS
#   ./.)
# (S
#   The/DT
#   regime/NN
#   in/IN
#   that/DT
#   country/NN
#   sponsors/NNS
#   terrorists/NNS
#   in/IN
#   the/DT
#   (GPE Palestinian/JJ)
#   territories/NNS
#   and/CC
#   in/IN
#   (GPE Lebanon/NNP)
#   --/:
#   and/CC
#   that/DT
#   must/MD
#   come/VB
#   to/TO
#   an/DT
#   end/NN
#   ./.)
# (S (/( (ORGANIZATION Applause/NNP) ./. )/))
# (S
#   The/DT
#   (GPE Iranian/JJ)
#   government/NN
#   is/VBZ
#   defying/VBG
#   the/DT
#   world/NN
#   with/IN
#   its/PRP$
#   nuclear/JJ
#   ambitions/NNS
#   ,/,
#   and/CC
#   the/DT
#   nations/NNS
#   of/IN
#   the/DT
#   world/NN
#   must/MD
#   not/RB
#   permit/VB
#   the/DT
#   (GPE Iranian/JJ)
#   regime/NN
#   to/TO
#   gain/VB
#   nuclear/JJ
#   weapons/NNS
#   ./.)
# (S (/( (ORGANIZATION Applause/NNP) ./. )/))
# (S
#   (GPE America/NNP)
#   will/MD
#   continue/VB
#   to/TO
#   rally/VB
#   the/DT
#   world/NN
#   to/TO
#   confront/VB
#   these/DT
#   threats/NNS
#   ./.)
# (S
#   (GPE Tonight/NNP)
#   ,/,
#   let/VB
#   me/PRP
#   speak/VB
#   directly/RB
#   to/TO
#   the/DT
#   citizens/NNS
#   of/IN
#   (GPE Iran/NNP)
#   :/:
#   (GPE America/NNP)
#   respects/VBZ
#   you/PRP
#   ,/,
#   and/CC
#   we/PRP
#   respect/VBP
#   your/PRP$
#   country/NN
#   ./.)
# (S
#   We/PRP
#   respect/VBP
#   your/PRP$
#   right/NN
#   to/TO
#   choose/VB
#   your/PRP$
#   own/JJ
#   future/NN
#   and/CC
#   win/VB
#   your/PRP$
#   own/JJ
#   freedom/NN
#   ./.)
# (S
#   And/CC
#   our/PRP$
#   nation/NN
#   hopes/VBZ
#   one/CD
#   day/NN
#   to/TO
#   be/VB
#   the/DT
#   closest/JJS
#   of/IN
#   friends/NNS
#   with/IN
#   a/DT
#   free/JJ
#   and/CC
#   democratic/JJ
#   (GPE Iran/NNP)
#   ./.)
# (S (/( (ORGANIZATION Applause/NNP) ./. )/))
# (S
#   To/TO
#   overcome/VB
#   dangers/NNS
#   in/IN
#   our/PRP$
#   world/NN
#   ,/,
#   we/PRP
#   must/MD
#   also/RB
#   take/VB
#   the/DT
#   offensive/JJ
#   by/IN
#   encouraging/VBG
#   economic/JJ
#   progress/NN
#   ,/,
#   and/CC
#   fighting/VBG
#   disease/NN
#   ,/,
#   and/CC
#   spreading/VBG
#   hope/NN
#   in/IN
#   hopeless/JJ
#   lands/NNS
#   ./.)
# (S
#   (GPE Isolationism/NNP)
#   would/MD
#   not/RB
#   only/RB
#   tie/VB
#   our/PRP$
#   hands/NNS
#   in/IN
#   fighting/VBG
#   enemies/NNS
#   ,/,
#   it/PRP
#   would/MD
#   keep/VB
#   us/PRP
#   from/IN
#   helping/VBG
#   our/PRP$
#   friends/NNS
#   in/IN
#   desperate/JJ
#   need/NN
#   ./.)
# (S
#   We/PRP
#   show/VBP
#   compassion/JJ
#   abroad/RB
#   because/IN
#   (GSP Americans/NNPS)
#   believe/VBP
#   in/IN
#   the/DT
#   God-given/NNP
#   dignity/NN
#   and/CC
#   worth/NN
#   of/IN
#   a/DT
#   villager/NN
#   with/IN
#   HIV/AIDS/NNP
#   ,/,
#   or/CC
#   an/DT
#   infant/NN
#   with/IN
#   malaria/NNS
#   ,/,
#   or/CC
#   a/DT
#   refugee/JJ
#   fleeing/NN
#   genocide/NN
#   ,/,
#   or/CC
#   a/DT
#   young/JJ
#   girl/NN
#   sold/VBN
#   into/IN
#   slavery/NN
#   ./.)
# (S
#   We/PRP
#   also/RB
#   show/VBP
#   compassion/NN
#   abroad/RB
#   because/IN
#   regions/NNS
#   overwhelmed/VBN
#   by/IN
#   poverty/NN
#   ,/,
#   corruption/NN
#   ,/,
#   and/CC
#   despair/NN
#   are/VBP
#   sources/NNS
#   of/IN
#   terrorism/NN
#   ,/,
#   and/CC
#   organized/VBD
#   crime/NN
#   ,/,
#   and/CC
#   human/JJ
#   trafficking/NN
#   ,/,
#   and/CC
#   the/DT
#   drug/NN
#   trade/NN
#   ./.)
# (S
#   In/IN
#   recent/JJ
#   years/NNS
#   ,/,
#   you/PRP
#   and/CC
#   I/PRP
#   have/VBP
#   taken/VBN
#   unprecedented/JJ
#   action/NN
#   to/TO
#   fight/VB
#   (ORGANIZATION AIDS/NNP)
#   and/CC
#   malaria/NNS
#   ,/,
#   expand/VBP
#   the/DT
#   education/NN
#   of/IN
#   girls/NNS
#   ,/,
#   and/CC
#   reward/RB
#   developing/VBG
#   nations/NNS
#   that/WDT
#   are/VBP
#   moving/VBG
#   forward/RB
#   with/IN
#   economic/JJ
#   and/CC
#   political/JJ
#   reform/NN
#   ./.)
# (S
#   For/IN
#   people/NNS
#   everywhere/RB
#   ,/,
#   the/DT
#   (GPE United/NNP States/NNPS)
#   is/VBZ
#   a/DT
#   partner/NN
#   for/IN
#   a/DT
#   better/JJR
#   life/NN
#   ./.)
# (S
#   Short-changing/VBG
#   these/DT
#   efforts/NNS
#   would/MD
#   increase/VB
#   the/DT
#   suffering/NN
#   and/CC
#   chaos/NN
#   of/IN
#   our/PRP$
#   world/NN
#   ,/,
#   undercut/JJ
#   our/PRP$
#   long-term/JJ
#   security/NN
#   ,/,
#   and/CC
#   dull/VB
#   the/DT
#   conscience/NN
#   of/IN
#   our/PRP$
#   country/NN
#   ./.)
# (S
#   I/PRP
#   urge/VBP
#   members/NNS
#   of/IN
#   (ORGANIZATION Congress/NNP)
#   to/TO
#   serve/VB
#   the/DT
#   interests/NNS
#   of/IN
#   (GPE America/NNP)
#   by/IN
#   showing/VBG
#   the/DT
#   compassion/NN
#   of/IN
#   (GPE America/NNP)
#   ./.)
# (S
#   Our/PRP$
#   country/NN
#   must/MD
#   also/RB
#   remain/VB
#   on/IN
#   the/DT
#   offensive/JJ
#   against/IN
#   terrorism/NN
#   here/RB
#   at/IN
#   home/NN
#   ./.)
# (S
#   The/DT
#   enemy/NN
#   has/VBZ
#   not/RB
#   lost/VBN
#   the/DT
#   desire/NN
#   or/CC
#   capability/NN
#   to/TO
#   attack/VB
#   us/PRP
#   ./.)
# (S
#   Fortunately/RB
#   ,/,
#   this/DT
#   nation/NN
#   has/VBZ
#   superb/VBN
#   professionals/NNS
#   in/IN
#   law/NN
#   enforcement/NN
#   ,/,
#   intelligence/NN
#   ,/,
#   the/DT
#   military/JJ
#   ,/,
#   and/CC
#   homeland/VBP
#   security/NN
#   ./.)
# (S
#   These/DT
#   men/NNS
#   and/CC
#   women/NNS
#   are/VBP
#   dedicating/VBG
#   their/PRP$
#   lives/NNS
#   ,/,
#   protecting/VBG
#   us/PRP
#   all/DT
#   ,/,
#   and/CC
#   they/PRP
#   deserve/VBP
#   our/PRP$
#   support/NN
#   and/CC
#   our/PRP$
#   thanks/NNS
#   ./.)
# (S (/( (ORGANIZATION Applause/NNP) ./. )/))
# (S
#   They/PRP
#   also/RB
#   deserve/VBP
#   the/DT
#   same/JJ
#   tools/NNS
#   they/PRP
#   already/RB
#   use/VBP
#   to/TO
#   fight/VB
#   drug/NN
#   trafficking/NN
#   and/CC
#   organized/VBN
#   crime/NN
#   --/:
#   so/RB
#   I/PRP
#   ask/VBP
#   you/PRP
#   to/TO
#   reauthorize/VB
#   the/DT
#   (ORGANIZATION Patriot/NNP Act/NNP)
#   ./.)
# (S (/( (ORGANIZATION Applause/NNP) ./. )/))
# (S
#   It/PRP
#   is/VBZ
#   said/VBD
#   that/IN
#   prior/JJ
#   to/TO
#   the/DT
#   attacks/NNS
#   of/IN
#   September/NNP
#   the/DT
#   11th/CD
#   ,/,
#   our/PRP$
#   government/NN
#   failed/VBD
#   to/TO
#   connect/VB
#   the/DT
#   dots/NNS
#   of/IN
#   the/DT
#   conspiracy/NN
#   ./.)
# (S
#   We/PRP
#   now/RB
#   know/VBP
#   that/IN
#   two/CD
#   of/IN
#   the/DT
#   hijackers/NNS
#   in/IN
#   the/DT
#   (GPE United/NNP States/NNPS)
#   placed/VBD
#   telephone/NN
#   calls/NNS
#   to/TO
#   al/VB
#   (PERSON Qaeda/NNP)
#   operatives/VBZ
#   overseas/RB
#   ./.)
# (S
#   But/CC
#   we/PRP
#   did/VBD
#   not/RB
#   know/VB
#   about/IN
#   their/PRP$
#   plans/NNS
#   until/IN
#   it/PRP
#   was/VBD
#   too/RB
#   late/JJ
#   ./.)
# (S
#   So/RB
#   to/TO
#   prevent/VB
#   another/DT
#   attack/NN
#   --/:
#   based/VBN
#   on/IN
#   authority/NN
#   given/VBN
#   to/TO
#   me/PRP
#   by/IN
#   the/DT
#   (ORGANIZATION Constitution/NNP)
#   and/CC
#   by/IN
#   statute/NN
#   --/:
#   I/PRP
#   have/VBP
#   authorized/VBN
#   a/DT
#   terrorist/JJ
#   surveillance/NN
#   program/NN
#   to/TO
#   aggressively/RB
#   pursue/VB
#   the/DT
#   international/JJ
#   communications/NNS
#   of/IN
#   suspected/JJ
#   al/JJ
#   Qaeda/NNP
#   operatives/NNS
#   and/CC
#   affiliates/NNS
#   to/TO
#   and/CC
#   from/IN
#   (GPE America/NNP)
#   ./.)
# (S
#   Previous/JJ
#   Presidents/NNS
#   have/VBP
#   used/VBN
#   the/DT
#   same/JJ
#   constitutional/JJ
#   authority/NN
#   I/PRP
#   have/VBP
#   ,/,
#   and/CC
#   federal/JJ
#   courts/NNS
#   have/VBP
#   approved/VBN
#   the/DT
#   use/NN
#   of/IN
#   that/DT
#   authority/NN
#   ./.)
# (S
#   Appropriate/JJ
#   members/NNS
#   of/IN
#   (ORGANIZATION Congress/NNP)
#   have/VBP
#   been/VBN
#   kept/VBN
#   informed/VBN
#   ./.)
# (S
#   The/DT
#   terrorist/JJ
#   surveillance/NN
#   program/NN
#   has/VBZ
#   helped/VBN
#   prevent/VB
#   terrorist/JJ
#   attacks/NNS
#   ./.)
# (S
#   It/PRP
#   remains/VBZ
#   essential/JJ
#   to/TO
#   the/DT
#   security/NN
#   of/IN
#   (GPE America/NNP)
#   ./.)
# (S
#   If/IN
#   there/EX
#   are/VBP
#   people/NNS
#   inside/IN
#   our/PRP$
#   country/NN
#   who/WP
#   are/VBP
#   talking/VBG
#   with/IN
#   al/NN
#   (PERSON Qaeda/NNP)
#   ,/,
#   we/PRP
#   want/VBP
#   to/TO
#   know/VB
#   about/IN
#   it/PRP
#   ,/,
#   because/IN
#   we/PRP
#   will/MD
#   not/RB
#   sit/VB
#   back/RB
#   and/CC
#   wait/NN
#   to/TO
#   be/VB
#   hit/VBN
#   again/RB
#   ./.)
# (S (/( (ORGANIZATION Applause/NNP) ./. )/))
# (S
#   In/IN
#   all/PDT
#   these/DT
#   areas/NNS
#   --/:
#   from/IN
#   the/DT
#   disruption/NN
#   of/IN
#   terror/NN
#   networks/NNS
#   ,/,
#   to/TO
#   victory/NN
#   in/IN
#   (GPE Iraq/NNP)
#   ,/,
#   to/TO
#   the/DT
#   spread/NN
#   of/IN
#   freedom/NN
#   and/CC
#   hope/NN
#   in/IN
#   troubled/JJ
#   regions/NNS
#   --/:
#   we/PRP
#   need/VBP
#   the/DT
#   support/NN
#   of/IN
#   our/PRP$
#   friends/NNS
#   and/CC
#   allies/NNS
#   ./.)
# (S
#   To/TO
#   draw/VB
#   that/DT
#   support/NN
#   ,/,
#   we/PRP
#   must/MD
#   always/RB
#   be/VB
#   clear/JJ
#   in/IN
#   our/PRP$
#   principles/NNS
#   and/CC
#   willing/JJ
#   to/TO
#   act/VB
#   ./.)
# (S
#   The/DT
#   only/JJ
#   alternative/NN
#   to/TO
#   (GPE American/JJ)
#   leadership/NN
#   is/VBZ
#   a/DT
#   dramatically/RB
#   more/RBR
#   dangerous/JJ
#   and/CC
#   anxious/JJ
#   world/NN
#   ./.)
# (S
#   Yet/CC
#   we/PRP
#   also/RB
#   choose/VBP
#   to/TO
#   lead/VB
#   because/IN
#   it/PRP
#   is/VBZ
#   a/DT
#   privilege/NN
#   to/TO
#   serve/VB
#   the/DT
#   values/NNS
#   that/WDT
#   gave/VBD
#   us/PRP
#   birth/NN
#   ./.)
# (S
#   (GPE American/JJ)
#   leaders/NNS
#   --/:
#   from/IN
#   (GPE Roosevelt/NNP)
#   to/TO
#   (PERSON Truman/NNP)
#   to/TO
#   (PERSON Kennedy/NNP)
#   to/TO
#   (GPE Reagan/NNP)
#   --/:
#   rejected/VBD
#   isolation/NN
#   and/CC
#   retreat/NN
#   ,/,
#   because/IN
#   they/PRP
#   knew/VBD
#   that/IN
#   (GPE America/NNP)
#   is/VBZ
#   always/RB
#   more/RBR
#   secure/JJ
#   when/WRB
#   freedom/NN
#   is/VBZ
#   on/IN
#   the/DT
#   march/NN
#   ./.)
# (S
#   Our/PRP$
#   own/JJ
#   generation/NN
#   is/VBZ
#   in/IN
#   a/DT
#   long/JJ
#   war/NN
#   against/IN
#   a/DT
#   determined/JJ
#   enemy/NN
#   --/:
#   a/DT
#   war/NN
#   that/WDT
#   will/MD
#   be/VB
#   fought/VBN
#   by/IN
#   Presidents/NNS
#   of/IN
#   both/DT
#   parties/NNS
#   ,/,
#   who/WP
#   will/MD
#   need/VB
#   steady/JJ
#   bipartisan/JJ
#   support/NN
#   from/IN
#   the/DT
#   (ORGANIZATION Congress/NNP)
#   ./.)
# (S And/CC tonight/NN I/PRP ask/VBP for/IN yours/NNS ./.)
# (S
#   Together/RB
#   ,/,
#   let/VB
#   us/PRP
#   protect/VB
#   our/PRP$
#   country/NN
#   ,/,
#   support/VB
#   the/DT
#   men/NNS
#   and/CC
#   women/NNS
#   who/WP
#   defend/VBP
#   us/PRP
#   ,/,
#   and/CC
#   lead/VB
#   this/DT
#   world/NN
#   toward/IN
#   freedom/NN
#   ./.)
# (S (/( (ORGANIZATION Applause/NNP) ./. )/))
# (S
#   Here/RB
#   at/IN
#   home/NN
#   ,/,
#   (GPE America/NNP)
#   also/RB
#   has/VBZ
#   a/DT
#   great/JJ
#   opportunity/NN
#   :/:
#   We/PRP
#   will/MD
#   build/VB
#   the/DT
#   prosperity/NN
#   of/IN
#   our/PRP$
#   country/NN
#   by/IN
#   strengthening/VBG
#   our/PRP$
#   economic/JJ
#   leadership/NN
#   in/IN
#   the/DT
#   world/NN
#   ./.)
# (S
#   Our/PRP$
#   economy/NN
#   is/VBZ
#   healthy/JJ
#   and/CC
#   vigorous/JJ
#   ,/,
#   and/CC
#   growing/VBG
#   faster/RBR
#   than/IN
#   other/JJ
#   major/JJ
#   industrialized/VBN
#   nations/NNS
#   ./.)
# (S
#   In/IN
#   the/DT
#   last/JJ
#   two-and-a-half/JJ
#   years/NNS
#   ,/,
#   (GPE America/NNP)
#   has/VBZ
#   created/VBN
#   4.6/CD
#   million/CD
#   new/JJ
#   jobs/NNS
#   --/:
#   more/JJR
#   than/IN
#   (GPE Japan/NNP)
#   and/CC
#   the/DT
#   (ORGANIZATION European/NNP Union/NNP)
#   combined/VBD
#   ./.)
# (S (/( (ORGANIZATION Applause/NNP) ./. )/))
# (S
#   Even/RB
#   in/IN
#   the/DT
#   face/NN
#   of/IN
#   higher/JJR
#   energy/NN
#   prices/NNS
#   and/CC
#   natural/JJ
#   disasters/NNS
#   ,/,
#   the/DT
#   (GPE American/JJ)
#   people/NNS
#   have/VBP
#   turned/VBN
#   in/IN
#   an/DT
#   economic/JJ
#   performance/NN
#   that/WDT
#   is/VBZ
#   the/DT
#   envy/NN
#   of/IN
#   the/DT
#   world/NN
#   ./.)
# (S
#   The/DT
#   (GPE American/JJ)
#   economy/NN
#   is/VBZ
#   preeminent/JJ
#   ,/,
#   but/CC
#   we/PRP
#   can/MD
#   not/RB
#   afford/VB
#   to/TO
#   be/VB
#   complacent/JJ
#   ./.)
# (S
#   In/IN
#   a/DT
#   dynamic/JJ
#   world/NN
#   economy/NN
#   ,/,
#   we/PRP
#   are/VBP
#   seeing/VBG
#   new/JJ
#   competitors/NNS
#   ,/,
#   like/IN
#   (GPE China/NNP)
#   and/CC
#   (GPE India/NNP)
#   ,/,
#   and/CC
#   this/DT
#   creates/VBZ
#   uncertainty/NN
#   ,/,
#   which/WDT
#   makes/VBZ
#   it/PRP
#   easier/JJR
#   to/TO
#   feed/VB
#   people/NNS
#   's/POS
#   fears/NNS
#   ./.)
# (S
#   So/IN
#   we/PRP
#   're/VBP
#   seeing/VBG
#   some/DT
#   old/JJ
#   temptations/NNS
#   return/NN
#   ./.)
# (S
#   Protectionists/NNS
#   want/VBP
#   to/TO
#   escape/VB
#   competition/NN
#   ,/,
#   pretending/VBG
#   that/IN
#   we/PRP
#   can/MD
#   keep/VB
#   our/PRP$
#   high/JJ
#   standard/NN
#   of/IN
#   living/NN
#   while/IN
#   walling/VBG
#   off/RP
#   our/PRP$
#   economy/NN
#   ./.)
# (S
#   Others/NNS
#   say/VBP
#   that/IN
#   the/DT
#   government/NN
#   needs/VBZ
#   to/TO
#   take/VB
#   a/DT
#   larger/JJR
#   role/NN
#   in/IN
#   directing/VBG
#   the/DT
#   economy/NN
#   ,/,
#   centralizing/VBG
#   more/JJR
#   power/NN
#   in/IN
#   (GPE Washington/NNP)
#   and/CC
#   increasing/VBG
#   taxes/NNS
#   ./.)
# (S
#   We/PRP
#   hear/VBP
#   claims/NNS
#   that/IN
#   immigrants/NNS
#   are/VBP
#   somehow/RB
#   bad/JJ
#   for/IN
#   the/DT
#   economy/NN
#   --/:
#   even/RB
#   though/IN
#   this/DT
#   economy/NN
#   could/MD
#   not/RB
#   function/VB
#   without/IN
#   them/PRP
#   ./.)
# (S (/( (ORGANIZATION Applause/NNP) ./. )/))
# (S
#   All/PDT
#   these/DT
#   are/VBP
#   forms/NNS
#   of/IN
#   economic/JJ
#   retreat/NN
#   ,/,
#   and/CC
#   they/PRP
#   lead/VBP
#   in/IN
#   the/DT
#   same/JJ
#   direction/NN
#   --/:
#   toward/IN
#   a/DT
#   stagnant/JJ
#   and/CC
#   second-rate/JJ
#   economy/NN
#   ./.)
# (S
#   Tonight/NNP
#   I/PRP
#   will/MD
#   set/VB
#   out/RP
#   a/DT
#   better/JJR
#   path/NN
#   :/:
#   an/DT
#   agenda/NN
#   for/IN
#   a/DT
#   nation/NN
#   that/WDT
#   competes/VBZ
#   with/IN
#   confidence/NN
#   ;/:
#   an/DT
#   agenda/NN
#   that/WDT
#   will/MD
#   raise/VB
#   standards/NNS
#   of/IN
#   living/NN
#   and/CC
#   generate/VB
#   new/JJ
#   jobs/NNS
#   ./.)
# (S
#   (GPE Americans/NNPS)
#   should/MD
#   not/RB
#   fear/VB
#   our/PRP$
#   economic/JJ
#   future/NN
#   ,/,
#   because/IN
#   we/PRP
#   intend/VBP
#   to/TO
#   shape/VB
#   it/PRP
#   ./.)
# (S
#   Keeping/VBG
#   (GPE America/NNP)
#   competitive/JJ
#   begins/NNS
#   with/IN
#   keeping/VBG
#   our/PRP$
#   economy/NN
#   growing/VBG
#   ./.)
# (S
#   And/CC
#   our/PRP$
#   economy/NN
#   grows/VBZ
#   when/WRB
#   (GPE Americans/NNPS)
#   have/VBP
#   more/JJR
#   of/IN
#   their/PRP$
#   own/JJ
#   money/NN
#   to/TO
#   spend/VB
#   ,/,
#   save/VB
#   ,/,
#   and/CC
#   invest/JJS
#   ./.)
# (S
#   In/IN
#   the/DT
#   last/JJ
#   five/CD
#   years/NNS
#   ,/,
#   the/DT
#   tax/NN
#   relief/NN
#   you/PRP
#   passed/VBN
#   has/VBZ
#   left/VBN
#   $/$
#   880/CD
#   billion/CD
#   in/IN
#   the/DT
#   hands/NNS
#   of/IN
#   (GPE American/JJ)
#   workers/NNS
#   ,/,
#   investors/NNS
#   ,/,
#   small/JJ
#   businesses/NNS
#   ,/,
#   and/CC
#   families/NNS
#   --/:
#   and/CC
#   they/PRP
#   have/VBP
#   used/VBN
#   it/PRP
#   to/TO
#   help/VB
#   produce/VB
#   more/JJR
#   than/IN
#   four/CD
#   years/NNS
#   of/IN
#   uninterrupted/JJ
#   economic/JJ
#   growth/NN
#   ./.)
# (S (/( (ORGANIZATION Applause/NNP) ./. )/))
# (S
#   Yet/RB
#   the/DT
#   tax/NN
#   relief/NN
#   is/VBZ
#   set/VBN
#   to/TO
#   expire/VB
#   in/IN
#   the/DT
#   next/JJ
#   few/JJ
#   years/NNS
#   ./.)
# (S
#   If/IN
#   we/PRP
#   do/VBP
#   nothing/NN
#   ,/,
#   (GPE American/NNP)
#   families/NNS
#   will/MD
#   face/VB
#   a/DT
#   massive/JJ
#   tax/NN
#   increase/NN
#   they/PRP
#   do/VBP
#   not/RB
#   expect/VB
#   and/CC
#   will/MD
#   not/RB
#   welcome/VB
#   ./.)
# (S
#   Because/IN
#   (GPE America/NNP)
#   needs/VBZ
#   more/JJR
#   than/IN
#   a/DT
#   temporary/JJ
#   expansion/NN
#   ,/,
#   we/PRP
#   need/VBP
#   more/JJR
#   than/IN
#   temporary/JJ
#   tax/NN
#   relief/NN
#   ./.)
# (S
#   I/PRP
#   urge/VBP
#   the/DT
#   (ORGANIZATION Congress/NNP)
#   to/TO
#   act/VB
#   responsibly/RB
#   ,/,
#   and/CC
#   make/VB
#   the/DT
#   tax/NN
#   cuts/NNS
#   permanent/NN
#   ./.)
# (S (/( (ORGANIZATION Applause/NNP) ./. )/))
# (S
#   Keeping/VBG
#   (GPE America/NNP)
#   competitive/JJ
#   requires/VBZ
#   us/PRP
#   to/TO
#   be/VB
#   good/JJ
#   stewards/NNS
#   of/IN
#   tax/NN
#   dollars/NNS
#   ./.)
# (S
#   Every/DT
#   year/NN
#   of/IN
#   my/PRP$
#   presidency/NN
#   ,/,
#   we/PRP
#   've/VBP
#   reduced/VBN
#   the/DT
#   growth/NN
#   of/IN
#   non-security/JJ
#   discretionary/JJ
#   spending/NN
#   ,/,
#   and/CC
#   last/JJ
#   year/NN
#   you/PRP
#   passed/VBD
#   bills/NNS
#   that/IN
#   cut/VBD
#   this/DT
#   spending/NN
#   ./.)
# (S
#   This/DT
#   year/NN
#   my/PRP$
#   budget/NN
#   will/MD
#   cut/VB
#   it/PRP
#   again/RB
#   ,/,
#   and/CC
#   reduce/VB
#   or/CC
#   eliminate/VB
#   more/JJR
#   than/IN
#   140/CD
#   programs/NNS
#   that/WDT
#   are/VBP
#   performing/VBG
#   poorly/RB
#   or/CC
#   not/RB
#   fulfilling/JJ
#   essential/JJ
#   priorities/NNS
#   ./.)
# (S
#   By/IN
#   passing/VBG
#   these/DT
#   reforms/NNS
#   ,/,
#   we/PRP
#   will/MD
#   save/VB
#   the/DT
#   (GPE American/NNP)
#   taxpayer/NN
#   another/DT
#   $/$
#   14/CD
#   billion/CD
#   next/JJ
#   year/NN
#   ,/,
#   and/CC
#   stay/VB
#   on/IN
#   track/NN
#   to/TO
#   cut/VB
#   the/DT
#   deficit/NN
#   in/IN
#   half/NN
#   by/IN
#   2009/CD
#   ./.)
# (S (/( (ORGANIZATION Applause/NNP) ./. )/))
# (S
#   I/PRP
#   am/VBP
#   pleased/JJ
#   that/IN
#   members/NNS
#   of/IN
#   (ORGANIZATION Congress/NNP)
#   are/VBP
#   working/VBG
#   on/IN
#   earmark/NN
#   reform/NN
#   ,/,
#   because/IN
#   the/DT
#   federal/JJ
#   budget/NN
#   has/VBZ
#   too/RB
#   many/JJ
#   special/JJ
#   interest/NN
#   projects/NNS
#   ./.)
# (S (/( (ORGANIZATION Applause/NNP) ./. )/))
# (S
#   And/CC
#   we/PRP
#   can/MD
#   tackle/VB
#   this/DT
#   problem/NN
#   together/RB
#   ,/,
#   if/IN
#   you/PRP
#   pass/VBP
#   the/DT
#   line-item/JJ
#   veto/NN
#   ./.)
# (S (/( (ORGANIZATION Applause/NNP) ./. )/))
# (S
#   We/PRP
#   must/MD
#   also/RB
#   confront/VB
#   the/DT
#   larger/JJR
#   challenge/NN
#   of/IN
#   mandatory/JJ
#   spending/NN
#   ,/,
#   or/CC
#   entitlements/NNS
#   ./.)
# (S
#   This/DT
#   year/NN
#   ,/,
#   the/DT
#   first/JJ
#   of/IN
#   about/RB
#   78/CD
#   million/CD
#   baby/NN
#   boomers/NNS
#   turn/VBP
#   60/CD
#   ,/,
#   including/VBG
#   two/CD
#   of/IN
#   my/PRP$
#   (GPE Dad/NNP)
#   's/POS
#   favorite/JJ
#   people/NNS
#   --/:
#   me/PRP
#   and/CC
#   President/NNP
#   (PERSON Clinton/NNP)
#   ./.)
# (S (/( Laughter/NNP ./. )/))
# (S
#   This/DT
#   milestone/NN
#   is/VBZ
#   more/JJR
#   than/IN
#   a/DT
#   personal/JJ
#   crisis/NN
#   --/:
#   (/(
#   laughter/NN
#   )/)
#   --/:
#   it/PRP
#   is/VBZ
#   a/DT
#   national/JJ
#   challenge/NN
#   ./.)
# (S
#   The/DT
#   retirement/NN
#   of/IN
#   the/DT
#   baby/NN
#   boom/NN
#   generation/NN
#   will/MD
#   put/VB
#   unprecedented/JJ
#   strains/NNS
#   on/IN
#   the/DT
#   federal/JJ
#   government/NN
#   ./.)
# (S
#   By/IN
#   2030/CD
#   ,/,
#   spending/VBG
#   for/IN
#   (ORGANIZATION Social/NNP)
#   Security/NNP
#   ,/,
#   (ORGANIZATION Medicare/NNP)
#   and/CC
#   (PERSON Medicaid/NNP)
#   alone/RB
#   will/MD
#   be/VB
#   almost/RB
#   60/CD
#   percent/NN
#   of/IN
#   the/DT
#   entire/JJ
#   federal/JJ
#   budget/NN
#   ./.)
# (S
#   And/CC
#   that/DT
#   will/MD
#   present/VB
#   future/JJ
#   Congresses/NNS
#   with/IN
#   impossible/JJ
#   choices/NNS
#   --/:
#   staggering/VBG
#   tax/NN
#   increases/NNS
#   ,/,
#   immense/JJ
#   deficits/NNS
#   ,/,
#   or/CC
#   deep/JJ
#   cuts/NNS
#   in/IN
#   every/DT
#   category/NN
#   of/IN
#   spending/NN
#   ./.)
# (S
#   (ORGANIZATION Congress/NNP)
#   did/VBD
#   not/RB
#   act/VB
#   last/JJ
#   year/NN
#   on/IN
#   my/PRP$
#   proposal/NN
#   to/TO
#   save/VB
#   (ORGANIZATION Social/NNP)
#   Security/NNP
#   --/:
#   (/(
#   applause/NN
#   )/)
#   --/:
#   yet/RB
#   the/DT
#   rising/VBG
#   cost/NN
#   of/IN
#   entitlements/NNS
#   is/VBZ
#   a/DT
#   problem/NN
#   that/WDT
#   is/VBZ
#   not/RB
#   going/VBG
#   away/RB
#   ./.)
# (S (/( (ORGANIZATION Applause/NNP) ./. )/))
# (S
#   And/CC
#   every/DT
#   year/NN
#   we/PRP
#   fail/VBP
#   to/TO
#   act/VB
#   ,/,
#   the/DT
#   situation/NN
#   gets/VBZ
#   worse/JJR
#   ./.)
# (S
#   So/RB
#   tonight/JJ
#   ,/,
#   I/PRP
#   ask/VBP
#   you/PRP
#   to/TO
#   join/VB
#   me/PRP
#   in/IN
#   creating/VBG
#   a/DT
#   commission/NN
#   to/TO
#   examine/VB
#   the/DT
#   full/JJ
#   impact/NN
#   of/IN
#   baby/NN
#   boom/NN
#   retirements/NNS
#   on/IN
#   (ORGANIZATION Social/NNP)
#   Security/NNP
#   ,/,
#   (GPE Medicare/NNP)
#   ,/,
#   and/CC
#   (ORGANIZATION Medicaid/NNP)
#   ./.)
# (S
#   This/DT
#   commission/NN
#   should/MD
#   include/VB
#   members/NNS
#   of/IN
#   (ORGANIZATION Congress/NNP)
#   of/IN
#   both/DT
#   parties/NNS
#   ,/,
#   and/CC
#   offer/VBP
#   bipartisan/JJ
#   solutions/NNS
#   ./.)
# (S
#   We/PRP
#   need/VBP
#   to/TO
#   put/VB
#   aside/RP
#   partisan/JJ
#   politics/NNS
#   and/CC
#   work/NN
#   together/RB
#   and/CC
#   get/VB
#   this/DT
#   problem/NN
#   solved/VBD
#   ./.)
# (S (/( (ORGANIZATION Applause/NNP) ./. )/))
# (S
#   Keeping/VBG
#   (GPE America/NNP)
#   competitive/JJ
#   requires/VBZ
#   us/PRP
#   to/TO
#   open/VB
#   more/JJR
#   markets/NNS
#   for/IN
#   all/DT
#   that/DT
#   Americans/NNPS
#   make/VBP
#   and/CC
#   grow/VB
#   ./.)
# (S
#   One/CD
#   out/NN
#   of/IN
#   every/DT
#   five/CD
#   factory/NN
#   jobs/NNS
#   in/IN
#   (GPE America/NNP)
#   is/VBZ
#   related/VBN
#   to/TO
#   global/JJ
#   trade/NN
#   ,/,
#   and/CC
#   we/PRP
#   want/VBP
#   people/NNS
#   everywhere/RB
#   to/TO
#   buy/VB
#   (GPE American/NNP)
#   ./.)
# (S
#   With/IN
#   open/JJ
#   markets/NNS
#   and/CC
#   a/DT
#   level/JJ
#   playing/NN
#   field/NN
#   ,/,
#   no/DT
#   one/NN
#   can/MD
#   out-produce/VB
#   or/CC
#   out-compete/VB
#   the/DT
#   (GPE American/JJ)
#   worker/NN
#   ./.)
# (S (/( (ORGANIZATION Applause/NNP) ./. )/))
# (S
#   Keeping/VBG
#   (GPE America/NNP)
#   competitive/JJ
#   requires/VBZ
#   an/DT
#   immigration/NN
#   system/NN
#   that/WDT
#   upholds/VBZ
#   our/PRP$
#   laws/NNS
#   ,/,
#   reflects/VBZ
#   our/PRP$
#   values/NNS
#   ,/,
#   and/CC
#   serves/VBZ
#   the/DT
#   interests/NNS
#   of/IN
#   our/PRP$
#   economy/NN
#   ./.)
# (S
#   Our/PRP$
#   nation/NN
#   needs/VBZ
#   orderly/JJ
#   and/CC
#   secure/JJ
#   borders/NNS
#   ./.)
# (S (/( (ORGANIZATION Applause/NNP) ./. )/))
# (S
#   To/TO
#   meet/VB
#   this/DT
#   goal/NN
#   ,/,
#   we/PRP
#   must/MD
#   have/VB
#   stronger/JJR
#   immigration/NN
#   enforcement/NN
#   and/CC
#   border/NN
#   protection/NN
#   ./.)
# (S (/( (ORGANIZATION Applause/NNP) ./. )/))
# (S
#   And/CC
#   we/PRP
#   must/MD
#   have/VB
#   a/DT
#   rational/JJ
#   ,/,
#   humane/JJ
#   guest/JJS
#   worker/NN
#   program/NN
#   that/WDT
#   rejects/VBZ
#   amnesty/JJ
#   ,/,
#   allows/VBZ
#   temporary/JJ
#   jobs/NNS
#   for/IN
#   people/NNS
#   who/WP
#   seek/VBP
#   them/PRP
#   legally/RB
#   ,/,
#   and/CC
#   reduces/NNS
#   smuggling/VBG
#   and/CC
#   crime/NN
#   at/IN
#   the/DT
#   border/NN
#   ./.)
# (S (/( (ORGANIZATION Applause/NNP) ./. )/))
# (S
#   Keeping/VBG
#   (GPE America/NNP)
#   competitive/JJ
#   requires/VBZ
#   affordable/JJ
#   health/NN
#   care/NN
#   ./.)
# (S (/( (ORGANIZATION Applause/NNP) ./. )/))
# (S
#   Our/PRP$
#   government/NN
#   has/VBZ
#   a/DT
#   responsibility/NN
#   to/TO
#   provide/VB
#   health/NN
#   care/NN
#   for/IN
#   the/DT
#   poor/JJ
#   and/CC
#   the/DT
#   elderly/JJ
#   ,/,
#   and/CC
#   we/PRP
#   are/VBP
#   meeting/VBG
#   that/IN
#   responsibility/NN
#   ./.)
# (S (/( (ORGANIZATION Applause/NNP) ./. )/))
# (S
#   For/IN
#   all/DT
#   Americans/NNPS
#   --/:
#   for/IN
#   all/DT
#   Americans/NNPS
#   ,/,
#   we/PRP
#   must/MD
#   confront/VB
#   the/DT
#   rising/VBG
#   cost/NN
#   of/IN
#   care/NN
#   ,/,
#   strengthen/VB
#   the/DT
#   doctor-patient/JJ
#   relationship/NN
#   ,/,
#   and/CC
#   help/NN
#   people/NNS
#   afford/VBP
#   the/DT
#   insurance/NN
#   coverage/NN
#   they/PRP
#   need/VBP
#   ./.)
# (S (/( (ORGANIZATION Applause/NNP) ./. )/))
# (S
#   We/PRP
#   will/MD
#   make/VB
#   wider/JJR
#   use/NN
#   of/IN
#   electronic/JJ
#   records/NNS
#   and/CC
#   other/JJ
#   health/NN
# ...
#   propose/VBP
#   to/TO
#   train/VB
#   70,000/CD
#   high/JJ
#   school/NN
#   teachers/NNS
#   to/TO
#   lead/VB
#   advanced-placement/JJ
#   courses/NNS
#   in/IN
#   math/NN
#   and/CC
#   science/NN
#   ,/,
#   bring/VBG
#   30,000/CD
#   math/NN
#   and/CC
#   science/NN
#   professionals/NNS
#   to/TO
#   teach/VB
#   in/IN
#   classrooms/NNS
#   ,/,
#   and/CC
#   give/VB
#   early/JJ
#   help/NN
#   to/TO
#   students/NNS
#   who/WP
#   struggle/VBP
#   with/IN
#   math/NN
#   ,/,
#   so/IN
#   they/PRP
#   have/VBP
#   a/DT
#   better/JJR
#   chance/NN
#   at/IN
#   good/JJ
#   ,/,
#   high-wage/JJ
#   jobs/NNS
#   ./.)
# (S
#   If/IN
#   we/PRP
#   ensure/VB
#   that/IN
#   (GPE America/NNP)
#   's/POS
#   children/NNS
#   succeed/VB
#   in/IN
#   life/NN
#   ,/,
#   they/PRP
#   will/MD
#   ensure/VB
#   that/IN
#   (GPE America/NNP)
#   succeeds/VBZ
#   in/IN
#   the/DT
#   world/NN
#   ./.)
# (S (/( (ORGANIZATION Applause/NNP) ./. )/))
# (S
#   Preparing/VBG
#   our/PRP$
#   nation/NN
#   to/TO
#   compete/VB
#   in/IN
#   the/DT
#   world/NN
#   is/VBZ
#   a/DT
#   goal/NN
#   that/IN
#   all/DT
#   of/IN
#   us/PRP
#   can/MD
#   share/NN
#   ./.)
# (S
#   I/PRP
#   urge/VBP
#   you/PRP
#   to/TO
#   support/VB
#   the/DT
#   (ORGANIZATION American/JJ)
#   (ORGANIZATION Competitiveness/NNP Initiative/NNP)
#   ,/,
#   and/CC
#   together/RB
#   we/PRP
#   will/MD
#   show/VB
#   the/DT
#   world/NN
#   what/WP
#   the/DT
#   (GPE American/JJ)
#   people/NNS
#   can/MD
#   achieve/VB
#   ./.)
# (S
#   (GPE America/NNP)
#   is/VBZ
#   a/DT
#   great/JJ
#   force/NN
#   for/IN
#   freedom/NN
#   and/CC
#   prosperity/NN
#   ./.)
# (S
#   Yet/RB
#   our/PRP$
#   greatness/NN
#   is/VBZ
#   not/RB
#   measured/VBN
#   in/IN
#   power/NN
#   or/CC
#   luxuries/NNS
#   ,/,
#   but/CC
#   by/IN
#   who/WP
#   we/PRP
#   are/VBP
#   and/CC
#   how/WRB
#   we/PRP
#   treat/VBP
#   one/CD
#   another/DT
#   ./.)
# (S
#   So/IN
#   we/PRP
#   strive/VBP
#   to/TO
#   be/VB
#   a/DT
#   compassionate/NN
#   ,/,
#   decent/NN
#   ,/,
#   hopeful/JJ
#   society/NN
#   ./.)
# (S
#   In/IN
#   recent/JJ
#   years/NNS
#   ,/,
#   (GPE America/NNP)
#   has/VBZ
#   become/VBN
#   a/DT
#   more/RBR
#   hopeful/JJ
#   nation/NN
#   ./.)
# (S
#   Violent/JJ
#   crime/NN
#   rates/NNS
#   have/VBP
#   fallen/VBN
#   to/TO
#   their/PRP$
#   lowest/JJS
#   levels/NNS
#   since/IN
#   the/DT
#   1970s/CD
#   ./.)
# (S
#   (GPE Welfare/NN)
#   cases/NNS
#   have/VBP
#   dropped/VBN
#   by/IN
#   more/JJR
#   than/IN
#   half/NN
#   over/IN
#   the/DT
#   past/JJ
#   decade/NN
#   ./.)
# (S
#   (GPE Drug/NN)
#   use/NN
#   among/IN
#   youth/NN
#   is/VBZ
#   down/RB
#   19/CD
#   percent/NN
#   since/IN
#   2001/CD
#   ./.)
# (S
#   There/EX
#   are/VBP
#   fewer/JJR
#   abortions/NNS
#   in/IN
#   (GPE America/NNP)
#   than/IN
#   at/IN
#   any/DT
#   point/NN
#   in/IN
#   the/DT
#   last/JJ
#   three/CD
#   decades/NNS
#   ,/,
#   and/CC
#   the/DT
#   number/NN
#   of/IN
#   children/NNS
#   born/VBN
#   to/TO
#   teenage/VB
#   mothers/NNS
#   has/VBZ
#   been/VBN
#   falling/VBG
#   for/IN
#   a/DT
#   dozen/NN
#   years/NNS
#   in/IN
#   a/DT
#   row/NN
#   ./.)
# (S (/( (ORGANIZATION Applause/NNP) ./. )/))
# (S
#   These/DT
#   gains/NNS
#   are/VBP
#   evidence/NN
#   of/IN
#   a/DT
#   quiet/JJ
#   transformation/NN
#   --/:
#   a/DT
#   revolution/NN
#   of/IN
#   conscience/NN
#   ,/,
#   in/IN
#   which/WDT
#   a/DT
#   rising/VBG
#   generation/NN
#   is/VBZ
#   finding/VBG
#   that/IN
#   a/DT
#   life/NN
#   of/IN
#   personal/JJ
#   responsibility/NN
#   is/VBZ
#   a/DT
#   life/NN
#   of/IN
#   fulfillment/NN
#   ./.)
# (S Government/NNP has/VBZ played/VBN a/DT role/NN ./.)
# (S
#   (GPE Wise/NNP)
#   policies/NNS
#   ,/,
#   such/JJ
#   as/IN
#   welfare/NN
#   reform/NN
#   and/CC
#   drug/NN
#   education/NN
#   and/CC
#   support/NN
#   for/IN
#   abstinence/NN
#   and/CC
#   adoption/NN
#   have/VBP
#   made/VBN
#   a/DT
#   difference/NN
#   in/IN
#   the/DT
#   character/NN
#   of/IN
#   our/PRP$
#   country/NN
#   ./.)
# (S
#   And/CC
#   everyone/NN
#   here/RB
#   tonight/RB
#   ,/,
#   (ORGANIZATION Democrat/NNP)
#   and/CC
#   (ORGANIZATION Republican/NNP)
#   ,/,
#   has/VBZ
#   a/DT
#   right/NN
#   to/TO
#   be/VB
#   proud/JJ
#   of/IN
#   this/DT
#   record/NN
#   ./.)
# (S (/( (ORGANIZATION Applause/NNP) ./. )/))
# (S
#   Yet/RB
#   many/JJ
#   Americans/NNPS
#   ,/,
#   especially/RB
#   parents/NNS
#   ,/,
#   still/RB
#   have/VBP
#   deep/JJ
#   concerns/NNS
#   about/IN
#   the/DT
#   direction/NN
#   of/IN
#   our/PRP$
#   culture/NN
#   ,/,
#   and/CC
#   the/DT
#   health/NN
#   of/IN
#   our/PRP$
#   most/JJS
#   basic/JJ
#   institutions/NNS
#   ./.)
# (S
#   They/PRP
#   're/VBP
#   concerned/VBN
#   about/IN
#   unethical/JJ
#   conduct/NN
#   by/IN
#   public/JJ
#   officials/NNS
#   ,/,
#   and/CC
#   discouraged/VBN
#   by/IN
#   activist/NN
#   courts/NNS
#   that/WDT
#   try/VBP
#   to/TO
#   redefine/VB
#   marriage/NN
#   ./.)
# (S
#   They/PRP
#   worry/VBP
#   about/IN
#   children/NNS
#   in/IN
#   our/PRP$
#   society/NN
#   who/WP
#   need/VBP
#   direction/NN
#   and/CC
#   love/NN
#   ,/,
#   and/CC
#   about/IN
#   fellow/JJ
#   citizens/NNS
#   still/RB
#   displaced/VBN
#   by/IN
#   natural/JJ
#   disaster/NN
#   ,/,
#   and/CC
#   about/IN
#   suffering/VBG
#   caused/VBN
#   by/IN
#   treatable/JJ
#   diseases/NNS
#   ./.)
# (S
#   As/IN
#   we/PRP
#   look/VBP
#   at/IN
#   these/DT
#   challenges/NNS
#   ,/,
#   we/PRP
#   must/MD
#   never/RB
#   give/VB
#   in/IN
#   to/TO
#   the/DT
#   belief/NN
#   that/IN
#   (GPE America/NNP)
#   is/VBZ
#   in/IN
#   decline/NN
#   ,/,
#   or/CC
#   that/IN
#   our/PRP$
#   culture/NN
#   is/VBZ
#   doomed/VBN
#   to/TO
#   unravel/VB
#   ./.)
# (S
#   The/DT
#   (GPE American/JJ)
#   people/NNS
#   know/VBP
#   better/JJR
#   than/IN
#   that/DT
#   ./.)
# (S
#   We/PRP
#   have/VBP
#   proven/VBN
#   the/DT
#   pessimists/NNS
#   wrong/JJ
#   before/RB
#   --/:
#   and/CC
#   we/PRP
#   will/MD
#   do/VB
#   it/PRP
#   again/RB
#   ./.)
# (S (/( (ORGANIZATION Applause/NNP) ./. )/))
# (S
#   A/DT
#   hopeful/JJ
#   society/NN
#   depends/VBZ
#   on/IN
#   courts/NNS
#   that/IN
#   deliver/VBP
#   equal/JJ
#   justice/NN
#   under/IN
#   the/DT
#   law/NN
#   ./.)
# (S
#   The/DT
#   (ORGANIZATION Supreme/NNP Court/NNP)
#   now/RB
#   has/VBZ
#   two/CD
#   superb/JJ
#   new/JJ
#   members/NNS
#   --/:
#   new/JJ
#   members/NNS
#   on/IN
#   its/PRP$
#   bench/NN
#   :/:
#   Chief/JJ
#   Justice/NNP
#   (PERSON John/NNP Roberts/NNP)
#   and/CC
#   (ORGANIZATION Justice/NNP Sam/NNP Alito/NNP)
#   ./.)
# (S (/( (ORGANIZATION Applause/NNP) ./. )/))
# (S
#   I/PRP
#   thank/VBD
#   the/DT
#   (ORGANIZATION Senate/NNP)
#   for/IN
#   confirming/VBG
#   both/DT
#   of/IN
#   them/PRP
#   ./.)
# (S
#   I/PRP
#   will/MD
#   continue/VB
#   to/TO
#   nominate/VB
#   men/NNS
#   and/CC
#   women/NNS
#   who/WP
#   understand/VBP
#   that/IN
#   judges/NNS
#   must/MD
#   be/VB
#   servants/NNS
#   of/IN
#   the/DT
#   law/NN
#   ,/,
#   and/CC
#   not/RB
#   legislate/VB
#   from/IN
#   the/DT
#   bench/NN
#   ./.)
# (S (/( (ORGANIZATION Applause/NNP) ./. )/))
# (S
#   Today/NN
#   marks/VBZ
#   the/DT
#   official/JJ
#   retirement/NN
#   of/IN
#   a/DT
#   very/RB
#   special/JJ
#   (GPE American/NNP)
#   ./.)
# (S
#   For/IN
#   24/CD
#   years/NNS
#   of/IN
#   faithful/JJ
#   service/NN
#   to/TO
#   our/PRP$
#   nation/NN
#   ,/,
#   the/DT
#   (GPE United/NNP States/NNPS)
#   is/VBZ
#   grateful/JJ
#   to/TO
#   (ORGANIZATION Justice/NNP Sandra/NNP)
#   Day/NNP
#   O'Connor/NNP
#   ./.)
# (S (/( (ORGANIZATION Applause/NNP) ./. )/))
# (S
#   A/DT
#   hopeful/JJ
#   society/NN
#   has/VBZ
#   institutions/NNS
#   of/IN
#   science/NN
#   and/CC
#   medicine/NN
#   that/WDT
#   do/VBP
#   not/RB
#   cut/VB
#   ethical/JJ
#   corners/NNS
#   ,/,
#   and/CC
#   that/IN
#   recognize/VBP
#   the/DT
#   matchless/NN
#   value/NN
#   of/IN
#   every/DT
#   life/NN
#   ./.)
# (S
#   Tonight/NNP
#   I/PRP
#   ask/VBP
#   you/PRP
#   to/TO
#   pass/VB
#   legislation/NN
#   to/TO
#   prohibit/VB
#   the/DT
#   most/RBS
#   egregious/JJ
#   abuses/NNS
#   of/IN
#   medical/JJ
#   research/NN
#   :/:
#   human/JJ
#   cloning/VBG
#   in/IN
#   all/DT
#   its/PRP$
#   forms/NNS
#   ,/,
#   creating/VBG
#   or/CC
#   implanting/VBG
#   embryos/NN
#   for/IN
#   experiments/NNS
#   ,/,
#   creating/VBG
#   human-animal/JJ
#   hybrids/NNS
#   ,/,
#   and/CC
#   buying/NN
#   ,/,
#   selling/NN
#   ,/,
#   or/CC
#   patenting/VBG
#   human/JJ
#   embryos/NN
#   ./.)
# (S
#   (GPE Human/NNP)
#   life/NN
#   is/VBZ
#   a/DT
#   gift/NN
#   from/IN
#   our/PRP$
#   Creator/NNP
#   --/:
#   and/CC
#   that/IN
#   gift/NN
#   should/MD
#   never/RB
#   be/VB
#   discarded/VBN
#   ,/,
#   devalued/VBD
#   or/CC
#   put/VB
#   up/RP
#   for/IN
#   sale/NN
#   ./.)
# (S (/( (ORGANIZATION Applause/NNP) ./. )/))
# (S
#   A/DT
#   hopeful/JJ
#   society/NN
#   expects/VBZ
#   elected/VBN
#   officials/NNS
#   to/TO
#   uphold/VB
#   the/DT
#   public/JJ
#   trust/NN
#   ./.)
# (S (/( (ORGANIZATION Applause/NNP) ./. )/))
# (S
#   (GPE Honorable/JJ)
#   people/NNS
#   in/IN
#   both/DT
#   parties/NNS
#   are/VBP
#   working/VBG
#   on/IN
#   reforms/NNS
#   to/TO
#   strengthen/VB
#   the/DT
#   ethical/JJ
#   standards/NNS
#   of/IN
#   (GPE Washington/NNP)
#   --/:
#   I/PRP
#   support/VBP
#   your/PRP$
#   efforts/NNS
#   ./.)
# (S
#   Each/DT
#   of/IN
#   us/PRP
#   has/VBZ
#   made/VBN
#   a/DT
#   pledge/NN
#   to/TO
#   be/VB
#   worthy/JJ
#   of/IN
#   public/JJ
#   responsibility/NN
#   --/:
#   and/CC
#   that/DT
#   is/VBZ
#   a/DT
#   pledge/NN
#   we/PRP
#   must/MD
#   never/RB
#   forget/VB
#   ,/,
#   never/RB
#   dismiss/NN
#   ,/,
#   and/CC
#   never/RB
#   betray/NN
#   ./.)
# (S (/( (ORGANIZATION Applause/NNP) ./. )/))
# (S
#   As/IN
#   we/PRP
#   renew/VBP
#   the/DT
#   promise/NN
#   of/IN
#   our/PRP$
#   institutions/NNS
#   ,/,
#   let/VB
#   us/PRP
#   also/RB
#   show/VBP
#   the/DT
#   character/NN
#   of/IN
#   (GPE America/NNP)
#   in/IN
#   our/PRP$
#   compassion/NN
#   and/CC
#   care/NN
#   for/IN
#   one/CD
#   another/DT
#   ./.)
# (S
#   A/DT
#   hopeful/JJ
#   society/NN
#   gives/VBZ
#   special/JJ
#   attention/NN
#   to/TO
#   children/NNS
#   who/WP
#   lack/VBP
#   direction/NN
#   and/CC
#   love/NN
#   ./.)
# (S
#   Through/IN
#   the/DT
#   (ORGANIZATION Helping/NNP America/NNP)
#   's/POS
#   Youth/NNP
#   Initiative/NNP
#   ,/,
#   we/PRP
#   are/VBP
#   encouraging/VBG
#   caring/VBG
#   adults/NNS
#   to/TO
#   get/VB
#   involved/VBN
#   in/IN
#   the/DT
#   life/NN
#   of/IN
#   a/DT
#   child/NN
#   --/:
#   and/CC
#   this/DT
#   good/JJ
#   work/NN
#   is/VBZ
#   being/VBG
#   led/VBN
#   by/IN
#   our/PRP$
#   First/NNP
#   Lady/NNP
#   ,/,
#   (PERSON Laura/NNP Bush/NNP)
#   ./.)
# (S (/( (ORGANIZATION Applause/NNP) ./. )/))
# (S
#   This/DT
#   year/NN
#   we/PRP
#   will/MD
#   add/VB
#   resources/NNS
#   to/TO
#   encourage/VB
#   young/JJ
#   people/NNS
#   to/TO
#   stay/VB
#   in/IN
#   school/NN
#   ,/,
#   so/RB
#   more/JJR
#   of/IN
#   (GPE America/NNP)
#   's/POS
#   youth/NN
#   can/MD
#   raise/VB
#   their/PRP$
#   sights/NNS
#   and/CC
#   achieve/VBP
#   their/PRP$
#   dreams/NNS
#   ./.)
# (S
#   A/DT
#   hopeful/JJ
#   society/NN
#   comes/VBZ
#   to/TO
#   the/DT
#   aid/NN
#   of/IN
#   fellow/JJ
#   citizens/NNS
#   in/IN
#   times/NNS
#   of/IN
#   suffering/NN
#   and/CC
#   emergency/NN
#   --/:
#   and/CC
#   stays/NNS
#   at/IN
#   it/PRP
#   until/IN
#   they/PRP
#   're/VBP
#   back/RB
#   on/IN
#   their/PRP$
#   feet/NNS
#   ./.)
# (S
#   So/RB
#   far/RB
#   the/DT
#   federal/JJ
#   government/NN
#   has/VBZ
#   committed/VBN
#   $/$
#   85/CD
#   billion/CD
#   to/TO
#   the/DT
#   people/NNS
#   of/IN
#   the/DT
#   (ORGANIZATION Gulf/NNP Coast/NNP)
#   and/CC
#   (GSP New/NNP Orleans/NNP)
#   ./.)
# (S
#   We/PRP
#   're/VBP
#   removing/VBG
#   debris/NN
#   and/CC
#   repairing/NN
#   highways/NNS
#   and/CC
#   rebuilding/VBG
#   stronger/JJR
#   levees/NNS
#   ./.)
# (S
#   We/PRP
#   're/VBP
#   providing/VBG
#   business/NN
#   loans/NNS
#   and/CC
#   housing/NN
#   assistance/NN
#   ./.)
# (S
#   Yet/RB
#   as/IN
#   we/PRP
#   meet/VBP
#   these/DT
#   immediate/JJ
#   needs/NNS
#   ,/,
#   we/PRP
#   must/MD
#   also/RB
#   address/VB
#   deeper/JJR
#   challenges/NNS
#   that/WDT
#   existed/VBD
#   before/IN
#   the/DT
#   storm/NN
#   arrived/VBD
#   ./.)
# (S
#   In/IN
#   (GSP New/NNP Orleans/NNP)
#   and/CC
#   in/IN
#   other/JJ
#   places/NNS
#   ,/,
#   many/JJ
#   of/IN
#   our/PRP$
#   fellow/JJ
#   citizens/NNS
#   have/VBP
#   felt/VBN
#   excluded/VBN
#   from/IN
#   the/DT
#   promise/NN
#   of/IN
#   our/PRP$
#   country/NN
#   ./.)
# (S
#   The/DT
#   answer/NN
#   is/VBZ
#   not/RB
#   only/RB
#   temporary/JJ
#   relief/NN
#   ,/,
#   but/CC
#   schools/NNS
#   that/WDT
#   teach/VBP
#   every/DT
#   child/NN
#   ,/,
#   and/CC
#   job/NN
#   skills/NNS
#   that/IN
#   bring/VBG
#   upward/JJ
#   mobility/NN
#   ,/,
#   and/CC
#   more/JJR
#   opportunities/NNS
#   to/TO
#   own/VB
#   a/DT
#   home/NN
#   and/CC
#   start/VB
#   a/DT
#   business/NN
#   ./.)
# (S
#   As/IN
#   we/PRP
#   recover/VBP
#   from/IN
#   a/DT
#   disaster/NN
#   ,/,
#   let/VB
#   us/PRP
#   also/RB
#   work/NN
#   for/IN
#   the/DT
#   day/NN
#   when/WRB
#   all/DT
#   Americans/NNPS
#   are/VBP
#   protected/VBN
#   by/IN
#   justice/NN
#   ,/,
#   equal/JJ
#   in/IN
#   hope/NN
#   ,/,
#   and/CC
#   rich/JJ
#   in/IN
#   opportunity/NN
#   ./.)
# (S (/( (ORGANIZATION Applause/NNP) ./. )/))
# (S
#   A/DT
#   hopeful/JJ
#   society/NN
#   acts/NNS
#   boldly/RB
#   to/TO
#   fight/VB
#   diseases/NNS
#   like/IN
#   HIV/AIDS/NNP
#   ,/,
#   which/WDT
#   can/MD
#   be/VB
#   prevented/VBN
#   ,/,
#   and/CC
#   treated/VBD
#   ,/,
#   and/CC
#   defeated/VBD
#   ./.)
# (S
#   More/JJR
#   than/IN
#   a/DT
#   million/CD
#   Americans/NNPS
#   live/VBP
#   with/IN
#   (ORGANIZATION HIV/NNP)
#   ,/,
#   and/CC
#   half/NN
#   of/IN
#   all/DT
#   AIDS/NNP
#   cases/NNS
#   occur/VBP
#   among/IN
#   (ORGANIZATION African/JJ Americans/NNPS)
#   ./.)
# (S
#   I/PRP
#   ask/VBP
#   (ORGANIZATION Congress/NNP)
#   to/TO
#   reform/VB
#   and/CC
#   reauthorize/VB
#   the/DT
#   (ORGANIZATION Ryan/NNP)
#   (FACILITY White/NNP Act/NNP)
#   ,/,
#   and/CC
#   provide/VB
#   new/JJ
#   funding/NN
#   to/TO
#   states/NNS
#   ,/,
#   so/IN
#   we/PRP
#   end/VBP
#   the/DT
#   waiting/NN
#   lists/NNS
#   for/IN
#   (ORGANIZATION AIDS/NNP)
#   medicines/NNS
#   in/IN
#   (GPE America/NNP)
#   ./.)
# (S (/( (ORGANIZATION Applause/NNP) ./. )/))
# (S
#   We/PRP
#   will/MD
#   also/RB
#   lead/VB
#   a/DT
#   nationwide/JJ
#   effort/NN
#   ,/,
#   working/VBG
#   closely/RB
#   with/IN
#   (GSP African/JJ)
#   (GPE American/JJ)
#   churches/NNS
#   and/CC
#   faith-based/JJ
#   groups/NNS
#   ,/,
#   to/TO
#   deliver/VB
#   rapid/JJ
#   HIV/NNP
#   tests/NNS
#   to/TO
#   millions/NNS
#   ,/,
#   end/VBP
#   the/DT
#   stigma/NN
#   of/IN
#   (ORGANIZATION AIDS/NNP)
#   ,/,
#   and/CC
#   come/VB
#   closer/JJR
#   to/TO
#   the/DT
#   day/NN
#   when/WRB
#   there/EX
#   are/VBP
#   no/DT
#   new/JJ
#   infections/NNS
#   in/IN
#   (GPE America/NNP)
#   ./.)
# (S (/( (ORGANIZATION Applause/NNP) ./. )/))
# (S
#   (GPE Fellow/NNP)
#   citizens/NNS
#   ,/,
#   we/PRP
#   've/VBP
#   been/VBN
#   called/VBN
#   to/TO
#   leadership/NN
#   in/IN
#   a/DT
#   period/NN
#   of/IN
#   consequence/NN
#   ./.)
# (S
#   We/PRP
#   've/VBP
#   entered/VBN
#   a/DT
#   great/JJ
#   ideological/JJ
#   conflict/NN
#   we/PRP
#   did/VBD
#   nothing/NN
#   to/TO
#   invite/VB
#   ./.)
# (S
#   We/PRP
#   see/VBP
#   great/JJ
#   changes/NNS
#   in/IN
#   science/NN
#   and/CC
#   commerce/NN
#   that/WDT
#   will/MD
#   influence/VB
#   all/DT
#   our/PRP$
#   lives/NNS
#   ./.)
# (S
#   Sometimes/RB
#   it/PRP
#   can/MD
#   seem/VB
#   that/DT
#   history/NN
#   is/VBZ
#   turning/VBG
#   in/IN
#   a/DT
#   wide/JJ
#   arc/NN
#   ,/,
#   toward/IN
#   an/DT
#   unknown/JJ
#   shore/NN
#   ./.)
# (S
#   Yet/CC
#   the/DT
#   destination/NN
#   of/IN
#   history/NN
#   is/VBZ
#   determined/VBN
#   by/IN
#   human/JJ
#   action/NN
#   ,/,
#   and/CC
#   every/DT
#   great/JJ
#   movement/NN
#   of/IN
#   history/NN
#   comes/VBZ
#   to/TO
#   a/DT
#   point/NN
#   of/IN
#   choosing/NN
#   ./.)
# (S
#   (PERSON Lincoln/NNP)
#   could/MD
#   have/VB
#   accepted/VBN
#   peace/NN
#   at/IN
#   the/DT
#   cost/NN
#   of/IN
#   disunity/NN
#   and/CC
#   continued/JJ
#   slavery/NN
#   ./.)
# (S
#   (PERSON Martin/NNP)
#   (PERSON Luther/NNP King/NNP)
#   could/MD
#   have/VB
#   stopped/VBN
#   at/IN
#   (ORGANIZATION Birmingham/NNP)
#   or/CC
#   at/IN
#   (ORGANIZATION Selma/NNP)
#   ,/,
#   and/CC
#   achieved/VBD
#   only/RB
#   half/PDT
#   a/DT
#   victory/NN
#   over/IN
#   segregation/NN
#   ./.)
# (S
#   The/DT
#   (GPE United/NNP States/NNPS)
#   could/MD
#   have/VB
#   accepted/VBN
#   the/DT
#   permanent/JJ
#   division/NN
#   of/IN
#   (GPE Europe/NNP)
#   ,/,
#   and/CC
#   been/VBN
#   complicit/NNS
#   in/IN
#   the/DT
#   oppression/NN
#   of/IN
#   others/NNS
#   ./.)
# (S
#   Today/NN
#   ,/,
#   having/VBG
#   come/VBN
#   far/RB
#   in/IN
#   our/PRP$
#   own/JJ
#   historical/JJ
#   journey/NN
#   ,/,
#   we/PRP
#   must/MD
#   decide/VB
#   :/:
#   Will/MD
#   we/PRP
#   turn/VB
#   back/RP
#   ,/,
#   or/CC
#   finish/VB
#   well/RB
#   ?/.)
# (S
#   Before/IN
#   history/NN
#   is/VBZ
#   written/VBN
#   down/RP
#   in/IN
#   books/NNS
#   ,/,
#   it/PRP
#   is/VBZ
#   written/VBN
#   in/IN
#   courage/NN
#   ./.)
# (S
#   Like/IN
#   Americans/NNPS
#   before/IN
#   us/PRP
#   ,/,
#   we/PRP
#   will/MD
#   show/VB
#   that/DT
#   courage/NN
#   and/CC
#   we/PRP
#   will/MD
#   finish/VB
#   well/RB
#   ./.)
# (S We/PRP will/MD lead/VB freedom/NN 's/POS advance/NN ./.)
# (S
#   We/PRP
#   will/MD
#   compete/VB
#   and/CC
#   excel/VB
#   in/IN
#   the/DT
#   global/JJ
#   economy/NN
#   ./.)
# (S
#   We/PRP
#   will/MD
#   renew/VB
#   the/DT
#   defining/VBG
#   moral/JJ
#   commitments/NNS
#   of/IN
#   this/DT
#   land/NN
#   ./.)
# (S
#   And/CC
#   so/RB
#   we/PRP
#   move/VBP
#   forward/RB
#   --/:
#   optimistic/JJ
#   about/IN
#   our/PRP$
#   country/NN
#   ,/,
#   faithful/JJ
#   to/TO
#   its/PRP$
#   cause/NN
#   ,/,
#   and/CC
#   confident/NN
#   of/IN
#   the/DT
#   victories/NNS
#   to/TO
#   come/VB
#   ./.)
# (S May/NNP God/NNP bless/NN (GPE America/NNP) ./.)
# (S (/( (ORGANIZATION Applause/NNP) ./. )/))

# %% [markdown]
# # Lesson 8 - Lemmatization

# %% [markdown]
# - Similar to stemming, finding the root word.
# - Generally will find the root stem or synonym to the original word

# %%
from nltk.stem import WordNetLemmatizer

lemmatizer = WordNetLemmatizer()

print(lemmatizer.lemmatize("cats"))
print(lemmatizer.lemmatize("cats"))
print(lemmatizer.lemmatize("cacti"))
print(lemmatizer.lemmatize("geese"))
print(lemmatizer.lemmatize("rocks"))
print(lemmatizer.lemmatize("python"))
# Out:
# cat
# cat
# cactus
# goose
# rock
# python

# %%
print(lemmatizer.lemmatize("better", pos="a"))
# Out:
# good

# %% [markdown]
# This came back with a completely different word, which is good...literally.

# %%
print(lemmatizer.lemmatize("best", pos="a"))
print(lemmatizer.lemmatize("run"))
print(lemmatizer.lemmatize("run", pos="v"))
# Out:
# best
# run
# run

# %%
print(lemmatizer.lemmatize("better"))
# Out:
# better

# %% [markdown]
# - The default parameter for lemmatize is pos="n". If you have something that isn't a noun, you have to pass through the POS tag.
# - Lemmatizing is better than stemming b/c it gives you an actual word with an actual meaning. Easier for humans to understand

# %% [markdown]
# # Lesson 9 - NLTK Corpora

# %%
import nltk
print(nltk.__file__) # to see the location of python modules
# we probably want this to default to /usr/local/lib/python3.7/site-packages/nltk
# Out:
# /Users/andrewrubino/anaconda2/lib/python2.7/site-packages/nltk/__init__.pyc

# %%
from nltk.corpus import gutenberg
from nltk.tokenize import sent_tokenize

sample = gutenberg.raw("bible-kjv.txt")

tok = sent_tokenize(sample)

print(tok[5:15])
# Out:
# [u'1:5 And God called the light Day, and the darkness he called Night.', u'And the evening and the morning were the first day.', u'1:6 And God said, Let there be a firmament in the midst of the waters,\nand let it divide the waters from the waters.', u'1:7 And God made the firmament, and divided the waters which were\nunder the firmament from the waters which were above the firmament:\nand it was so.', u'1:8 And God called the firmament Heaven.', u'And the evening and the\nmorning were the second day.', u'1:9 And God said, Let the waters under the heaven be gathered together\nunto one place, and let the dry land appear: and it was so.', u'1:10 And God called the dry land Earth; and the gathering together of\nthe waters called he Seas: and God saw that it was good.', u'1:11 And God said, Let the earth bring forth grass, the herb yielding\nseed, and the fruit tree yielding fruit after his kind, whose seed is\nin itself, upon the earth: and it was so.', u'1:12 And the earth brought forth grass, and herb yielding seed after\nhis kind, and the tree yielding fruit, whose seed was in itself, after\nhis kind: and God saw that it was good.']

# %% [markdown]
# # Lesson 10 - WordNet

# %% [markdown]
# - WordNet let's you look up synonmyms, antonyms, definitions, context, etc\
#
# #### What do ppl use synsets for?
# 1. To rewrite things, like term papers.
# 2. To catch ppl who use tools like wordnets.
#
# Basically, people use this to cheat, or to catch people who cheat.

# %%
from nltk.corpus import wordnet

syns = wordnet.synsets("program")

print(syns)
# Out:
# [Synset('plan.n.01'), Synset('program.n.02'), Synset('broadcast.n.02'), Synset('platform.n.02'), Synset('program.n.05'), Synset('course_of_study.n.01'), Synset('program.n.07'), Synset('program.n.08'), Synset('program.v.01'), Synset('program.v.02')]

# %%
print(syns[0])
# Out:
# Synset('plan.n.01')
# /Users/andrewrubino/anaconda2/lib/python2.7/site-packages/unidecode/__init__.py:46: RuntimeWarning: Argument <type 'str'> is not an unicode object. Passing an encoded string will likely have unexpected results.
#   _warn_if_not_unicode(string)

# %%
# synset
print(syns[0].lemmas())

# just the word
print(syns[0].lemmas()[0].name())

# what if we want the definition
print(syns[0].definition())

# examples
print(syns[0].examples())
# Out:
# [Lemma('plan.n.01.plan'), Lemma('plan.n.01.program'), Lemma('plan.n.01.programme')]
# plan
# a series of steps to be carried out or goals to be accomplished
# [u'they drew up a six-step plan', u'they discussed plans for a new bond issue']

# %%
synonyms = []
antonyms = []

for syn in wordnet.synsets("good"):
    for l in syn.lemmas():
        # print("l: ",l)
        synonyms.append(l.name())
        if l.antonyms():
            antonyms.append(l.antonyms()[0].name())
            
print(set(synonyms))
print(set(antonyms))
# Out:
# set([u'beneficial', u'right', u'secure', u'just', u'unspoilt', u'respectable', u'good', u'goodness', u'dear', u'salutary', u'ripe', u'expert', u'skillful', u'in_force', u'proficient', u'unspoiled', u'dependable', u'soundly', u'honorable', u'full', u'undecomposed', u'safe', u'adept', u'upright', u'trade_good', u'sound', u'in_effect', u'practiced', u'effective', u'commodity', u'estimable', u'well', u'honest', u'near', u'skilful', u'thoroughly', u'serious'])
# set([u'bad', u'badness', u'ill', u'evil', u'evilness'])

# %%
w1 = wordnet.synset("ship.n.01")
w2 = wordnet.synset("boat.n.01")

print(w1.wup_similarity(w2)) # wup = wu & palmer, based on a paper they wrote on semantics

# these words are 91% similar
# Out:
# 0.909090909091

# %%
w1 = wordnet.synset("ship.n.01")
w2 = wordnet.synset("car.n.01")

print(w1.wup_similarity(w2)) # wup = wu & palmer, based on a paper they wrote on semantics

w1 = wordnet.synset("ship.n.01")
w2 = wordnet.synset("cat.n.01")

print(w1.wup_similarity(w2)) # wup = wu & palmer, based on a paper they wrote on semantics
# Out:
# 0.695652173913
# 0.32

# %% [markdown]
# # Lesson 11 - Text Classification

# %% [markdown]
# For sentiment analysis!! In this, to classify things with two choices (ex: spam or not spam, positive or negative sentiment)

# %%
import nltk
import random
from nltk.corpus import movie_reviews

# documents = [(list(movie_reviews.words(fileid)), category)
#             for category in movie_reviews.categories()
#             for fileid in movie_reviews.fileids(category)]

# another way of writing the above
documents = []

for category in movie_reviews.categories():
    for fileid in movie_reviews.fileids(category):
        documents.append((list(movie_reviews.words(fileid.decode('utf-8'))), category))

# we're gonna train and test, and want to make sure train & test sets are not the same to avoid extreme bias
random.shuffle(documents)

print(documents[1])
# Out:
# ([u'devotees', u'of', u'robert', u'a', u'.', u'heinlein', u',', u'be', u'forewarned', u':', u'paul', u'verhoeven', u"'", u's', u'starship', u'troopers', u'is', u'less', u'an', u'adaptation', u'of', u'heinlein', u"'", u's', u'novel', u'than', u'it', u'is', u'a', u'literary', u'satire', u'.', u'the', u'author', u"'", u's', u'jingo', u'-', u'all', u'-', u'the', u'-', u'way', u'militarism', u'and', u'his', u'tendency', u'to', u'create', u'plastic', u'characters', u'with', u'plastic', u'conflicts', u'had', u'me', u'expecting', u'a', u'soulless', u',', u'faceless', u'parade', u'of', u'carnage', u'from', u'the', u'film', u'version', u'.', u'and', u'i', u'suppose', u'that', u"'", u's', u'exactly', u'what', u'verhoeven', u'delivers', u',', u'with', u'sometimes', u'hilarious', u'results', u'.', u'heinlein', u"'", u's', u'basic', u'motifs', u'are', u'so', u'faithfully', u'rendered', u'that', u'their', u'flaws', u'become', u'a', u'source', u'of', u'amusement', u',', u'while', u'their', u'strengths', u'become', u'the', u'stuff', u'of', u'high', u'-', u'energy', u'entertainment', u'.', u'outlining', u'the', u'plot', u'of', u'starship', u'troopers', u'is', u'a', u'fairly', u'silly', u'endeavor', u',', u'since', u'it', u"'", u's', u'basically', u'a', u'big', u'bug', u'hunt', u'.', u'.', u'.', u'aliens', u'in', u'broad', u'daylight', u'.', u'sometime', u'in', u'the', u'future', u',', u'humanity', u'is', u'threatened', u'by', u'giant', u',', u'malevolent', u'insects', u'which', u'have', u'evolved', u'into', u'twenty', u'-', u'foot', u'-', u'tall', u'action', u'figures', u'(', u'arachnids', u'with', u'super', u'-', u'impaling', u'spikes', u',', u'beetles', u'that', u'spew', u'forth', u'lava', u',', u'dragonflies', u'with', u'guillotine', u'legs', u')', u'.', u'among', u'those', u'who', u'sign', u'on', u'to', u'save', u'the', u'earth', u'are', u'a', u'group', u'of', u'high', u'school', u'classmates', u'from', u'buenos', u'aires', u':', u'conflicted', u'rich', u'kid', u'johnny', u'rico', u'(', u'casper', u'van', u'dien', u')', u';', u'his', u'math', u'whiz', u'girlfriend', u'carmen', u'(', u'denise', u'richards', u')', u';', u'dizzy', u'(', u'dina', u'meyer', u')', u',', u'who', u'secretly', u'carries', u'a', u'torch', u'for', u'johnny', u';', u'and', u'carl', u'(', u'neil', u'patrick', u'"', u'doogie', u'howser', u'"', u'harris', u')', u',', u'who', u'not', u'-', u'so', u'-', u'secretly', u'carries', u'a', u'torch', u'for', u'dizzy', u',', u'and', u'also', u'has', u'a', u'talent', u'for', u'speaking', u'telepathically', u'to', u'ferrets', u'.', u'while', u'carmen', u'heads', u'for', u'flight', u'school', u'and', u'carl', u'joins', u'military', u'intelligence', u',', u'johnny', u'and', u'dizzy', u'become', u'mobile', u'infantry', u',', u'their', u'various', u'battles', u'intertwining', u'with', u'romantic', u'sub', u'-', u'plots', u'out', u'of', u'a', u'third', u'season', u'episode', u'from', u'"', u'beverly', u'hills', u'90210', u'.', u'"', u'so', u'if', u'starship', u'troopers', u'is', u'another', u'movie', u'where', u'one', u'-', u'dimensional', u'characters', u'wade', u'through', u'trite', u'situations', u'on', u'their', u'way', u'to', u'killing', u'a', u'bunch', u'of', u'aliens', u',', u'what', u'makes', u'it', u'any', u'better', u'than', u',', u'say', u',', u'independence', u'day', u',', u'a', u'movie', u'where', u'one', u'-', u'dimensional', u'characters', u'waded', u'through', u'trite', u'situations', u'on', u'their', u'way', u'to', u'killing', u'a', u'bunch', u'of', u'slightly', u'different', u'aliens', u'?', u'for', u'one', u'thing', u',', u'you', u'sense', u'that', u'the', u'film', u'-', u'makers', u'are', u'aware', u'of', u'the', u'pulp', u'nonsense', u'they', u'have', u'as', u'source', u'material', u'.', u'the', u'very', u'absence', u'of', u'major', u'stars', u'in', u'the', u'cast', u'feels', u'thematically', u'appropriate', u',', u'not', u'just', u'fiscally', u'prudent', u'.', u'if', u'starship', u'troopers', u'had', u'been', u'turne ...

# %% [markdown]
# #### The above bag of words has a negative sentiment
# What we want to do is take every word from every review, compile them, take that list and find the most popular words used. Then, we'll associated those popular words and see which appear in more popular positive or negative texts. Then we'll classify them. This is a naive bayes classification.

# %%
all_words = []

for w in movie_reviews.words():
    all_words.append(w.lower())
    
# convert all_words to nltk frequency distribution
all_words = nltk.FreqDist(all_words)
print(all_words.most_common(15))
# Out:
# [(u',', 77717), (u'the', 76529), (u'.', 65876), (u'a', 38106), (u'and', 35576), (u'of', 34123), (u'to', 31937), (u"'", 30585), (u'is', 25195), (u'in', 21822), (u's', 18513), (u'"', 17612), (u'it', 16107), (u'that', 15924), (u'-', 15595)]

# %%
# mostly useless stopwords above
print(all_words["stupid"])
# in 2000 movie reviews, the word stupid shows up 253 times
# Out:
# 253

# %% [markdown]
# # Lesson 12 - Words as Features for Learning

# %%
# let's use the most common words, the rest don't matter so much for modeling
# word_features = list(all_words.keys())[:3000]
# this is actually wrong since list(all_words.keys()) does not have any order inside
# to order the top 3000 words, we can do something like:
word_features = [w[0] for w in all_words.most_common(3000)]
# as we can see, there are a lot of stop words in this list. we should consider
# removing the stop words to get better word features, but for now let's leave them in.

def find_features(document):
    words = set(document)
    features = {}
    for w in word_features:
        features[w] = (w in words)

    return features

print((find_features(movie_reviews.words('neg/cv000_29416.txt'))))
# this basically is saying False if the word is not associated with a negative review, and true otherwise

featuresets = [(find_features(rev), category) for (rev, category) in documents]
# Out:
# {u'limited': False, u'suspenseful': False, u'everybody': False, u'four': False, u'woods': False, u'sleep': False, u'hanging': False, u'woody': False, u'captain': False, u'hate': False, u'consider': False, u'relationships': False, u'whose': False, u'buddy': False, u'themes': False, u'paris': False, u'presents': True, u'edward': False, u'whatsoever': False, u'under': False, u'lord': False, u'sorry': False, u'worth': False, u'rescue': False, u'rise': False, u'costume': False, u'hitchcock': False, u'every': True, u'jack': False, u'bringing': False, u'encounter': False, u'school': False, u'skills': False, u'murders': False, u'ups': False, u'clothes': False, u'enjoy': False, u'force': False, u'tired': False, u'miller': False, u'bacon': False, u'direct': False, u'talks': False, u'second': False, u'street': True, u'n': False, u'theory': False, u'even': True, u'established': False, u'saved': False, u'+': False, u'boogie': False, u'revolves': False, u'weren': False, u'above': False, u'cars': False, u'new': True, u'poorly': False, u'ever': True, u'disney': False, u'told': False, u'meg': False, u'hero': False, u'reporter': False, u'mel': False, u'human': False, u'men': False, u'here': True, u'met': False, u'studio': True, u'cult': False, u'path': False, u'100': False, u'dry': False, u'kids': True, u'daughter': False, u'leaves': False, u'changed': False, u'credit': False, u'military': False, u'changes': False, u'golden': False, u'fantastic': False, u'campaign': False, u'julie': False, u'explained': True, u'treatment': False, u'julia': False, u'highly': False, u'brought': False, u'moral': False, u'actions': False, u'total': False, u'sarah': False, u'plot': True, u'charge': False, u'would': True, u'army': False, u'hospital': False, u'arms': False, u'foster': False, u'music': True, u'therefore': False, u'recommend': False, u'strike': False, u'survive': False, u'type': False, u'until': True, u'speaking': False, u'successful': False, u'brings': False, u'wars': False, u'award': False, u'hurt': False, u'phone': False, u'warm': False, u'adult': False, u'excellent': False, u'90': False, u'hole': False, u'hold': False, u'must': False, u'shoot': False, u'directorial': False, u'1993': False, u'word': False, u'room': False, u'1997': False, u'1996': False, u'1999': False, u'1998': False, u'setup': False, u'blade': False, u'movies': True, u'era': False, u'ms': False, u'mr': False, u'my': True, u'example': False, u'gloria': False, u'initial': False, u'saturday': False, u'give': True, u'climax': False, u'laughs': False, u'increasingly': False, u'want': True, u'times': False, u'risk': False, u'end': False, u'thing': False, u'provide': False, u'travel': False, u'sitting': True, u'feature': False, u'machine': False, u'how': True, u'amazing': False, u'writers': False, u'kilmer': False, u'answer': False, u'ordinary': False, u'beach': False, u'gordon': False, u'badly': False, u'pig': False, u'elizabeth': False, u'beauty': True, u'mess': True, u'after': True, u'wrong': False, u'president': False, u'law': False, u'types': True, u'las': False, u'danny': False, u'attempt': True, u'third': False, u'shrek': False, u'appreciate': False, u'lost': True, u'subplots': False, u'childhood': False, u'green': False, u'ultimate': False, u'keeps': False, u'worst': False, u'order': False, u'wind': False, u'blind': False, u'executed': True, u'office': False, u'enter': True, u'over': True, u'murray': False, u'london': False, u'before': True, u'fit': False, u'personal': False, u'screaming': False, u'blown': False, u',': True, u'writing': False, u'better': False, u'production': True, u'compelling': False, u'hidden': False, u'overcome': False, u'then': True, u'them': False, u'combination': False, u'safe': False, u'break': True, u'band': False, u'bang': False, u'effects': False, u'they': True, u'one': True, u'silver': False, u'bank': False, u'alex': False, u'rocky': False, u'debut': False, u'l': False, u'grows': False, u'wooden': False, u'each': False, u'went': False, u'side': False, u ...

# %% [markdown]
# # Lesson 13 - Naive Bayes

# %% [markdown]
# The algorithm of choice, at least at a basic level, for text analysis is often the Naive Bayes classifier. Part of the reason for this is that text data is almost always massive in size. The Naive Bayes algorithm is so simple that it can be used at scale very easily with minimal process requirements.

# %%
training_set = featuresets[:1900]
testing_set = featuresets[1900:]

# This is the algorithm calculation:
# posterior = prior occurences x likelihood / evidence
# the above gives us the likelihood of something to be positive (or negative). It's not the best algorithm,
# but it's scalable and easy to use

classifier = nltk.NaiveBayesClassifier.train(training_set)
print("Naive Bayes Algo accuracy:", (nltk.classify.accuracy(classifier, testing_set))*100)
classifier.show_most_informative_features(15)
# none of the top 15 words contained grammar. Grammar doesn't matter much in a large dataset, or it's not an informative feature
# Out:
# ('Naive Bayes Algo accuracy:', 84.0)
# Most Informative Features
#              outstanding = True              pos : neg    =     10.6 : 1.0
#                   finest = True              pos : neg    =      9.0 : 1.0
#                    mulan = True              pos : neg    =      8.8 : 1.0
#              beautifully = True              pos : neg    =      8.4 : 1.0
#              wonderfully = True              pos : neg    =      7.6 : 1.0
#                   seagal = True              neg : pos    =      7.1 : 1.0
#               schumacher = True              neg : pos    =      6.7 : 1.0
#                   prinze = True              neg : pos    =      6.7 : 1.0
#                   alicia = True              neg : pos    =      6.7 : 1.0
#                   wasted = True              neg : pos    =      6.1 : 1.0
#                    damon = True              pos : neg    =      6.0 : 1.0
#                    inept = True              neg : pos    =      5.6 : 1.0
#                   ripley = True              pos : neg    =      5.6 : 1.0
#                     lame = True              neg : pos    =      5.5 : 1.0
#                    awful = True              neg : pos    =      5.3 : 1.0

# %% [markdown]
# # Lesson 14 - Save Classifier with Pickle

# %% [markdown]
# As you will likely find with any form of data analysis, there is going to be some sort of processing bottleneck, that you repeat over and over, often yielding the same object in Python memory.
#
# Examples of this might be loading a massive dataset into memory, some basic pre-processing of a static dataset, or, like in our case, the training of a classifier.
#
# In our case, we spend much time on training our classifier, and soon we may add more. It is a wise choice to go ahead and pickle the trained classifer. This way, we can load in the trained classifier in a matter of milliseconds, rather than waiting 3-5+ minutes for the classifier to be trained.

# %%
import pickle

save_classifier = open("naive_bayes.pickle", "wb")
pickle.dump(classifier, save_classifier)
save_classifier.close()

# %%
# lets open the pickle file now
classifier_f = open("naive_bayes.pickle", "rb")
classifier = pickle.load(classifier_f)
classifier_f.close()

# let's see how it does this time

word_features = [w[0] for w in all_words.most_common(3000)]

featuresets = [(find_features(rev), category) for (rev, category) in documents]

training_set = featuresets[:1900]
testing_set = featuresets[1900:]

print("Naive Bayes Algo accuracy:", (nltk.classify.accuracy(classifier, testing_set))*100)
classifier.show_most_informative_features(15)
# Out:
# ('Naive Bayes Algo accuracy:', 60.842273453549424)
# Most Informative Features
#              outstanding = True              pos : neg    =     10.6 : 1.0
#                   finest = True              pos : neg    =      9.0 : 1.0
#                    mulan = True              pos : neg    =      8.8 : 1.0
#              beautifully = True              pos : neg    =      8.4 : 1.0
#              wonderfully = True              pos : neg    =      7.6 : 1.0
#                   seagal = True              neg : pos    =      7.1 : 1.0
#               schumacher = True              neg : pos    =      6.7 : 1.0
#                   prinze = True              neg : pos    =      6.7 : 1.0
#                   alicia = True              neg : pos    =      6.7 : 1.0
#                   wasted = True              neg : pos    =      6.1 : 1.0
#                    damon = True              pos : neg    =      6.0 : 1.0
#                    inept = True              neg : pos    =      5.6 : 1.0
#                   ripley = True              pos : neg    =      5.6 : 1.0
#                     lame = True              neg : pos    =      5.5 : 1.0
#                    awful = True              neg : pos    =      5.3 : 1.0

# %%
testing_set[1]
# Out:
# ({u'writings': False,
#   u'magnetic': False,
#   u'saves': False,
#   u'foul': False,
#   u'sleek': False,
#   u'four': False,
#   u'woods': False,
#   u'asian': False,
#   u'hanging': False,
#   u'woody': False,
#   u'comically': False,
#   u'marching': False,
#   u'relationships': False,
#   u'psychopathic': False,
#   u'endings': False,
#   u'presents': False,
#   u'superficially': False,
#   u'bike': False,
#   u'xtc': False,
#   u'lord': False,
#   u'immature': False,
#   u'worth': False,
#   u'alternating': False,
#   u'compassion': False,
#   u'blanket': False,
#   u'hilarious': False,
#   u'sellers': False,
#   u'manic': False,
#   u'leisurely': False,
#   u'bringing': False,
#   u'tickets': False,
#   u'wednesday': False,
#   u'relentlessly': False,
#   u'deceptions': False,
#   u'stereotypical': False,
#   u'eye-popping': False,
#   u'undercover': False,
#   u'build-up': False,
#   u'clothes': False,
#   u'wisegirls': False,
#   u'chew': False,
#   u'sturm': False,
#   u'diverting': False,
#   u'tired': False,
#   u'miller': False,
#   u'pulse': False,
#   u'elegant': False,
#   u'second': False,
#   u'sterile': False,
#   u'paulette': False,
#   u'admire': False,
#   u'stardom': False,
#   u'deliberate': False,
#   u'ruthless': False,
#   u'contributed': False,
#   u'fingers': False,
#   u'asia': False,
#   u'cars': False,
#   u'struggled': False,
#   u'ever': False,
#   u'succumb': False,
#   u'shocks': False,
#   u'disappoint': False,
#   u'widget': False,
#   u'hero': False,
#   u'sinks': False,
#   u'intentioned': False,
#   u'revels': False,
#   u'never': False,
#   u'equals': False,
#   u'here': False,
#   u'china': False,
#   u'personified': False,
#   u'cult': False,
#   u'self-absorption': False,
#   u'celebration': False,
#   u'dry': False,
#   u'kids': True,
#   u'daughter': False,
#   u'uplifting': False,
#   u'pretensions': False,
#   u'elaborate': False,
#   u'vulnerability': False,
#   u'controversy': False,
#   u'hokey': False,
#   u'cogent': False,
#   u'chilling': False,
#   u'smoke': False,
#   u'military': False,
#   u'midway': False,
#   u'smoochy': False,
#   u'golden': False,
#   u'envious': False,
#   u'muccino': False,
#   u'divide': False,
#   u'ground': False,
#   u'spooky': False,
#   u'flotsam': False,
#   u'psychological': False,
#   u'neil': False,
#   u'hindsight': False,
#   u'compulsively': False,
#   u'taymor': False,
#   u'total': False,
#   u'sarah': False,
#   u'originality': False,
#   u'palestinian': False,
#   u'gloss': False,
#   u'chooses': False,
#   u'cannibal': False,
#   u'music': False,
#   u'strike': False,
#   u'indiana': False,
#   u'until': False,
#   u'fragmentary': False,
#   u'borstal': False,
#   u'holy': False,
#   u'successful': False,
#   u'brings': False,
#   u'hanussen': False,
#   u'infusion': False,
#   u'reign': False,
#   u'hurt': False,
#   u'glass': False,
#   u'holm': False,
#   u'adult': False,
#   u'90': False,
#   u'midst': False,
#   u'hold': False,
#   u'94': False,
#   u'authentically': False,
#   u'circumstances': False,
#   u'springer': False,
#   u'morally': False,
#   u'1995': False,
#   u'room': False,
#   u'huppert': False,
#   u'1998': False,
#   u'blade': False,
#   u'era': False,
#   u'ms': False,
#   u'mr': False,
#   u'elegantly': False,
#   u'example': False,
#   u'scripting': False,
#   u'wang': False,
#   u'indie': False,
#   u'dragons': False,
#   u'currency': False,
#   u'fanciful': False,
#   u'want': False,
#   u'answers': False,
#   u'absolute': False,
#   u'farce': False,
#   u'provide': False,
#   u'travel': False,
#   u'feature': False,
#   u'machine': False,
#   u'how': False,
#   u'hot': False,
#   u'rookie': False,
#   u'puns': False,
#   u'ordinary': False,
#   u'beach': False,
#   u'lan': False,
#   u'beauty': False,
#   u'earlier': False,
#   u'hong': False,
#   u'despondent': False,
#   u'shores': False,
#   u'wrong': False,
#   u'kwan': False,
#   u'considers': False,
#   u'destined': False,
#   u'lau': False,
#   u'law': False,
#   u'types': False,
#   u'chilled': False,
#   u'padre': False,
#   u'effective': False,
#   u'alienate': False,
#   u'wins': False,
#   u'grant': False,
#   u'appreciate': False,
#   u'fictional': False,
#   u'sickening': False,
#   u'baggage': False,
#   u'davies': False,
#   u'keeps': False,
#   u'worst': False,
#   u'nonsensical': False,
#   u'order': False,
#   u'backdrop': False,
#   u'blind': False,
#   u'modesty': False,
#   u'office': False,
#   u'dreamed': False,
#   u'satisfied': False,
#   u'innovative': False,
#   u'japan': False,
#   u'rewarded': False,
#   u'greengrass': False,
#   u'bombing': False,
#   u'admirably': False,
#   u'lovingly': False,
#   u'fit': False,
#   u'somewhere': False,
#   u'screaming': False,
#   u'fix': False,
#   u'stevens': False,
#   u'survivors': False,
#   u'implausibility': False,
#   u'production': False,
#   u'understated': False,
#   u'hidden': False,
#   u'admirable': False,
#   u'easier': False,
#   u'versus': False,
#   u'then': False,
#   u'them': False,
#   u'jerking': False,
#   u'safe': False,
#   u'break': False,
#   u'band': False,
#   u'bang': False,
#   u'detachment': False,
#   u'effects': False,
#   u'they': False,
#   u'schools': False,
#   u'low-tech': False,
#   u'lifelong': False,
#   u'silver': False,
#   u'bank': False,
#   u'ebullient': False,
#   u'pervasive': False,
#   u'represents': False,
#   u'rocky': False,
#   u'ascends': False,
#   u'debut': False,
#   u'l': False,
#   u'arrow': False,
#   u'meal': False,
#   u'luck': False,
#   u'preceded': False,
#   u'schemes': False,
#   u'series': False,
#   u'crimes': False,
#   u'spider': False,
#   u'yiddish': False,
#   u'crimen': False,
#   u'ring': False,
#   u'smirk': False,
#   u'tried': False,
#   u'cameras': False,
#   u'strangers': False,
#   u'forte': False,
#   u"'em": False,
#   u'medicine': False,
#   u'self-important': False,
#   u'size': False,
#   u'forth': False,
#   u'foundation': False,
#   u'assaults': False,
#   u'assured': False,
#   u'tops': False,
#   u'threatened': False,
#   u'sheer': False,
#   u'standard': False,
#   u'amazement': False,
#   u'9-11': False,
#   u'incorporates': False,
#   u'enormous': False,
#   u'bates': False,
#   u'exposing': False,
#   u'created': False,
#   u'creates': False,
#   u'disturbed': False,
#   u'speedy': False,
#   u'triumph': False,
#   u'tempting': False,
#   u'1970s': False,
#   u'uses': False,
#   u'quirkiness': False,
#   u'breed': False,
#   u'features': False,
#   u'subtlety': False,
#   u'hoot': False,
#   u'channels': False,
#   u'haunting': False,
#   u'spinning': False,
#   u'another': False,
#   u'comic': False,
#   u'clarity': False,
#   u'170': False,
#   u'basketball': False,
#   u'service': False,
#   u'similarly': False,
#   u'fiction': False,
#   u'needed': False,
#   u'airs': False,
#   u'master': False,
#   u'observations': False,
#   u'phones': False,
#   u'swingers': False,
#   u'john': False,
#   u'bitter': False,
#   u'listen': False,
#   u'danish': False,
#   u'rewards': False,
#   u'collapse': False,
#   u'predictably': False,
#   u'wisdom': False,
#   u'predictable': False,
#   u'legally': False,
#   u'wasted': False,
#   u'peculiar': False,
#   u'positively': False,
#   u'mercy': False,
#   u'trek': False,
#   u'chases': False,
#   u'target': False,
#   u'preaches': False,
#   u'likely': False,
#   u'tackles': False,
#   u'godard': False,
#   u'project': False,
#   u'guilt': False,
#   u'williams': False,
#   u'childlike': False,
#   u'k': False,
#   u'feeling': False,
#   u'powers': False,
#   u'minus': False,
#   u'este': False,
#   u'fashion': False,
#   u'willingness': False,
#   u'runner': False,
#   u'pessimism': False,
#   u'manner': False,
#   u'corny': False,
#   u'high-minded': False,
#   u'dozen': False,
#   u'forced': False,
#   u'strength': False,
#   u'wholesome': False,
#   u'hispanic': False,
#   u'convenient': False,
#   u'latter': False,
#   u'responsible': False,
#   u'aptly': False,
#   u'mean-spirited': False,
#   u'recommended': False,
#   u'subjects': False,
#   u'amusing': False,
#   u'doors': False,
#   u'season': False,
#   u'swims': False,
#   u'circles': False,
#   u'established': False,
#   u'bruce': False,
#   u'object': False,
#   u'cinematic': False,
#   u'disjointed': False,
#   u'regular': False,
#   u'mouth': False,
#   u'reverence': False,
#   u'scripts': False,
#   u'thriller': False,
#   u'morality': False,
#   u'camps': False,
#   u'episode': False,
#   u'observation': False,
#   u'medical': False,
#   u'camp': False,
#   u'm': False,
#   u'fessenden': False,
#   u'points': False,
#   u'consummate': False,
#   u'profundity': False,
#   u'er': False,
#   u'scream': False,
#   u'came': False,
#   u'marvel': False,
#   u'decidedly': False,
#   u'saying': False,
#   u'subtly': False,
#   u'lewis': False,
#   u'probe': False,
#   u'precarious': False,
#   u'nominated': False,
#   u'padded': False,
#   u'sexism': False,
#   u'earth': False,
#   u'enjoyed': False,
#   u'fixating': False,
#   u'traditions': False,
#   u'caper': False,
#   u'witnesses': False,
#   u'touches': False,
#   u'busy': False,
#   u'painfully': False,
#   u'quaint': False,
#   u'sentence': False,
#   u'self-glorification': False,
#   u'bust': False,
#   u'than': False,
#   u'bush': False,
#   u'touched': False,
#   u'rich': False,
#   u'adequate': False,
#   u'rice': False,
#   u'personality': False,
#   u'predecessor': False,
#   u'plate': False,
#   u'godzilla': False,
#   u'culkin': False,
#   u'de': False,
#   u'da': False,
#   u'pocket': False,
#   u'gored': False,
#   u'underwritten': False,
#   u'haunted': False,
#   u'altogether': False,
#   u'dv': False,
#   u'dr': False,
#   u'slack': False,
#   u'runs': False,
#   u'nicely': False,
#   u'puffery': False,
#   u'stunningly': False,
#   u'release': False,
#   u'wannabe': False,
#   u'told': False,
#   u'steal': False,
#   u'steam': False,
#   u'secretary': False,
#   u'respond': False,
#   u'disaster': False,
#   u'fair': False,
#   u'sensitivity': False,
#   u'epochs': False,
#   u'bled': False,
#   u'depends': False,
#   u'expedience': False,
#   u'result': False,
#   u'holding': False,
#   u'fail': False,
#   u'channeling': False,
#   u'best': False,
#   u'subject': False,
#   u'draws': False,
#   u'ambitions': False,
#   u'lots': False,
#   u'ringu': False,
#   u'afloat': False,
#   u'rings': False,
#   u'future': False,
#   u'conceptual': False,
#   u'drawn': False,
#   u'misguided': False,
#   u'failings': False,
#   u'screwball': False,
#   u'loose': False,
#   u'terms': False,
#   u'nationwide': False,
#   u'nature': False,
#   u'rolled': False,
#   u'handful': False,
#   u'weary': False,
#   u'unseemly': False,
#   u'extent': False,
#   u'defiance': False,
#   u'debt': False,
#   u'kitchen': False,
#   u'pity': False,
#   u'cop': False,
#   u'essentially': False,
#   u'accident': False,
#   u'sacrificing': False,
#   u'disdain': False,
#   u'country': False,
#   u'ill': False,
#   u'adventures': False,
#   u'orwell': False,
#   u'didactic': False,
#   u'planned': False,
#   u'logic': False,
#   u'argue': False,
#   u'adapted': False,
#   u'old-fashioned': False,
#   u'con': False,
#   u'tough': False,
#   u'irresponsible': False,
#   u'nonconformist': False,
#   u'condescending': False,
#   u'stillborn': False,
#   u'illness': False,
#   u'tony': False,
#   u'blonde': False,
#   u'fudges': False,
#   u'speak': False,
#   u'unhappily': False,
#   u'puts': False,
#   u'.': True,
#   u'bothers': False,
#   u'desta': False,
#   u'much': False,
#   u'makhmalbaf': False,
#   u'jackass': False,
#   u'incompetent': False,
#   u'dots': False,
#   u'doldrums': False,
#   u'life': False,
#   u'families': False,
#   u'innocent': False,
#   u'eastern': False,
#   u'filmmaker': False,
#   u'coherent': False,
#   u'substance': False,
#   u"'70s": False,
#   u'child': False,
#   u'worked': False,
#   u'crossover': False,
#   u'spin': False,
#   u'postmodern': False,
#   u'modern-day': False,
#   u'chill': False,
#   u'sheridan': False,
#   u'gritty': False,
#   u'adaptations': False,
#   u'remakes': False,
#   u'pungent': False,
#   u'castro': False,
#   u'air': False,
#   u'employ': False,
#   u'entertains': False,
#   u'aid': False,
#   u'voice': False,
#   u'anchor': False,
#   u'skirts': False,
#   u'mistake': False,
#   u'remembering': False,
#   u'unease': False,
#   u'cons': False,
#   u'schaeffer': False,
#   u'played': False,
#   u'sting': False,
#   u'weirdness': False,
#   u'audrey': False,
#   u'elicit': False,
#   u'dizzy': False,
#   u'upscale': False,
#   u'creepy': False,
#   u'madonna': False,
#   u'kurys': False,
#   u'damaged': False,
#   u'jolting': False,
#   u'things': False,
#   u'yellow': False,
#   u'cumulative': False,
#   u'jerry': False,
#   u'rebellion': False,
#   u'haphazard': False,
#   u'potentially': False,
#   u'avoids': False,
#   u'monarch': False,
#   u'convictions': False,
#   u'showing': False,
#   u'european': False,
#   u'fairly': False,
#   u'effortlessly': False,
#   u'inadvertently': False,
#   u'nod': False,
#   u'middle-aged': False,
#   u'rain': False,
#   u'hand': False,
#   u'norwegian': False,
#   u'fish-out-of-water': False,
#   u'toback': False,
#   u'preachy': False,
#   u'crushingly': False,
#   u'tune': False,
#   u'kept': False,
#   u'lucas': False,
#   u'scenario': False,
#   u'1975': False,
#   u'humble': False,
#   u'game': False,
#   u'ragged': False,
#   u'academic': False,
#   u'contact': False,
#   u'the': False,
#   u'backhanded': False,
#   u'corporate': False,
#   u'musical': False,
#   u'solaris': False,
#   u'letterman': False,
#   u'absurdities': False,
#   u'appropriately': False,
#   u'photo': False,
#   u'sporting': False,
#   u'newton': False,
#   u'forsaken': False,
#   u'thanks': False,
#   u'human': False,
#   u'stultifyingly': False,
#   u'plight': False,
#   u'portrayed': False,
#   u'previous': False,
#   u'nicolas': False,
#   u'adding': False,
#   u'enters': False,
#   u'ham': False,
#   u'photographer': False,
#   u'ease': False,
#   u'had': False,
#   u'fresh-faced': False,
#   u'topical': False,
#   u'shout': False,
#   u'belongs': False,
#   u'board': False,
#   u'easy': False,
#   u'prison': False,
#   u'has': False,
#   u'hat': False,
#   u'humanity': False,
#   u'photographed': False,
#   u'survival': False,
#   u'possible': False,
#   u'retread': False,
#   u'unequivocally': False,
#   u'possibly': False,
#   u'otherworldly': False,
#   u'birth': False,
#   u'shadow': False,
#   u'poses': False,
#   u'retreat': False,
#   u'brought': False,
#   u'bobby': False,
#   u'alice': False,
#   u'soap': False,
#   u'remind': False,
#   u'sparse': False,
#   u'night': False,
#   u'lapses': False,
#   u'notorious': False,
#   u'grotesquely': False,
#   u'saccharine': False,
#   u'unabashedly': False,
#   u'right': False,
#   u'old': False,
#   u'crowd': False,
#   u'people': False,
#   u'macabre': False,
#   u'somehow': False,
#   u'elderly': False,
#   u'born': False,
#   u'productions': False,
#   u'kieslowski': False,
#   u'confusing': False,
#   u'sociology': False,
#   u'humor': False,
#   u'for': False,
#   u'bottom': False,
#   u'phenomenal': False,
#   u'inhuman': False,
#   u'comments': False,
#   u'creative': False,
#   u'witty': False,
#   u'filming': False,
#   u'asking': False,
#   u'exposition': False,
#   u'denied': False,
#   u'triste': False,
#   u'palatable': False,
#   u'columbus': False,
#   u'shakes': False,
#   u'biopic': False,
#   u'plot': False,
#   u'marketing': False,
#   u'conventional': False,
#   u'starring': False,
#   u'losing': False,
#   u'memorable': False,
#   u'finding': False,
#   u'transcends': False,
#   u'empowerment': False,
#   u'impenetrable': False,
#   u'innuendo': False,
#   u'months': False,
#   u'o': False,
#   u'magazine': False,
#   u'despair': False,
#   u'repellent': False,
#   u'spins': False,
#   u'cherish': False,
#   u'slightly': False,
#   u'jacques': False,
#   u'raised': False,
#   u'contains': False,
#   u'dilemma': False,
#   u'pays': False,
#   u'profession': False,
#   u'delighted': False,
#   u'son': False,
#   u'lies': False,
#   u'raises': False,
#   u'wrap': False,
#   u'honored': False,
#   u'shoots': False,
#   u'stumble': False,
#   u'strangely': False,
#   u'east': False,
#   u'deception': False,
#   u'fabric': False,
#   u'support': False,
#   u'constantly': False,
#   u'convincing': False,
#   u'unfocused': False,
#   u'fight': False,
#   u'joseph': False,
#   u'way': False,
#   u'greatness': False,
#   u'jane': False,
#   u'quirky': False,
#   u'was': False,
#   u'trappings': False,
#   u'happy': False,
#   u'underestimated': False,
#   u'infomercial': False,
#   u'offering': False,
#   u'offer': False,
#   u'fascination': False,
#   u'becoming': False,
#   u'vitality': False,
#   u'co-writer': False,
#   u'failure': False,
#   u'talents': False,
#   u'understandable': False,
#   u'true': False,
#   u'throw': False,
#   u'silliness': False,
#   u'urgent': False,
#   u'invincible': False,
#   u'inside': False,
#   u'mtv': False,
#   u'maximum': False,
#   u'devices': False,
#   u'crystal': False,
#   u'heartstrings': False,
#   u'complications': False,
#   u'lays': False,
#   u'rerun': False,
#   u'emotional': False,
#   u'terminally': False,
#   u'temper': False,
#   u'juvenile': False,
#   u'proved': False,
#   u'moore': False,
#   u'barrymore': False,
#   u'metaphysical': False,
#   u'abstract': False,
#   u'textbook': False,
#   u'evidence': False,
#   u'howling': False,
#   u'proves': False,
#   u'exist': False,
#   u'promised': False,
#   u'lumpen': False,
#   u'ship': False,
#   u'mold': False,
#   u'physical': False,
#   u'eventual': False,
#   u'floor': False,
#   u'stake': False,
#   u'generally': False,
#   u'actor': False,
#   u'reality': False,
#   u'one-joke': False,
#   u'conjures': False,
#   u'interested': False,
#   u'wollter': False,
#   u'ambitious': False,
#   u'escapism': False,
#   u'test': False,
#   u'superfluous': False,
#   u'roll': False,
#   u'scored': False,
#   u"'s": False,
#   u'brothers': False,
#   u'welcome': False,
#   u'illogic': False,
#   u'update': False,
#   u'improvisation': False,
#   u"'d": False,
#   u'palma': False,
#   u"'a": False,
#   u'scores': False,
#   u'rolling': False,
#   u'transporter': False,
#   u"'m": False,
#   u"'i": False,
#   u'regime': False,
#   u'spader': False,
#   u'excuse': False,
#   u'ferrara': False,
#   u'cathartic': False,
#   u'together': False,
#   u'loyal': False,
#   u'good-natured': False,
#   u'time': True,
#   u'push': False,
#   u'paced': False,
#   u'songs': False,
#   u'breadth': False,
#   u'concept': False,
#   u'chain': False,
#   u'dance': False,
#   u'skip': False,
#   u'themes': False,
#   u'crocodile': False,
#   u'avalanche': False,
#   u'manages': False,
#   u'jarring': False,
#   u'battle': False,
#   u'primer': False,
#   u'layers': False,
#   u'ballet': False,
#   u'uneven': False,
#   u'ver': False,
#   u'zone': False,
#   u'rousing': False,
#   u'flash': False,
#   u'vez': False,
#   u'compensate': False,
#   u'ararat': False,
#   u'rhythm': False,
#   u'terror': False,
#   u'uma': False,
#   u'over-the-top': False,
#   u'counter-cultural': False,
#   u'zhang': False,
#   u'seemingly': False,
#   u'choice': False,
#   u'1992': False,
#   u'serrault': False,
#   u'stays': False,
#   u'trouble': False,
#   u'blast': False,
#   u'minute': False,
#   u'cool': False,
#   u'aggressively': False,
#   u'presented': False,
#   u'tear': False,
#   u'turns': False,
#   u'fragile': False,
#   u'gun': False,
#   u'leave': False,
#   u'p': False,
#   u'engrossing': False,
#   u'live-action': False,
#   u'team': False,
#   u'speculation': False,
#   u'upper': False,
#   u'spiritual': False,
#   u'work': False,
#   u'regret': False,
#   u'peek': False,
#   u'collage': False,
#   u'hindered': False,
#   u'rouge': False,
#   u'discover': False,
#   u'sign': False,
#   u'professionalism': False,
#   u'erotic': False,
#   u'cost': False,
#   u'long-suffering': False,
#   u'sordid': False,
#   u'enticing': False,
#   u'curse': False,
#   u'appear': False,
#   u'cremaster': False,
#   u'trivial': False,
#   u'takashi': False,
#   u'celebrated': False,
#   u'shares': False,
#   u'current': False,
#   u'freaks': False,
#   u'falling': False,
#   u'appeal': False,
#   u'self-preservation': False,
#   u'unintentionally': False,
#   u'satisfy': False,
#   u'creepiest': False,
#   u'explosion': False,
#   u'funeral': False,
#   u'plucking': False,
#   u'understanding': False,
#   u'nemesis': False,
#   u'alone': False,
#   u'along': False,
#   u'teaches': False,
#   u'teacher': False,
#   u'change': False,
#   u'bygone': False,
#   u'redemption': False,
#   u'brilliant': False,
#   u'title': False,
#   u'behan': False,
#   u'trial': False,
#   u'accomplished': False,
#   u'bangs': False,
#   u'franklin': False,
#   u'suggestion': False,
#   u'usually': False,
#   u'myers': False,
#   u'plotted': False,
#   u'love': False,
#   u'extra': False,
#   u'schlocky': False,
#   u'bloody': False,
#   u'uphill': False,
#   u'marvelous': False,
#   u'fake': False,
#   u'nauseating': False,
#   u'relating': False,
#   u'disguising': False,
#   u'yourself': False,
#   u'crammed': False,
#   u'anim\u0103\u0161': False,
#   u'working': False,
#   u'prove': False,
#   u'positive': False,
#   u'angry': False,
#   u'visit': False,
#   u'only': False,
#   u"'love": False,
#   u'live': False,
#   u'opposed': False,
#   u'wondering': False,
#   u'films': False,
#   u'angels': False,
#   u'loving': False,
#   u'introducing': False,
#   u'``': False,
#   u'dramatizing': False,
#   u'zwick': False,
#   u'fast-moving': False,
#   u'apparent': False,
#   u'envelope': False,
#   u'visual': False,
#   u'everywhere': False,
#   u'virtue': False,
#   u'behalf': False,
#   u'graphic': False,
#   u'deserved': False,
#   u'car': False,
#   u'believer': False,
#   u'believes': False,
#   u'values': False,
#   u'can': False,
#   u'cal': False,
#   u'following': False,
#   u'gunfire': False,
#   u'heart': False,
#   u'awesome': False,
#   u'topic': False,
#   u'heard': False,
#   u'purity': False,
#   u'allowed': False,
#   u'winter': False,
#   u'unintentional': False,
#   u'fortunately': False,
#   u'discussion': False,
#   u'statham': False,
#   u'strays': False,
#   u'lips': False,
#   u'nonstop': False,
#   u'anime': False,
#   u'snaps': False,
#   u'rigors': False,
#   u'dampened': False,
#   u'hypnotically': False,
#   u'spot': False,
#   u'high-energy': False,
#   u'convincingly': False,
#   u'explored': False,
#   u'wistful': False,
#   u'date': False,
#   u'such': False,
#   u'suck': False,
#   u'dahmer': False,
#   u'revealed': False,
#   u'shockingly': False,
#   u'harmon': False,
#   u'stress': False,
#   u'surfing': False,
#   u'natural': False,
#   u'highlights': False,
#   u'whenever': False,
#   ...},
#  'pos')

# %% [markdown]
# # Lesson 15 - Scikit-Learn Incorporation with NLTK

# %%
from nltk.classify.scikitlearn import SklearnClassifier
from sklearn.naive_bayes import MultinomialNB, GaussianNB, BernoulliNB

print("Original Naive Bayes Algo accuracy:", (nltk.classify.accuracy(classifier, testing_set))*100)
classifier.show_most_informative_features(15)

# Multinomial NB
MNB_classifier = SklearnClassifier(MultinomialNB())
MNB_classifier.train(training_set)
print("MNB_classifier accuracy percent:", (nltk.classify.accuracy(MNB_classifier, testing_set))*100)

# Gaussian
# GaussianNB_classifier = SklearnClassifier(GaussianNB())
# GaussianNB_classifier.train(training_set)
# print("GaussianNB_classifier accuracy percent:", (nltk.classify.accuracy(GaussianNB_classifier, testing_set))*100)

# Bernoulli
BernoulliNB_classifier = SklearnClassifier(BernoulliNB())
BernoulliNB_classifier.train(training_set)
print("BernoulliNB_classifier accuracy percent:", (nltk.classify.accuracy(BernoulliNB_classifier, testing_set))*100)
# Out:
# ('Original Naive Bayes Algo accuracy:', 84.0)
# Most Informative Features
#              outstanding = True              pos : neg    =     10.6 : 1.0
#                   finest = True              pos : neg    =      9.0 : 1.0
#                    mulan = True              pos : neg    =      8.8 : 1.0
#              beautifully = True              pos : neg    =      8.4 : 1.0
#              wonderfully = True              pos : neg    =      7.6 : 1.0
#                   seagal = True              neg : pos    =      7.1 : 1.0
#                   prinze = True              neg : pos    =      6.7 : 1.0
#               schumacher = True              neg : pos    =      6.7 : 1.0
#                   alicia = True              neg : pos    =      6.7 : 1.0
#                   wasted = True              neg : pos    =      6.1 : 1.0
#                    damon = True              pos : neg    =      6.0 : 1.0
#                    inept = True              neg : pos    =      5.6 : 1.0
#                   ripley = True              pos : neg    =      5.6 : 1.0
#                     lame = True              neg : pos    =      5.5 : 1.0
#                    awful = True              neg : pos    =      5.3 : 1.0
# ('MNB_classifier accuracy percent:', 90.0)
# ('BernoulliNB_classifier accuracy percent:', 84.0)

# %%
# NOTE: all of these models are using default parameters. When you study and understand the parameters,
# then you can tune them to improve the accuracy of the models.
from sklearn.linear_model import LogisticRegression, SGDClassifier
from sklearn.svm import SVC, LinearSVC, NuSVC

LogisticRegression_classifier = SklearnClassifier(LogisticRegression())
LogisticRegression_classifier.train(training_set)
print("LogisticRegression_classifier accuracy percent:", (nltk.classify.accuracy(LogisticRegression_classifier, testing_set))*100)

SGDClassifier_classifier = SklearnClassifier(SGDClassifier())
SGDClassifier_classifier.train(training_set)
print("SGDClassifier_classifier accuracy percent:", (nltk.classify.accuracy(SGDClassifier_classifier, testing_set))*100)

SVC_classifier = SklearnClassifier(SVC())
SVC_classifier.train(training_set)
print("SVC_classifier accuracy percent:", (nltk.classify.accuracy(SVC_classifier, testing_set))*100)

LinearSVC_classifier = SklearnClassifier(LinearSVC())
LinearSVC_classifier.train(training_set)
print("LinearSVC_classifier accuracy percent:", (nltk.classify.accuracy(LinearSVC_classifier, testing_set))*100)

NuSVC_classifier = SklearnClassifier(NuSVC())
NuSVC_classifier.train(training_set)
print("NuSVC_classifier accuracy percent:", (nltk.classify.accuracy(NuSVC_classifier, testing_set))*100)
# Out:
# /Users/andrewrubino/anaconda2/lib/python2.7/site-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# ('LogisticRegression_classifier accuracy percent:', 83.0)
# /Users/andrewrubino/anaconda2/lib/python2.7/site-packages/sklearn/linear_model/stochastic_gradient.py:166: FutureWarning: max_iter and tol parameters have been added in SGDClassifier in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   FutureWarning)
# ('SGDClassifier_classifier accuracy percent:', 80.0)
# /Users/andrewrubino/anaconda2/lib/python2.7/site-packages/sklearn/svm/base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# ('SVC_classifier accuracy percent:', 86.0)
# ('LinearSVC_classifier accuracy percent:', 77.0)
# ('NuSVC_classifier accuracy percent:', 85.0)

# %% [markdown]
# # Lesson 16 - Combining Algos with a Vote

# %% [markdown]
# Now that we have many classifiers, what if we created a new classifier, which combined the votes of all of the classifiers, and then classified the text whatever the majority vote was?
#
# Turns out, doing this is super easy. NLTK has considered this in advance, allowing us to inherit from their ClassifierI class from nltk.classify, which will give us the attributes of a classifier, yet allow us to write our own custom classifier code.

# %%
# Take the models from above, but remove SVC (cuz that's what he does since the accuracy is low)
from nltk.classify import ClassifierI
from statistics import mode

class VoteClassifier(ClassifierI):
    def __init__(self, *classifiers):
        self._classifiers = classifiers
        
    def classify(self, features):
        votes = []
        for c in self._classifiers:
            v = c.classify(features)
            votes.append(v)
        return mode(votes)
    
    def confidence(self, features):
        votes = []
        for c in self._classifiers:
            v = c.classify(features)
            votes.append(v)
            
        choice_votes = votes.count(mode(votes))
        conf = float(choice_votes) / len(votes)
        return conf

# %%
voted_classifier = VoteClassifier(classifier, MNB_classifier, BernoulliNB_classifier,
                                  LogisticRegression_classifier, SGDClassifier_classifier, 
                                  LinearSVC_classifier, NuSVC_classifier)

print("voted_classifier accuracy percent:", (nltk.classify.accuracy(voted_classifier, testing_set))*100)

print("Classification:", voted_classifier.classify(testing_set[0][0]),
      "Confidence %:", voted_classifier.confidence(testing_set[0][0])*100)
print("Classification:", voted_classifier.classify(testing_set[1][0]),
      "Confidence %:", voted_classifier.confidence(testing_set[1][0])*100)
print("Classification:", voted_classifier.classify(testing_set[2][0]),
      "Confidence %:", voted_classifier.confidence(testing_set[2][0])*100)
print("Classification:", voted_classifier.classify(testing_set[3][0]),
      "Confidence %:", voted_classifier.confidence(testing_set[3][0])*100)
print("Classification:", voted_classifier.classify(testing_set[4][0]),
      "Confidence %:", voted_classifier.confidence(testing_set[4][0])*100)
print("Classification:", voted_classifier.classify(testing_set[5][0]),
      "Confidence %:", voted_classifier.confidence(testing_set[5][0])*100)
# Out:
# ('voted_classifier accuracy percent:', 85.0)
# ('Classification:', u'neg', 'Confidence %:', 100.0)
# ('Classification:', u'neg', 'Confidence %:', 57.14285714285714)
# ('Classification:', u'pos', 'Confidence %:', 57.14285714285714)
# ('Classification:', u'neg', 'Confidence %:', 71.42857142857143)
# ('Classification:', u'pos', 'Confidence %:', 100.0)
# ('Classification:', u'neg', 'Confidence %:', 100.0)

# %%
for i in range(25):
    print("Classification:", voted_classifier.classify(testing_set[i][0]),
      "Confidence %:", voted_classifier.confidence(testing_set[i][0])*100)
# Out:
# ('Classification:', u'neg', 'Confidence %:', 100.0)
# ('Classification:', u'neg', 'Confidence %:', 57.14285714285714)
# ('Classification:', u'pos', 'Confidence %:', 57.14285714285714)
# ('Classification:', u'neg', 'Confidence %:', 71.42857142857143)
# ('Classification:', u'pos', 'Confidence %:', 100.0)
# ('Classification:', u'neg', 'Confidence %:', 100.0)
# ('Classification:', u'pos', 'Confidence %:', 100.0)
# ('Classification:', u'pos', 'Confidence %:', 57.14285714285714)
# ('Classification:', u'pos', 'Confidence %:', 100.0)
# ('Classification:', u'neg', 'Confidence %:', 100.0)
# ('Classification:', u'neg', 'Confidence %:', 100.0)
# ('Classification:', u'pos', 'Confidence %:', 100.0)
# ('Classification:', u'pos', 'Confidence %:', 100.0)
# ('Classification:', u'neg', 'Confidence %:', 100.0)
# ('Classification:', u'neg', 'Confidence %:', 100.0)
# ('Classification:', u'neg', 'Confidence %:', 100.0)
# ('Classification:', u'pos', 'Confidence %:', 100.0)
# ('Classification:', u'neg', 'Confidence %:', 100.0)
# ('Classification:', u'neg', 'Confidence %:', 100.0)
# ('Classification:', u'pos', 'Confidence %:', 57.14285714285714)
# ('Classification:', u'pos', 'Confidence %:', 100.0)
# ('Classification:', u'neg', 'Confidence %:', 100.0)
# ('Classification:', u'pos', 'Confidence %:', 100.0)
# ('Classification:', u'pos', 'Confidence %:', 100.0)
# ('Classification:', u'neg', 'Confidence %:', 100.0)

# %% [markdown]
# When the above is 100%, it means that ALL the models agree that list of features is pos or neg. When it's less than 100% it's saying that x/7 of the models (the number of models we passed into VoteClassifier) agree with the test set

# %% [markdown]
# # Lesson 17 - Investigating Bias

# %% [markdown]
# At this point in our project, we're interested in moving on to a real dataset, but we're concerned still about our volatility in accuracy.
#
# In this video, we peak into the classifiers to see if we have any bias leans towards positive or negative, and we wind up finding out that not only do we have a bias, we have a bug!

# %%
# This one is hard to follow. All's i know is he doesn't shffule the dataset in the video, and the models
# get stuck in a local minima and become biased.

# %% [markdown]
# # Lesson 18 - Better Training Data

# %% [markdown]
# After some consideration it became clear that a new dataset would solve a lot of problems. This tutorial covers employing a new dataset, and what is involved in this process.
#
# This time, we're using a movie reviews data set that contains much shorter movie reviews.
#
# You can get this data set from: http://pythonprogramming.net/static/d...
#
# This one yields us a far more reliable reading across the board, and is far more fitting for the tweets we intend to read from the Twitter API soon.

# %%
import codecs

class VoteClassifier(ClassifierI):
    def __init__(self, *classifiers):
        self._classifiers = classifiers
        
    def classify(self, features):
        votes = []
        for c in self._classifiers:
            v = c.classify(features)
            votes.append(v)
        return mode(votes)
    
    def confidence(self, features):
        votes = []
        for c in self._classifiers:
            v = c.classify(features)
            votes.append(v)
            
        choice_votes = votes.count(mode(votes))
        conf = float(choice_votes) / len(votes)
        return conf
    
# short_pos = open("data/short_reviews/positive.txt", "r").read()
# short_neg = open("data/short_reviews/negative.txt", "r").read()
short_pos = codecs.open("data/short_reviews/positive.txt","r", encoding='latin2').read()
short_neg = codecs.open("data/short_reviews/negative.txt","r",encoding='latin2').read()

documents = []

for r in short_pos.split('\n'):
    documents.append((r, "pos"))
    
for r in short_neg.split('\n'):
    documents.append((r, "neg"))
    
all_words = []

short_pos_words = set(word_tokenize(short_pos))
short_neg_words = set(word_tokenize(short_neg))

for w in short_pos_words:
    all_words.append(w.lower())
    
for w in short_neg_words:
    all_words.append(w.lower())
    
all_words = nltk.FreqDist(all_words)

word_features = list(all_words.keys())[:5000]

def find_features(document):
    words = word_tokenize(document)
    features = {}
    for w in word_features:
        features[w] = (w in words)

    return features

featuresets = [(find_features(rev), category) for (rev, category) in documents]

random.shuffle(featuresets)

# positive data example:
training_set = featuresets[:10000]
testing_set = featuresets[10000:]

# lets open the pickle file now
classifier_f = open("naive_bayes.pickle", "rb")
classifier = pickle.load(classifier_f)
classifier_f.close()


print("Original Naive Bayes Algo accuracy:", (nltk.classify.accuracy(classifier, testing_set))*100)
classifier.show_most_informative_features(15)

# Multinomial NB
MNB_classifier = SklearnClassifier(MultinomialNB())
MNB_classifier.train(training_set)
print("MNB_classifier accuracy percent:", (nltk.classify.accuracy(MNB_classifier, testing_set))*100)

# Bernoulli
BernoulliNB_classifier = SklearnClassifier(BernoulliNB())
BernoulliNB_classifier.train(training_set)
print("BernoulliNB_classifier accuracy percent:", (nltk.classify.accuracy(BernoulliNB_classifier, testing_set))*100)

LogisticRegression_classifier = SklearnClassifier(LogisticRegression())
LogisticRegression_classifier.train(training_set)
print("LogisticRegression_classifier accuracy percent:", (nltk.classify.accuracy(LogisticRegression_classifier, testing_set))*100)

SGDClassifier_classifier = SklearnClassifier(SGDClassifier())
SGDClassifier_classifier.train(training_set)
print("SGDClassifier_classifier accuracy percent:", (nltk.classify.accuracy(SGDClassifier_classifier, testing_set))*100)

SVC_classifier = SklearnClassifier(SVC())
SVC_classifier.train(training_set)
print("SVC_classifier accuracy percent:", (nltk.classify.accuracy(SVC_classifier, testing_set))*100)

LinearSVC_classifier = SklearnClassifier(LinearSVC())
LinearSVC_classifier.train(training_set)
print("LinearSVC_classifier accuracy percent:", (nltk.classify.accuracy(LinearSVC_classifier, testing_set))*100)

NuSVC_classifier = SklearnClassifier(NuSVC())
NuSVC_classifier.train(training_set)
print("NuSVC_classifier accuracy percent:", (nltk.classify.accuracy(NuSVC_classifier, testing_set))*100)

# we want to pickle every classifier so that we can reuse these models on future test setsþyou
# Out:
# ('Original Naive Bayes Algo accuracy:', 45.16616314199396)
# Most Informative Features
#              outstanding = True              pos : neg    =     10.6 : 1.0
#                   finest = True              pos : neg    =      9.0 : 1.0
#                    mulan = True              pos : neg    =      8.8 : 1.0
#              beautifully = True              pos : neg    =      8.4 : 1.0
#              wonderfully = True              pos : neg    =      7.6 : 1.0
#                   seagal = True              neg : pos    =      7.1 : 1.0
#                   prinze = True              neg : pos    =      6.7 : 1.0
#               schumacher = True              neg : pos    =      6.7 : 1.0
#                   alicia = True              neg : pos    =      6.7 : 1.0
#                   wasted = True              neg : pos    =      6.1 : 1.0
#                    damon = True              pos : neg    =      6.0 : 1.0
#                    inept = True              neg : pos    =      5.6 : 1.0
#                   ripley = True              pos : neg    =      5.6 : 1.0
#                     lame = True              neg : pos    =      5.5 : 1.0
#                    awful = True              neg : pos    =      5.3 : 1.0
# ('MNB_classifier accuracy percent:', 68.27794561933534)
# ('BernoulliNB_classifier accuracy percent:', 68.12688821752266)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-41-9ae736e82e00> in <module>()
#      86
#      87 LogisticRegression_classifier = SklearnClassifier(LogisticRegression())
# ---> 88 LogisticRegression_classifier.train(training_set)
#      89 print("LogisticRegression_classifier accuracy percent:", (nltk.classify.accuracy(LogisticRegression_classifier, testing_set))*100)
#      90
#
# /Users/andrewrubino/anaconda2/lib/python2.7/site-packages/nltk/classify/scikitlearn.pyc in train(self, labeled_featuresets)
#     115
#     116         X, y = list(zip(*labeled_featuresets))
# --> 117         X = self._vectorizer.fit_transform(X)
#     118         y = self._encoder.fit_transform(y)
#     119         self._clf.fit(X, y)
#
# /Users/andrewrubino/anaconda2/lib/python2.7/site-packages/sklearn/feature_extraction/dict_vectorizer.pyc in fit_transform(self, X, y)
#     229             Feature vectors; always 2-d.
#     230         """
# --> 231         return self._transform(X, fitting=True)
#     232
#     233     def inverse_transform(self, X, dict_type=dict):
#
# /Users/andrewrubino/anaconda2/lib/python2.7/site-packages/sklearn/feature_extraction/dict_vectorizer.pyc in _transform(self, X, fitting)
#     170                     v = 1
#     171                 if f in vocab:
# --> 172                     indices.append(vocab[f])
#     173                     values.append(dtype(v))
#     174                 else:
#
# KeyboardInterrupt:

# %%
documents
# Out:
# [(u'the rock is destined to be the 21st century\'s new " conan " and that he\'s going to make a splash even greater than arnold schwarzenegger , jean-claud van damme or steven segal . ',
#   'pos'),
#  (u'the gorgeously elaborate continuation of " the lord of the rings " trilogy is so huge that a column of words cannot adequately describe co-writer/director peter jackson\'s expanded vision of j . r . r . tolkien\'s middle-earth . ',
#   'pos'),
#  (u'effective but too-tepid biopic', 'pos'),
#  (u'if you sometimes like to go to the movies to have fun , wasabi is a good place to start . ',
#   'pos'),
#  (u"emerges as something rare , an issue movie that's so honest and keenly observed that it doesn't feel like one . ",
#   'pos'),
#  (u'the film provides some great insight into the neurotic mindset of all comics -- even those who have reached the absolute top of the game . ',
#   'pos'),
#  (u'offers that rare combination of entertainment and education . ', 'pos'),
#  (u'perhaps no picture ever made has more literally showed that the road to hell is paved with good intentions . ',
#   'pos'),
#  (u"steers turns in a snappy screenplay that curls at the edges ; it's so clever you want to hate it . but he somehow pulls it off . ",
#   'pos'),
#  (u'take care of my cat offers a refreshingly different slice of asian cinema . ',
#   'pos'),
#  (u'this is a film well worth seeing , talking and singing heads and all . ',
#   'pos'),
#  (u'what really surprises about wisegirls is its low-key quality and genuine tenderness . ',
#   'pos'),
#  (u' ( wendigo is ) why we go to the cinema : to be fed through the eye , the heart , the mind . ',
#   'pos'),
#  (u'one of the greatest family-oriented , fantasy-adventure movies ever . ',
#   'pos'),
#  (u'ultimately , it ponders the reasons we need stories so much . ', 'pos'),
#  (u"an utterly compelling 'who wrote it' in which the reputation of the most famous author who ever lived comes into question . ",
#   'pos'),
#  (u'illuminating if overly talky documentary . ', 'pos'),
#  (u'a masterpiece four years in the making . ', 'pos'),
#  (u"the movie's ripe , enrapturing beauty will tempt those willing to probe its inscrutable mysteries . ",
#   'pos'),
#  (u'offers a breath of the fresh air of true sophistication . ', 'pos'),
#  (u'a thoughtful , provocative , insistently humanizing film . ', 'pos'),
#  (u'with a cast that includes some of the top actors working in independent film , lovely & amazing involves us because it is so incisive , so bleakly amusing about how we go about our lives . ',
#   'pos'),
#  (u'a disturbing and frighteningly evocative assembly of imagery and hypnotic music composed by philip glass . ',
#   'pos'),
#  (u"not for everyone , but for those with whom it will connect , it's a nice departure from standard moviegoing fare . ",
#   'pos'),
#  (u'scores a few points for doing what it does with a dedicated and good-hearted professionalism . ',
#   'pos'),
#  (u"occasionally melodramatic , it's also extremely effective . ", 'pos'),
#  (u'spiderman rocks', 'pos'),
#  (u'an idealistic love story that brings out the latent 15-year-old romantic in everyone . ',
#   'pos'),
#  (u"at about 95 minutes , treasure planet maintains a brisk pace as it races through the familiar story . however , it lacks grandeur and that epic quality often associated with stevenson's tale as well as with earlier disney efforts . ",
#   'pos'),
#  (u'it helps that lil bow wow . . . tones down his pint-sized gangsta act to play someone who resembles a real kid . ',
#   'pos'),
#  (u'guaranteed to move anyone who ever shook , rattled , or rolled . ', 'pos'),
#  (u'a masterful film from a master filmmaker , unique in its deceptive grimness , compelling in its fatalist worldview . ',
#   'pos'),
#  (u'light , cute and forgettable . ', 'pos'),
#  (u"if there's a way to effectively teach kids about the dangers of drugs , i think it's in projects like the ( unfortunately r-rated ) paid . ",
#   'pos'),
#  (u"while it would be easy to give crush the new title of two weddings and a funeral , it's a far more thoughtful film than any slice of hugh grant whimsy . ",
#   'pos'),
#  (u'though everything might be literate and smart , it never took off and always seemed static . ',
#   'pos'),
#  (u"cantet perfectly captures the hotel lobbies , two-lane highways , and roadside cafes that permeate vincent's days",
#   'pos'),
#  (u'ms . fulford-wierzbicki is almost spooky in her sulky , calculating lolita turn . ',
#   'pos'),
#  (u'though it is by no means his best work , laissez-passer is a distinguished and distinctive effort by a bona-fide master , a fascinating film replete with rewards to be had by all willing to make the effort to reap them . ',
#   'pos'),
#  (u'like most bond outings in recent years , some of the stunts are so outlandish that they border on being cartoonlike . a heavy reliance on cgi technology is beginning to creep into the series . ',
#   'pos'),
#  (u'newton draws our attention like a magnet , and acts circles around her better known co-star , mark wahlberg . ',
#   'pos'),
#  (u"the story loses its bite in a last-minute happy ending that's even less plausible than the rest of the picture . much of the way , though , this is a refreshingly novel ride . ",
#   'pos'),
#  (u'fuller would surely have called this gutsy and at times exhilarating movie a great yarn . ',
#   'pos'),
#  (u"'compleja e intelectualmente retadora , el ladr\u0102\u0142n de orqu\u0102\xaddeas es uno de esos filmes que vale la pena ver precisamente por su originalidad . '",
#   'pos'),
#  (u'the film makes a strong case for the importance of the musicians in creating the motown sound . ',
#   'pos'),
#  (u'karmen moves like rhythm itself , her lips chanting to the beat , her long , braided hair doing little to wipe away the jeweled beads of sweat . ',
#   'pos'),
#  (u'gosling provides an amazing performance that dwarfs everything else in the film . ',
#   'pos'),
#  (u"a real movie , about real people , that gives us a rare glimpse into a culture most of us don't know . ",
#   'pos'),
#  (u'tender yet lacerating and darkly funny fable . ', 'pos'),
#  (u"may be spoofing an easy target -- those old '50's giant creature features -- but . . . it acknowledges and celebrates their cheesiness as the reason why people get a kick out of watching them today . ",
#   'pos'),
#  (u"an engaging overview of johnson's eccentric career . ", 'pos'),
#  (u'in its ragged , cheap and unassuming way , the movie works . ', 'pos'),
#  (u"some actors have so much charisma that you'd be happy to listen to them reading the phone book . hugh grant and sandra bullock are two such likeable actors . ",
#   'pos'),
#  (u'sandra nettelbeck beautifully orchestrates the transformation of the chilly , neurotic , and self-absorbed martha as her heart begins to open . ',
#   'pos'),
#  (u'behind the snow games and lovable siberian huskies ( plus one sheep dog ) , the picture hosts a parka-wrapped dose of heart . ',
#   'pos'),
#  (u'everytime you think undercover brother has run out of steam , it finds a new way to surprise and amuse . ',
#   'pos'),
#  (u'manages to be original , even though it rips off many of its ideas . ',
#   'pos'),
#  (u'singer/composer bryan adams contributes a slew of songs \xe2\x80\x94 a few potential hits , a few more simply intrusive to the story \xe2\x80\x94 but the whole package certainly captures the intended , er , spirit of the piece . ',
#   'pos'),
#  (u"you'd think by now america would have had enough of plucky british eccentrics with hearts of gold . yet the act is still charming here . ",
#   'pos'),
#  (u'whether or not you\'re enlightened by any of derrida\'s lectures on " the other " and " the self , " derrida is an undeniably fascinating and playful fellow . ',
#   'pos'),
#  (u'a pleasant enough movie , held together by skilled ensemble actors . ',
#   'pos'),
#  (u"this is the best american movie about troubled teens since 1998's whatever . ",
#   'pos'),
#  (u"disney has always been hit-or-miss when bringing beloved kids' books to the screen . . . tuck everlasting is a little of both . ",
#   'pos'),
#  (u'just the labour involved in creating the layered richness of the imagery in this chiaroscuro of madness and light is astonishing . ',
#   'pos'),
#  (u'the animated subplot keenly depicts the inner struggles of our adolescent heroes - insecure , uncontrolled , and intense . ',
#   'pos'),
#  (u'the invincible werner herzog is alive and well and living in la', 'pos'),
#  (u'morton is a great actress portraying a complex character , but morvern callar grows less compelling the farther it meanders from its shocking start . ',
#   'pos'),
#  (u'part of the charm of satin rouge is that it avoids the obvious with humour and lightness . ',
#   'pos'),
#  (u'son of the bride may be a good half-hour too long but comes replete with a flattering sense of mystery and quietness . ',
#   'pos'),
#  (u'a simmering psychological drama in which the bursts of sudden violence are all the more startling for the slow buildup that has preceded them . ',
#   'pos'),
#  (u'a taut , intelligent psychological drama . ', 'pos'),
#  (u"a compelling coming-of-age drama about the arduous journey of a sensitive young girl through a series of foster homes and a fierce struggle to pull free from her dangerous and domineering mother's hold over her . ",
#   'pos'),
#  (u'a truly moving experience , and a perfect example of how art -- when done right -- can help heal , clarify , and comfort . ',
#   'pos'),
#  (u'this delicately observed story , deeply felt and masterfully stylized , is a triumph for its maverick director . ',
#   'pos'),
#  (u'at heart the movie is a deftly wrought suspense yarn whose richer shadings work as coloring rather than substance . ',
#   'pos'),
#  (u"the appearance of treebeard and gollum's expanded role will either have you loving what you're seeing , or rolling your eyes . i loved it ! gollum's 'performance' is incredible ! ",
#   'pos'),
#  (u'a screenplay more ingeniously constructed than " memento " ', 'pos'),
#  (u"if this movie were a book , it would be a page-turner , you can't wait to see what happens next . ",
#   'pos'),
#  (u'haneke challenges us to confront the reality of sexual aberration . ',
#   'pos'),
#  (u'absorbing and disturbing -- perhaps more disturbing than originally intended -- but a little clarity would have gone a long way . ',
#   'pos'),
#  (u"it's the best film of the year so far , the benchmark against which all other best picture contenders should be measured . ",
#   'pos'),
#  (u"painful to watch , but viewers willing to take a chance will be rewarded with two of the year's most accomplished and riveting film performances . ",
#   'pos'),
#  (u'this is a startling film that gives you a fascinating , albeit depressing view of iranian rural life close to the iraqi border . ',
#   'pos'),
#  (u'an imaginative comedy/thriller . ', 'pos'),
#  (u'a few artsy flourishes aside , narc is as gritty as a movie gets these days . ',
#   'pos'),
#  (u'while the isle is both preposterous and thoroughly misogynistic , its vistas are incredibly beautiful to look at . ',
#   'pos'),
#  (u"together , tok and o orchestrate a buoyant , darkly funny dance of death . in the process , they demonstrate that there's still a lot of life in hong kong cinema . ",
#   'pos'),
#  (u'director kapur is a filmmaker with a real flair for epic landscapes and adventure , and this is a better film than his earlier english-language movie , the overpraised elizabeth . ',
#   'pos'),
#  (u'the movie is a blast of educational energy , as bouncy animation and catchy songs escort you through the entire 85 minutes . ',
#   'pos'),
#  (u"a sports movie with action that's exciting on the field and a story you care about off it . ",
#   'pos'),
#  (u"doug liman , the director of bourne , directs the traffic well , gets a nice wintry look from his locations , absorbs us with the movie's spycraft and uses damon's ability to be focused and sincere . ",
#   'pos'),
#  (u'the tenderness of the piece is still intact . ', 'pos'),
#  (u'katz uses archival footage , horrifying documents of lynchings , still photographs and charming old reel-to-reel recordings of meeropol entertaining his children to create his song history , but most powerful of all is the song itself',
#   'pos'),
#  (u"like the film's almost anthropologically detailed realization of early-'80s suburbia , it's significant without being overstated . ",
#   'pos'),
#  (u"while mcfarlane's animation lifts the film firmly above the level of other coming-of-age films . . . it's also so jarring that it's hard to get back into the boys' story . ",
#   'pos'),
#  (u'if nothing else , this movie introduces a promising , unusual kind of psychological horror . ',
#   'pos'),
#  (u'in a normal screen process , these bromides would be barely enough to sustain an interstitial program on the discovery channel . but in imax 3-d , the clich\u0102\u0160s disappear into the vertiginous perspectives opened up by the photography . ',
#   'pos'),
#  (u'writer-director burger imaginatively fans the embers of a dormant national grief and curiosity that has calcified into chronic cynicism and fear . ',
#   'pos'),
#  (u' . . . a roller-coaster ride of a movie', 'pos'),
#  (u'i enjoyed time of favor while i was watching it , but i was surprised at how quickly it faded from my memory . ',
#   'pos'),
#  (u'chicago is sophisticated , brash , sardonic , completely joyful in its execution . ',
#   'pos'),
#  (u"steve irwin's method is ernest hemmingway at accelerated speed and volume . ",
#   'pos'),
#  (u'a refreshing korean film about five female high school friends who face an uphill battle when they try to take their relationships into deeper waters . ',
#   'pos'),
#  (u"on the surface , it's a lovers-on-the-run crime flick , but it has a lot in common with piesiewicz's and kieslowski's earlier work , films like the double life of veronique . ",
#   'pos'),
#  (u'the values that have held the enterprise crew together through previous adventures and perils do so again-courage , self-sacrifice and patience under pressure . ',
#   'pos'),
#  (u"if it's possible for a sequel to outshine the original , then sl2 does just that . ",
#   'pos'),
#  (u'a romantic comedy that operates by the rules of its own self-contained universe . ',
#   'pos'),
#  (u"4 friends , 2 couples , 2000 miles , and all the pabst blue ribbon beer they can drink - it's the ultimate redneck road-trip . ",
#   'pos'),
#  (u"the film is often filled with a sense of pure wonderment and excitement not often seen in today's cinema du sarcasm",
#   'pos'),
#  (u"it might be tempting to regard mr . andrew and his collaborators as oddballs , but mr . earnhart's quizzical , charming movie allows us to see them , finally , as artists . ",
#   'pos'),
#  (u'a feel-good picture in the best sense of the term . ', 'pos'),
#  (u'edited and shot with a syncopated style mimicking the work of his subjects , pray turns the idea of the documentary on its head , making it rousing , invigorating fun lacking any mtv puffery . ',
#   'pos'),
#  (u'a mostly intelligent , engrossing and psychologically resonant suspenser . ',
#   'pos'),
#  (u"it's this memory-as-identity obviation that gives secret life its intermittent unease , reaffirming that long-held illusions are indeed reality , and that erasing them recasts the self . ",
#   'pos'),
#  (u"hip-hop has a history , and it's a metaphor for this love story . ",
#   'pos'),
#  (u"in scope , ambition and accomplishment , children of the century . . . takes kurys' career to a whole new level . ",
#   'pos'),
#  (u"this may not have the dramatic gut-wrenching impact of other holocaust films , but it's a compelling story , mainly because of the way it's told by the people who were there . ",
#   'pos'),
#  (u'between the drama of cube ? s personal revelations regarding what the shop means in the big picture , iconic characters gambol fluidly through the story , with charming results . ',
#   'pos'),
#  (u'a gentle , compassionate drama about grief and healing . ', 'pos'),
#  (u'somewhere short of tremors on the modern b-scene : neither as funny nor as clever , though an agreeably unpretentious way to spend ninety minutes . ',
#   'pos'),
#  (u'digital-video documentary about stand-up comedians is a great glimpse into a very different world . ',
#   'pos'),
#  (u'unlike most teen flicks , swimming takes its time to tell its story , casts mostly little-known performers in key roles , and introduces some intriguing ambiguity . ',
#   'pos'),
#  (u"an enthralling , playful film that constantly frustrates our desire to know the 'truth' about this man , while deconstructing the very format of the biography in a manner that derrida would doubtless give his blessing to . ",
#   'pos'),
#  (u' " extreme ops " exceeds expectations . good fun , good action , good acting , good dialogue , good pace , good cinematography . ',
#   'pos'),
#  (u'you should pay nine bucks for this : because you can hear about suffering afghan refugees on the news and still be unaffected . dramas like this make it human . ',
#   'pos'),
#  (u'a thunderous ride at first , quiet cadences of pure finesse are few and far between ; their shortage dilutes the potency of otherwise respectable action . still , this flick is fun , and host to some truly excellent sequences . ',
#   'pos'),
#  (u"it's obviously struck a responsive chord with many south koreans , and should work its magic in other parts of the world . ",
#   'pos'),
#  (u"run , don't walk , to see this barbed and bracing comedy on the big screen . ",
#   'pos'),
#  (u'a classy item by a legend who may have nothing left to prove but still has the chops and drive to show how its done . ',
#   'pos'),
#  (u"it is nature against progress . in fessenden's horror trilogy , this theme has proved important to him and is especially so in the finale . ",
#   'pos'),
#  (u"it's not exactly a gourmet meal but the fare is fair , even coming from the drive-thru . ",
#   'pos'),
#  (u'this is what imax was made for : strap on a pair of 3-d goggles , shut out the real world , and take a vicarious voyage to the last frontier -- space . ',
#   'pos'),
#  (u'merely as a technical , logistical feat , russian ark marks a cinematic milestone . ',
#   'pos'),
#  (u'[schweiger is] talented and terribly charismatic , qualities essential to both movie stars and social anarchists . ',
#   'pos'),
#  (u"it's a great deal of sizzle and very little steak . but what spectacular sizzle it is ! . . . in this incarnation its fizz is infectious . ",
#   'pos'),
#  (u'an original gem about an obsession with time . ', 'pos'),
#  (u'it will delight newcomers to the story and those who know it from bygone days . ',
#   'pos'),
#  (u'gloriously goofy ( and gory ) midnight movie stuff . ', 'pos'),
#  (u'the film overcomes the regular minefield of coming-of-age cliches with potent doses of honesty and sensitivity . ',
#   'pos'),
#  (u"if your senses haven't been dulled by slasher films and gorefests , if you're a connoisseur of psychological horror , this is your ticket . ",
#   'pos'),
#  (u"it's a minor comedy that tries to balance sweetness with coarseness , while it paints a sad picture of the singles scene . ",
#   'pos'),
#  (u'it is intensely personal and yet -- unlike quills -- deftly shows us the temper of the times . ',
#   'pos'),
#  (u'as lo-fi as the special effects are , the folks who cobbled nemesis together indulge the force of humanity over hardware in a way that george lucas has long forgotten . ',
#   'pos'),
#  (u"like mike doesn't win any points for originality . it does succeed by following a feel-good formula with a winning style , and by offering its target audience of urban kids some welcome role models and optimism . ",
#   'pos'),
#  (u"it's a hoot and a half , and a great way for the american people to see what a candidate is like when he's not giving the same 15-cent stump speech . ",
#   'pos'),
#  (u'far from perfect , but its heart is in the right place . . . innocent and well-meaning . ',
#   'pos'),
#  (u'a sad , superior human comedy played out on the back roads of life . ',
#   'pos'),
#  (u'waydowntown is by no means a perfect film , but its boasts a huge charm factor and smacks of originality . ',
#   'pos'),
#  (u'tim allen is great in his role but never hogs the scenes from his fellow cast , as there are plenty of laughs and good lines for everyone in this comedy . ',
#   'pos'),
#  (u'more a load of enjoyable , conan-esque claptrap than the punishing , special-effects soul assaults the mummy pictures represent . ',
#   'pos'),
#  (u'enormously likable , partly because it is aware of its own grasp of the absurd . ',
#   'pos'),
#  (u"here's a british flick gleefully unconcerned with plausibility , yet just as determined to entertain you . ",
#   'pos'),
#  (u"it's an old story , but a lively script , sharp acting and partially animated interludes make just a kiss seem minty fresh . ",
#   'pos'),
#  (u'must be seen to be believed . ', 'pos'),
#  (u"ray liotta and jason patric do some of their best work in their underwritten roles , but don't be fooled : nobody deserves any prizes here . ",
#   'pos'),
#  (u"everything that has to do with yvan and charlotte , and everything that has to do with yvan's rambunctious , jewish sister and her non-jew husband , feels funny and true . ",
#   'pos'),
#  (u'sweet home alabama " is what it is \xe2\x80\x93 a nice , harmless date film . . . ',
#   'pos'),
#  (u"the year's happiest surprise , a movie that deals with a real subject in an always surprising way . ",
#   'pos'),
#  (u"fans of behan's work and of irish movies in general will be rewarded by borstal boy . ",
#   'pos'),
#  (u"its mysteries are transparently obvious , and it's too slowly paced to be a thriller . [but it's] worth recommending because of two marvelous performances by michael caine and brendan fraser . ",
#   'pos'),
#  (u"the film is faithful to what one presumes are the book's twin premises -- that we become who we are on the backs of our parents , but we have no idea who they were at our age ; and that time is a fleeting and precious commodity no matter how old you are . ",
#   'pos'),
#  (u"stephen earnhart's homespun documentary mule skinner blues has nothing but love for its posse of trailer park denizens . ",
#   'pos'),
#  (u'a solidly seaworthy chiller . ', 'pos'),
#  (u'if you can get past the fantastical aspects and harsh realities of " the isle " you\'ll get a sock-you-in-the-eye flick that is a visual tour-de-force and a story that is unlike any you will likely see anywhere else . ',
#   'pos'),
#  (u"there are as many misses as hits , but ultimately , it finds humor in the foibles of human behavior , and it's a welcome return to the roots of a genre that should depend on surprises . ",
#   'pos'),
#  (u'a well-made thriller with a certain level of intelligence and non-reactionary morality . ',
#   'pos'),
#  (u"there's enough science to make it count as educational , and enough beauty to make it unforgettable . ",
#   'pos'),
#  (u'remains a solid , if somewhat heavy-handed , account of the near-disaster . . . done up by howard with a steady , if not very imaginative , hand . ',
#   'pos'),
#  (u"makmalbaf follows a resolutely realistic path in this uncompromising insight into the harsh existence of the kurdish refugees of iran's borderlands . ",
#   'pos'),
#  (u'for a good chunk of its running time , trapped is an effective and claustrophobic thriller . ',
#   'pos'),
#  (u'most of crush is a clever and captivating romantic comedy with a welcome pinch of tartness . ',
#   'pos'),
#  (u'nair does capture the complexity of a big family and its trials and tribulations . . . ',
#   'pos'),
#  (u'the seaside splendor and shallow , beautiful people are nice to look at while you wait for the story to get going . ',
#   'pos'),
#  (u"rare is the 'urban comedy' that even attempts the insight and honesty of this disarming indie . ",
#   'pos'),
#  (u"ranks among willams' best screen work . ", 'pos'),
#  (u'engagingly captures the maddening and magnetic ebb and flow of friendship . ',
#   'pos'),
#  (u'an experience so engrossing it is like being buried in a new environment . ',
#   'pos'),
#  (u"it's traditional moviemaking all the way , but it's done with a lot of careful period attention as well as some very welcome wit . ",
#   'pos'),
#  (u'thoroughly enjoyable . ', 'pos'),
#  (u"maybe it's just because this past year has seen the release of some of the worst film comedies in decades . . . but honestly , analyze that really isn't all that bad . ",
#   'pos'),
#  (u'a droll , well-acted , character-driven comedy with unexpected deposits of feeling . ',
#   'pos'),
#  (u"this is simply the most fun you'll ever have with a documentary ! ",
#   'pos'),
#  (u'a very funny movie . ', 'pos'),
#  (u"watching haneke's film is , aptly enough , a challenge and a punishment . but watching huppert , a great actress tearing into a landmark role , is riveting . ",
#   'pos'),
#  (u'a cop story that understands the medium amazingly well . ', 'pos'),
#  (u"one of the best , most understated performances of [jack nicholson's] career . ",
#   'pos'),
#  (u'britney has been delivered to the big screen safe and sound , the way we like our 20-year-old superstar girls to travel on the fame freeway . ',
#   'pos'),
#  (u"those outside show business will enjoy a close look at people they don't really want to know . ",
#   'pos'),
#  (u'the kind of nervous film that will either give you a mild headache or exhilarate you . ',
#   'pos'),
#  (u'watching beanie and his gang put together his slasher video from spare parts and borrowed materials is as much fun as it must have been for them to make it . ',
#   'pos'),
#  (u"children may not understand everything that happens -- i'm not sure even miyazaki himself does -- but they will almost certainly be fascinated , and undoubtedly delighted . ",
#   'pos'),
#  (u'a fascinating and fun film . ', 'pos'),
#  (u'tadpole is a sophisticated , funny and good-natured treat , slight but a pleasure . ',
#   'pos'),
#  (u'this insightful , oscar-nominated documentary , in which children on both sides of the ever-escalating conflict have their say away from watchful parental eyes , gives peace yet another chance . ',
#   'pos'),
#  (u'i admired this work a lot . ', 'pos'),
#  (u"whether you're moved and love it , or bored or frustrated by the film , you'll still feel something . ",
#   'pos'),
#  (u' . . . there are enough moments of heartbreaking honesty to keep one glued to the screen . ',
#   'pos'),
#  (u'my goodness , queen latifah has a lot to offer and she seemed to have no problem flaunting her natural gifts . she must have a very strong back . ',
#   'pos'),
#  (u'a smart , sweet and playful romantic comedy . ', 'pos'),
#  (u'australian actor/director john polson and award-winning english cinematographer giles nuttgens make a terrific effort at disguising the obvious with energy and innovation . ',
#   'pos'),
#  (u'without heavy-handedness , dong provides perspective with his intelligent grasp of human foibles and contradictions . ',
#   'pos'),
#  (u'solid , lump-in-the-throat family entertainment that derives its power by sticking to the facts . ',
#   'pos'),
#  (u'as an entertainment , the movie keeps you diverted and best of all , it lightens your wallet without leaving a sting . ',
#   'pos'),
#  (u'it is interesting and fun to see goodall and her chimpanzees on the bigger-than-life screen . ',
#   'pos'),
#  (u"it won't bust your gut -- and it's not intended to -- it's merely a blandly cinematic surgical examination of what makes a joke a joke . ",
#   'pos'),
#  (u'a somewhat crudely constructed but gripping , questing look at a person so racked with self-loathing , he becomes an enemy to his own race . ',
#   'pos'),
#  (u'it extends the writings of jean genet and john rechy , the films of fassbinder , perhaps even the nocturnal works of goya . ',
#   'pos'),
#  (u"narc may not get an 'a' for originality , but it wears its b-movie heritage like a badge of honor . ",
#   'pos'),
#  (u"with the film's striking ending , one realizes that we have a long way to go before we fully understand all the sexual permutations involved . ",
#   'pos'),
#  (u"[drumline] is entertaining for what it does , and admirable for what it doesn't do . ",
#   'pos'),
#  (u'at its best early on as it plays the culture clashes between the brothers . ',
#   'pos'),
#  (u'[a] rare , beautiful film . ', 'pos'),
#  (u'an unabashedly schmaltzy and thoroughly enjoyable true story . ', 'pos'),
#  (u'a thoughtful look at a painful incident that made headlines in 1995 . ',
#   'pos'),
#  (u'you walk out of the good girl with mixed emotions \xe2\x80\x94 disapproval of justine combined with a tinge of understanding for her actions . ',
#   'pos'),
#  (u'tsai ming-liang has taken his trademark style and refined it to a crystalline point . ',
#   'pos'),
#  (u'purely propaganda , a work of unabashed hero worship , it is nonetheless -- and likely inadvertently -- a timely and invaluable implicit reminder of the role that u . s . foreign policy has played in the rise of castro . ',
#   'pos'),
#  (u'now trimmed by about 20 minutes , this lavish three-year-old production has enough grandeur and scale to satisfy as grown-up escapism . ',
#   'pos'),
#  (u"we get some truly unique character studies and a cross-section of americana that hollywood couldn't possibly fictionalize and be believed . ",
#   'pos'),
#  (u'though this film can be clumsy , its ambitions are equally -- and admirably -- uncommercial . ',
#   'pos'),
#  (u'daring , mesmerizing and exceedingly hard to forget . ', 'pos'),
#  (u"the dangerous lives of altar boys' take on adolescence feels painfully true . ",
#   'pos'),
#  (u"moore's performance impresses almost as much as her work with haynes in 1995's safe . ",
#   'pos'),
#  (u"visits spy-movie territory like a novel you can't put down , examines a footnote to history seldom brought to light on the screen , and keeps you guessing from first frame to last . ",
#   'pos'),
#  (u'an absorbing , slice-of-depression life that touches nerves and rings true . ',
#   'pos'),
#  (u'mr . parker has brilliantly updated his source and grasped its essence , composing a sorrowful and hilarious tone poem about alienated labor , or an absurdist workplace sitcom . ',
#   'pos'),
#  (u'the result is something quite fresh and delightful . ', 'pos'),
#  (u'all but the most persnickety preteens should enjoy this nonthreatening but thrilling adventure . ',
#   'pos'),
#  (u"despite its many infuriating flaws -- not the least of which is amy's self-absorbed personality -- amy's o's honesty will win you over . ",
#   'pos'),
#  (u"this is one of polanski's best films . ", 'pos'),
#  (u'day is not a great bond movie , but it is a good bond movie , which still makes it much better than your typical bond knock-offs . ',
#   'pos'),
#  (u'polished korean political-action film is just as good -- and bad -- as hollywood action epics . is this progress ? ',
#   'pos'),
#  (u'elling , portrayed with quiet fastidiousness by per christian ellefsen , is a truly singular character , one whose frailties are only slightly magnified versions of the ones that vex nearly everyone . ',
#   'pos'),
#  (u"denis and co-writer michele petin's impeccable screenplay penetrates with a rawness that that is both unflinching and tantalizing . lead provocatuers testud and parmentier give superlative performances",
#   'pos'),
#  (u'an absorbing trip into the minds and motivations of people under stress as well as a keen , unsentimental look at variations on the theme of motherhood . ',
#   'pos'),
#  (u'i admired it , particularly that unexpected downer of an ending . ',
#   'pos'),
#  (u'the passions aroused by the discord between old and new cultures are set against the strange , stark beauty of the mideast desert , so lovingly and perceptively filmed that you can almost taste the desiccated air . ',
#   'pos'),
#  (u'remarkably accessible and affecting . ', 'pos'),
#  (u'never mind whether you buy the stuff about barris being a cia hit man . the kooky yet shadowy vision clooney sustains throughout is daring , inventive and impressive . ',
#   'pos'),
#  (u'a triumph of art direction over narrative , but what art direction ! ',
#   'pos'),
#  (u"behan himself knew how to spin a tale and one can't help but think he'd appreciate this attempt to turn his life into art . ",
#   'pos'),
#  (u"jir\u0102\xad hubac's script is a gem . his characters are engaging , intimate and the dialogue is realistic and greatly moving . the scope of the silberstein family is large and we grow attached to their lives , full of strength , warmth and vitality . . ",
#   'pos'),
#  (u"moore's complex and important film is also , believe it or not , immensely entertaining , a david and goliath story that's still very much playing itself out . ",
#   'pos'),
#  (u"the additional storyline is interesting and entertaining , but it doesn't have the same magical quality as the beginning of the story . i like the new footage and still love the old stuff . ",
#   'pos'),
#  (u'though mama takes a bit too long to find its rhythm and a third-act plot development is somewhat melodramatic , its ribald humor and touching nostalgia are sure to please anyone in search of a jules and jim for the new millennium . ',
#   'pos'),
#  (u"you might not buy the ideas . but you'll definitely want the t-shirt . ",
#   'pos'),
#  (u'provides an intriguing window into the imagination and hermetic analysis of todd solondz . ',
#   'pos'),
#  (u'windtalkers is shapelessly gratifying , the kind of movie that invites you to pick apart its faults even as you have to admit that somehow it hit you where you live . ',
#   'pos'),
#  (u'presents an astute appraisal of middle american musical torpor and the desperate struggle to escape it . ',
#   'pos'),
#  (u'just what makes us happy , anyway ? ', 'pos'),
#  (u'a thoughtful , moving piece that faces difficult issues with honesty and beauty . ',
#   'pos'),
#  (u'one of the greatest romantic comedies of the past decade . ', 'pos'),
#  (u"you wouldn't call the good girl a date movie ( an anti-date movie is more like it ) , but when it's good , it's good and horrid . ",
#   'pos'),
#  (u"benefits from a strong performance from zhao , but it's dong jie's face you remember at the end . ",
#   'pos'),
#  (u'this is a film brimming with detail and nuance and one that speaks volumes about the ability of the human spirit to find solace in events that could easily crush it forever . ',
#   'pos'),
#  (u'the director , steven shainberg , has succeeded by focusing intently on his characters , making them quirky individuals rather than figures of fun . ',
#   'pos'),
#  (u"it ultimately stands forth as an important chronicle of the abuses of one of latin america's most oppressive regimes . ",
#   'pos'),
#  (u'the movie has a soft , percolating magic , a deadpan suspense . ', 'pos'),
#  (u'a well-made and often lovely depiction of the mysteries of friendship . ',
#   'pos'),
#  (u'using his audience as a figurative port-of-call , dong pulls his even-handed ideological ship to their dock for unloading , before he continues his longer journey still ahead . ',
#   'pos'),
#  (u' . . . understands that a generation defines its music as much as the music defines a generation . ',
#   'pos'),
#  (u'the transporter is as lively and as fun as it is unapologetically dumb',
#   'pos'),
#  (u"as a witness to several greek-american weddings -- but , happily , a victim of none -- i can testify to the comparative accuracy of ms . vardalos' memories and insights . ",
#   'pos'),
#  (u'has it ever been possible to say that williams has truly inhabited a character ? it is now . ',
#   'pos'),
#  (u"by presenting an impossible romance in an impossible world , pumpkin dares us to say why either is impossible -- which forces us to confront what's possible and what we might do to make it so . ",
#   'pos'),
#  (u'an impressive debut for first-time writer-director mark romanek , especially considering his background is in music video . ',
#   'pos'),
#  (u'an incendiary , deeply thought-provoking look at one of the most peculiar ( and peculiarly venomous ) bigotries in our increasingly frightening theocracy',
#   'pos'),
#  (u'all the performances are top notch and , once you get through the accents , all or nothing becomes an emotional , though still positive , wrench of a sit . ',
#   'pos'),
#  (u' " its successes are also tempered with elements which prove the direct antithesis of what it gets right . " ',
#   'pos'),
#  (u"it's solid and affecting and exactly as thought-provoking as it should be . ",
#   'pos'),
#  (u"this is such a dazzlingly self-assured directorial debut that it's hard to know what to praise first . ",
#   'pos'),
#  (u"parker holds true to wilde's own vision of a pure comedy with absolutely no meaning , and no desire to be anything but a polished , sophisticated entertainment that is in love with its own cleverness . ",
#   'pos'),
#  (u"m\u0102\u017anch's genuine insight makes the film's occasional overindulgence forgivable . ",
#   'pos'),
#  (u'thankfully , the film , which skirts that rapidly deteriorating line between fantasy and reality . . . takes a tongue-in-cheek attitude even as it pushes the croc hunter agenda . ',
#   'pos'),
#  (u"ultimately , the message of trouble every day seems to be that all sexual desire disrupts life's stasis . ",
#   'pos'),
#  (u"if you're like me , a sucker for a good old fashion romance and someone who shamelessly loves to eat , then mostly martha offers all the perfect ingredients to more than satisfy your appetite . ",
#   'pos'),
#  (u'the film has just enough of everything -- re-enactments , archival footage , talking-head interviews -- and the music is simply sublime . ',
#   'pos'),
#  (u'there are a few stabs at absurdist comedy . . . but mostly the humor is of the sweet , gentle and occasionally cloying kind that has become an iranian specialty . ',
#   'pos'),
#  (u'a wonderful character-based comedy . ', 'pos'),
#  (u'it would be interesting to hear from the other side , but in talk to her , the women are down for the count . ',
#   'pos'),
#  (u'an endearingly offbeat romantic comedy with a great meet-cute gimmick . ',
#   'pos'),
#  (u'the unique tug-of-war with viewer expectations is undeniable , if not a pleasure in its own right . ',
#   'pos'),
#  (u"it uses an old-time formula , it's not terribly original and it's rather messy -- but you just have to love the big , dumb , happy movie my big fat greek wedding . ",
#   'pos'),
#  (u"it's almost impossible not to be moved by the movie's depiction of sacrifice and its stirring epilogue in post-soviet russia . ",
#   'pos'),
#  (u"who knows what exactly godard is on about in this film , but his words and images don't have to add up to mesmerize you . ",
#   'pos'),
#  (u'the tone is balanced , reflective and reasonable . ', 'pos'),
#  (u'the principals in this cast are all fine , but bishop and stevenson are standouts . ',
#   'pos'),
#  (u'it could change america , not only because it is full of necessary discussion points , but because it is so accessible that it makes complex politics understandable to viewers looking for nothing but energetic entertainment . ',
#   'pos'),
#  (u"what's most striking about this largely celebratory film . . . is the sense of isolation that permeates these bastions of individuality in an ikea world . ",
#   'pos'),
#  (u" . . . if you're in a mind set for goofy comedy , the troopers will entertain with their gross outs , bawdy comedy and head games . ",
#   'pos'),
#  (u"somewhat blurred , but kinnear's performance is razor sharp . ", 'pos'),
#  (u'as a director , mr . ratliff wisely rejects the temptation to make fun of his subjects . ',
#   'pos'),
#  (u"for anyone who remembers the '60s or is interested in one man's response to stroke , ram dass : fierce grace is worth seeking out . ",
#   'pos'),
#  (u'intriguing and beautiful film , but those of you who read the book are likely to be disappointed . ',
#   'pos'),
#  (u'the new guy does have a heart . now , if it only had a brain . ', 'pos'),
#  (u"a savvy exploration of paranoia and insecurity in america's culture of fear . ",
#   'pos'),
#  (u"legendary irish writer brendan behan's memoir , borstal boy , has been given a loving screen transferral . ",
#   'pos'),
#  (u"the film's greatest asset is how much it's not just another connect-the-dots , spy-on-the-run picture . ",
#   'pos'),
#  (u'this clever caper movie has twists worthy of david mamet and is enormous fun for thinking audiences . ',
#   'pos'),
#  (u"it's one of the saddest films i have ever seen that still manages to be uplifting but not overly sentimental . ",
#   'pos'),
#  (u'morton is , as usual , brilliant . ', 'pos'),
#  (u'even with all those rough edges safely sanded down , the american insomnia is still pretty darned good . ',
#   'pos'),
#  (u"i don't know precisely what to make of steven soderbergh's full frontal , though that didn't stop me from enjoying much of it . ",
#   'pos'),
#  (u'the tug of war that ensues is as much a snapshot of modern china in microcosm as it is a crash course in movie mythology . ',
#   'pos'),
#  (u"nearly surreal , dabbling in french , this is no simple movie , and you'll be taking a risk if you choose to see it . i enjoyed the ride ( bumps and all ) , creamy depth , and ultimate theme . ",
#   'pos'),
#  (u"you could say that it's slow at times , you could say that a few of the characters act in ways that real people wouldn't , but one thing you couldn't say is that alias betty is predictable . ",
#   'pos'),
#  (u'asia authors herself as anna battista , an italian superstar and aspiring directress who just happens to be her own worst enemy . ',
#   'pos'),
#  (u"roman coppola may never become the filmmaker his dad was , but heck \xe2\x80\x93 few filmmakers will . but based on cq , i'll certainly be keeping an eye out for his next project . ",
#   'pos'),
#  (u'an amusing , breezily apolitical documentary about life on the campaign trail . ',
#   'pos'),
#  (u"high on melodrama . but it's emotionally engrossing , too , thanks to strong , credible performances from the whole cast . ",
#   'pos'),
#  (u'finally , a genre movie that delivers -- in a couple of genres , no less . ',
#   'pos'),
#  (u"it's not so much enjoyable to watch as it is enlightening to listen to new sides of a previous reality , and to visit with some of the people who were able to make an impact in the theater world . ",
#   'pos'),
#  (u'spielberg is the rare director who does not want to invite viewers to gawk at or applaud his special effects . he just wants them to be part of the action , the wallpaper of his chosen reality . here , thankfully , they are . ',
#   'pos'),
#  (u'post 9/11 the philosophical message of " personal freedom first " might not be as palatable as intended . ',
#   'pos'),
#  (u'hu and liu offer natural , matter-of-fact performances that glint with sorrow , longing and love . ',
#   'pos'),
#  (u'this bold and lyrical first feature from raja amari expands the pat notion that middle-aged women just wanna have fun into a rousing treatise of sensual empowerment . ',
#   'pos'),
#  (u"easier to respect than enthuse over , andersson's rigorous personal vision is not only distanced but distancing . ",
#   'pos'),
#  (u'girls gone wild and gone civil again', 'pos'),
#  (u' . . . tunney is allowed to build an uncommonly human character , an almost real-live girl complete with trouble and hope . ',
#   'pos'),
#  (u'while this film is not in the least surprising , it is still ultimately very satisfying . think of it as a sort of comfort food for the mind . ',
#   'pos'),
#  (u'clever , brutal and strangely soulful movie . ', 'pos'),
#  (u' . . . always remains movingly genuine . ', 'pos'),
#  (u'an intelligent fiction about learning through cultural clash . ', 'pos'),
#  (u'will grab your children by the imagination and amaze them and amuse them . ',
#   'pos'),
#  (u'a remarkable 179-minute meditation on the nature of revolution . ', 'pos'),
#  (u'those who would follow haneke on his creepy explorations . . . are rewarded by brutal , committed performances from huppert and magimel . ',
#   'pos'),
#  (u'an involving true story of a chinese actor who takes up drugs and winds up in an institution--acted mostly by the actual people involved . ',
#   'pos'),
#  (u"hands down the year's most thought-provoking film . but it pays a price for its intricate intellectual gamesmanship . ",
#   'pos'),
#  (u"it's a terrific american sports movie and dennis quaid is its athletic heart . ",
#   'pos'),
#  (u"this is such a high-energy movie where the drumming and the marching are so excellent , who cares if the story's a little weak . ",
#   'pos'),
#  (u'compelling revenge thriller , though somewhat weakened by a miscast leading lady . ',
#   'pos'),
#  (u"it's amazingly perceptive in its subtle , supportive but unsentimental look at the marks family . ",
#   'pos'),
#  (u'a whole lot foul , freaky and funny . ', 'pos'),
#  (u'family fare . ', 'pos'),
#  (u'attal mixes comedy with a serious exploration of ego and jealousy within a seemingly serene marriage . ',
#   'pos'),
#  (u'the diversity of the artists represented , both in terms of style and ethnicity , prevents the proceedings from feeling repetitious , as does the appropriately brief 40-minute running time . ',
#   'pos'),
#  (u'the pianist is a fine valedictory work for polanski , made richer by his own experiences , making his other movies somehow richer in the bargain . ',
#   'pos'),
#  (u'foster nails the role , giving a tight , focused performance illuminated by shards of feeling . ',
#   'pos'),
#  (u'even if you can\'t pronounce " gyro " correctly , you\'ll appreciate much of vardalos\' humor , which transcends ethnic boundaries . ',
#   'pos'),
#  (u"is office work really as alienating as 'bartleby' so effectively makes it ? ",
#   'pos'),
#  (u"farrell . . . thankfully manages to outshine the role and successfully plays the foil to willis's world-weary colonel . ",
#   'pos'),
#  (u"audiences conditioned to getting weepy over saucer-eyed , downy-cheeked moppets and their empathetic caretakers will probably feel emotionally cheated by the film's tart , sugar-free wit . ",
#   'pos'),
#  (u"bennett's dramatization of her personal descent into post-breakup perdition has a morbid appeal that's tough to shake . ",
#   'pos'),
#  (u'an intriguing and entertaining introduction to johnson . ', 'pos'),
#  (u"as expected , sayles' smart wordplay and clever plot contrivances are as sharp as ever , though they may be overshadowed by some strong performances . ",
#   'pos'),
#  (u'a model of what films like this should be like . ', 'pos'),
#  (u"as weber and weissman demonstrate with such insight and celebratory verve , the cockettes weren't as much about gender , sexual preference or political agitprop as they were simply a triumph of the indomitable human will to rebel , connect and create . ",
#   'pos'),
#  (u"yeah , these flicks are just that damn good . isn't it great ? ", 'pos'),
#  (u'an unbelievably fun film just a leading man away from perfection . ',
#   'pos'),
#  (u"over-the-top and a bit ostentatious , this is a movie that's got oodles of style and substance . ",
#   'pos'),
#  (u' . . . a poignant and powerful narrative that reveals that reading writing and arithmetic are not the only subjects to learn in life . ',
#   'pos'),
#  (u'nicely serves as an examination of a society in transition . ', 'pos'),
#  (u'boisterous , heartfelt comedy . ', 'pos'),
#  (u"a tender and touching drama , based on the true story of a troubled african-american's quest to come to terms with his origins , reveals the yearning we all have in our hearts for acceptance within the family circle . ",
#   'pos'),
#  (u'as a randy film about sexy people in gorgeous places being pushed and pulled ( literally and figuratively ) by desire . . . [sex and luc\u0102\xada] makes for an arousing good time . ',
#   'pos'),
#  (u'absorbing character study by andr\u0102\u0160 turpin . ', 'pos'),
#  (u"celebrated at sundance , this slight comedy of manners has winning performances and a glossy , glib charm that's hard to beat . ",
#   'pos'),
#  (u"renner's performance as dahmer is unforgettable , deeply absorbing . ",
#   'pos'),
#  (u"if no one singles out any of these performances as award-worthy , it's only because we would expect nothing less from this bunch . ",
#   'pos'),
#  (u"if you love reading and/or poetry , then by all means check it out . you'll probably love it . ",
#   'pos'),
#  (u'though of particular interest to students and enthusiast of international dance and world music , the film is designed to make viewers of all ages , cultural backgrounds and rhythmic ability want to get up and dance . ',
#   'pos'),
# ...
#   'pos'),
#  (u'noyce films it more as a shocking history lesson than as drama . ', 'pos'),
#  (u'like a south-of-the-border melrose place . ', 'pos'),
#  (u'those with an interest in new or singular sorts of film experiences will find what time is it there ? well worth the time . ',
#   'pos'),
#  (u'a wildly funny prison caper . ', 'pos'),
#  (u"huppert gives erika a persona that is so intriguing that you find yourself staring hypnotically at her , trying to understand her and wondering if she'll crack . ",
#   'pos'),
#  (u"despite what anyone believes about the goal of its makers , the show . . . represents a spectacular piece of theater , and there's no denying the talent of the creative forces behind it . ",
#   'pos'),
#  (u"you'll be left with the sensation of having just witnessed a great performance and , perhaps , give in to the urge to get on your feet and shake it . ",
#   'pos'),
#  (u'the actors are so terrific at conveying their young angst , we do indeed feel for them . ',
#   'pos'),
#  (u"the reason this picture works better than its predecessors is that myers is no longer simply spoofing the mini-mod-madness of '60s spy movies . ",
#   'pos'),
#  (u"it is a kickass , dense sci-fi action thriller hybrid that delivers and then some . i haven't seen one in so long , no wonder i didn't recognize it at first . ",
#   'pos'),
#  (u'a compelling portrait of moral emptiness', 'pos'),
#  (u'in adobo , ethnicity is not just the spice , but at the heart of more universal concerns . ',
#   'pos'),
#  (u'it is ridiculous , of course . . . but it is also refreshing , disarming , and just outright enjoyable despite its ridiculousness . ',
#   'pos'),
#  (u' . . . blade ii is more enjoyable than the original . ', 'pos'),
#  (u'a film that takes you inside the rhythms of its subject : you experience it as you watch . ',
#   'pos'),
#  (u'the movie exists for its soccer action and its fine acting . ', 'pos'),
#  (u'the movie is saved from unbearable lightness by the simplicity of the storytelling and the authenticity of the performances . ',
#   'pos'),
#  (u'the film starts out as competent but unremarkable . . . and gradually grows into something of considerable power . ',
#   'pos'),
#  (u'nothing denis has made before , like beau travil and nenette et boni , could prepare us for this gory , perverted , sex-soaked riff on the cannibal genre . ',
#   'pos'),
#  (u'reinforces the talents of screenwriter charlie kaufman , creator of adaptation and being john malkovich . ',
#   'pos'),
#  (u'greene delivers a typically solid performance in a role that is a bit of a departure from the noble characters he has played in the past , and he is matched by schweig , who carries the film on his broad , handsome shoulders . ',
#   'pos'),
#  (u'finds a way to tell a simple story , perhaps the simplest story of all , in a way that seems compelling and even original . ',
#   'pos'),
#  (u"a stunning piece of visual poetry that will , hopefully , be remembered as one of the most important stories to be told in australia's film history . ",
#   'pos'),
#  (u'this is art paying homage to art . ', 'pos'),
#  (u' . . . a joke at once flaky and resonant , lightweight and bizarrely original . ',
#   'pos'),
#  (u'invincible is a wonderful movie . ', 'pos'),
#  (u' . . . a cute and sometimes side-splittingly funny blend of legally blonde and drop dead gorgeous , starring piper perabo in what could be her breakthrough role . ',
#   'pos'),
#  (u'dazzling and sugar-sweet , a blast of shallow magnificence that only sex , scandal , and a chorus line of dangerous damsels can deliver . ',
#   'pos'),
#  (u'occasionally amateurishly made but a winsome cast and nice dialogue keeps it going . ',
#   'pos'),
#  (u"japan's premier stylist of sex and blood hits audiences with what may be his most demented film to date . ",
#   'pos'),
#  (u"culkin , who's in virtually every scene , shines as a young man who uses sarcastic lies like a shield . ",
#   'pos'),
#  (u'cuts right through the b . s . giving a big middle-fingered " shut up " to those who talk up what is nothing more than two guys beating the hell outta one another . ',
#   'pos'),
#  (u'the am-radio soundtrack and game cast -- tierney and the inimitable walken especially -- keep this unusual comedy from choking on its own conceit . ',
#   'pos'),
#  (u" . . . does such a fine job of engulfing you in its world and allying you with its characters' choices , good and ill , that its shortcomings are remembered only as an afterthought . ",
#   'pos'),
#  (u'marvelous , merry and , yes , melancholy film . ', 'pos'),
#  (u"from spiritual rebirth to bruising defeat , vincent's odyssey resonates in a profound way , comparable to the classic films of jean renoir . ",
#   'pos'),
#  (u'novak manages to capture a cruelly hilarious vein of black comedy in the situation with his cast of non-actors and a gritty , no-budget approach . ',
#   'pos'),
#  (u'insomnia is involving . still , i thought it could have been more . ',
#   'pos'),
#  (u"there was time on that second round to see the subtleties of ramsay's portrait of grief . ",
#   'pos'),
#  (u'we can see the wheels turning , and we might resent it sometimes , but this is still a nice little picture , made by bright and friendly souls with a lot of good cheer . ',
#   'pos'),
#  (u'a comprehensive and provocative film -- one that pushes the boundaries of biography , and challenges its audience . ',
#   'pos'),
#  (u'the way coppola professes his love for movies -- both colorful pop junk and the classics that unequivocally qualify as art -- is giddily entertaining . ',
#   'pos'),
#  (u'a modest masterpiece . ', 'pos'),
#  (u'a worthwhile way to spend two hours . ', 'pos'),
#  (u"francophiles will snicker knowingly and you'll want to slap them . ",
#   'pos'),
#  (u'sensitive , insightful and beautifully rendered film . one of the best of the year . ',
#   'pos'),
#  (u'a love for films shines through each frame and the era is recreated with obvious affection , scored to perfection with some tasty boogaloo beats . ',
#   'pos'),
#  (u'throwing caution to the wind with an invitation to the hedonist in us all , nair has constructed this motion picture in such a way that even the most cynical curmudgeon with find himself or herself smiling at one time or another . ',
#   'pos'),
#  (u"makes an aborbing if arguable case for the man's greatness . ", 'pos'),
#  (u'an endlessly fascinating , landmark movie that is as bold as anything the cinema has seen in years . ',
#   'pos'),
#  (u' . . . a haunting vision , with images that seem more like disturbing hallucinations . ',
#   'pos'),
#  (u"they crush each other under cars , throw each other out windows , electrocute and dismember their victims in full consciousness . and we don't avert our eyes for a moment . ",
#   'pos'),
#  (u'it is not a mass-market entertainment but an uncompromising attempt by one artist to think about another . ',
#   'pos'),
#  (u"frailty isn't as gory or explicit . but in its child-centered , claustrophobic context , it can be just as frightening and disturbing -- even punishing . ",
#   'pos'),
#  (u'mixes likeable personalities , inventive photography and cutting , and wall-to-wall toe-tapping music to paint a picture of a subculture that is at once exhilarating , silly , perverse , hopeful and always fun . ',
#   'pos'),
#  (u'the long-range appeal of " minority report " should transcend any awards it bags . this is one for the ages . ',
#   'pos'),
#  (u"[a] superbly controlled , passionate adaptation of graham greene's 1955 novel . ",
#   'pos'),
#  (u'much monkeyfun for all . ', 'pos'),
#  (u"an enchanting film that presents an audacious tour of the past and takes within its warm embrace the bounties of cultural artifacts inside st . petersburg's hermitage museum . ",
#   'pos'),
#  (u"[hawn's character]is so bluntly written , without a trace of sentimentality , and so blisteringly defined , that every other character seems overlooked and underwritten . ",
#   'pos'),
#  (u'the heightened symmetry of this new/old cinema paradiso makes the film a fuller experience , like an old friend haunted by the exigencies of time . ',
#   'pos'),
#  (u"the powers team has fashioned a comedy with more laughs than many , no question . but this time there's some mold on the gold . ",
#   'pos'),
#  (u'while surprisingly sincere , this average little story is adorned with some awesome action photography and surfing . ',
#   'pos'),
#  (u'it is far from the worst , thanks to the topical issues it raises , the performances of stewart and hardy , and that essential feature -- a decent full-on space battle . ',
#   'pos'),
#  (u'a film that is a portrait of grace in an imperfect world . ', 'pos'),
#  (u'a pleasurably jacked-up piece of action moviemaking . ', 'pos'),
#  (u'nicolas philibert observes life inside a one-room schoolhouse in northern france in his documentary to be and to have , easily one of the best films of the year . ',
#   'pos'),
#  (u'a perverse little truffle , dainty psychological terror on the outside with a creamy filling of familial jealousy and unrepentant domestic psychopathy . ',
#   'pos'),
#  (u'this ecologically minded , wildlife friendly film teaches good ethics while entertaining with its unconventionally wacky but loving family',
#   'pos'),
#  (u'an enjoyably half-wit remake of the venerable italian comedy big deal on madonna street . ',
#   'pos'),
#  (u'it takes this never-ending confusion and hatred , puts a human face on it , evokes shame among all who are party to it and even promotes understanding . ',
#   'pos'),
#  (u"reign of fire may be little more than another platter of reheated aliens , but it's still pretty tasty . ",
#   'pos'),
#  (u'there are times when a rumor of angels plays like an extended episode of touched by an angel -- a little too much dancing , a few too many weeping scenes -- but i liked its heart and its spirit . ',
#   'pos'),
#  (u"two hours of melodramatic musical married to two hours of underdog sports intrigue , if the picture also shares the weaknesses of both genres , more's the pity . ",
#   'pos'),
#  (u'this cheery , down-to-earth film is warm with the cozy feeling of relaxing around old friends . ',
#   'pos'),
#  (u'thrilling , provocative and darkly funny , this timely sci-fi mystery works on so many different levels that it not only invites , it demands repeated viewings . ',
#   'pos'),
#  (u"a tale of horror and revenge that is nearly perfect in its relentless descent to the depths of one man's tortured soul . ",
#   'pos'),
#  (u"an epic of grandeur and scale that's been decades gone from the popcorn pushing sound stages of hollywood . ",
#   'pos'),
#  (u"genuinely touching because it's realistic about all kinds of love . ",
#   'pos'),
#  (u'lauren ambrose comes alive under the attention from two strangers in town - with honest performances and realistic interaction between the characters , this is a coming-of-age story with a twist . ',
#   'pos'),
#  (u'there has been much puzzlement among critics about what the election symbolizes . i believe the message is in the messenger : the agent is a woman . ',
#   'pos'),
#  (u'an enjoyable film for the family , amusing and cute for both adults and kids . ',
#   'pos'),
#  (u' " the mothman prophecies " is a difficult film to shake from your conscience when night falls . ',
#   'pos'),
#  (u'the second chapter of the harry potter series is even more magical than the first and simply the best family film of the year . ',
#   'pos'),
#  (u"more honest about alzheimer's disease , i think , than iris . ", 'pos'),
#  (u'the acting alone is worth the price of admission . ', 'pos'),
#  (u'an excellent romp that boasts both a heart and a mind . ', 'pos'),
#  (u"interacting eyeball-to-eyeball and toe-to-toe , hopkins and norton are a winning combination -- but fiennes steals 'red dragon' right from under their noses . ",
#   'pos'),
#  (u'this is a terrific character study , a probe into the life of a complex man . ',
#   'pos'),
#  (u'impresses you with its open-endedness and surprises . ', 'pos'),
#  (u"this isn't a narrative film -- i don't know if it's possible to make a narrative film about september 11th , though i'm sure some will try -- but it's as close as anyone has dared to come . ",
#   'pos'),
#  (u'my oh my , is this an invigorating , electric movie . ', 'pos'),
#  (u'the two leads chomp considerably more scenery with their acting than fire-breathing monsters barbecue with their breath . . . ',
#   'pos'),
#  (u'cedar takes a very open-minded approach to this sensitive material , showing impressive control , both visually and in the writing . ',
#   'pos'),
#  (u'never once predictable . ', 'pos'),
#  (u'biggie and tupac is so single-mindedly daring , it puts far more polished documentaries to shame . ',
#   'pos'),
#  (u'so many documentaries like this presuppose religious bigotry or zealous nuttiness of its antagonists , but family fundamentals displays a rare gift for unflinching impartiality . ',
#   'pos'),
#  (u'the cast is uniformly excellent and relaxed . ', 'pos'),
#  (u"after making several adaptations of other writers' work , armenian-canadian director atom egoyan broached an original treatment of a deeply personal subject . ",
#   'pos'),
#  (u'the film is painfully authentic , and the performances of the young players are utterly convincing . ',
#   'pos'),
#  (u"if it seems like a minor miracle that its septuagenarian star is young enough to be the nonagenarian filmmaker's son , more incredible still are the clear-eyed boldness and quiet irony with which actor and director take on life's urgent questions . ",
#   'pos'),
#  (u'a candid and often fascinating documentary about a pentecostal church in dallas that assembles an elaborate haunted house each year to scare teenagers into attending services . ',
#   'pos'),
#  (u'fans of the animated wildlife adventure show will be in warthog heaven ; others need not necessarily apply . ',
#   'pos'),
#  (u'without resorting to hyperbole , i can state that kissing jessica stein may be the best same-sex romance i have seen . ',
#   'pos'),
#  (u'nolan bravely treads where few american films dare to delve -- into the world of ambivalence and ambiguity . . . ',
#   'pos'),
#  (u"unlike the nauseating fictions peddled by such 'have-yourself-a-happy-little-holocaust' movies as life is beautiful and jakob the liar , the grey zone is honest enough to deny the possibility of hope in auschwitz . ",
#   'pos'),
#  (u'a potent allegorical love story . ', 'pos'),
#  (u'even those who would like to dismiss the film outright should find much to mull and debate . ',
#   'pos'),
#  (u'this is cool , slick stuff , ready to quench the thirst of an audience that misses the summer blockbusters . ',
#   'pos'),
#  (u'the movie is full of fine performances , led by josef bierbichler as brecht and monica bleibtreu as helene weigel , his wife . ',
#   'pos'),
#  (u'a captivating cross-cultural comedy of manners . ', 'pos'),
#  (u'andy garcia enjoys one of his richest roles in years and mick jagger gives his best movie performance since , well , performance . ',
#   'pos'),
#  (u"the movie isn't always easy to look at . but if it is indeed a duty of art to reflect life , than leigh has created a masterful piece of artistry right here . ",
#   'pos'),
#  (u"it's [ricci's] best work yet , this girl-woman who sincerely believes she can thwart the world's misery with blind good will . ",
#   'pos'),
#  (u'highlights are the terrific performances by christopher plummer , as the prime villain , and nathan lane as vincent crummles , the eccentric theater company manager . ',
#   'pos'),
#  (u'[howard] so good as leon barlow . . . that he hardly seems to be acting . ',
#   'pos'),
#  (u'an uplifting , near-masterpiece . ', 'pos'),
#  (u'superior genre storytelling , which gets under our skin simply by crossing the nuclear line . ',
#   'pos'),
#  (u'by taking entertainment tonight subject matter and giving it humor and poignancy , auto focus becomes both gut-bustingly funny and crushingly depressing . ',
#   'pos'),
#  (u"it's a bittersweet and lyrical mix of elements . ", 'pos'),
#  (u'subversive , meditative , clinical and poetic , the piano teacher is a daring work of genius . ',
#   'pos'),
#  ...]

# %% [markdown]
# # Lesson 19 - Sentiment Analysis Module

# %% [markdown]
# Now that we've got a more reliable classifier, we're ready to push forward. Here, we cover how we can convert our classifier training script to an actual sentiment analysis module.
#
# We pickle everything, and create a new sentiment function, which, with a parameter of "Text" will perform a classification and return the result.
#
# By pickling everything, we find that we can load this module in seconds, rather than the prior 3-5 minutes. After this, we're ready to apply this module to a live Twitter stream.

# %%
# a lot of pickling - worth going back to

# %% [markdown]
# # Lesson 20 - Twitter Sentiment Analysis

# %% [markdown]
# Let's do a live test with Twitter!

# %% [markdown]
# # Lesson 21 - Graphing Live Twitter Sentiment

# %% [markdown]
# Note! There is a section on how to do live updating graphs on pythonprogramming.net
